# %% [markdown]
# # Initialization

# %%
import os 

# %load_ext autoreload
# %autoreload 2

os.chdir("/Users/antoineluciano/Documents/Recherche/permABC_new/permABC")


from vanilla import abc_vanilla, perm_abc_vanilla
from smc import abc_smc, perm_abc_smc
from over_sampling import perm_abc_smc_os
from under_matching import perm_abc_smc_um  
from kernels import KernelTruncatedRW
from distances import optimal_index_distance
from models.Gaussian_with_correlated_params import GaussianWithCorrelatedParams
from utils import Theta
from jax import random
import numpy as np
import jax.numpy as jnp
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
key = random.PRNGKey(0)
key, key_theta, key_yobs = random.split(key, 3)
K = 10
n_obs = 20
sigma_mu, sigma_alpha = 10., 10.
model = GaussianWithCorrelatedParams(K = K, n_obs = n_obs, sigma_mu = sigma_mu, sigma_alpha = sigma_alpha)
true_theta = model.prior_generator(key_theta, 1)
true_theta.loc[0,0,0] = 0.
true_theta.glob[0,0] = 0.
y_obs = model.data_generator(key_yobs, true_theta)
print("True theta: ", true_theta)
# Out:
# True theta:  Theta(loc=array([[[  0.       ],
#         [ 21.891056 ],
#         [ -1.6292391],
#         [ -0.574461 ],
#         [  4.99312  ],
#         [  1.0972358],
#         [-16.793629 ],
#         [ -6.226515 ],
#         [ -2.968302 ],
#         [  7.779063 ]]], dtype=float32), glob=array([[0.]], dtype=float32))

# %% [markdown]
# # Vanilla

# %% [markdown]
# ## permABC

# %%
key, subkey = random.split(key)
N_points = 100000
zs_perm, thetas_perm, dists_perm, n_sim_perm = perm_abc_vanilla(key = subkey, model = model, n_points = N_points, epsilon = jnp.inf, y_obs = y_obs)
epsilon = np.quantile(dists_perm, 0.01)
index = np.where(dists_perm < epsilon)[0]
mus_perm_van = thetas_perm.loc[index].squeeze()
betas_perm_van = thetas_perm.glob[index].squeeze()
print(epsilon)

N = 1000
# Out:
# Performing full optimal assignment (no prior indices).
# 11.692900009155274

# %% [markdown]
# ## ABC

# %%
key, subkey = random.split(key)
zs_van, thetas_van, dists_van, n_sim_van = abc_vanilla(key = subkey, model = model, n_points = N, epsilon = epsilon, y_obs = y_obs)
mus_van = thetas_van.loc.squeeze()
betas_van = thetas_van.glob.squeeze()

# %% [markdown]
# # SMC

# %% [markdown]
# ## ABC

# %%
kernel = KernelTruncatedRW 
key, subkey = random.split(key)
# epsilon = 0.
# N = 1000
out_smc = abc_smc(key = subkey, model = model, n_particles= N, epsilon_target= 0, y_obs = y_obs, kernel = kernel, verbose =2, N_sim_max= N*M*K, stopping_accept_rate= 0.)

mus_smc = out_smc['Thetas'][-1].loc.squeeze()
betas_smc = out_smc['Thetas'][-1].glob.squeeze()
n_sim_smc = np.sum(out_smc["N_sim"])
# Out:
# Weights distance: min = 0.0936, max = 0.107
# Iteration 0: Epsilon = inf, ESS = 1000 Acc. rate = 100% Numb. unique particles = 1000
# 1. Forward kernel:
# Sample proposal: loc min = -6.6e+01 max 6.4e+01 mean = -0.11 glob min = -4.2e+01 max = 5.5e+01 mean = 0.16
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.034
# Prior ratio: min = -42.1, max = 4.08, mean = -11.0
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.58% Rejection ABC = 38.84% Rejection MH = 57.58%
# Iteration 1: Espilon = 1321.0296, ESS = 950 Acc. rate = 3.58% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0947, max = 0.106
# After update weights update: 950 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 19500/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -7.7e+01 max 6.8e+01 mean = 0.17 glob min = -4.5e+01 max = 4.8e+01 mean = 1.4
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0399
# Prior ratio: min = -44.2, max = 3.41, mean = -10.7
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 4.21% Rejection ABC = 49.78% Rejection MH = 46.01%
# Iteration 2: Espilon = 1058.6281, ESS = 902 Acc. rate = 4.21% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0942, max = 0.105
# After update weights update: 902 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 28520/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.7e+01 max 6.4e+01 mean = 0.11 glob min = -5.3e+01 max = 4.8e+01 mean = 0.83
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0365
# Prior ratio: min = -37.6, max = 4.21, mean = -10.3
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.39% Rejection ABC = 55.96% Rejection MH = 40.65%
# Iteration 3: Espilon = 919.8124, ESS = 856 Acc. rate = 3.39% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0944, max = 0.104
# After update weights update: 856 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 37080/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.7e+01 max 6.1e+01 mean = 0.18 glob min = -3.8e+01 max = 4.2e+01 mean = 0.59
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0377
# Prior ratio: min = -32.3, max = 3.6, mean = -10.6
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.57% Rejection ABC = 63.59% Rejection MH = 32.84%
# Iteration 4: Espilon = 832.3613, ESS = 813 Acc. rate = 3.57% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0943, max = 0.104
# After update weights update: 812 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 45210/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.6e+01 max 6.5e+01 mean = 0.02 glob min = -3.9e+01 max = 4.2e+01 mean = 0.12
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0372
# Prior ratio: min = -30.9, max = 5.8, mean = -9.89
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.63% Rejection ABC = 65.63% Rejection MH = 30.74%
# Iteration 5: Espilon = 759.0256, ESS = 771 Acc. rate = 3.63% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0941, max = 0.104
# After update weights update: 771 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 52920/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.5e+01 max 6.4e+01 mean = 0.24 glob min = -3.9e+01 max = 4.2e+01 mean = 0.27
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0403
# Prior ratio: min = -38.1, max = 3.38, mean = -9.89
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.96% Rejection ABC = 67.35% Rejection MH = 28.69%
# Iteration 6: Espilon = 715.0950, ESS = 732 Acc. rate = 3.96% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.094, max = 0.103
# After update weights update: 729 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 60240/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.2e+01 max 6e+01 mean = -0.086 glob min = -3.6e+01 max = 3.9e+01 mean = 0.37
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0218
# Prior ratio: min = -40.3, max = 3.72, mean = -9.97
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.02% Rejection ABC = 74.86% Rejection MH = 23.12%
# Iteration 7: Espilon = 678.8076, ESS = 692 Acc. rate = 2.02% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0946, max = 0.103
# After update weights update: 691 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 67160/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.3e+01 max 6.1e+01 mean = 0.41 glob min = -3.9e+01 max = 3.4e+01 mean = 1.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0275
# Prior ratio: min = -33.3, max = 3.67, mean = -9.94
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.35% Rejection ABC = 74.39% Rejection MH = 22.26%
# Iteration 8: Espilon = 645.3857, ESS = 656 Acc. rate = 3.35% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0948, max = 0.103
# After update weights update: 656 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 73720/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.6e+01 max 6.9e+01 mean = 0.14 glob min = -3.7e+01 max = 4.7e+01 mean = 0.52
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0427
# Prior ratio: min = -31.4, max = 4.48, mean = -9.37
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 4.17% Rejection ABC = 73.68% Rejection MH = 22.15%
# Iteration 9: Espilon = 619.3176, ESS = 623 Acc. rate = 4.17% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0945, max = 0.103
# After update weights update: 622 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 79950/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.9e+01 max 6.5e+01 mean = 0.049 glob min = -3e+01 max = 3.7e+01 mean = -0.055
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0491
# Prior ratio: min = -31.3, max = 6.0, mean = -9.17
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 5.25% Rejection ABC = 73.73% Rejection MH = 21.02%
# Iteration 10: Espilon = 589.0391, ESS = 590 Acc. rate = 5.25% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.095, max = 0.103
# After update weights update: 590 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 85850/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6e+01 max 5.2e+01 mean = -0.059 glob min = -3.8e+01 max = 3.3e+01 mean = 0.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0367
# Prior ratio: min = -30.7, max = 3.71, mean = -9.22
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.93% Rejection ABC = 74.29% Rejection MH = 21.79%
# Iteration 11: Espilon = 567.3981, ESS = 560 Acc. rate = 3.93% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0954, max = 0.103
# After update weights update: 560 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 91450/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.1e+01 max 5.6e+01 mean = 0.17 glob min = -2.5e+01 max = 3.3e+01 mean = 0.74
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0327
# Prior ratio: min = -34.1, max = 2.76, mean = -9.25
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.01% Rejection ABC = 76.50% Rejection MH = 20.49%
# Iteration 12: Espilon = 545.6155, ESS = 532 Acc. rate = 3.01% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0958, max = 0.104
# After update weights update: 531 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 96770/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -7.3e+01 max 5.5e+01 mean = 0.28 glob min = -2.5e+01 max = 2.8e+01 mean = 0.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0301
# Prior ratio: min = -33.6, max = 5.26, mean = -8.56
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.37% Rejection ABC = 80.16% Rejection MH = 16.47%
# Iteration 13: Espilon = 531.2691, ESS = 504 Acc. rate = 3.37% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# f) Update weights distance: Weights distance: min = 0.0958, max = 0.104
# After update weights update: 503 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 101810/1000000
#
# Resampling... 477 unique particles left
# 1. Forward kernel:
# Sample proposal: loc min = -6.2e+01 max 5.6e+01 mean = 0.13 glob min = -2.7e+01 max = 3.1e+01 mean = 0.62
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0294
# Prior ratio: min = -34.5, max = 3.56, mean = -9.06
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.40% Rejection ABC = 80.10% Rejection MH = 16.50%
# Iteration 14: Espilon = 509.9006, ESS = 1000 Acc. rate = 3.40% Uniqueness rate particules = 51.1% Uniqueness rate components = 51.1% Global parameters uniqueness rate = 51.1%
# f) Update weights distance: Weights distance: min = 0.0957, max = 0.105
# After update weights update: 990 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 111810/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.2e+01 max 6.5e+01 mean = 0.015 glob min = -3.5e+01 max = 3.1e+01 mean = 0.86
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0242
# Prior ratio: min = -54.5, max = 3.04, mean = -8.52
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.23% Rejection ABC = 80.11% Rejection MH = 17.66%
# Iteration 15: Espilon = 488.8723, ESS = 940 Acc. rate = 2.23% Uniqueness rate particules = 52.9% Uniqueness rate components = 52.9% Global parameters uniqueness rate = 52.9%
# f) Update weights distance: Weights distance: min = 0.0957, max = 0.105
# After update weights update: 931 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 121210/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6e+01 max 5.7e+01 mean = 0.25 glob min = -2.5e+01 max = 2.6e+01 mean = 0.91
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0281
# Prior ratio: min = -26.0, max = 3.29, mean = -8.49
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.71% Rejection ABC = 80.34% Rejection MH = 16.95%
# Iteration 16: Espilon = 476.3535, ESS = 885 Acc. rate = 2.71% Uniqueness rate particules = 54.7% Uniqueness rate components = 54.7% Global parameters uniqueness rate = 54.7%
# f) Update weights distance: Weights distance: min = 0.0954, max = 0.105
# After update weights update: 883 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 130060/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.3e+01 max 5.5e+01 mean = 0.31 glob min = -2.6e+01 max = 2.9e+01 mean = 0.51
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0274
# Prior ratio: min = -26.5, max = 3.57, mean = -8.21
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.38% Rejection ABC = 79.02% Rejection MH = 18.59%
# Iteration 17: Espilon = 461.4961, ESS = 839 Acc. rate = 2.38% Uniqueness rate particules = 56.4% Uniqueness rate components = 56.4% Global parameters uniqueness rate = 56.4%
# f) Update weights distance: Weights distance: min = 0.0954, max = 0.105
# After update weights update: 839 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 138450/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6e+01 max 6.3e+01 mean = -0.058 glob min = -2.3e+01 max = 3.2e+01 mean = 0.93
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0265
# Prior ratio: min = -29.1, max = 3.92, mean = -8.74
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.51% Rejection ABC = 81.68% Rejection MH = 15.81%
# Iteration 18: Espilon = 447.5223, ESS = 797 Acc. rate = 2.51% Uniqueness rate particules = 57.8% Uniqueness rate components = 57.8% Global parameters uniqueness rate = 57.8%
# f) Update weights distance: Weights distance: min = 0.096, max = 0.105
# After update weights update: 797 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 146420/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.5e+01 max 6.2e+01 mean = 0.18 glob min = -2.6e+01 max = 2.9e+01 mean = 0.42
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0281
# Prior ratio: min = -30.7, max = 2.87, mean = -8.21
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.77% Rejection ABC = 84.04% Rejection MH = 13.19%
# Iteration 19: Espilon = 431.5172, ESS = 758 Acc. rate = 2.77% Uniqueness rate particules = 59.4% Uniqueness rate components = 59.4% Global parameters uniqueness rate = 59.4%
# f) Update weights distance: Weights distance: min = 0.096, max = 0.104
# After update weights update: 751 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 154000/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.4e+01 max 5e+01 mean = 0.18 glob min = -2.1e+01 max = 2.7e+01 mean = 0.78
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0346
# Prior ratio: min = -32.6, max = 3.37, mean = -8.14
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.09% Rejection ABC = 82.61% Rejection MH = 14.31%
# Iteration 20: Espilon = 423.4028, ESS = 713 Acc. rate = 3.09% Uniqueness rate particules = 61.0% Uniqueness rate components = 61.0% Global parameters uniqueness rate = 61.0%
# f) Update weights distance: Weights distance: min = 0.0953, max = 0.105
# After update weights update: 709 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 161130/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.4e+01 max 5.5e+01 mean = 0.17 glob min = -2.3e+01 max = 2.8e+01 mean = 0.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0225
# Prior ratio: min = -28.1, max = 6.28, mean = -8.05
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.53% Rejection ABC = 84.84% Rejection MH = 12.63%
# Iteration 21: Espilon = 414.2146, ESS = 673 Acc. rate = 2.53% Uniqueness rate particules = 62.4% Uniqueness rate components = 62.4% Global parameters uniqueness rate = 62.4%
# f) Update weights distance: Weights distance: min = 0.0956, max = 0.104
# After update weights update: 671 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 167860/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.6e+01 max 6.1e+01 mean = -0.054 glob min = -3e+01 max = 2.7e+01 mean = 0.59
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0253
# Prior ratio: min = -25.9, max = 3.23, mean = -7.99
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.04% Rejection ABC = 85.87% Rejection MH = 12.09%
# Iteration 22: Espilon = 398.1521, ESS = 637 Acc. rate = 2.04% Uniqueness rate particules = 63.5% Uniqueness rate components = 63.5% Global parameters uniqueness rate = 63.5%
# f) Update weights distance: Weights distance: min = 0.0961, max = 0.105
# After update weights update: 630 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 174230/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.5e+01 max 6.2e+01 mean = 0.24 glob min = -2.4e+01 max = 2.7e+01 mean = 0.48
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0256
# Prior ratio: min = -33.0, max = 3.6, mean = -7.86
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.51% Rejection ABC = 85.12% Rejection MH = 12.37%
# Iteration 23: Espilon = 389.3542, ESS = 598 Acc. rate = 2.51% Uniqueness rate particules = 64.3% Uniqueness rate components = 64.3% Global parameters uniqueness rate = 64.3%
# f) Update weights distance: Weights distance: min = 0.0962, max = 0.105
# After update weights update: 594 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 180210/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6.2e+01 max 5.3e+01 mean = 0.22 glob min = -2.3e+01 max = 2.8e+01 mean = 0.9
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0221
# Prior ratio: min = -30.5, max = 3.37, mean = -7.51
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.66% Rejection ABC = 86.35% Rejection MH = 10.99%
# Iteration 24: Espilon = 381.7965, ESS = 564 Acc. rate = 2.66% Uniqueness rate particules = 65.1% Uniqueness rate components = 65.1% Global parameters uniqueness rate = 65.1%
# f) Update weights distance: Weights distance: min = 0.0962, max = 0.105
# After update weights update: 561 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 185850/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.3e+01 max 5.4e+01 mean = 0.15 glob min = -2.3e+01 max = 2e+01 mean = 0.95
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0251
# Prior ratio: min = -28.4, max = 2.79, mean = -7.54
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.63% Rejection ABC = 86.12% Rejection MH = 11.26%
# Iteration 25: Espilon = 369.0008, ESS = 533 Acc. rate = 2.63% Uniqueness rate particules = 65.8% Uniqueness rate components = 65.8% Global parameters uniqueness rate = 65.8%
# f) Update weights distance: Weights distance: min = 0.0962, max = 0.105
# After update weights update: 528 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 191180/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.7e+01 max 5.8e+01 mean = -0.022 glob min = -2.3e+01 max = 1.9e+01 mean = 0.55
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0259
# Prior ratio: min = -27.1, max = 2.29, mean = -7.61
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.79% Rejection ABC = 86.63% Rejection MH = 10.58%
# Iteration 26: Espilon = 361.6540, ESS = 501 Acc. rate = 2.79% Uniqueness rate particules = 66.7% Uniqueness rate components = 66.7% Global parameters uniqueness rate = 66.7%
# f) Update weights distance: Weights distance: min = 0.096, max = 0.106
# After update weights update: 491 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 196190/1000000
#
# Resampling... 349 unique particles left
# 1. Forward kernel:
# Sample proposal: loc min = -5.9e+01 max 6.3e+01 mean = 0.59 glob min = -2.1e+01 max = 2.9e+01 mean = 0.97
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0332
# Prior ratio: min = -29.9, max = 6.06, mean = -7.56
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 3.00% Rejection ABC = 87.10% Rejection MH = 9.90%
# Iteration 27: Espilon = 354.5492, ESS = 1000 Acc. rate = 3.00% Uniqueness rate particules = 37.9% Uniqueness rate components = 37.9% Global parameters uniqueness rate = 37.9%
# f) Update weights distance: Weights distance: min = 0.0952, max = 0.11
# After update weights update: 940 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 206190/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.9e+01 max 6e+01 mean = 0.31 glob min = -2.8e+01 max = 2.4e+01 mean = 0.87
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0258
# Prior ratio: min = -26.6, max = 2.03, mean = -7.55
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.69% Rejection ABC = 84.43% Rejection MH = 12.88%
# Iteration 28: Espilon = 348.8227, ESS = 893 Acc. rate = 2.69% Uniqueness rate particules = 40.0% Uniqueness rate components = 40.0% Global parameters uniqueness rate = 40.0%
# f) Update weights distance: Weights distance: min = 0.0945, max = 0.111
# After update weights update: 883 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 215120/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5e+01 max 5.9e+01 mean = 0.18 glob min = -2.2e+01 max = 2.6e+01 mean = 0.91
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0301
# Prior ratio: min = -28.5, max = 2.99, mean = -7.35
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.98% Rejection ABC = 86.90% Rejection MH = 10.12%
# Iteration 29: Espilon = 342.4697, ESS = 840 Acc. rate = 2.98% Uniqueness rate particules = 42.0% Uniqueness rate components = 42.0% Global parameters uniqueness rate = 42.0%
# f) Update weights distance: Weights distance: min = 0.0956, max = 0.111
# After update weights update: 836 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 223520/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.9e+01 max 5.8e+01 mean = 0.32 glob min = -2.4e+01 max = 2.1e+01 mean = 0.56
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0208
# Prior ratio: min = -32.1, max = 5.4, mean = -7.15
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 1.88% Rejection ABC = 88.60% Rejection MH = 9.52%
# Iteration 30: Espilon = 336.9322, ESS = 798 Acc. rate = 1.88% Uniqueness rate particules = 43.4% Uniqueness rate components = 43.4% Global parameters uniqueness rate = 43.4%
# f) Update weights distance: Weights distance: min = 0.097, max = 0.111
# After update weights update: 786 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 231500/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.1e+01 max 4.7e+01 mean = 0.39 glob min = -2.7e+01 max = 2.5e+01 mean = 0.55
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0258
# Prior ratio: min = -22.9, max = 3.78, mean = -7.33
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.54% Rejection ABC = 88.22% Rejection MH = 9.24%
# Iteration 31: Espilon = 332.8946, ESS = 747 Acc. rate = 2.54% Uniqueness rate particules = 45.2% Uniqueness rate components = 45.2% Global parameters uniqueness rate = 45.2%
# f) Update weights distance: Weights distance: min = 0.0963, max = 0.11
# After update weights update: 747 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 238970/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -6e+01 max 5.9e+01 mean = 0.46 glob min = -2e+01 max = 2e+01 mean = 0.69
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0277
# Prior ratio: min = -23.1, max = 3.72, mean = -7.05
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.25% Rejection ABC = 87.04% Rejection MH = 10.70%
# Iteration 32: Espilon = 324.0036, ESS = 710 Acc. rate = 2.25% Uniqueness rate particules = 46.5% Uniqueness rate components = 46.5% Global parameters uniqueness rate = 46.5%
# f) Update weights distance: Weights distance: min = 0.0954, max = 0.11
# After update weights update: 704 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 246070/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.3e+01 max 5.2e+01 mean = 0.43 glob min = -2.1e+01 max = 2.5e+01 mean = 0.55
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.024
# Prior ratio: min = -28.7, max = 2.55, mean = -7.25
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.54% Rejection ABC = 87.44% Rejection MH = 10.01%
# Iteration 33: Espilon = 318.5572, ESS = 669 Acc. rate = 2.54% Uniqueness rate particules = 47.8% Uniqueness rate components = 47.8% Global parameters uniqueness rate = 47.8%
# f) Update weights distance: Weights distance: min = 0.0951, max = 0.11
# After update weights update: 654 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 252760/1000000
#
# 1. Forward kernel:
# Sample proposal: loc min = -5.8e+01 max 6.2e+01 mean = 0.26 glob min = -2e+01 max = 2.5e+01 mean = 0.32
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0156
# Prior ratio: min = -26.4, max = 2.62, mean = -7.18
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 1.45% Rejection ABC = 87.94% Rejection MH = 10.61%
# Iteration 34: Espilon = 313.8849, ESS = 622 Acc. rate = 1.45% Uniqueness rate particules = 48.6% Uniqueness rate components = 48.6% Global parameters uniqueness rate = 48.6%
# f) Update weights distance: Weights distance: min = 0.0948, max = 0.109
# After update weights update: 622 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 258980/1000000
# Acceptance rate is too low, stopping the algorithm for epsilon =  313.88494873046875
#
# Resampling... 338 unique particles left
# 1. Forward kernel:
# Sample proposal: loc min = -5.2e+01 max 5.1e+01 mean = 0.38 glob min = -2.1e+01 max = 2.6e+01 mean = 0.42
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0185
# Prior ratio: min = -26.0, max = 2.05, mean = -7.13
# Kernel ratio: min = 0.0, max = 0.0, mean = 0.0
# 3. Results: Acceptance = 2.40% Rejection ABC = 87.90% Rejection MH = 9.70%
# Iteration 35: Espilon = 313.8849, ESS = 1000 Acc. rate = 2.40% Uniqueness rate particules = 36.0% Uniqueness rate components = 36.0% Global parameters uniqueness rate = 36.0%
# f) Update weights distance: Weights distance: min = 0.0924, max = 0.106
# After update weights update: 937 particles alive (0 particles killed)
# NUMBER OF SIMULATIONS 268980/1000000

# %%
key, key_theta, key_sim = random.split(key, 3)
thetas = model.prior_generator(key_theta, N)
key, key_sim = random.split(key, 2)
zs = model.data_generator(key_sim, thetas)
dists = model.distance(zs, y_obs)
dists_perm, _, _, _= optimal_index_distance(model, zs, y_obs, 0)
print("ABC dist: min = {}, max = {}, mean = {}".format(np.min(dists), np.max(dists), np.mean(dists)))
print("Perm dist: min = {}, max = {}, mean = {}".format(np.min(dists_perm), np.max(dists_perm), np.mean(dists_perm)))
# Out:
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# ABC dist: min = 262.0743408203125, max = 4554.1357421875, mean = 1522.1527099609375
# Perm dist: min = 16.749174118041992, max = 1314.7113037109375, mean = 266.2978820800781

# %% [markdown]
# ## perm

# %%
N

# %%
key, subkey = random.split(key)
kernel = KernelTruncatedRW
N = 1000
out_perm_smc = perm_abc_smc(key = subkey, model = model, n_particles= N, epsilon_target= 0, y_obs = y_obs, kernel = kernel, verbose = 2, update_weights_distance=False, Final_iteration=20)
x
mus_perm_smc = out_perm_smc["Thetas"][-1].loc.squeeze()
betas_perm_smc = out_perm_smc["Thetas"][-1].glob.squeeze()
n_sim_perm_smc = np.sum(out_perm_smc["N_sim"])
# Out:
# Weights distance: min = 0.0939, max = 0.105
# Performing full optimal assignment (no prior indices).
# Weights distance: min = 0.0847, max = 0.127
# Iteration 0: Epsilon = inf, ESS = 1000 Acc. rate = 100% Numb. unique particles = 1000
# a) Update Epsilon: new epsilon = 9.17e+02
# b) Update weights: Old ESS = 1000 New ESS = 950 (5.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.5e+01 max 5.3e+01 mean = -0.068 glob min = -5.6e+01 max = 5.3e+01 mean = 0.5
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.261
# Prior ratio: min = -20.8, max = 5.01, mean = -2.9
# Kernel ratio: min = -5.17, max = 3.73, mean = -0.0565
# 3. Results: Acceptance = 26.63% Rejection ABC = 16.63% Rejection MH = 56.74%
# Iteration 2: Espilon = 916.5930, ESS = 950 Acc. rate = 26.63% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 6.43e+02
# b) Update weights: Old ESS = 950 New ESS = 902 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.1e+01 max 5.4e+01 mean = 0.11 glob min = -3.7e+01 max = 4.7e+01 mean = 0.43
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.245
# Prior ratio: min = -14.7, max = 4.91, mean = -2.88
# Kernel ratio: min = -4.95, max = 3.48, mean = -0.0575
# 3. Results: Acceptance = 23.06% Rejection ABC = 20.40% Rejection MH = 56.54%
# Iteration 3: Espilon = 643.2892, ESS = 902 Acc. rate = 23.06% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 5.23e+02
# b) Update weights: Old ESS = 902 New ESS = 856 (5.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.1e+01 max 4.7e+01 mean = 0.067 glob min = -4.4e+01 max = 4.4e+01 mean = 0.19
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.224
# Prior ratio: min = -18.6, max = 4.21, mean = -2.92
# Kernel ratio: min = -4.74, max = 3.41, mean = 0.0378
# 3. Results: Acceptance = 22.66% Rejection ABC = 22.31% Rejection MH = 55.02%
# Iteration 4: Espilon = 522.7868, ESS = 856 Acc. rate = 22.66% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 3.97e+02
# b) Update weights: Old ESS = 856 New ESS = 813 (5.02% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 5e+01 mean = -0.0036 glob min = -3.8e+01 max = 4e+01 mean = 0.83
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.226
# Prior ratio: min = -13.5, max = 5.47, mean = -2.81
# Kernel ratio: min = -5.84, max = 4.36, mean = -0.111
# 3. Results: Acceptance = 22.51% Rejection ABC = 29.64% Rejection MH = 47.85%
# Iteration 5: Espilon = 397.1666, ESS = 813 Acc. rate = 22.51% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 3.46e+02
# b) Update weights: Old ESS = 813 New ESS = 772 (5.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.7e+01 max 4.5e+01 mean = -0.1 glob min = -3.6e+01 max = 3.8e+01 mean = 0.15
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.207
# Prior ratio: min = -12.2, max = 4.28, mean = -2.74
# Kernel ratio: min = -4.56, max = 3.39, mean = -0.119
# 3. Results: Acceptance = 22.02% Rejection ABC = 30.44% Rejection MH = 47.54%
# Iteration 6: Espilon = 345.5697, ESS = 772 Acc. rate = 22.02% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 3e+02
# b) Update weights: Old ESS = 772 New ESS = 733 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 5.6e+01 mean = 0.017 glob min = -3.6e+01 max = 3.5e+01 mean = 0.95
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.216
# Prior ratio: min = -15.3, max = 6.5, mean = -2.68
# Kernel ratio: min = -5.36, max = 2.97, mean = -0.177
# 3. Results: Acceptance = 22.51% Rejection ABC = 30.42% Rejection MH = 47.07%
# Iteration 7: Espilon = 300.2984, ESS = 733 Acc. rate = 22.51% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 2.6e+02
# b) Update weights: Old ESS = 733 New ESS = 696 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.9e+01 max 4.6e+01 mean = -0.017 glob min = -3.7e+01 max = 3.3e+01 mean = 0.69
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.226
# Prior ratio: min = -14.5, max = 5.26, mean = -2.57
# Kernel ratio: min = -6.4, max = 3.58, mean = -0.148
# 3. Results: Acceptance = 22.41% Rejection ABC = 33.05% Rejection MH = 44.54%
# Iteration 8: Espilon = 259.5731, ESS = 696 Acc. rate = 22.41% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 2.36e+02
# b) Update weights: Old ESS = 696 New ESS = 661 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 4.4e+01 mean = -0.13 glob min = -2.6e+01 max = 2.9e+01 mean = 1.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.208
# Prior ratio: min = -11.9, max = 4.14, mean = -2.53
# Kernel ratio: min = -5.51, max = 3.4, mean = -0.14
# 3. Results: Acceptance = 20.27% Rejection ABC = 32.98% Rejection MH = 46.75%
# Iteration 9: Espilon = 236.0260, ESS = 661 Acc. rate = 20.27% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 2.1e+02
# b) Update weights: Old ESS = 661 New ESS = 628 (4.99% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.1e+01 max 4.6e+01 mean = -0.14 glob min = -2.6e+01 max = 4.2e+01 mean = 0.79
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.2
# Prior ratio: min = -12.9, max = 3.87, mean = -2.6
# Kernel ratio: min = -5.61, max = 3.24, mean = -0.105
# 3. Results: Acceptance = 19.75% Rejection ABC = 34.71% Rejection MH = 45.54%
# Iteration 10: Espilon = 209.8829, ESS = 628 Acc. rate = 19.75% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.88e+02
# b) Update weights: Old ESS = 628 New ESS = 596 (5.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.8e+01 max 5.4e+01 mean = -0.065 glob min = -2.5e+01 max = 2.8e+01 mean = 0.51
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.186
# Prior ratio: min = -12.9, max = 4.89, mean = -2.51
# Kernel ratio: min = -5.65, max = 3.4, mean = -0.181
# 3. Results: Acceptance = 18.46% Rejection ABC = 37.92% Rejection MH = 43.62%
# Iteration 11: Espilon = 187.5022, ESS = 596 Acc. rate = 18.46% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.71e+02
# b) Update weights: Old ESS = 596 New ESS = 566 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.8e+01 mean = -0.18 glob min = -2.5e+01 max = 2.7e+01 mean = 0.37
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.212
# Prior ratio: min = -12.2, max = 4.46, mean = -2.38
# Kernel ratio: min = -5.75, max = 3.53, mean = -0.192
# 3. Results: Acceptance = 21.20% Rejection ABC = 38.52% Rejection MH = 40.28%
# Iteration 12: Espilon = 171.1196, ESS = 566 Acc. rate = 21.20% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.56e+02
# b) Update weights: Old ESS = 566 New ESS = 537 (5.12% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4.8e+01 mean = -0.091 glob min = -2.5e+01 max = 2.7e+01 mean = 0.87
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.176
# Prior ratio: min = -11.0, max = 3.98, mean = -2.41
# Kernel ratio: min = -5.59, max = 4.06, mean = -0.227
# 3. Results: Acceptance = 18.81% Rejection ABC = 39.66% Rejection MH = 41.53%
# Iteration 13: Espilon = 155.6672, ESS = 537 Acc. rate = 18.81% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.41e+02
# b) Update weights: Old ESS = 537 New ESS = 510 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.5e+01 mean = -0.14 glob min = -2.5e+01 max = 2.7e+01 mean = 0.35
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.17
# Prior ratio: min = -11.4, max = 4.95, mean = -2.45
# Kernel ratio: min = -4.82, max = 2.65, mean = -0.179
# 3. Results: Acceptance = 17.45% Rejection ABC = 46.86% Rejection MH = 35.69%
# Iteration 14: Espilon = 141.2709, ESS = 510 Acc. rate = 17.45% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.31e+02
# b) Update weights: Old ESS = 510 New ESS = 484 (5.10% of particles killed)
# c) Resampling: Resampling... 484 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.3e+01 mean = -0.042 glob min = -2.7e+01 max = 2.7e+01 mean = 0.39
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.191
# Prior ratio: min = -12.2, max = 5.3, mean = -2.43
# Kernel ratio: min = -5.21, max = 3.47, mean = -0.212
# 3. Results: Acceptance = 18.70% Rejection ABC = 42.10% Rejection MH = 39.20%
# Iteration 15: Espilon = 131.1470, ESS = 1000 Acc. rate = 18.70% Uniqueness rate particules = 65.4% Uniqueness rate components = 65.4% Global parameters uniqueness rate = 65.4%
#
# a) Update Epsilon: new epsilon = 1.24e+02
# b) Update weights: Old ESS = 1000 New ESS = 950 (5.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.7e+01 max 5.1e+01 mean = 0.079 glob min = -2.2e+01 max = 2.3e+01 mean = 0.42
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.194
# Prior ratio: min = -10.7, max = 3.54, mean = -2.43
# Kernel ratio: min = -5.21, max = 3.5, mean = -0.201
# 3. Results: Acceptance = 19.16% Rejection ABC = 43.05% Rejection MH = 37.79%
# Iteration 16: Espilon = 123.6408, ESS = 950 Acc. rate = 19.16% Uniqueness rate particules = 76.3% Uniqueness rate components = 76.3% Global parameters uniqueness rate = 76.3%
#
# a) Update Epsilon: new epsilon = 1.15e+02
# b) Update weights: Old ESS = 950 New ESS = 902 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4.9e+01 mean = 0.015 glob min = -2.3e+01 max = 2.4e+01 mean = 0.51
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.171
# Prior ratio: min = -12.1, max = 4.66, mean = -2.52
# Kernel ratio: min = -5.38, max = 3.81, mean = -0.177
# 3. Results: Acceptance = 17.52% Rejection ABC = 46.23% Rejection MH = 36.25%
# Iteration 17: Espilon = 115.3061, ESS = 902 Acc. rate = 17.52% Uniqueness rate particules = 82.7% Uniqueness rate components = 82.6% Global parameters uniqueness rate = 82.7%
#
# a) Update Epsilon: new epsilon = 1.08e+02
# b) Update weights: Old ESS = 902 New ESS = 856 (5.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.8e+01 max 4.7e+01 mean = 0.13 glob min = -2e+01 max = 2.5e+01 mean = 0.29
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.172
# Prior ratio: min = -12.6, max = 3.51, mean = -2.42
# Kernel ratio: min = -6.66, max = 4.22, mean = -0.128
# 3. Results: Acceptance = 18.22% Rejection ABC = 47.55% Rejection MH = 34.23%
# Iteration 18: Espilon = 108.0780, ESS = 856 Acc. rate = 18.22% Uniqueness rate particules = 85.9% Uniqueness rate components = 85.9% Global parameters uniqueness rate = 85.9%
#
# a) Update Epsilon: new epsilon = 1.02e+02
# b) Update weights: Old ESS = 856 New ESS = 813 (5.02% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.3e+01 mean = 0.11 glob min = -2e+01 max = 2.4e+01 mean = 0.63
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.185
# Prior ratio: min = -11.7, max = 4.39, mean = -2.19
# Kernel ratio: min = -5.35, max = 2.96, mean = -0.148
# 3. Results: Acceptance = 18.45% Rejection ABC = 47.48% Rejection MH = 34.07%
# Iteration 19: Espilon = 101.6770, ESS = 813 Acc. rate = 18.45% Uniqueness rate particules = 89.1% Uniqueness rate components = 89.1% Global parameters uniqueness rate = 89.1%
#
# a) Update Epsilon: new epsilon = 96.7
# b) Update weights: Old ESS = 813 New ESS = 772 (5.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.3e+01 mean = 0.044 glob min = -1.9e+01 max = 2e+01 mean = 0.13
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.184
# Prior ratio: min = -10.2, max = 4.4, mean = -2.2
# Kernel ratio: min = -5.59, max = 2.62, mean = -0.132
# 3. Results: Acceptance = 17.49% Rejection ABC = 50.78% Rejection MH = 31.74%
# Iteration 20: Espilon = 96.7070, ESS = 772 Acc. rate = 17.49% Uniqueness rate particules = 90.5% Uniqueness rate components = 90.5% Global parameters uniqueness rate = 90.5%
#
# a) Update Epsilon: new epsilon = 92.2
# b) Update weights: Old ESS = 772 New ESS = 733 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.9e+01 max 4.3e+01 mean = -0.089 glob min = -1.8e+01 max = 2.4e+01 mean = 0.32
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.192
# Prior ratio: min = -13.7, max = 4.47, mean = -2.19
# Kernel ratio: min = -4.0, max = 3.47, mean = -0.116
# 3. Results: Acceptance = 17.33% Rejection ABC = 51.57% Rejection MH = 31.11%
# Iteration 21: Espilon = 92.1504, ESS = 733 Acc. rate = 17.33% Uniqueness rate particules = 91.7% Uniqueness rate components = 91.7% Global parameters uniqueness rate = 91.7%
#
# a) Update Epsilon: new epsilon = 86.0
# b) Update weights: Old ESS = 733 New ESS = 696 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 4.2e+01 mean = -0.022 glob min = -2.1e+01 max = 2.1e+01 mean = 0.57
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.183
# Prior ratio: min = -11.5, max = 4.32, mean = -2.15
# Kernel ratio: min = -5.84, max = 3.52, mean = -0.113
# 3. Results: Acceptance = 18.25% Rejection ABC = 55.32% Rejection MH = 26.44%
# Iteration 22: Espilon = 85.9886, ESS = 696 Acc. rate = 18.25% Uniqueness rate particules = 92.1% Uniqueness rate components = 92.1% Global parameters uniqueness rate = 92.1%
#
# a) Update Epsilon: new epsilon = 81.8
# b) Update weights: Old ESS = 696 New ESS = 661 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 5e+01 mean = 0.045 glob min = -1.9e+01 max = 1.9e+01 mean = 0.38
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.191
# Prior ratio: min = -12.6, max = 5.18, mean = -2.27
# Kernel ratio: min = -5.54, max = 3.16, mean = -0.0418
# 3. Results: Acceptance = 19.36% Rejection ABC = 53.86% Rejection MH = 26.78%
# Iteration 23: Espilon = 81.7670, ESS = 661 Acc. rate = 19.36% Uniqueness rate particules = 93.1% Uniqueness rate components = 93.1% Global parameters uniqueness rate = 93.1%
#
# a) Update Epsilon: new epsilon = 78.7
# b) Update weights: Old ESS = 661 New ESS = 628 (4.99% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 4.3e+01 mean = 0.11 glob min = -2e+01 max = 2.2e+01 mean = 1.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.166
# Prior ratio: min = -10.8, max = 4.41, mean = -2.0
# Kernel ratio: min = -4.18, max = 3.48, mean = -0.104
# 3. Results: Acceptance = 15.76% Rejection ABC = 56.37% Rejection MH = 27.87%
# Iteration 24: Espilon = 78.6728, ESS = 628 Acc. rate = 15.76% Uniqueness rate particules = 93.5% Uniqueness rate components = 93.5% Global parameters uniqueness rate = 93.5%
#
# a) Update Epsilon: new epsilon = 75.5
# b) Update weights: Old ESS = 628 New ESS = 596 (5.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.1e+01 max 3.9e+01 mean = 0.13 glob min = -1.7e+01 max = 2.4e+01 mean = 0.68
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.171
# Prior ratio: min = -11.3, max = 3.35, mean = -2.12
# Kernel ratio: min = -4.84, max = 2.86, mean = -0.055
# 3. Results: Acceptance = 15.44% Rejection ABC = 59.23% Rejection MH = 25.34%
# Iteration 25: Espilon = 75.4830, ESS = 596 Acc. rate = 15.44% Uniqueness rate particules = 94.0% Uniqueness rate components = 94.0% Global parameters uniqueness rate = 94.0%
#
# a) Update Epsilon: new epsilon = 72.0
# b) Update weights: Old ESS = 596 New ESS = 566 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.8e+01 max 4.3e+01 mean = 0.03 glob min = -2e+01 max = 1.8e+01 mean = 0.63
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.159
# Prior ratio: min = -9.02, max = 3.64, mean = -1.96
# Kernel ratio: min = -6.46, max = 2.64, mean = -0.113
# 3. Results: Acceptance = 15.90% Rejection ABC = 59.19% Rejection MH = 24.91%
# Iteration 26: Espilon = 71.9746, ESS = 566 Acc. rate = 15.90% Uniqueness rate particules = 94.0% Uniqueness rate components = 94.0% Global parameters uniqueness rate = 94.0%
#
# a) Update Epsilon: new epsilon = 69.4
# b) Update weights: Old ESS = 566 New ESS = 537 (5.12% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4e+01 max 4.6e+01 mean = -0.066 glob min = -1.7e+01 max = 2.2e+01 mean = 0.45
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.15
# Prior ratio: min = -13.0, max = 2.77, mean = -1.94
# Kernel ratio: min = -6.28, max = 2.95, mean = -0.112
# 3. Results: Acceptance = 15.83% Rejection ABC = 61.64% Rejection MH = 22.53%
# Iteration 27: Espilon = 69.3522, ESS = 537 Acc. rate = 15.83% Uniqueness rate particules = 94.0% Uniqueness rate components = 94.0% Global parameters uniqueness rate = 94.0%
#
# a) Update Epsilon: new epsilon = 67.0
# b) Update weights: Old ESS = 537 New ESS = 510 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.6e+01 mean = 0.038 glob min = -1.9e+01 max = 1.8e+01 mean = 0.63
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.165
# Prior ratio: min = -14.6, max = 3.68, mean = -1.98
# Kernel ratio: min = -6.17, max = 3.88, mean = -0.121
# 3. Results: Acceptance = 16.27% Rejection ABC = 63.14% Rejection MH = 20.59%
# Iteration 28: Espilon = 67.0301, ESS = 510 Acc. rate = 16.27% Uniqueness rate particules = 94.0% Uniqueness rate components = 94.0% Global parameters uniqueness rate = 94.0%
#
# a) Update Epsilon: new epsilon = 65.0
# b) Update weights: Old ESS = 510 New ESS = 484 (5.10% of particles killed)
# c) Resampling: Resampling... 482 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.7e+01 max 4.4e+01 mean = -0.1 glob min = -1.8e+01 max = 2e+01 mean = 0.71
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.153
# Prior ratio: min = -10.0, max = 4.26, mean = -1.94
# Kernel ratio: min = -5.98, max = 4.77, mean = -0.128
# 3. Results: Acceptance = 14.50% Rejection ABC = 62.30% Rejection MH = 23.20%
# Iteration 29: Espilon = 64.9629, ESS = 1000 Acc. rate = 14.50% Uniqueness rate particules = 62.2% Uniqueness rate components = 62.2% Global parameters uniqueness rate = 62.2%
#
# a) Update Epsilon: new epsilon = 62.9
# b) Update weights: Old ESS = 1000 New ESS = 950 (5.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 4.4e+01 mean = -0.047 glob min = -1.7e+01 max = 2e+01 mean = 0.63
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.149
# Prior ratio: min = -12.5, max = 3.83, mean = -2.05
# Kernel ratio: min = -4.77, max = 3.57, mean = -0.0832
# 3. Results: Acceptance = 15.58% Rejection ABC = 64.11% Rejection MH = 20.32%
# Iteration 30: Espilon = 62.8805, ESS = 950 Acc. rate = 15.58% Uniqueness rate particules = 72.4% Uniqueness rate components = 72.4% Global parameters uniqueness rate = 72.4%
#
# a) Update Epsilon: new epsilon = 60.9
# b) Update weights: Old ESS = 950 New ESS = 903 (4.95% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.6e+01 mean = -0.043 glob min = -2.2e+01 max = 1.7e+01 mean = 0.82
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.153
# Prior ratio: min = -11.2, max = 4.46, mean = -1.94
# Kernel ratio: min = -6.05, max = 3.49, mean = -0.0995
# 3. Results: Acceptance = 16.39% Rejection ABC = 64.56% Rejection MH = 19.05%
# Iteration 31: Espilon = 60.9491, ESS = 903 Acc. rate = 16.39% Uniqueness rate particules = 79.0% Uniqueness rate components = 79.0% Global parameters uniqueness rate = 79.0%
#
# a) Update Epsilon: new epsilon = 59.5
# b) Update weights: Old ESS = 903 New ESS = 857 (5.09% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.8e+01 mean = -0.15 glob min = -1.8e+01 max = 2.2e+01 mean = 0.63
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.15
# Prior ratio: min = -10.8, max = 3.29, mean = -1.96
# Kernel ratio: min = -5.17, max = 4.91, mean = -0.0214
# 3. Results: Acceptance = 16.22% Rejection ABC = 65.81% Rejection MH = 17.97%
# Iteration 32: Espilon = 59.4951, ESS = 857 Acc. rate = 16.22% Uniqueness rate particules = 83.4% Uniqueness rate components = 83.4% Global parameters uniqueness rate = 83.4%
#
# a) Update Epsilon: new epsilon = 57.5
# b) Update weights: Old ESS = 857 New ESS = 814 (5.02% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.9e+01 max 4.4e+01 mean = -0.013 glob min = -2e+01 max = 2.3e+01 mean = 0.74
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.14
# Prior ratio: min = -12.1, max = 3.87, mean = -1.92
# Kernel ratio: min = -4.8, max = 3.32, mean = -0.0695
# 3. Results: Acceptance = 13.51% Rejection ABC = 68.55% Rejection MH = 17.94%
# Iteration 33: Espilon = 57.4694, ESS = 814 Acc. rate = 13.51% Uniqueness rate particules = 86.0% Uniqueness rate components = 86.0% Global parameters uniqueness rate = 86.0%
#
# a) Update Epsilon: new epsilon = 55.8
# b) Update weights: Old ESS = 814 New ESS = 774 (4.91% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4.3e+01 mean = 0.016 glob min = -1.8e+01 max = 2e+01 mean = 0.64
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.163
# Prior ratio: min = -11.2, max = 4.17, mean = -1.77
# Kernel ratio: min = -4.28, max = 3.72, mean = -0.0501
# 3. Results: Acceptance = 16.54% Rejection ABC = 64.47% Rejection MH = 18.99%
# Iteration 34: Espilon = 55.7890, ESS = 774 Acc. rate = 16.54% Uniqueness rate particules = 88.2% Uniqueness rate components = 88.2% Global parameters uniqueness rate = 88.2%
#
# a) Update Epsilon: new epsilon = 54.5
# b) Update weights: Old ESS = 774 New ESS = 735 (5.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 5.1e+01 mean = 0.02 glob min = -1.9e+01 max = 2e+01 mean = 0.44
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.14
# Prior ratio: min = -10.6, max = 2.98, mean = -1.62
# Kernel ratio: min = -3.31, max = 3.74, mean = -0.0775
# 3. Results: Acceptance = 13.06% Rejection ABC = 68.44% Rejection MH = 18.50%
# Iteration 35: Espilon = 54.5293, ESS = 735 Acc. rate = 13.06% Uniqueness rate particules = 89.9% Uniqueness rate components = 89.9% Global parameters uniqueness rate = 89.9%
#
# a) Update Epsilon: new epsilon = 53.4
# b) Update weights: Old ESS = 735 New ESS = 698 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.4e+01 mean = 0.2 glob min = -1.6e+01 max = 2e+01 mean = 0.9
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.143
# Prior ratio: min = -11.0, max = 4.06, mean = -1.78
# Kernel ratio: min = -5.44, max = 3.21, mean = -0.0407
# 3. Results: Acceptance = 14.33% Rejection ABC = 68.48% Rejection MH = 17.19%
# Iteration 36: Espilon = 53.3624, ESS = 698 Acc. rate = 14.33% Uniqueness rate particules = 90.4% Uniqueness rate components = 90.4% Global parameters uniqueness rate = 90.4%
#
# a) Update Epsilon: new epsilon = 52.2
# b) Update weights: Old ESS = 698 New ESS = 664 (4.87% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.8e+01 mean = 0.074 glob min = -1.8e+01 max = 1.9e+01 mean = 0.27
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.135
# Prior ratio: min = -10.8, max = 3.74, mean = -1.59
# Kernel ratio: min = -4.46, max = 4.15, mean = -0.121
# 3. Results: Acceptance = 13.86% Rejection ABC = 70.93% Rejection MH = 15.21%
# Iteration 37: Espilon = 52.1503, ESS = 664 Acc. rate = 13.86% Uniqueness rate particules = 91.3% Uniqueness rate components = 91.3% Global parameters uniqueness rate = 91.3%
#
# a) Update Epsilon: new epsilon = 50.7
# b) Update weights: Old ESS = 664 New ESS = 630 (5.12% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.2e+01 mean = 0.011 glob min = -2.2e+01 max = 2.2e+01 mean = 0.68
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.109
# Prior ratio: min = -10.5, max = 3.72, mean = -1.82
# Kernel ratio: min = -3.73, max = 3.63, mean = -0.0699
# 3. Results: Acceptance = 11.75% Rejection ABC = 71.75% Rejection MH = 16.51%
# Iteration 38: Espilon = 50.7318, ESS = 630 Acc. rate = 11.75% Uniqueness rate particules = 91.4% Uniqueness rate components = 91.4% Global parameters uniqueness rate = 91.4%
#
# a) Update Epsilon: new epsilon = 49.4
# b) Update weights: Old ESS = 630 New ESS = 598 (5.08% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4e+01 max 4e+01 mean = -0.016 glob min = -1.9e+01 max = 1.8e+01 mean = 0.44
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.126
# Prior ratio: min = -9.19, max = 3.11, mean = -1.76
# Kernel ratio: min = -4.69, max = 3.66, mean = -0.0778
# 3. Results: Acceptance = 11.71% Rejection ABC = 71.57% Rejection MH = 16.72%
# Iteration 39: Espilon = 49.3980, ESS = 598 Acc. rate = 11.71% Uniqueness rate particules = 91.8% Uniqueness rate components = 91.8% Global parameters uniqueness rate = 91.8%
#
# a) Update Epsilon: new epsilon = 48.1
# b) Update weights: Old ESS = 598 New ESS = 568 (5.02% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.7e+01 max 4e+01 mean = 0.16 glob min = -1.7e+01 max = 1.9e+01 mean = 0.35
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.124
# Prior ratio: min = -8.54, max = 4.31, mean = -1.8
# Kernel ratio: min = -3.71, max = 3.35, mean = 0.00457
# 3. Results: Acceptance = 13.38% Rejection ABC = 70.42% Rejection MH = 16.20%
# Iteration 40: Espilon = 48.1095, ESS = 568 Acc. rate = 13.38% Uniqueness rate particules = 91.9% Uniqueness rate components = 91.9% Global parameters uniqueness rate = 91.9%
#
# a) Update Epsilon: new epsilon = 47.1
# b) Update weights: Old ESS = 568 New ESS = 539 (5.11% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.4e+01 mean = 0.18 glob min = -1.6e+01 max = 1.8e+01 mean = 0.16
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.128
# Prior ratio: min = -10.0, max = 2.76, mean = -1.73
# Kernel ratio: min = -4.64, max = 3.07, mean = -0.0841
# 3. Results: Acceptance = 13.73% Rejection ABC = 72.54% Rejection MH = 13.73%
# Iteration 41: Espilon = 47.0550, ESS = 539 Acc. rate = 13.73% Uniqueness rate particules = 92.0% Uniqueness rate components = 92.0% Global parameters uniqueness rate = 92.0%
#
# a) Update Epsilon: new epsilon = 46.0
# b) Update weights: Old ESS = 539 New ESS = 512 (5.01% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 4.2e+01 mean = 0.2 glob min = -1.7e+01 max = 2e+01 mean = 0.71
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.101
# Prior ratio: min = -10.9, max = 3.67, mean = -1.93
# Kernel ratio: min = -5.37, max = 3.46, mean = 0.0258
# 3. Results: Acceptance = 9.77% Rejection ABC = 76.17% Rejection MH = 14.06%
# Iteration 42: Espilon = 45.9628, ESS = 512 Acc. rate = 9.77% Uniqueness rate particules = 92.2% Uniqueness rate components = 92.2% Global parameters uniqueness rate = 92.2%
#
# a) Update Epsilon: new epsilon = 44.9
# b) Update weights: Old ESS = 512 New ESS = 486 (5.08% of particles killed)
# c) Resampling: Resampling... 484 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.9e+01 max 5.5e+01 mean = 0.14 glob min = -2e+01 max = 1.9e+01 mean = 0.46
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.127
# Prior ratio: min = -12.2, max = 3.98, mean = -1.73
# Kernel ratio: min = -6.03, max = 3.97, mean = -0.0554
# 3. Results: Acceptance = 12.80% Rejection ABC = 72.50% Rejection MH = 14.70%
# Iteration 43: Espilon = 44.9450, ESS = 1000 Acc. rate = 12.80% Uniqueness rate particules = 60.2% Uniqueness rate components = 60.2% Global parameters uniqueness rate = 60.2%
#
# a) Update Epsilon: new epsilon = 44.2
# b) Update weights: Old ESS = 1000 New ESS = 950 (5.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.9e+01 max 4.5e+01 mean = 0.25 glob min = -1.9e+01 max = 1.8e+01 mean = 0.33
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0999
# Prior ratio: min = -12.1, max = 4.21, mean = -1.84
# Kernel ratio: min = -3.93, max = 3.11, mean = -0.0412
# 3. Results: Acceptance = 9.68% Rejection ABC = 74.42% Rejection MH = 15.89%
# Iteration 44: Espilon = 44.1689, ESS = 950 Acc. rate = 9.68% Uniqueness rate particules = 67.4% Uniqueness rate components = 67.4% Global parameters uniqueness rate = 67.4%
#
# a) Update Epsilon: new epsilon = 43.4
# b) Update weights: Old ESS = 950 New ESS = 903 (4.95% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.2e+01 mean = 0.053 glob min = -1.7e+01 max = 1.9e+01 mean = 0.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.105
# Prior ratio: min = -9.53, max = 3.49, mean = -1.74
# Kernel ratio: min = -3.97, max = 5.11, mean = 0.000177
# 3. Results: Acceptance = 10.19% Rejection ABC = 76.74% Rejection MH = 13.07%
# Iteration 45: Espilon = 43.3996, ESS = 903 Acc. rate = 10.19% Uniqueness rate particules = 73.2% Uniqueness rate components = 73.2% Global parameters uniqueness rate = 73.2%
#
# a) Update Epsilon: new epsilon = 42.7
# b) Update weights: Old ESS = 903 New ESS = 857 (5.09% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.1e+01 max 4.6e+01 mean = 0.14 glob min = -1.8e+01 max = 1.7e+01 mean = 0.43
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.104
# Prior ratio: min = -12.4, max = 3.64, mean = -1.71
# Kernel ratio: min = -4.78, max = 4.02, mean = 0.0242
# 3. Results: Acceptance = 10.85% Rejection ABC = 78.88% Rejection MH = 10.27%
# Iteration 46: Espilon = 42.7049, ESS = 857 Acc. rate = 10.85% Uniqueness rate particules = 77.5% Uniqueness rate components = 77.5% Global parameters uniqueness rate = 77.5%
#
# a) Update Epsilon: new epsilon = 41.9
# b) Update weights: Old ESS = 857 New ESS = 815 (4.90% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.5e+01 mean = 0.12 glob min = -1.7e+01 max = 1.8e+01 mean = 0.42
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0953
# Prior ratio: min = -9.51, max = 3.44, mean = -1.64
# Kernel ratio: min = -4.9, max = 2.52, mean = -0.0811
# 3. Results: Acceptance = 8.96% Rejection ABC = 78.90% Rejection MH = 12.15%
# Iteration 47: Espilon = 41.9150, ESS = 815 Acc. rate = 8.96% Uniqueness rate particules = 80.0% Uniqueness rate components = 80.0% Global parameters uniqueness rate = 80.0%
#
# a) Update Epsilon: new epsilon = 41.1
# b) Update weights: Old ESS = 815 New ESS = 774 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.3e+01 mean = 0.29 glob min = -2e+01 max = 1.7e+01 mean = 0.53
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0913
# Prior ratio: min = -9.76, max = 3.17, mean = -1.88
# Kernel ratio: min = -4.97, max = 2.84, mean = 0.019
# 3. Results: Acceptance = 9.56% Rejection ABC = 81.14% Rejection MH = 9.30%
# Iteration 48: Espilon = 41.1275, ESS = 774 Acc. rate = 9.56% Uniqueness rate particules = 82.1% Uniqueness rate components = 82.1% Global parameters uniqueness rate = 82.1%
#
# a) Update Epsilon: new epsilon = 40.2
# b) Update weights: Old ESS = 774 New ESS = 735 (5.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 4.1e+01 mean = 0.23 glob min = -1.6e+01 max = 1.8e+01 mean = 0.35
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0872
# Prior ratio: min = -10.4, max = 4.25, mean = -1.83
# Kernel ratio: min = -3.64, max = 3.29, mean = -0.0551
# 3. Results: Acceptance = 8.30% Rejection ABC = 80.41% Rejection MH = 11.29%
# Iteration 49: Espilon = 40.2249, ESS = 735 Acc. rate = 8.30% Uniqueness rate particules = 83.6% Uniqueness rate components = 83.6% Global parameters uniqueness rate = 83.6%
#
# a) Update Epsilon: new epsilon = 39.4
# b) Update weights: Old ESS = 735 New ESS = 698 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.4e+01 mean = 0.061 glob min = -2e+01 max = 2e+01 mean = 0.65
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0903
# Prior ratio: min = -9.93, max = 4.25, mean = -1.73
# Kernel ratio: min = -5.9, max = 2.66, mean = -0.0526
# 3. Results: Acceptance = 9.60% Rejection ABC = 80.95% Rejection MH = 9.46%
# Iteration 50: Espilon = 39.4346, ESS = 698 Acc. rate = 9.60% Uniqueness rate particules = 84.7% Uniqueness rate components = 84.7% Global parameters uniqueness rate = 84.7%
#
# a) Update Epsilon: new epsilon = 38.9
# b) Update weights: Old ESS = 698 New ESS = 663 (5.01% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 4.4e+01 mean = 0.084 glob min = -1.7e+01 max = 2.2e+01 mean = 0.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0846
# Prior ratio: min = -10.5, max = 4.49, mean = -1.77
# Kernel ratio: min = -3.85, max = 2.52, mean = -0.00459
# 3. Results: Acceptance = 7.84% Rejection ABC = 81.00% Rejection MH = 11.16%
# Iteration 51: Espilon = 38.8547, ESS = 663 Acc. rate = 7.84% Uniqueness rate particules = 85.4% Uniqueness rate components = 85.4% Global parameters uniqueness rate = 85.4%
#
# a) Update Epsilon: new epsilon = 38.1
# b) Update weights: Old ESS = 663 New ESS = 629 (5.13% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4.2e+01 mean = 0.085 glob min = -1.8e+01 max = 1.7e+01 mean = 0.9
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0898
# Prior ratio: min = -12.1, max = 2.88, mean = -1.63
# Kernel ratio: min = -4.23, max = 2.98, mean = -0.048
# 3. Results: Acceptance = 8.11% Rejection ABC = 80.92% Rejection MH = 10.97%
# Iteration 52: Espilon = 38.1169, ESS = 629 Acc. rate = 8.11% Uniqueness rate particules = 86.1% Uniqueness rate components = 86.1% Global parameters uniqueness rate = 86.1%
#
# a) Update Epsilon: new epsilon = 37.2
# b) Update weights: Old ESS = 629 New ESS = 597 (5.09% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.8e+01 mean = 0.13 glob min = -1.8e+01 max = 1.7e+01 mean = 0.51
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0859
# Prior ratio: min = -8.55, max = 4.62, mean = -1.66
# Kernel ratio: min = -3.94, max = 2.89, mean = -0.0521
# 3. Results: Acceptance = 7.71% Rejection ABC = 81.91% Rejection MH = 10.39%
# Iteration 53: Espilon = 37.1807, ESS = 597 Acc. rate = 7.71% Uniqueness rate particules = 86.6% Uniqueness rate components = 86.6% Global parameters uniqueness rate = 86.6%
#
# a) Update Epsilon: new epsilon = 36.5
# b) Update weights: Old ESS = 597 New ESS = 567 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.8e+01 mean = 0.16 glob min = -2.1e+01 max = 2e+01 mean = 0.66
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0667
# Prior ratio: min = -10.7, max = 3.8, mean = -1.94
# Kernel ratio: min = -5.95, max = 2.8, mean = 0.029
# 3. Results: Acceptance = 7.23% Rejection ABC = 85.54% Rejection MH = 7.23%
# Iteration 54: Espilon = 36.4973, ESS = 567 Acc. rate = 7.23% Uniqueness rate particules = 87.3% Uniqueness rate components = 87.3% Global parameters uniqueness rate = 87.3%
#
# a) Update Epsilon: new epsilon = 36.0
# b) Update weights: Old ESS = 567 New ESS = 538 (5.11% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 4.1e+01 mean = 0.059 glob min = -1.6e+01 max = 2e+01 mean = 0.75
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0808
# Prior ratio: min = -8.41, max = 4.09, mean = -1.63
# Kernel ratio: min = -2.98, max = 2.56, mean = 0.00926
# 3. Results: Acceptance = 7.06% Rejection ABC = 82.71% Rejection MH = 10.22%
# Iteration 55: Espilon = 35.9882, ESS = 538 Acc. rate = 7.06% Uniqueness rate particules = 87.5% Uniqueness rate components = 87.5% Global parameters uniqueness rate = 87.5%
#
# a) Update Epsilon: new epsilon = 35.3
# b) Update weights: Old ESS = 538 New ESS = 511 (5.02% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.1e+01 max 4.3e+01 mean = -0.058 glob min = -1.9e+01 max = 1.7e+01 mean = 1.2
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0802
# Prior ratio: min = -7.77, max = 3.95, mean = -1.71
# Kernel ratio: min = -4.98, max = 2.94, mean = -0.0516
# 3. Results: Acceptance = 8.61% Rejection ABC = 84.15% Rejection MH = 7.24%
# Iteration 56: Espilon = 35.2896, ESS = 511 Acc. rate = 8.61% Uniqueness rate particules = 88.0% Uniqueness rate components = 88.0% Global parameters uniqueness rate = 88.0%
#
# a) Update Epsilon: new epsilon = 34.7
# b) Update weights: Old ESS = 511 New ESS = 485 (5.09% of particles killed)
# c) Resampling: Resampling... 462 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.2e+01 mean = -0.039 glob min = -1.8e+01 max = 1.7e+01 mean = 0.83
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0755
# Prior ratio: min = -11.6, max = 4.9, mean = -1.68
# Kernel ratio: min = -5.52, max = 2.96, mean = -0.047
# 3. Results: Acceptance = 8.10% Rejection ABC = 83.80% Rejection MH = 8.10%
# Iteration 57: Espilon = 34.6502, ESS = 1000 Acc. rate = 8.10% Uniqueness rate particules = 54.1% Uniqueness rate components = 54.1% Global parameters uniqueness rate = 54.1%
#
# a) Update Epsilon: new epsilon = 33.9
# b) Update weights: Old ESS = 1000 New ESS = 952 (4.80% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.6e+01 mean = 0.099 glob min = -1.6e+01 max = 1.9e+01 mean = 0.96
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0736
# Prior ratio: min = -11.3, max = 3.61, mean = -1.61
# Kernel ratio: min = -5.13, max = 3.13, mean = -0.0389
# 3. Results: Acceptance = 7.67% Rejection ABC = 83.93% Rejection MH = 8.40%
# Iteration 58: Espilon = 33.9235, ESS = 952 Acc. rate = 7.67% Uniqueness rate particules = 59.9% Uniqueness rate components = 59.9% Global parameters uniqueness rate = 59.9%
#
# a) Update Epsilon: new epsilon = 33.5
# b) Update weights: Old ESS = 952 New ESS = 904 (5.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.4e+01 mean = -0.063 glob min = -1.5e+01 max = 1.6e+01 mean = 0.89
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0723
# Prior ratio: min = -10.4, max = 2.98, mean = -1.61
# Kernel ratio: min = -5.4, max = 3.36, mean = -0.0372
# 3. Results: Acceptance = 7.52% Rejection ABC = 83.19% Rejection MH = 9.29%
# Iteration 59: Espilon = 33.5269, ESS = 904 Acc. rate = 7.52% Uniqueness rate particules = 64.5% Uniqueness rate components = 64.5% Global parameters uniqueness rate = 64.5%
#
# a) Update Epsilon: new epsilon = 32.9
# b) Update weights: Old ESS = 904 New ESS = 858 (5.09% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4.3e+01 mean = -0.0011 glob min = -1.7e+01 max = 1.8e+01 mean = 0.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0683
# Prior ratio: min = -10.3, max = 3.41, mean = -1.62
# Kernel ratio: min = -5.71, max = 3.51, mean = 0.00122
# 3. Results: Acceptance = 6.29% Rejection ABC = 86.48% Rejection MH = 7.23%
# Iteration 60: Espilon = 32.8675, ESS = 858 Acc. rate = 6.29% Uniqueness rate particules = 67.9% Uniqueness rate components = 67.9% Global parameters uniqueness rate = 67.9%
#
# a) Update Epsilon: new epsilon = 32.3
# b) Update weights: Old ESS = 858 New ESS = 815 (5.01% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.4e+01 max 4.2e+01 mean = -0.14 glob min = -1.4e+01 max = 2e+01 mean = 1.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0658
# Prior ratio: min = -11.0, max = 3.67, mean = -1.7
# Kernel ratio: min = -6.43, max = 2.15, mean = -0.0108
# 3. Results: Acceptance = 6.87% Rejection ABC = 85.40% Rejection MH = 7.73%
# Iteration 61: Espilon = 32.2866, ESS = 815 Acc. rate = 6.87% Uniqueness rate particules = 71.5% Uniqueness rate components = 71.5% Global parameters uniqueness rate = 71.5%
#
# a) Update Epsilon: new epsilon = 31.7
# b) Update weights: Old ESS = 815 New ESS = 774 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.1e+01 max 4.4e+01 mean = 0.0038 glob min = -1.9e+01 max = 1.7e+01 mean = 0.93
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0705
# Prior ratio: min = -8.65, max = 4.27, mean = -1.64
# Kernel ratio: min = -5.05, max = 2.45, mean = -0.00858
# 3. Results: Acceptance = 6.98% Rejection ABC = 85.92% Rejection MH = 7.11%
# Iteration 62: Espilon = 31.7155, ESS = 774 Acc. rate = 6.98% Uniqueness rate particules = 73.6% Uniqueness rate components = 73.6% Global parameters uniqueness rate = 73.6%
#
# a) Update Epsilon: new epsilon = 31.2
# b) Update weights: Old ESS = 774 New ESS = 735 (5.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4.5e+01 mean = -0.065 glob min = -1.6e+01 max = 1.7e+01 mean = 0.88
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.059
# Prior ratio: min = -11.7, max = 3.19, mean = -1.63
# Kernel ratio: min = -4.58, max = 2.63, mean = -0.0228
# 3. Results: Acceptance = 5.99% Rejection ABC = 88.03% Rejection MH = 5.99%
# Iteration 63: Espilon = 31.1747, ESS = 735 Acc. rate = 5.99% Uniqueness rate particules = 75.5% Uniqueness rate components = 75.5% Global parameters uniqueness rate = 75.5%
#
# a) Update Epsilon: new epsilon = 30.6
# b) Update weights: Old ESS = 735 New ESS = 698 (5.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.7e+01 mean = -0.028 glob min = -1.6e+01 max = 1.9e+01 mean = 1.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0591
# Prior ratio: min = -10.9, max = 4.25, mean = -1.57
# Kernel ratio: min = -3.81, max = 3.91, mean = -0.0167
# 3. Results: Acceptance = 6.30% Rejection ABC = 87.39% Rejection MH = 6.30%
# Iteration 64: Espilon = 30.5525, ESS = 698 Acc. rate = 6.30% Uniqueness rate particules = 76.9% Uniqueness rate components = 76.9% Global parameters uniqueness rate = 76.9%
#
# a) Update Epsilon: new epsilon = 30.0
# b) Update weights: Old ESS = 698 New ESS = 664 (4.87% of particles killed)
# c) Resampling: No resampling
# ...
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.8e+01 max 3.7e+01 mean = 0.22 glob min = -1.8e+01 max = 2.2e+01 mean = 0.43
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0237
# Prior ratio: min = -10.2, max = 2.68, mean = -1.35
# Kernel ratio: min = -2.48, max = 2.77, mean = 0.0683
# 3. Results: Acceptance = 2.50% Rejection ABC = 96.00% Rejection MH = 1.50%
# Iteration 112: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.50% Uniqueness rate particules = 36.0% Uniqueness rate components = 36.0% Global parameters uniqueness rate = 36.0%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.2e+01 mean = 0.28 glob min = -1.8e+01 max = 1.7e+01 mean = 0.54
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.014
# Prior ratio: min = -9.28, max = 4.37, mean = -1.31
# Kernel ratio: min = -2.47, max = 1.99, mean = 0.0507
# 3. Results: Acceptance = 1.30% Rejection ABC = 97.10% Rejection MH = 1.60%
# Iteration 113: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.30% Uniqueness rate particules = 37.1% Uniqueness rate components = 37.1% Global parameters uniqueness rate = 37.1%
# Acceptance rate is too low, stopping the algorithm for epsilon =  15.945850372314453
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.8e+01 max 4.4e+01 mean = 0.17 glob min = -1.5e+01 max = 2e+01 mean = 0.66
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0184
# Prior ratio: min = -8.34, max = 3.42, mean = -1.39
# Kernel ratio: min = -3.61, max = 1.57, mean = 0.0386
# 3. Results: Acceptance = 1.90% Rejection ABC = 96.50% Rejection MH = 1.60%
# Iteration 114: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.90% Uniqueness rate particules = 38.8% Uniqueness rate components = 38.8% Global parameters uniqueness rate = 38.8%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4e+01 max 4.1e+01 mean = 0.26 glob min = -1.7e+01 max = 1.7e+01 mean = 0.31
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0166
# Prior ratio: min = -8.3, max = 3.41, mean = -1.33
# Kernel ratio: min = -2.31, max = 1.98, mean = 0.0531
# 3. Results: Acceptance = 1.70% Rejection ABC = 97.20% Rejection MH = 1.10%
# Iteration 115: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.70% Uniqueness rate particules = 40.4% Uniqueness rate components = 40.4% Global parameters uniqueness rate = 40.4%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.2e+01 mean = 0.23 glob min = -1.8e+01 max = 1.7e+01 mean = 0.49
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0129
# Prior ratio: min = -8.24, max = 3.09, mean = -1.41
# Kernel ratio: min = -1.89, max = 3.35, mean = 0.057
# 3. Results: Acceptance = 1.30% Rejection ABC = 97.30% Rejection MH = 1.40%
# Iteration 116: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.30% Uniqueness rate particules = 41.5% Uniqueness rate components = 41.5% Global parameters uniqueness rate = 41.5%
# Acceptance rate is too low, stopping the algorithm for epsilon =  15.945850372314453
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.9e+01 max 4.2e+01 mean = 0.21 glob min = -1.7e+01 max = 1.7e+01 mean = 0.41
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0193
# Prior ratio: min = -9.04, max = 2.85, mean = -1.39
# Kernel ratio: min = -3.07, max = 1.55, mean = 0.0469
# 3. Results: Acceptance = 2.10% Rejection ABC = 96.90% Rejection MH = 1.00%
# Iteration 117: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.10% Uniqueness rate particules = 43.2% Uniqueness rate components = 43.2% Global parameters uniqueness rate = 43.2%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.5e+01 max 4e+01 mean = 0.13 glob min = -1.7e+01 max = 1.9e+01 mean = 0.48
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0183
# Prior ratio: min = -9.19, max = 2.55, mean = -1.36
# Kernel ratio: min = -2.7, max = 2.34, mean = 0.0734
# 3. Results: Acceptance = 2.10% Rejection ABC = 96.50% Rejection MH = 1.40%
# Iteration 118: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.10% Uniqueness rate particules = 45.2% Uniqueness rate components = 45.2% Global parameters uniqueness rate = 45.2%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.7e+01 max 4.4e+01 mean = 0.25 glob min = -1.7e+01 max = 1.6e+01 mean = 0.49
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0139
# Prior ratio: min = -7.73, max = 3.52, mean = -1.47
# Kernel ratio: min = -2.01, max = 2.07, mean = 0.0598
# 3. Results: Acceptance = 1.40% Rejection ABC = 97.20% Rejection MH = 1.40%
# Iteration 119: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.40% Uniqueness rate particules = 46.1% Uniqueness rate components = 46.1% Global parameters uniqueness rate = 46.1%
# Acceptance rate is too low, stopping the algorithm for epsilon =  15.945850372314453
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.1e+01 max 4.2e+01 mean = 0.2 glob min = -1.5e+01 max = 1.5e+01 mean = 0.43
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.019
# Prior ratio: min = -7.49, max = 3.28, mean = -1.36
# Kernel ratio: min = -3.1, max = 1.96, mean = 0.0587
# 3. Results: Acceptance = 2.10% Rejection ABC = 96.80% Rejection MH = 1.10%
# Iteration 120: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.10% Uniqueness rate particules = 48.0% Uniqueness rate components = 48.0% Global parameters uniqueness rate = 48.0%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.6e+01 max 4.2e+01 mean = 0.2 glob min = -1.8e+01 max = 2e+01 mean = 0.41
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0224
# Prior ratio: min = -8.1, max = 3.48, mean = -1.37
# Kernel ratio: min = -2.4, max = 1.96, mean = 0.0754
# 3. Results: Acceptance = 2.50% Rejection ABC = 96.30% Rejection MH = 1.20%
# Iteration 121: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.50% Uniqueness rate particules = 49.7% Uniqueness rate components = 49.7% Global parameters uniqueness rate = 49.7%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.9e+01 max 4e+01 mean = 0.17 glob min = -1.6e+01 max = 1.8e+01 mean = 0.37
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0162
# Prior ratio: min = -8.68, max = 3.56, mean = -1.37
# Kernel ratio: min = -2.45, max = 1.97, mean = 0.0921
# 3. Results: Acceptance = 1.50% Rejection ABC = 96.50% Rejection MH = 2.00%
# Iteration 122: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.50% Uniqueness rate particules = 50.6% Uniqueness rate components = 50.6% Global parameters uniqueness rate = 50.6%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 4.3e+01 mean = 0.21 glob min = -1.7e+01 max = 1.7e+01 mean = 0.48
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0158
# Prior ratio: min = -8.27, max = 3.04, mean = -1.32
# Kernel ratio: min = -2.28, max = 2.1, mean = 0.0339
# 3. Results: Acceptance = 1.50% Rejection ABC = 96.80% Rejection MH = 1.70%
# Iteration 123: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.50% Uniqueness rate particules = 51.5% Uniqueness rate components = 51.5% Global parameters uniqueness rate = 51.5%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.6e+01 max 4.3e+01 mean = 0.31 glob min = -1.7e+01 max = 2e+01 mean = 0.47
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0171
# Prior ratio: min = -7.48, max = 3.58, mean = -1.43
# Kernel ratio: min = -2.63, max = 2.14, mean = 0.0658
# 3. Results: Acceptance = 1.50% Rejection ABC = 96.80% Rejection MH = 1.70%
# Iteration 124: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.50% Uniqueness rate particules = 52.6% Uniqueness rate components = 52.6% Global parameters uniqueness rate = 52.6%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.9e+01 max 4e+01 mean = 0.19 glob min = -1.8e+01 max = 1.9e+01 mean = 0.36
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0237
# Prior ratio: min = -8.19, max = 3.39, mean = -1.3
# Kernel ratio: min = -2.32, max = 2.0, mean = 0.0367
# 3. Results: Acceptance = 2.20% Rejection ABC = 96.20% Rejection MH = 1.60%
# Iteration 125: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.20% Uniqueness rate particules = 53.9% Uniqueness rate components = 53.9% Global parameters uniqueness rate = 53.9%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.3e+01 max 3.8e+01 mean = 0.3 glob min = -1.6e+01 max = 2.1e+01 mean = 0.55
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0146
# Prior ratio: min = -12.5, max = 3.09, mean = -1.37
# Kernel ratio: min = -2.52, max = 2.56, mean = 0.0728
# 3. Results: Acceptance = 1.20% Rejection ABC = 97.50% Rejection MH = 1.30%
# Iteration 126: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.20% Uniqueness rate particules = 54.5% Uniqueness rate components = 54.5% Global parameters uniqueness rate = 54.5%
# Acceptance rate is too low, stopping the algorithm for epsilon =  15.945850372314453
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.8e+01 max 4.5e+01 mean = 0.34 glob min = -1.6e+01 max = 2.2e+01 mean = 0.4
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0238
# Prior ratio: min = -8.97, max = 3.69, mean = -1.53
# Kernel ratio: min = -1.97, max = 2.39, mean = 0.0796
# 3. Results: Acceptance = 2.00% Rejection ABC = 96.10% Rejection MH = 1.90%
# Iteration 127: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.00% Uniqueness rate particules = 55.8% Uniqueness rate components = 55.8% Global parameters uniqueness rate = 55.8%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 4.3e+01 mean = 0.25 glob min = -1.5e+01 max = 1.7e+01 mean = 0.45
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0267
# Prior ratio: min = -7.67, max = 3.77, mean = -1.43
# Kernel ratio: min = -2.42, max = 2.87, mean = 0.0924
# 3. Results: Acceptance = 2.60% Rejection ABC = 95.30% Rejection MH = 2.10%
# Iteration 128: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.60% Uniqueness rate particules = 57.3% Uniqueness rate components = 57.3% Global parameters uniqueness rate = 57.3%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.2e+01 max 4.4e+01 mean = 0.28 glob min = -1.7e+01 max = 2e+01 mean = 0.51
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0156
# Prior ratio: min = -9.43, max = 3.27, mean = -1.44
# Kernel ratio: min = -2.49, max = 1.83, mean = 0.0612
# 3. Results: Acceptance = 1.80% Rejection ABC = 97.20% Rejection MH = 1.00%
# Iteration 129: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.80% Uniqueness rate particules = 57.8% Uniqueness rate components = 57.8% Global parameters uniqueness rate = 57.8%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.8e+01 max 4.5e+01 mean = 0.3 glob min = -1.9e+01 max = 1.8e+01 mean = 0.41
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0157
# Prior ratio: min = -12.4, max = 3.6, mean = -1.45
# Kernel ratio: min = -2.68, max = 2.04, mean = 0.0725
# 3. Results: Acceptance = 1.60% Rejection ABC = 97.00% Rejection MH = 1.40%
# Iteration 130: Espilon = 15.9459, ESS = 1000 Acc. rate = 1.60% Uniqueness rate particules = 58.7% Uniqueness rate components = 58.7% Global parameters uniqueness rate = 58.7%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.6e+01 max 4.4e+01 mean = 0.24 glob min = -1.7e+01 max = 2.1e+01 mean = 0.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0246
# Prior ratio: min = -10.9, max = 3.62, mean = -1.34
# Kernel ratio: min = -2.16, max = 2.23, mean = 0.0583
# 3. Results: Acceptance = 2.50% Rejection ABC = 95.60% Rejection MH = 1.90%
# Iteration 131: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.50% Uniqueness rate particules = 60.1% Uniqueness rate components = 60.1% Global parameters uniqueness rate = 60.1%
#
# a) Update Epsilon: new epsilon = 15.9
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -3.7e+01 max 4e+01 mean = 0.23 glob min = -1.9e+01 max = 2.3e+01 mean = 0.3
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0179
# Prior ratio: min = -7.34, max = 2.99, mean = -1.44
# Kernel ratio: min = -1.75, max = 2.68, mean = 0.0737
# 3. Results: Acceptance = 2.00% Rejection ABC = 96.80% Rejection MH = 1.20%
# Iteration 132: Espilon = 15.9459, ESS = 1000 Acc. rate = 2.00% Uniqueness rate particules = 60.7% Uniqueness rate components = 60.7% Global parameters uniqueness rate = 60.7%

# %%
key, subkey = random.split(key)
kernel = KernelTruncatedRW
N = 1000
model.reset_weights_distance()
out_perm_smc2 = perm_abc_smc(key = subkey, model = model, n_particles= N, epsilon_target= 0, y_obs = y_obs, kernel = kernel, verbose = 2, update_weights_distance=True, Final_iteration=20)

mus_perm_smc2 = out_perm_smc2["Thetas"][-1].loc.squeeze()
betas_perm_smc2 = out_perm_smc2["Thetas"][-1].glob.squeeze()
n_sim_perm_smc2 = np.sum(out_perm_smc2["N_sim"])
# Out:
# Weights distance: min = 0.0957, max = 0.106
# Performing full optimal assignment (no prior indices).
# Weights distance: min = 0.0892, max = 0.135
# Iteration 0: Epsilon = inf, ESS = 1000 Acc. rate = 100% Numb. unique particles = 1000
# a) Update Epsilon: new epsilon = 9.83e+02
# b) Update weights: Old ESS = 1000 New ESS = 950 (5.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.7e+01 max 4.8e+01 mean = 0.014 glob min = -5e+01 max = 5e+01 mean = 0.15
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.253
# Prior ratio: min = -16.9, max = 8.03, mean = -2.94
# Kernel ratio: min = -4.37, max = 2.87, mean = -0.00308
# 3. Results: Acceptance = 25.26% Rejection ABC = 17.26% Rejection MH = 57.47%
# e) Update weights distance: Weights distance: min = 0.0833, max = 0.143
# Performing full optimal assignment (no prior indices).
# After update weights update: 950 particles alive (0 particles killed)
# Iteration 2: Espilon = 983.2031, ESS = 950 Acc. rate = 25.26% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 6.35e+02
# b) Update weights: Old ESS = 950 New ESS = 902 (5.05% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 4.6e+01 mean = -0.031 glob min = -4.1e+01 max = 4.7e+01 mean = -0.41
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.192
# Prior ratio: min = -17.6, max = 4.38, mean = -3.37
# Kernel ratio: min = -6.17, max = 3.22, mean = -0.362
# 3. Results: Acceptance = 21.18% Rejection ABC = 22.39% Rejection MH = 56.43%
# e) Update weights distance: Weights distance: min = 0.0507, max = 0.223
# Performing full optimal assignment (no prior indices).
# After update weights update: 902 particles alive (0 particles killed)
# Iteration 3: Espilon = 635.4695, ESS = 902 Acc. rate = 21.18% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 4.19e+02
# b) Update weights: Old ESS = 902 New ESS = 856 (5.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.3e+01 max 5.9e+01 mean = 0.1 glob min = -4.6e+01 max = 5.5e+01 mean = 0.25
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.125
# Prior ratio: min = -29.6, max = 5.49, mean = -4.38
# Kernel ratio: min = -15.5, max = 5.88, mean = -1.18
# 3. Results: Acceptance = 12.85% Rejection ABC = 24.42% Rejection MH = 62.73%
# e) Update weights distance: Weights distance: min = 0.0319, max = 0.311
# Performing full optimal assignment (no prior indices).
# After update weights update: 856 particles alive (0 particles killed)
# Iteration 4: Espilon = 418.7083, ESS = 856 Acc. rate = 12.85% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 2.75e+02
# b) Update weights: Old ESS = 856 New ESS = 813 (5.02% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.9e+01 max 6.9e+01 mean = -0.2 glob min = -4.7e+01 max = 3.5e+01 mean = -0.71
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.103
# Prior ratio: min = -30.3, max = 4.61, mean = -5.08
# Kernel ratio: min = -19.7, max = 4.65, mean = -1.36
# 3. Results: Acceptance = 10.58% Rejection ABC = 26.57% Rejection MH = 62.85%
# e) Update weights distance: Weights distance: min = 0.0226, max = 0.317
# Performing full optimal assignment (no prior indices).
# After update weights update: 811 particles alive (0 particles killed)
# Iteration 5: Espilon = 274.6870, ESS = 813 Acc. rate = 10.60% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 2.15e+02
# b) Update weights: Old ESS = 813 New ESS = 770 (5.29% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -8.2e+01 max 6.4e+01 mean = -0.17 glob min = -3.7e+01 max = 4.4e+01 mean = -0.018
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.101
# Prior ratio: min = -32.8, max = 5.55, mean = -5.17
# Kernel ratio: min = -19.9, max = 4.66, mean = -1.41
# 3. Results: Acceptance = 9.61% Rejection ABC = 26.62% Rejection MH = 63.77%
# e) Update weights distance: Weights distance: min = 0.0211, max = 0.303
# Performing full optimal assignment (no prior indices).
# After update weights update: 768 particles alive (0 particles killed)
# Iteration 6: Espilon = 215.0553, ESS = 770 Acc. rate = 9.64% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.85e+02
# b) Update weights: Old ESS = 770 New ESS = 729 (5.32% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -9.5e+01 max 7.6e+01 mean = -0.088 glob min = -3.1e+01 max = 3.7e+01 mean = 0.31
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.115
# Prior ratio: min = -43.7, max = 5.5, mean = -5.16
# Kernel ratio: min = -15.6, max = 7.07, mean = -1.35
# 3. Results: Acceptance = 12.07% Rejection ABC = 29.49% Rejection MH = 58.44%
# e) Update weights distance: Weights distance: min = 0.0202, max = 0.277
# Performing full optimal assignment (no prior indices).
# After update weights update: 721 particles alive (0 particles killed)
# Iteration 7: Espilon = 185.0853, ESS = 729 Acc. rate = 12.21% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.51e+02
# b) Update weights: Old ESS = 729 New ESS = 685 (6.04% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7e+01 max 9e+01 mean = 0.094 glob min = -3.2e+01 max = 3.2e+01 mean = -0.058
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0998
# Prior ratio: min = -41.2, max = 4.52, mean = -5.0
# Kernel ratio: min = -26.6, max = 4.93, mean = -1.39
# 3. Results: Acceptance = 9.05% Rejection ABC = 29.34% Rejection MH = 61.61%
# e) Update weights distance: Weights distance: min = 0.0188, max = 0.261
# Performing full optimal assignment (no prior indices).
# After update weights update: 681 particles alive (0 particles killed)
# Iteration 8: Espilon = 151.2118, ESS = 685 Acc. rate = 9.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.38e+02
# b) Update weights: Old ESS = 685 New ESS = 647 (5.55% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.7e+01 max 6.8e+01 mean = -0.12 glob min = -3.1e+01 max = 2.7e+01 mean = -0.029
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0986
# Prior ratio: min = -31.1, max = 5.04, mean = -5.36
# Kernel ratio: min = -17.8, max = 5.57, mean = -1.07
# 3. Results: Acceptance = 10.20% Rejection ABC = 29.06% Rejection MH = 60.74%
# e) Update weights distance: Weights distance: min = 0.0183, max = 0.246
# Performing full optimal assignment (no prior indices).
# After update weights update: 647 particles alive (0 particles killed)
# Iteration 9: Espilon = 137.7844, ESS = 647 Acc. rate = 10.20% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.21e+02
# b) Update weights: Old ESS = 647 New ESS = 614 (5.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -8.2e+01 max 6.7e+01 mean = -0.18 glob min = -3.2e+01 max = 3.1e+01 mean = 0.46
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.091
# Prior ratio: min = -37.5, max = 4.97, mean = -5.07
# Kernel ratio: min = -18.9, max = 6.18, mean = -1.34
# 3. Results: Acceptance = 9.12% Rejection ABC = 30.29% Rejection MH = 60.59%
# e) Update weights distance: Weights distance: min = 0.0179, max = 0.232
# Performing full optimal assignment (no prior indices).
# After update weights update: 612 particles alive (0 particles killed)
# Iteration 10: Espilon = 121.0106, ESS = 614 Acc. rate = 9.15% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 1.05e+02
# b) Update weights: Old ESS = 614 New ESS = 581 (5.37% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7e+01 max 7.4e+01 mean = -0.031 glob min = -2.5e+01 max = 2.4e+01 mean = 0.71
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.118
# Prior ratio: min = -28.3, max = 6.82, mean = -4.3
# Kernel ratio: min = -23.8, max = 4.15, mean = -1.52
# 3. Results: Acceptance = 12.74% Rejection ABC = 34.60% Rejection MH = 52.67%
# e) Update weights distance: Weights distance: min = 0.0196, max = 0.22
# Performing full optimal assignment (no prior indices).
# After update weights update: 576 particles alive (0 particles killed)
# Iteration 11: Espilon = 105.2759, ESS = 581 Acc. rate = 12.85% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 93.5
# b) Update weights: Old ESS = 581 New ESS = 547 (5.85% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.2e+01 max 8.2e+01 mean = -0.13 glob min = -3.2e+01 max = 2.6e+01 mean = 0.59
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0966
# Prior ratio: min = -32.3, max = 5.04, mean = -4.79
# Kernel ratio: min = -21.6, max = 4.99, mean = -1.19
# 3. Results: Acceptance = 10.05% Rejection ABC = 38.76% Rejection MH = 51.19%
# e) Update weights distance: Weights distance: min = 0.0189, max = 0.212
# Performing full optimal assignment (no prior indices).
# After update weights update: 542 particles alive (0 particles killed)
# Iteration 12: Espilon = 93.5364, ESS = 547 Acc. rate = 10.15% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 80.5
# b) Update weights: Old ESS = 547 New ESS = 514 (6.03% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.7e+01 max 5.4e+01 mean = -0.52 glob min = -2.4e+01 max = 3.8e+01 mean = 0.51
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0969
# Prior ratio: min = -22.6, max = 5.85, mean = -4.67
# Kernel ratio: min = -33.4, max = 5.5, mean = -1.2
# 3. Results: Acceptance = 9.92% Rejection ABC = 37.35% Rejection MH = 52.72%
# e) Update weights distance: Weights distance: min = 0.0191, max = 0.205
# Performing full optimal assignment (no prior indices).
# After update weights update: 505 particles alive (0 particles killed)
# Iteration 13: Espilon = 80.5341, ESS = 514 Acc. rate = 10.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
#
# a) Update Epsilon: new epsilon = 74.3
# b) Update weights: Old ESS = 514 New ESS = 479 (6.81% of particles killed)
# c) Resampling: Resampling... 479 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.2e+01 max 5.9e+01 mean = -0.33 glob min = -2.2e+01 max = 2.8e+01 mean = 0.73
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.107
# Prior ratio: min = -30.0, max = 6.32, mean = -4.16
# Kernel ratio: min = -19.8, max = 8.95, mean = -1.2
# 3. Results: Acceptance = 10.10% Rejection ABC = 38.70% Rejection MH = 51.20%
# e) Update weights distance: Weights distance: min = 0.0178, max = 0.197
# Performing full optimal assignment (no prior indices).
# After update weights update: 988 particles alive (0 particles killed)
# Iteration 14: Espilon = 74.2902, ESS = 1000 Acc. rate = 10.22% Uniqueness rate particules = 57.3% Uniqueness rate components = 57.3% Global parameters uniqueness rate = 57.3%
#
# a) Update Epsilon: new epsilon = 66.8
# b) Update weights: Old ESS = 1000 New ESS = 939 (6.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.9e+01 max 6.6e+01 mean = -0.041 glob min = -2.9e+01 max = 3.1e+01 mean = 0.3
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.113
# Prior ratio: min = -31.5, max = 5.09, mean = -4.36
# Kernel ratio: min = -15.0, max = 5.43, mean = -1.23
# 3. Results: Acceptance = 11.71% Rejection ABC = 39.40% Rejection MH = 48.88%
# e) Update weights distance: Weights distance: min = 0.0185, max = 0.189
# Performing full optimal assignment (no prior indices).
# After update weights update: 926 particles alive (0 particles killed)
# Iteration 15: Espilon = 66.8409, ESS = 939 Acc. rate = 11.88% Uniqueness rate particules = 65.8% Uniqueness rate components = 65.8% Global parameters uniqueness rate = 65.8%
#
# a) Update Epsilon: new epsilon = 59.6
# b) Update weights: Old ESS = 939 New ESS = 879 (6.39% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.7e+01 max 7.4e+01 mean = -0.087 glob min = -2.4e+01 max = 2e+01 mean = 0.58
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0858
# Prior ratio: min = -31.4, max = 6.01, mean = -4.43
# Kernel ratio: min = -20.3, max = 5.37, mean = -1.46
# 3. Results: Acceptance = 9.10% Rejection ABC = 47.44% Rejection MH = 43.46%
# e) Update weights distance: Weights distance: min = 0.0196, max = 0.179
# Performing full optimal assignment (no prior indices).
# After update weights update: 876 particles alive (0 particles killed)
# Iteration 16: Espilon = 59.6032, ESS = 879 Acc. rate = 9.13% Uniqueness rate particules = 70.2% Uniqueness rate components = 70.2% Global parameters uniqueness rate = 70.2%
#
# a) Update Epsilon: new epsilon = 54.3
# b) Update weights: Old ESS = 879 New ESS = 832 (5.35% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.7e+01 max 6.4e+01 mean = -0.069 glob min = -2.8e+01 max = 2.3e+01 mean = 0.97
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0821
# Prior ratio: min = -30.1, max = 5.86, mean = -4.35
# Kernel ratio: min = -38.8, max = 4.91, mean = -1.2
# 3. Results: Acceptance = 7.69% Rejection ABC = 48.44% Rejection MH = 43.87%
# e) Update weights distance: Weights distance: min = 0.0202, max = 0.171
# Performing full optimal assignment (no prior indices).
# After update weights update: 827 particles alive (0 particles killed)
# Iteration 17: Espilon = 54.2787, ESS = 832 Acc. rate = 7.74% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
#
# a) Update Epsilon: new epsilon = 49.5
# b) Update weights: Old ESS = 832 New ESS = 785 (5.65% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.9e+01 max 6.5e+01 mean = -0.04 glob min = -2e+01 max = 2.2e+01 mean = 0.82
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0928
# Prior ratio: min = -21.7, max = 4.73, mean = -3.97
# Kernel ratio: min = -23.4, max = 5.55, mean = -1.51
# 3. Results: Acceptance = 9.55% Rejection ABC = 50.45% Rejection MH = 40.00%
# e) Update weights distance: Weights distance: min = 0.02, max = 0.165
# Performing full optimal assignment (no prior indices).
# After update weights update: 781 particles alive (0 particles killed)
# Iteration 18: Espilon = 49.5437, ESS = 785 Acc. rate = 9.60% Uniqueness rate particules = 77.4% Uniqueness rate components = 77.4% Global parameters uniqueness rate = 77.4%
#
# a) Update Epsilon: new epsilon = 44.5
# b) Update weights: Old ESS = 785 New ESS = 742 (5.48% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -8e+01 max 7.1e+01 mean = -0.015 glob min = -2.2e+01 max = 2e+01 mean = 0.96
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0976
# Prior ratio: min = -33.0, max = 5.33, mean = -3.71
# Kernel ratio: min = -23.8, max = 6.04, mean = -1.57
# 3. Results: Acceptance = 9.43% Rejection ABC = 50.13% Rejection MH = 40.43%
# e) Update weights distance: Weights distance: min = 0.0191, max = 0.157
# Performing full optimal assignment (no prior indices).
# After update weights update: 741 particles alive (0 particles killed)
# Iteration 19: Espilon = 44.4733, ESS = 742 Acc. rate = 9.45% Uniqueness rate particules = 80.0% Uniqueness rate components = 80.0% Global parameters uniqueness rate = 80.0%
#
# a) Update Epsilon: new epsilon = 41.1
# b) Update weights: Old ESS = 742 New ESS = 704 (5.12% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.8e+01 max 6.2e+01 mean = 0.046 glob min = -1.9e+01 max = 2.3e+01 mean = 0.68
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0728
# Prior ratio: min = -22.2, max = 4.47, mean = -4.07
# Kernel ratio: min = -16.5, max = 3.73, mean = -1.54
# 3. Results: Acceptance = 7.81% Rejection ABC = 60.09% Rejection MH = 32.10%
# e) Update weights distance: Weights distance: min = 0.0187, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 698 particles alive (0 particles killed)
# Iteration 20: Espilon = 41.1088, ESS = 704 Acc. rate = 7.88% Uniqueness rate particules = 81.6% Uniqueness rate components = 81.6% Global parameters uniqueness rate = 81.6%
#
# a) Update Epsilon: new epsilon = 37.7
# b) Update weights: Old ESS = 704 New ESS = 663 (5.82% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.5e+01 max 7.3e+01 mean = -0.066 glob min = -2.6e+01 max = 2.2e+01 mean = 0.97
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0617
# Prior ratio: min = -27.4, max = 4.2, mean = -4.08
# Kernel ratio: min = -18.0, max = 5.17, mean = -1.48
# 3. Results: Acceptance = 6.64% Rejection ABC = 61.69% Rejection MH = 31.67%
# e) Update weights distance: Weights distance: min = 0.0177, max = 0.152
# Performing full optimal assignment (no prior indices).
# After update weights update: 662 particles alive (0 particles killed)
# Iteration 21: Espilon = 37.7136, ESS = 663 Acc. rate = 6.65% Uniqueness rate particules = 82.8% Uniqueness rate components = 82.8% Global parameters uniqueness rate = 82.8%
#
# a) Update Epsilon: new epsilon = 35.7
# b) Update weights: Old ESS = 663 New ESS = 628 (5.28% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.6e+01 max 5.6e+01 mean = 0.13 glob min = -2.4e+01 max = 2.1e+01 mean = 0.58
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0888
# Prior ratio: min = -25.4, max = 4.88, mean = -3.63
# Kernel ratio: min = -20.4, max = 5.69, mean = -1.43
# 3. Results: Acceptance = 8.60% Rejection ABC = 62.42% Rejection MH = 28.98%
# e) Update weights distance: Weights distance: min = 0.0169, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 626 particles alive (0 particles killed)
# Iteration 22: Espilon = 35.7349, ESS = 628 Acc. rate = 8.63% Uniqueness rate particules = 83.9% Uniqueness rate components = 83.9% Global parameters uniqueness rate = 83.9%
#
# a) Update Epsilon: new epsilon = 34.0
# b) Update weights: Old ESS = 628 New ESS = 594 (5.41% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.8e+01 max 6.2e+01 mean = 0.047 glob min = -2e+01 max = 2.2e+01 mean = 0.66
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0721
# Prior ratio: min = -29.6, max = 5.98, mean = -4.01
# Kernel ratio: min = -16.1, max = 5.89, mean = -1.42
# 3. Results: Acceptance = 7.58% Rejection ABC = 63.64% Rejection MH = 28.79%
# e) Update weights distance: Weights distance: min = 0.018, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 591 particles alive (0 particles killed)
# Iteration 23: Espilon = 33.9615, ESS = 594 Acc. rate = 7.61% Uniqueness rate particules = 84.7% Uniqueness rate components = 84.7% Global parameters uniqueness rate = 84.7%
#
# a) Update Epsilon: new epsilon = 32.0
# b) Update weights: Old ESS = 594 New ESS = 561 (5.56% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.9e+01 max 6e+01 mean = 0.21 glob min = -2.2e+01 max = 2.6e+01 mean = 0.86
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0844
# Prior ratio: min = -21.0, max = 3.75, mean = -3.7
# Kernel ratio: min = -23.4, max = 6.45, mean = -1.46
# 3. Results: Acceptance = 7.49% Rejection ABC = 61.14% Rejection MH = 31.37%
# e) Update weights distance: Weights distance: min = 0.017, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 560 particles alive (0 particles killed)
# Iteration 24: Espilon = 31.9928, ESS = 561 Acc. rate = 7.50% Uniqueness rate particules = 85.6% Uniqueness rate components = 85.6% Global parameters uniqueness rate = 85.6%
#
# a) Update Epsilon: new epsilon = 30.2
# b) Update weights: Old ESS = 561 New ESS = 532 (5.17% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.6e+01 max 6.1e+01 mean = -0.14 glob min = -1.8e+01 max = 2.1e+01 mean = 0.96
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0754
# Prior ratio: min = -23.4, max = 4.04, mean = -3.93
# Kernel ratio: min = -34.7, max = 3.97, mean = -1.68
# 3. Results: Acceptance = 8.83% Rejection ABC = 66.17% Rejection MH = 25.00%
# e) Update weights distance: Weights distance: min = 0.0169, max = 0.156
# Performing full optimal assignment (no prior indices).
# After update weights update: 524 particles alive (0 particles killed)
# Iteration 25: Espilon = 30.1701, ESS = 532 Acc. rate = 8.97% Uniqueness rate particules = 86.5% Uniqueness rate components = 86.5% Global parameters uniqueness rate = 86.5%
#
# a) Update Epsilon: new epsilon = 28.9
# b) Update weights: Old ESS = 532 New ESS = 498 (6.39% of particles killed)
# c) Resampling: Resampling... 469 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.6e+01 max 6.8e+01 mean = -0.032 glob min = -1.9e+01 max = 1.9e+01 mean = 0.56
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0637
# Prior ratio: min = -26.6, max = 5.23, mean = -3.73
# Kernel ratio: min = -25.7, max = 6.08, mean = -1.7
# 3. Results: Acceptance = 5.70% Rejection ABC = 67.20% Rejection MH = 27.10%
# e) Update weights distance: Weights distance: min = 0.0164, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 998 particles alive (0 particles killed)
# Iteration 26: Espilon = 28.8656, ESS = 1000 Acc. rate = 5.71% Uniqueness rate particules = 52.6% Uniqueness rate components = 52.6% Global parameters uniqueness rate = 52.6%
#
# a) Update Epsilon: new epsilon = 27.6
# b) Update weights: Old ESS = 1000 New ESS = 948 (5.20% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.9e+01 max 7e+01 mean = -0.023 glob min = -2e+01 max = 2e+01 mean = 0.72
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0709
# Prior ratio: min = -29.9, max = 4.04, mean = -3.6
# Kernel ratio: min = -34.5, max = 5.23, mean = -1.66
# 3. Results: Acceptance = 5.91% Rejection ABC = 67.83% Rejection MH = 26.27%
# e) Update weights distance: Weights distance: min = 0.0165, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 947 particles alive (0 particles killed)
# Iteration 27: Espilon = 27.6223, ESS = 948 Acc. rate = 5.91% Uniqueness rate particules = 57.5% Uniqueness rate components = 57.5% Global parameters uniqueness rate = 57.5%
#
# a) Update Epsilon: new epsilon = 26.5
# b) Update weights: Old ESS = 948 New ESS = 900 (5.06% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.3e+01 max 5.3e+01 mean = -0.13 glob min = -2.4e+01 max = 1.8e+01 mean = 0.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0618
# Prior ratio: min = -28.6, max = 3.63, mean = -3.44
# Kernel ratio: min = -24.1, max = 6.25, mean = -1.52
# 3. Results: Acceptance = 6.22% Rejection ABC = 70.00% Rejection MH = 23.78%
# e) Update weights distance: Weights distance: min = 0.0161, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 892 particles alive (0 particles killed)
# Iteration 28: Espilon = 26.4683, ESS = 900 Acc. rate = 6.28% Uniqueness rate particules = 62.2% Uniqueness rate components = 62.2% Global parameters uniqueness rate = 62.2%
#
# a) Update Epsilon: new epsilon = 25.5
# b) Update weights: Old ESS = 900 New ESS = 847 (5.89% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -7.1e+01 max 5.8e+01 mean = -0.02 glob min = -1.8e+01 max = 1.9e+01 mean = 0.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0488
# Prior ratio: min = -28.5, max = 5.38, mean = -3.34
# Kernel ratio: min = -23.5, max = 4.65, mean = -1.58
# 3. Results: Acceptance = 5.08% Rejection ABC = 72.96% Rejection MH = 21.96%
# e) Update weights distance: Weights distance: min = 0.0164, max = 0.154
# Performing full optimal assignment (no prior indices).
# After update weights update: 835 particles alive (0 particles killed)
# Iteration 29: Espilon = 25.5320, ESS = 847 Acc. rate = 5.15% Uniqueness rate particules = 64.9% Uniqueness rate components = 64.9% Global parameters uniqueness rate = 64.9%
#
# a) Update Epsilon: new epsilon = 24.9
# b) Update weights: Old ESS = 847 New ESS = 793 (6.38% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.3e+01 max 6.6e+01 mean = -0.045 glob min = -1.9e+01 max = 1.8e+01 mean = 0.89
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0727
# Prior ratio: min = -23.7, max = 6.11, mean = -3.24
# Kernel ratio: min = -16.2, max = 6.21, mean = -1.33
# 3. Results: Acceptance = 7.06% Rejection ABC = 72.26% Rejection MH = 20.68%
# e) Update weights distance: Weights distance: min = 0.0169, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 784 particles alive (0 particles killed)
# Iteration 30: Espilon = 24.8537, ESS = 793 Acc. rate = 7.14% Uniqueness rate particules = 68.1% Uniqueness rate components = 68.1% Global parameters uniqueness rate = 68.1%
#
# a) Update Epsilon: new epsilon = 24.0
# b) Update weights: Old ESS = 793 New ESS = 744 (6.18% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.6e+01 max 6e+01 mean = -0.11 glob min = -1.7e+01 max = 1.8e+01 mean = 0.76
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0567
# Prior ratio: min = -20.6, max = 4.35, mean = -3.33
# Kernel ratio: min = -19.3, max = 6.17, mean = -1.68
# 3. Results: Acceptance = 5.65% Rejection ABC = 76.48% Rejection MH = 17.88%
# e) Update weights distance: Weights distance: min = 0.0159, max = 0.156
# Performing full optimal assignment (no prior indices).
# After update weights update: 743 particles alive (0 particles killed)
# Iteration 31: Espilon = 24.0277, ESS = 744 Acc. rate = 5.65% Uniqueness rate particules = 70.4% Uniqueness rate components = 70.4% Global parameters uniqueness rate = 70.4%
#
# a) Update Epsilon: new epsilon = 23.4
# b) Update weights: Old ESS = 744 New ESS = 706 (5.11% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.8e+01 max 6e+01 mean = -0.091 glob min = -1.7e+01 max = 1.7e+01 mean = 0.66
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0588
# Prior ratio: min = -21.8, max = 5.92, mean = -3.29
# Kernel ratio: min = -19.3, max = 5.7, mean = -1.27
# 3. Results: Acceptance = 5.81% Rejection ABC = 77.90% Rejection MH = 16.29%
# e) Update weights distance: Weights distance: min = 0.0169, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 689 particles alive (0 particles killed)
# Iteration 32: Espilon = 23.3953, ESS = 706 Acc. rate = 5.95% Uniqueness rate particules = 72.6% Uniqueness rate components = 72.6% Global parameters uniqueness rate = 72.6%
#
# a) Update Epsilon: new epsilon = 22.9
# b) Update weights: Old ESS = 706 New ESS = 654 (7.37% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.4e+01 max 5.7e+01 mean = -0.36 glob min = -1.6e+01 max = 1.9e+01 mean = 1.1
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0496
# Prior ratio: min = -23.3, max = 4.71, mean = -3.25
# Kernel ratio: min = -18.2, max = 4.57, mean = -1.59
# 3. Results: Acceptance = 4.89% Rejection ABC = 74.46% Rejection MH = 20.64%
# e) Update weights distance: Weights distance: min = 0.0166, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 649 particles alive (0 particles killed)
# Iteration 33: Espilon = 22.9013, ESS = 654 Acc. rate = 4.93% Uniqueness rate particules = 73.6% Uniqueness rate components = 73.6% Global parameters uniqueness rate = 73.6%
#
# a) Update Epsilon: new epsilon = 22.2
# b) Update weights: Old ESS = 654 New ESS = 616 (5.81% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.5e+01 max 5.4e+01 mean = -0.18 glob min = -1.8e+01 max = 2e+01 mean = 0.87
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0569
# Prior ratio: min = -17.5, max = 4.15, mean = -3.1
# Kernel ratio: min = -13.7, max = 4.05, mean = -1.48
# 3. Results: Acceptance = 5.03% Rejection ABC = 77.76% Rejection MH = 17.21%
# e) Update weights distance: Weights distance: min = 0.0168, max = 0.152
# Performing full optimal assignment (no prior indices).
# After update weights update: 610 particles alive (0 particles killed)
# Iteration 34: Espilon = 22.2091, ESS = 616 Acc. rate = 5.08% Uniqueness rate particules = 75.1% Uniqueness rate components = 75.1% Global parameters uniqueness rate = 75.1%
#
# a) Update Epsilon: new epsilon = 21.8
# b) Update weights: Old ESS = 616 New ESS = 579 (6.01% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.5e+01 max 5.1e+01 mean = -0.16 glob min = -1.6e+01 max = 2e+01 mean = 0.68
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0654
# Prior ratio: min = -15.0, max = 3.75, mean = -2.99
# Kernel ratio: min = -14.5, max = 4.58, mean = -1.37
# 3. Results: Acceptance = 6.91% Rejection ABC = 77.55% Rejection MH = 15.54%
# e) Update weights distance: Weights distance: min = 0.0154, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 578 particles alive (0 particles killed)
# Iteration 35: Espilon = 21.8031, ESS = 579 Acc. rate = 6.92% Uniqueness rate particules = 76.4% Uniqueness rate components = 76.4% Global parameters uniqueness rate = 76.4%
#
# a) Update Epsilon: new epsilon = 21.1
# b) Update weights: Old ESS = 579 New ESS = 550 (5.01% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.9e+01 max 7e+01 mean = 0.08 glob min = -1.6e+01 max = 1.7e+01 mean = 0.82
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0449
# Prior ratio: min = -27.9, max = 5.07, mean = -3.07
# Kernel ratio: min = -19.7, max = 9.81, mean = -1.49
# 3. Results: Acceptance = 4.55% Rejection ABC = 81.45% Rejection MH = 14.00%
# e) Update weights distance: Weights distance: min = 0.0152, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 544 particles alive (0 particles killed)
# Iteration 36: Espilon = 21.0737, ESS = 550 Acc. rate = 4.60% Uniqueness rate particules = 77.3% Uniqueness rate components = 77.3% Global parameters uniqueness rate = 77.3%
#
# a) Update Epsilon: new epsilon = 20.7
# b) Update weights: Old ESS = 550 New ESS = 516 (6.18% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.1e+01 max 5e+01 mean = -0.26 glob min = -2e+01 max = 1.8e+01 mean = 0.67
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0363
# Prior ratio: min = -22.7, max = 3.79, mean = -3.07
# Kernel ratio: min = -23.3, max = 4.2, mean = -1.53
# 3. Results: Acceptance = 4.07% Rejection ABC = 84.88% Rejection MH = 11.05%
# e) Update weights distance: Weights distance: min = 0.0152, max = 0.152
# Performing full optimal assignment (no prior indices).
# After update weights update: 505 particles alive (0 particles killed)
# Iteration 37: Espilon = 20.6659, ESS = 516 Acc. rate = 4.16% Uniqueness rate particules = 78.0% Uniqueness rate components = 78.0% Global parameters uniqueness rate = 78.0%
#
# a) Update Epsilon: new epsilon = 20.3
# b) Update weights: Old ESS = 516 New ESS = 479 (7.17% of particles killed)
# c) Resampling: Resampling... 413 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.7e+01 max 6.5e+01 mean = -0.034 glob min = -2e+01 max = 1.7e+01 mean = 0.65
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0322
# Prior ratio: min = -22.7, max = 4.57, mean = -3.24
# Kernel ratio: min = -20.4, max = 7.89, mean = -1.27
# 3. Results: Acceptance = 3.00% Rejection ABC = 84.20% Rejection MH = 12.80%
# e) Update weights distance: Weights distance: min = 0.015, max = 0.154
# Performing full optimal assignment (no prior indices).
# After update weights update: 965 particles alive (0 particles killed)
# Iteration 38: Espilon = 20.2611, ESS = 1000 Acc. rate = 3.11% Uniqueness rate particules = 44.2% Uniqueness rate components = 44.2% Global parameters uniqueness rate = 44.2%
#
# a) Update Epsilon: new epsilon = 20.0
# b) Update weights: Old ESS = 1000 New ESS = 919 (8.10% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6e+01 max 7.2e+01 mean = -0.17 glob min = -2.1e+01 max = 2e+01 mean = 1.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0449
# Prior ratio: min = -26.5, max = 3.39, mean = -3.2
# Kernel ratio: min = -20.5, max = 4.68, mean = -1.35
# 3. Results: Acceptance = 5.22% Rejection ABC = 81.94% Rejection MH = 12.84%
# e) Update weights distance: Weights distance: min = 0.0149, max = 0.154
# Performing full optimal assignment (no prior indices).
# After update weights update: 904 particles alive (0 particles killed)
# Iteration 39: Espilon = 20.0038, ESS = 919 Acc. rate = 5.31% Uniqueness rate particules = 48.7% Uniqueness rate components = 48.7% Global parameters uniqueness rate = 48.7%
#
# a) Update Epsilon: new epsilon = 19.6
# b) Update weights: Old ESS = 919 New ESS = 859 (6.53% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.7e+01 max 6e+01 mean = -0.028 glob min = -1.5e+01 max = 2.1e+01 mean = 0.83
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0457
# Prior ratio: min = -25.0, max = 3.05, mean = -2.94
# Kernel ratio: min = -18.9, max = 6.38, mean = -1.49
# 3. Results: Acceptance = 4.42% Rejection ABC = 83.35% Rejection MH = 12.22%
# e) Update weights distance: Weights distance: min = 0.0148, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 844 particles alive (0 particles killed)
# Iteration 40: Espilon = 19.5902, ESS = 859 Acc. rate = 4.50% Uniqueness rate particules = 51.7% Uniqueness rate components = 51.7% Global parameters uniqueness rate = 51.7%
#
# a) Update Epsilon: new epsilon = 19.1
# b) Update weights: Old ESS = 859 New ESS = 802 (6.64% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.2e+01 max 6e+01 mean = -0.054 glob min = -1.9e+01 max = 2.3e+01 mean = 0.65
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0427
# Prior ratio: min = -20.4, max = 4.67, mean = -3.16
# Kernel ratio: min = -23.9, max = 5.81, mean = -1.18
# 3. Results: Acceptance = 4.49% Rejection ABC = 85.79% Rejection MH = 9.73%
# e) Update weights distance: Weights distance: min = 0.015, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 796 particles alive (0 particles killed)
# Iteration 41: Espilon = 19.0935, ESS = 802 Acc. rate = 4.52% Uniqueness rate particules = 54.4% Uniqueness rate components = 54.4% Global parameters uniqueness rate = 54.4%
#
# a) Update Epsilon: new epsilon = 18.8
# b) Update weights: Old ESS = 802 New ESS = 756 (5.74% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.6e+01 max 5.9e+01 mean = -0.016 glob min = -2e+01 max = 1.9e+01 mean = 0.96
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0339
# Prior ratio: min = -18.2, max = 3.58, mean = -2.96
# Kernel ratio: min = -18.0, max = 5.18, mean = -1.27
# 3. Results: Acceptance = 3.70% Rejection ABC = 85.19% Rejection MH = 11.11%
# e) Update weights distance: Weights distance: min = 0.0149, max = 0.154
# Performing full optimal assignment (no prior indices).
# After update weights update: 731 particles alive (0 particles killed)
# Iteration 42: Espilon = 18.7811, ESS = 756 Acc. rate = 3.83% Uniqueness rate particules = 56.6% Uniqueness rate components = 56.6% Global parameters uniqueness rate = 56.6%
#
# a) Update Epsilon: new epsilon = 18.5
# b) Update weights: Old ESS = 756 New ESS = 695 (8.07% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.7e+01 max 5.5e+01 mean = -0.13 glob min = -2e+01 max = 1.7e+01 mean = 0.55
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0458
# Prior ratio: min = -21.8, max = 3.92, mean = -2.92
# Kernel ratio: min = -18.4, max = 3.91, mean = -1.23
# 3. Results: Acceptance = 4.32% Rejection ABC = 84.03% Rejection MH = 11.65%
# e) Update weights distance: Weights distance: min = 0.0147, max = 0.153
# Performing full optimal assignment (no prior indices).
# After update weights update: 677 particles alive (0 particles killed)
# Iteration 43: Espilon = 18.5069, ESS = 695 Acc. rate = 4.43% Uniqueness rate particules = 58.5% Uniqueness rate components = 58.5% Global parameters uniqueness rate = 58.5%
#
# a) Update Epsilon: new epsilon = 18.2
# b) Update weights: Old ESS = 695 New ESS = 643 (7.48% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.7e+01 max 5.5e+01 mean = -0.1 glob min = -1.9e+01 max = 1.9e+01 mean = 0.57
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0355
# Prior ratio: min = -15.5, max = 2.66, mean = -2.76
# Kernel ratio: min = -16.4, max = 4.22, mean = -1.15
# 3. Results: Acceptance = 3.89% Rejection ABC = 85.23% Rejection MH = 10.89%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.155
# Performing full optimal assignment (no prior indices).
# After update weights update: 630 particles alive (0 particles killed)
# Iteration 44: Espilon = 18.2341, ESS = 643 Acc. rate = 3.97% Uniqueness rate particules = 60.4% Uniqueness rate components = 60.4% Global parameters uniqueness rate = 60.4%
#
# a) Update Epsilon: new epsilon = 17.8
# b) Update weights: Old ESS = 643 New ESS = 599 (6.84% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.7e+01 max 5e+01 mean = -0.1 glob min = -1.8e+01 max = 2.2e+01 mean = 1.1
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0337
# Prior ratio: min = -21.4, max = 3.83, mean = -2.83
# Kernel ratio: min = -11.1, max = 5.05, mean = -1.24
# 3. Results: Acceptance = 4.01% Rejection ABC = 87.81% Rejection MH = 8.18%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.157
# Performing full optimal assignment (no prior indices).
# After update weights update: 596 particles alive (0 particles killed)
# Iteration 45: Espilon = 17.8119, ESS = 599 Acc. rate = 4.03% Uniqueness rate particules = 61.9% Uniqueness rate components = 61.9% Global parameters uniqueness rate = 61.9%
#
# a) Update Epsilon: new epsilon = 17.4
# b) Update weights: Old ESS = 599 New ESS = 566 (5.51% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.7e+01 max 5.2e+01 mean = -0.18 glob min = -1.8e+01 max = 1.5e+01 mean = 0.5
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0347
# Prior ratio: min = -15.8, max = 4.76, mean = -2.83
# Kernel ratio: min = -21.7, max = 3.76, mean = -1.17
# 3. Results: Acceptance = 3.18% Rejection ABC = 87.46% Rejection MH = 9.36%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.159
# Performing full optimal assignment (no prior indices).
# After update weights update: 559 particles alive (0 particles killed)
# Iteration 46: Espilon = 17.4388, ESS = 566 Acc. rate = 3.22% Uniqueness rate particules = 62.8% Uniqueness rate components = 62.8% Global parameters uniqueness rate = 62.8%
#
# a) Update Epsilon: new epsilon = 17.1
# b) Update weights: Old ESS = 566 New ESS = 531 (6.18% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.7e+01 max 5.3e+01 mean = -0.2 glob min = -1.5e+01 max = 1.7e+01 mean = 0.87
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0349
# Prior ratio: min = -16.6, max = 4.28, mean = -2.81
# Kernel ratio: min = -14.2, max = 6.26, mean = -1.17
# 3. Results: Acceptance = 3.20% Rejection ABC = 86.82% Rejection MH = 9.98%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.158
# Performing full optimal assignment (no prior indices).
# After update weights update: 530 particles alive (0 particles killed)
# Iteration 47: Espilon = 17.1155, ESS = 531 Acc. rate = 3.21% Uniqueness rate particules = 63.8% Uniqueness rate components = 63.8% Global parameters uniqueness rate = 63.8%
#
# a) Update Epsilon: new epsilon = 16.8
# b) Update weights: Old ESS = 531 New ESS = 503 (5.27% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6e+01 max 5.8e+01 mean = -0.22 glob min = -2.1e+01 max = 1.6e+01 mean = 0.94
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0306
# Prior ratio: min = -18.5, max = 3.42, mean = -2.97
# Kernel ratio: min = -14.8, max = 4.4, mean = -1.25
# 3. Results: Acceptance = 1.99% Rejection ABC = 87.48% Rejection MH = 10.54%
# e) Update weights distance: Weights distance: min = 0.0143, max = 0.159
# Performing full optimal assignment (no prior indices).
# After update weights update: 495 particles alive (0 particles killed)
# Iteration 48: Espilon = 16.7794, ESS = 503 Acc. rate = 2.02% Uniqueness rate particules = 64.4% Uniqueness rate components = 64.4% Global parameters uniqueness rate = 64.4%
#
# a) Update Epsilon: new epsilon = 16.6
# b) Update weights: Old ESS = 503 New ESS = 471 (6.36% of particles killed)
# c) Resampling: Resampling... 348 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.4e+01 max 5.5e+01 mean = -0.31 glob min = -1.7e+01 max = 1.7e+01 mean = 0.73
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0331
# Prior ratio: min = -16.7, max = 4.94, mean = -2.66
# Kernel ratio: min = -19.9, max = 4.78, mean = -1.04
# 3. Results: Acceptance = 2.80% Rejection ABC = 88.80% Rejection MH = 8.40%
# e) Update weights distance: Weights distance: min = 0.0152, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 976 particles alive (0 particles killed)
# Iteration 49: Espilon = 16.5563, ESS = 1000 Acc. rate = 2.87% Uniqueness rate particules = 37.5% Uniqueness rate components = 37.5% Global parameters uniqueness rate = 37.5%
#
# a) Update Epsilon: new epsilon = 16.2
# b) Update weights: Old ESS = 1000 New ESS = 928 (7.20% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.2e+01 max 5.5e+01 mean = -0.3 glob min = -1.7e+01 max = 2.1e+01 mean = 0.89
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0334
# Prior ratio: min = -17.7, max = 3.31, mean = -2.7
# Kernel ratio: min = -19.1, max = 7.78, mean = -0.928
# 3. Results: Acceptance = 3.34% Rejection ABC = 90.09% Rejection MH = 6.57%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.161
# Performing full optimal assignment (no prior indices).
# After update weights update: 901 particles alive (0 particles killed)
# Iteration 50: Espilon = 16.2159, ESS = 928 Acc. rate = 3.44% Uniqueness rate particules = 40.3% Uniqueness rate components = 40.3% Global parameters uniqueness rate = 40.3%
#
# a) Update Epsilon: new epsilon = 16.0
# b) Update weights: Old ESS = 928 New ESS = 858 (7.54% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.5e+01 max 5.8e+01 mean = -0.061 glob min = -1.8e+01 max = 2.2e+01 mean = 0.61
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0294
# Prior ratio: min = -18.4, max = 4.11, mean = -2.74
# Kernel ratio: min = -25.1, max = 4.15, mean = -1.03
# 3. Results: Acceptance = 2.91% Rejection ABC = 90.68% Rejection MH = 6.41%
# e) Update weights distance: Weights distance: min = 0.0144, max = 0.163
# Performing full optimal assignment (no prior indices).
# After update weights update: 833 particles alive (0 particles killed)
# Iteration 51: Espilon = 16.0264, ESS = 858 Acc. rate = 3.00% Uniqueness rate particules = 42.5% Uniqueness rate components = 42.5% Global parameters uniqueness rate = 42.5%
#
# a) Update Epsilon: new epsilon = 15.8
# b) Update weights: Old ESS = 858 New ESS = 792 (7.69% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# ...
# Kernel ratio: min = -15.7, max = 6.31, mean = -0.872
# 3. Results: Acceptance = 1.60% Rejection ABC = 94.10% Rejection MH = 4.30%
# e) Update weights distance: Weights distance: min = 0.0143, max = 0.161
# Performing full optimal assignment (no prior indices).
# After update weights update: 1000 particles alive (0 particles killed)
# Iteration 60: Espilon = 15.0821, ESS = 1000 Acc. rate = 1.60% Uniqueness rate particules = 44.0% Uniqueness rate components = 44.0% Global parameters uniqueness rate = 44.0%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 5.2e+01 mean = -0.13 glob min = -1.9e+01 max = 2e+01 mean = 0.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0254
# Prior ratio: min = -14.7, max = 5.29, mean = -2.72
# Kernel ratio: min = -23.5, max = 8.19, mean = -1.01
# 3. Results: Acceptance = 2.60% Rejection ABC = 93.30% Rejection MH = 4.10%
# e) Update weights distance: Weights distance: min = 0.0143, max = 0.161
# Performing full optimal assignment (no prior indices).
# After update weights update: 998 particles alive (0 particles killed)
# Iteration 61: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.61% Uniqueness rate particules = 45.9% Uniqueness rate components = 45.9% Global parameters uniqueness rate = 45.9%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 998 (0.20% of particles killed)
# c) Resampling: Resampling... 457 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6e+01 max 5.4e+01 mean = 0.0043 glob min = -2.2e+01 max = 1.8e+01 mean = 0.58
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0279
# Prior ratio: min = -20.7, max = 3.74, mean = -2.44
# Kernel ratio: min = -15.6, max = 5.07, mean = -0.979
# 3. Results: Acceptance = 3.40% Rejection ABC = 91.70% Rejection MH = 4.90%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.161
# Performing full optimal assignment (no prior indices).
# After update weights update: 1000 particles alive (0 particles killed)
# Iteration 62: Espilon = 15.0821, ESS = 1000 Acc. rate = 3.40% Uniqueness rate particules = 47.8% Uniqueness rate components = 47.8% Global parameters uniqueness rate = 47.8%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.8e+01 max 5.6e+01 mean = -0.036 glob min = -2e+01 max = 1.9e+01 mean = 0.64
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0234
# Prior ratio: min = -16.1, max = 3.31, mean = -2.75
# Kernel ratio: min = -22.7, max = 6.37, mean = -0.765
# 3. Results: Acceptance = 2.70% Rejection ABC = 92.00% Rejection MH = 5.30%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.162
# Performing full optimal assignment (no prior indices).
# After update weights update: 994 particles alive (0 particles killed)
# Iteration 63: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.72% Uniqueness rate particules = 49.6% Uniqueness rate components = 49.6% Global parameters uniqueness rate = 49.6%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 994 (0.60% of particles killed)
# c) Resampling: Resampling... 490 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.2e+01 max 6e+01 mean = -0.028 glob min = -1.5e+01 max = 1.8e+01 mean = 1.1
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0305
# Prior ratio: min = -18.2, max = 4.27, mean = -2.55
# Kernel ratio: min = -14.3, max = 5.43, mean = -0.907
# 3. Results: Acceptance = 3.00% Rejection ABC = 92.00% Rejection MH = 5.00%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.162
# Performing full optimal assignment (no prior indices).
# After update weights update: 1000 particles alive (0 particles killed)
# Iteration 64: Espilon = 15.0821, ESS = 1000 Acc. rate = 3.00% Uniqueness rate particules = 51.2% Uniqueness rate components = 51.2% Global parameters uniqueness rate = 51.2%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.8e+01 max 5.9e+01 mean = 0.074 glob min = -2e+01 max = 2.2e+01 mean = 0.75
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.029
# Prior ratio: min = -20.3, max = 4.38, mean = -2.68
# Kernel ratio: min = -20.0, max = 4.96, mean = -1.06
# 3. Results: Acceptance = 3.30% Rejection ABC = 91.20% Rejection MH = 5.50%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 998 particles alive (0 particles killed)
# Iteration 65: Espilon = 15.0821, ESS = 1000 Acc. rate = 3.31% Uniqueness rate particules = 53.5% Uniqueness rate components = 53.5% Global parameters uniqueness rate = 53.5%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 998 (0.20% of particles killed)
# c) Resampling: Resampling... 533 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.7e+01 max 5.3e+01 mean = -0.014 glob min = -1.8e+01 max = 2.1e+01 mean = 0.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0211
# Prior ratio: min = -19.9, max = 3.4, mean = -2.63
# Kernel ratio: min = -16.9, max = 5.1, mean = -0.838
# 3. Results: Acceptance = 2.30% Rejection ABC = 92.80% Rejection MH = 4.90%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 997 particles alive (0 particles killed)
# Iteration 66: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.31% Uniqueness rate particules = 54.2% Uniqueness rate components = 54.2% Global parameters uniqueness rate = 54.2%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 997 (0.30% of particles killed)
# c) Resampling: Resampling... 539 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.5e+01 max 6.3e+01 mean = 0.089 glob min = -2.1e+01 max = 2.1e+01 mean = 0.76
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.027
# Prior ratio: min = -20.7, max = 3.78, mean = -2.73
# Kernel ratio: min = -17.6, max = 5.37, mean = -0.993
# 3. Results: Acceptance = 2.60% Rejection ABC = 91.20% Rejection MH = 6.20%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 998 particles alive (0 particles killed)
# Iteration 67: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.61% Uniqueness rate particules = 56.0% Uniqueness rate components = 56.0% Global parameters uniqueness rate = 56.0%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 998 (0.20% of particles killed)
# c) Resampling: Resampling... 558 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.4e+01 max 6e+01 mean = -0.047 glob min = -2.1e+01 max = 2e+01 mean = 0.69
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0282
# Prior ratio: min = -23.1, max = 3.05, mean = -2.79
# Kernel ratio: min = -21.5, max = 5.46, mean = -0.948
# 3. Results: Acceptance = 2.80% Rejection ABC = 93.30% Rejection MH = 3.90%
# e) Update weights distance: Weights distance: min = 0.0146, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 999 particles alive (0 particles killed)
# Iteration 68: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.80% Uniqueness rate particules = 57.2% Uniqueness rate components = 57.2% Global parameters uniqueness rate = 57.2%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 999 (0.10% of particles killed)
# c) Resampling: Resampling... 571 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.7e+01 max 4.9e+01 mean = 0.073 glob min = -1.8e+01 max = 2.2e+01 mean = 0.77
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0166
# Prior ratio: min = -14.6, max = 5.38, mean = -2.68
# Kernel ratio: min = -17.4, max = 6.34, mean = -1.04
# 3. Results: Acceptance = 1.70% Rejection ABC = 93.70% Rejection MH = 4.60%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.159
# Performing full optimal assignment (no prior indices).
# After update weights update: 999 particles alive (0 particles killed)
# Iteration 69: Espilon = 15.0821, ESS = 1000 Acc. rate = 1.70% Uniqueness rate particules = 58.3% Uniqueness rate components = 58.3% Global parameters uniqueness rate = 58.3%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 999 (0.10% of particles killed)
# c) Resampling: Resampling... 582 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -4.6e+01 max 6e+01 mean = -0.033 glob min = -1.6e+01 max = 1.9e+01 mean = 0.58
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0202
# Prior ratio: min = -16.9, max = 4.77, mean = -2.47
# Kernel ratio: min = -21.9, max = 5.83, mean = -1.08
# 3. Results: Acceptance = 1.90% Rejection ABC = 93.80% Rejection MH = 4.30%
# e) Update weights distance: Weights distance: min = 0.0143, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 998 particles alive (0 particles killed)
# Iteration 70: Espilon = 15.0821, ESS = 1000 Acc. rate = 1.90% Uniqueness rate particules = 59.2% Uniqueness rate components = 59.2% Global parameters uniqueness rate = 59.2%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 998 (0.20% of particles killed)
# c) Resampling: Resampling... 591 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.1e+01 max 4.9e+01 mean = 0.021 glob min = -2e+01 max = 2.4e+01 mean = 0.62
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0273
# Prior ratio: min = -15.2, max = 3.98, mean = -2.63
# Kernel ratio: min = -12.8, max = 5.09, mean = -0.927
# 3. Results: Acceptance = 2.50% Rejection ABC = 92.50% Rejection MH = 5.00%
# e) Update weights distance: Weights distance: min = 0.0144, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 997 particles alive (0 particles killed)
# Iteration 71: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.51% Uniqueness rate particules = 60.5% Uniqueness rate components = 60.5% Global parameters uniqueness rate = 60.5%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 997 (0.30% of particles killed)
# c) Resampling: Resampling... 603 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.2e+01 max 6.4e+01 mean = 0.047 glob min = -1.8e+01 max = 2e+01 mean = 0.84
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0282
# Prior ratio: min = -19.8, max = 4.68, mean = -2.7
# Kernel ratio: min = -20.7, max = 7.66, mean = -0.907
# 3. Results: Acceptance = 3.00% Rejection ABC = 92.30% Rejection MH = 4.70%
# e) Update weights distance: Weights distance: min = 0.0144, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 1000 particles alive (0 particles killed)
# Iteration 72: Espilon = 15.0821, ESS = 1000 Acc. rate = 3.00% Uniqueness rate particules = 62.2% Uniqueness rate components = 62.2% Global parameters uniqueness rate = 62.2%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 1000 (0.00% of particles killed)
# c) Resampling: No resampling
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5.4e+01 max 5.5e+01 mean = 0.03 glob min = -1.9e+01 max = 2.1e+01 mean = 0.81
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0239
# Prior ratio: min = -17.4, max = 3.63, mean = -2.72
# Kernel ratio: min = -17.8, max = 4.89, mean = -0.871
# 3. Results: Acceptance = 2.60% Rejection ABC = 93.60% Rejection MH = 3.80%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.159
# Performing full optimal assignment (no prior indices).
# After update weights update: 999 particles alive (0 particles killed)
# Iteration 73: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.60% Uniqueness rate particules = 63.7% Uniqueness rate components = 63.7% Global parameters uniqueness rate = 63.7%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 999 (0.10% of particles killed)
# c) Resampling: Resampling... 636 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -5e+01 max 7.2e+01 mean = -0.029 glob min = -2.5e+01 max = 2.1e+01 mean = 0.83
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0176
# Prior ratio: min = -26.2, max = 3.35, mean = -2.83
# Kernel ratio: min = -19.5, max = 5.33, mean = -0.916
# 3. Results: Acceptance = 1.50% Rejection ABC = 94.20% Rejection MH = 4.30%
# e) Update weights distance: Weights distance: min = 0.0144, max = 0.159
# Performing full optimal assignment (no prior indices).
# After update weights update: 997 particles alive (0 particles killed)
# Iteration 74: Espilon = 15.0821, ESS = 1000 Acc. rate = 1.50% Uniqueness rate particules = 64.4% Uniqueness rate components = 64.4% Global parameters uniqueness rate = 64.4%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 997 (0.30% of particles killed)
# c) Resampling: Resampling... 643 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6e+01 max 5e+01 mean = 0.044 glob min = -1.7e+01 max = 1.9e+01 mean = 0.75
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0223
# Prior ratio: min = -16.5, max = 3.22, mean = -2.69
# Kernel ratio: min = -25.6, max = 4.02, mean = -1.07
# 3. Results: Acceptance = 2.10% Rejection ABC = 92.00% Rejection MH = 5.90%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.16
# Performing full optimal assignment (no prior indices).
# After update weights update: 993 particles alive (0 particles killed)
# Iteration 75: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.11% Uniqueness rate particules = 65.2% Uniqueness rate components = 65.2% Global parameters uniqueness rate = 65.2%
#
# a) Update Epsilon: new epsilon = 15.1
# b) Update weights: Old ESS = 1000 New ESS = 993 (0.70% of particles killed)
# c) Resampling: Resampling... 648 unique particles left
# d) Move particles: 1. Forward kernel:
# Performing full optimal assignment (no prior indices).
# Sample proposal: loc min = -6.1e+01 max 5.2e+01 mean = 0.043 glob min = -1.6e+01 max = 2.3e+01 mean = 0.81
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.023
# Prior ratio: min = -18.6, max = 3.87, mean = -2.62
# Kernel ratio: min = -17.7, max = 5.32, mean = -1.11
# 3. Results: Acceptance = 2.50% Rejection ABC = 93.50% Rejection MH = 4.00%
# e) Update weights distance: Weights distance: min = 0.0145, max = 0.158
# Performing full optimal assignment (no prior indices).
# After update weights update: 997 particles alive (0 particles killed)
# Iteration 76: Espilon = 15.0821, ESS = 1000 Acc. rate = 2.51% Uniqueness rate particules = 66.0% Uniqueness rate components = 66.0% Global parameters uniqueness rate = 66.0%

# %%
k = 1
sns.kdeplot(mus_perm_smc[:,k], label="SMC perm", color="blue")
sns.kdeplot(mus_perm_smc2[:,k], label="SMC perm + weights", color="orange")
sns.kdeplot(true_post_mu[:,k], label="True post", color="green")
plt.legend()
plt.show()

# %% [markdown]
# ## Over Sampling

# %%
M0 = 50
key = random.PRNGKey(0)
key, subkey = random.split(key)
kernel = KernelTruncatedRW
os = perm_abc_smc_os(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 3, M_0 = M0, duplicate= True, n_duplicate = 0, alpha_M = .9, Final_iteration= 50, update_weights_distance= False)
mus_os = os["Thetas"][-1].loc.squeeze()
betas_os = os["Thetas"][-1].glob.squeeze()
n_sim_os = np.sum(os["N_sim"])
# Out:
# a) Simulation of the first particles:
# b) Computing the first distances: (10,)
# SHapes: y = (10, 100), z = (50, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# min = 0.69 max = 1.5e+02 mean = 7.4
# d) Setting the first weights: ESS = 971
# Iteration 0: M = 50 Epsilon = 29.23336061477661, ESS = 971 Acc. rate = 100% Numb. unique particles = 1000
#
# a) Update M: new M = 46 old M = 50
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 971 alive particles in 2 copies...
# (1942, 50) 2
# Now particles of shape (2942, 50, 1) and (2942, 50, 100) with 2942 unique particles
# c) Truncate particles: before (2942, 50, 1),(2942, 50, 100) after (2942, 46, 1),(2942, 46, 100)
# Aucun changement =  False
# d) Compute optimal distances: 971 unique alive particles (10,)
# SHapes: y = (10, 100), z = (46, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 2913 New ESS = 2902 (0.38% of the particles killed)
# f) Resampling: Resampling... 964 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.59 max = 1.1 std = 0.17
# Tau glob: min = 1.9 max = 1.9 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (46, 100), w = (10,), L = 10
# Performing linear sum assignment for 104 particles.
# Smart Acceptance: 89.60% (896/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 10.40% (104/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.59 max = 1.1 std = 0.17
# Tau glob: min = 1.9 max = 1.9 std = 0.0
# PRIOR MU: min = -1.92e+02, max = -1.6e+02, mean = -1.71e+02
# PRIOR SIGMA: min = -2.13e+03, max = -0.757, mean = -8.1
# PRIOR MU: min = -1.91e+02, max = -1.6e+02, mean = -1.71e+02
# PRIOR SIGMA: min = -5.94, max = -0.757, mean = -1.47
# Sample proposal: loc min = -3.8e+01 max 4.9e+01 mean = -0.039 glob min = 0.0023 max = 9.0 mean = 2.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.477
# Prior ratio: min = -2.13e+03, max = 4.42, mean = -6.73
# Kernel ratio: min = -15.3, max = 1.93, mean = -0.263
# 3. Results: Acceptance = 47.80% Rejection ABC = 10.40% Rejection MH = 41.80%
# Prior forward: min = -2.31e+03, max = -1.62e+02, mean = -1.79e+02
# Forward thetas loc: min = -37.8, max = 48.9, mean = -0.0391 global: min = 0.00231, max = 8.95, mean = 2.74
# Prior backward: min = -1.94e+02, max = -1.61e+02, mean = -1.73e+02
# Backward thetas loc: min = -37.8, max = 48.9, mean = -0.0409 global: min = 0.458, max = 7.54, mean = 2.17
# Iteration 2: M = 46 Espilon = 29.2334, ESS = 1000 Acc. rate = 47.80% Uniqueness rate particules = 100.0% Uniqueness rate components = 94.5% Global parameters uniqueness rate = 94.1%
#
# a) Update M: new M = 42 old M = 46
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 46) 2
# Now particles of shape (3000, 46, 1) and (3000, 46, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 46, 1),(3000, 46, 100) after (3000, 42, 1),(3000, 42, 100)
# Aucun changement =  False
# d) Compute optimal distances: 992 unique alive particles (10,)
# SHapes: y = (10, 100), z = (42, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2992 (0.27% of the particles killed)
# f) Resampling: Resampling... 974 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.62 max = 1.2 std = 0.2
# Tau glob: min = 1.8 max = 1.8 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (42, 100), w = (10,), L = 10
# Performing linear sum assignment for 124 particles.
# Smart Acceptance: 87.60% (876/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 12.40% (124/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.62 max = 1.2 std = 0.2
# Tau glob: min = 1.8 max = 1.8 std = 0.0
# PRIOR MU: min = -1.76e+02, max = -1.45e+02, mean = -1.56e+02
# PRIOR SIGMA: min = -4.63e+02, max = -0.757, mean = -5.01
# PRIOR MU: min = -1.76e+02, max = -1.45e+02, mean = -1.56e+02
# PRIOR SIGMA: min = -4.53, max = -0.757, mean = -1.45
# Sample proposal: loc min = -3.8e+01 max 4.9e+01 mean = 0.045 glob min = 0.01 max = 1.1e+01 mean = 2.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.491
# Prior ratio: min = -4.63e+02, max = 3.23, mean = -3.65
# Kernel ratio: min = -17.6, max = 3.71, mean = -0.414
# 3. Results: Acceptance = 50.40% Rejection ABC = 12.40% Rejection MH = 37.20%
# Prior forward: min = -6.18e+02, max = -1.46e+02, mean = -1.62e+02
# Forward thetas loc: min = -37.9, max = 49.1, mean = 0.0451 global: min = 0.0103, max = 10.6, mean = 2.69
# Prior backward: min = -1.79e+02, max = -1.47e+02, mean = -1.58e+02
# Backward thetas loc: min = -37.8, max = 48.9, mean = 0.043 global: min = 0.442, max = 7.36, mean = 2.15
# Iteration 3: M = 42 Espilon = 29.2334, ESS = 1000 Acc. rate = 50.40% Uniqueness rate particules = 100.0% Uniqueness rate components = 94.6% Global parameters uniqueness rate = 94.0%
#
# a) Update M: new M = 38 old M = 42
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 42) 2
# Now particles of shape (3000, 42, 1) and (3000, 42, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 42, 1),(3000, 42, 100) after (3000, 38, 1),(3000, 38, 100)
# Aucun changement =  False
# d) Compute optimal distances: 993 unique alive particles (10,)
# SHapes: y = (10, 100), z = (38, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2991 (0.30% of the particles killed)
# f) Resampling: Resampling... 981 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.69 max = 1.3 std = 0.22
# Tau glob: min = 1.7 max = 1.7 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (38, 100), w = (10,), L = 10
# Performing linear sum assignment for 188 particles.
# Smart Acceptance: 81.20% (812/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 18.80% (188/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.69 max = 1.3 std = 0.22
# Tau glob: min = 1.7 max = 1.7 std = 0.0
# PRIOR MU: min = -1.6e+02, max = -1.32e+02, mean = -1.42e+02
# PRIOR SIGMA: min = -4.07e+03, max = -0.757, mean = -7.35
# PRIOR MU: min = -1.58e+02, max = -1.31e+02, mean = -1.41e+02
# PRIOR SIGMA: min = -4.49, max = -0.757, mean = -1.41
# Sample proposal: loc min = -3.9e+01 max 4.8e+01 mean = -0.014 glob min = 0.0012 max = 9.7 mean = 2.6
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.469
# Prior ratio: min = -4.07e+03, max = 2.55, mean = -6.07
# Kernel ratio: min = -26.9, max = 2.51, mean = -0.666
# 3. Results: Acceptance = 47.20% Rejection ABC = 18.80% Rejection MH = 34.00%
# Prior forward: min = -4.21e+03, max = -1.33e+02, mean = -1.49e+02
# Forward thetas loc: min = -38.5, max = 47.9, mean = -0.0142 global: min = 0.00122, max = 9.66, mean = 2.59
# Prior backward: min = -1.62e+02, max = -1.33e+02, mean = -1.43e+02
# Backward thetas loc: min = -38.5, max = 47.9, mean = -0.0165 global: min = 0.427, max = 7.27, mean = 2.09
# Iteration 4: M = 38 Espilon = 29.2334, ESS = 1000 Acc. rate = 47.20% Uniqueness rate particules = 100.0% Uniqueness rate components = 94.4% Global parameters uniqueness rate = 93.7%
#
# a) Update M: new M = 35 old M = 38
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 38) 2
# Now particles of shape (3000, 38, 1) and (3000, 38, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 38, 1),(3000, 38, 100) after (3000, 35, 1),(3000, 35, 100)
# Aucun changement =  False
# d) Compute optimal distances: 995 unique alive particles (10,)
# SHapes: y = (10, 100), z = (35, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2985 (0.50% of the particles killed)
# f) Resampling: Resampling... 960 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.74 max = 1.4 std = 0.24
# Tau glob: min = 1.7 max = 1.7 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (35, 100), w = (10,), L = 10
# Performing linear sum assignment for 237 particles.
# Smart Acceptance: 76.30% (763/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 23.70% (237/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.74 max = 1.4 std = 0.24
# Tau glob: min = 1.7 max = 1.7 std = 0.0
# PRIOR MU: min = -1.47e+02, max = -1.2e+02, mean = -1.3e+02
# PRIOR SIGMA: min = -1.76e+02, max = -0.758, mean = -3.26
# PRIOR MU: min = -1.47e+02, max = -1.21e+02, mean = -1.3e+02
# PRIOR SIGMA: min = -4.32, max = -0.757, mean = -1.42
# Sample proposal: loc min = -3.7e+01 max 4.8e+01 mean = -0.015 glob min = 0.026 max = 9.0 mean = 2.5
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.446
# Prior ratio: min = -1.76e+02, max = 3.09, mean = -1.97
# Kernel ratio: min = -20.0, max = 3.9, mean = -0.87
# 3. Results: Acceptance = 44.40% Rejection ABC = 23.70% Rejection MH = 31.90%
# Prior forward: min = -3.02e+02, max = -1.21e+02, mean = -1.34e+02
# Forward thetas loc: min = -37.1, max = 48.2, mean = -0.0154 global: min = 0.0257, max = 9.05, mean = 2.48
# Prior backward: min = -1.51e+02, max = -1.22e+02, mean = -1.32e+02
# Backward thetas loc: min = -37.1, max = 47.9, mean = -0.0133 global: min = 0.442, max = 6.9, mean = 2.05
# Iteration 5: M = 35 Espilon = 29.2334, ESS = 1000 Acc. rate = 44.40% Uniqueness rate particules = 100.0% Uniqueness rate components = 92.6% Global parameters uniqueness rate = 91.9%
#
# a) Update M: new M = 32 old M = 35
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 35) 2
# Now particles of shape (3000, 35, 1) and (3000, 35, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 35, 1),(3000, 35, 100) after (3000, 32, 1),(3000, 32, 100)
# Aucun changement =  False
# d) Compute optimal distances: 989 unique alive particles (10,)
# SHapes: y = (10, 100), z = (32, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2964 (1.20% of the particles killed)
# f) Resampling: Resampling... 970 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.81 max = 1.6 std = 0.28
# Tau glob: min = 1.5 max = 1.5 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (32, 100), w = (10,), L = 10
# Performing linear sum assignment for 304 particles.
# Smart Acceptance: 69.60% (696/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 30.40% (304/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.81 max = 1.6 std = 0.28
# Tau glob: min = 1.5 max = 1.5 std = 0.0
# PRIOR MU: min = -1.37e+02, max = -1.1e+02, mean = -1.19e+02
# PRIOR SIGMA: min = -3.23e+03, max = -0.757, mean = -12.7
# PRIOR MU: min = -1.36e+02, max = -1.1e+02, mean = -1.19e+02
# PRIOR SIGMA: min = -4.32, max = -0.757, mean = -1.33
# Sample proposal: loc min = -3.6e+01 max 4.8e+01 mean = -0.056 glob min = 0.0015 max = 8.3 mean = 2.3
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.415
# Prior ratio: min = -3.23e+03, max = 4.11, mean = -11.5
# Kernel ratio: min = -18.1, max = 2.04, mean = -1.17
# 3. Results: Acceptance = 41.70% Rejection ABC = 30.40% Rejection MH = 27.90%
# Prior forward: min = -3.36e+03, max = -1.11e+02, mean = -1.32e+02
# Forward thetas loc: min = -35.6, max = 47.9, mean = -0.0565 global: min = 0.00153, max = 8.29, mean = 2.29
# Prior backward: min = -1.37e+02, max = -1.11e+02, mean = -1.2e+02
# Backward thetas loc: min = -36.6, max = 47.9, mean = -0.0573 global: min = 0.49, max = 6.9, mean = 1.95
# Iteration 6: M = 32 Espilon = 29.2334, ESS = 1000 Acc. rate = 41.70% Uniqueness rate particules = 100.0% Uniqueness rate components = 89.6% Global parameters uniqueness rate = 88.6%
#
# a) Update M: new M = 29 old M = 32
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 32) 2
# Now particles of shape (3000, 32, 1) and (3000, 32, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 32, 1),(3000, 32, 100) after (3000, 29, 1),(3000, 29, 100)
# Aucun changement =  False
# d) Compute optimal distances: 988 unique alive particles (10,)
# SHapes: y = (10, 100), z = (29, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2971 (0.97% of the particles killed)
# f) Resampling: Resampling... 975 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.88 max = 1.7 std = 0.3
# Tau glob: min = 1.5 max = 1.5 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (29, 100), w = (10,), L = 10
# Performing linear sum assignment for 409 particles.
# Smart Acceptance: 59.10% (591/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 40.90% (409/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.88 max = 1.7 std = 0.3
# Tau glob: min = 1.5 max = 1.5 std = 0.0
# PRIOR MU: min = -1.23e+02, max = -98.5, mean = -1.08e+02
# PRIOR SIGMA: min = -1.22e+03, max = -0.757, mean = -6.23
# PRIOR MU: min = -1.23e+02, max = -98.5, mean = -1.08e+02
# PRIOR SIGMA: min = -4.32, max = -0.757, mean = -1.31
# Sample proposal: loc min = -3.5e+01 max 4.9e+01 mean = -0.089 glob min = 0.004 max = 9.6 mean = 2.3
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.357
# Prior ratio: min = -1.21e+03, max = 2.64, mean = -5.06
# Kernel ratio: min = -19.2, max = 3.17, mean = -1.35
# 3. Results: Acceptance = 35.80% Rejection ABC = 40.90% Rejection MH = 23.30%
# Prior forward: min = -1.32e+03, max = -99.4, mean = -1.14e+02
# Forward thetas loc: min = -35.5, max = 48.7, mean = -0.0894 global: min = 0.00403, max = 9.56, mean = 2.3
# Prior backward: min = -1.25e+02, max = -99.5, mean = -1.09e+02
# Backward thetas loc: min = -36.6, max = 48.7, mean = -0.0819 global: min = 0.518, max = 6.9, mean = 1.93
# Iteration 7: M = 29 Espilon = 29.2334, ESS = 1000 Acc. rate = 35.80% Uniqueness rate particules = 100.0% Uniqueness rate components = 88.0% Global parameters uniqueness rate = 86.6%
#
# a) Update M: new M = 27 old M = 29
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 29) 2
# Now particles of shape (3000, 29, 1) and (3000, 29, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 29, 1),(3000, 29, 100) after (3000, 27, 1),(3000, 27, 100)
# Aucun changement =  False
# d) Compute optimal distances: 993 unique alive particles (10,)
# SHapes: y = (10, 100), z = (27, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2935 (2.17% of the particles killed)
# f) Resampling: Resampling... 949 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.92 max = 1.8 std = 0.31
# Tau glob: min = 1.4 max = 1.4 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (27, 100), w = (10,), L = 10
# Performing linear sum assignment for 477 particles.
# Smart Acceptance: 52.30% (523/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 47.70% (477/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.92 max = 1.8 std = 0.31
# Tau glob: min = 1.4 max = 1.4 std = 0.0
# PRIOR MU: min = -1.16e+02, max = -91.6, mean = -1e+02
# PRIOR SIGMA: min = -2.17e+03, max = -0.757, mean = -6.2
# PRIOR MU: min = -1.14e+02, max = -91.7, mean = -1e+02
# PRIOR SIGMA: min = -4.32, max = -0.757, mean = -1.29
# Sample proposal: loc min = -3.5e+01 max 4.9e+01 mean = -0.067 glob min = 0.0023 max = 1.1e+01 mean = 2.2
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.315
# Prior ratio: min = -2.17e+03, max = 1.93, mean = -5.06
# Kernel ratio: min = -20.7, max = 3.51, mean = -1.36
# 3. Results: Acceptance = 31.10% Rejection ABC = 47.70% Rejection MH = 21.20%
# Prior forward: min = -2.27e+03, max = -93.0, mean = -1.07e+02
# Forward thetas loc: min = -34.9, max = 49.4, mean = -0.0667 global: min = 0.00227, max = 10.6, mean = 2.2
# Prior backward: min = -1.16e+02, max = -92.6, mean = -1.01e+02
# Backward thetas loc: min = -34.9, max = 48.7, mean = -0.0684 global: min = 0.521, max = 6.9, mean = 1.9
# Iteration 8: M = 27 Espilon = 29.2334, ESS = 1000 Acc. rate = 31.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 86.9% Global parameters uniqueness rate = 85.6%
#
# a) Update M: new M = 25 old M = 27
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 27) 2
# Now particles of shape (3000, 27, 1) and (3000, 27, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 27, 1),(3000, 27, 100) after (3000, 25, 1),(3000, 25, 100)
# Aucun changement =  False
# d) Compute optimal distances: 978 unique alive particles (10,)
# SHapes: y = (10, 100), z = (25, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2921 (2.63% of the particles killed)
# f) Resampling: Resampling... 960 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 0.96 max = 1.9 std = 0.31
# Tau glob: min = 1.4 max = 1.4 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (25, 100), w = (10,), L = 10
# Performing linear sum assignment for 497 particles.
# Smart Acceptance: 50.30% (503/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 49.70% (497/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 0.96 max = 1.9 std = 0.31
# Tau glob: min = 1.4 max = 1.4 std = 0.0
# PRIOR MU: min = -1.06e+02, max = -85.0, mean = -92.9
# PRIOR SIGMA: min = -1.99e+03, max = -0.757, mean = -8.06
# PRIOR MU: min = -1.06e+02, max = -84.3, mean = -92.7
# PRIOR SIGMA: min = -4.19, max = -0.757, mean = -1.28
# Sample proposal: loc min = -3.6e+01 max 5e+01 mean = 0.0031 glob min = 0.0025 max = 8.7 mean = 2.2
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.307
# Prior ratio: min = -1.99e+03, max = 3.28, mean = -6.93
# Kernel ratio: min = -22.5, max = 4.04, mean = -1.37
# 3. Results: Acceptance = 32.50% Rejection ABC = 49.70% Rejection MH = 17.80%
# Prior forward: min = -2.08e+03, max = -85.9, mean = -1.01e+02
# Forward thetas loc: min = -35.7, max = 49.5, mean = 0.0031 global: min = 0.00248, max = 8.66, mean = 2.21
# Prior backward: min = -1.08e+02, max = -85.1, mean = -94.0
# Backward thetas loc: min = -34.9, max = 49.5, mean = -0.0028 global: min = 0.458, max = 6.63, mean = 1.89
# Iteration 9: M = 25 Espilon = 29.2334, ESS = 1000 Acc. rate = 32.50% Uniqueness rate particules = 100.0% Uniqueness rate components = 86.1% Global parameters uniqueness rate = 84.6%
#
# a) Update M: new M = 23 old M = 25
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 25) 2
# Now particles of shape (3000, 25, 1) and (3000, 25, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 25, 1),(3000, 25, 100) after (3000, 23, 1),(3000, 23, 100)
# Aucun changement =  False
# d) Compute optimal distances: 985 unique alive particles (10,)
# SHapes: y = (10, 100), z = (23, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2892 (3.60% of the particles killed)
# f) Resampling: Resampling... 970 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.1 max = 1.9 std = 0.31
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (23, 100), w = (10,), L = 10
# Performing linear sum assignment for 631 particles.
# Smart Acceptance: 36.90% (369/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 63.10% (631/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 1.1 max = 1.9 std = 0.31
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# PRIOR MU: min = -1e+02, max = -77.8, mean = -85.5
# PRIOR SIGMA: min = -1e+04, max = -0.757, mean = -15.0
# PRIOR MU: min = -99.9, max = -77.4, mean = -85.3
# PRIOR SIGMA: min = -4.19, max = -0.757, mean = -1.26
# Sample proposal: loc min = -3.5e+01 max 5e+01 mean = 0.13 glob min = 0.0005 max = 7.1 mean = 2.2
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.217
# Prior ratio: min = -1e+04, max = 2.93, mean = -13.9
# Kernel ratio: min = -13.4, max = 6.15, mean = -1.13
# 3. Results: Acceptance = 22.40% Rejection ABC = 63.10% Rejection MH = 14.50%
# Prior forward: min = -1.01e+04, max = -78.9, mean = -1e+02
# Forward thetas loc: min = -35.4, max = 50.1, mean = 0.131 global: min = 0.000498, max = 7.14, mean = 2.2
# Prior backward: min = -1.02e+02, max = -78.5, mean = -86.6
# Backward thetas loc: min = -34.9, max = 49.5, mean = 0.124 global: min = 0.451, max = 6.63, mean = 1.89
# Iteration 10: M = 23 Espilon = 29.2334, ESS = 1000 Acc. rate = 22.40% Uniqueness rate particules = 100.0% Uniqueness rate components = 81.5% Global parameters uniqueness rate = 79.4%
#
# a) Update M: new M = 21 old M = 23
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 23) 2
# Now particles of shape (3000, 23, 1) and (3000, 23, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 23, 1),(3000, 23, 100) after (3000, 21, 1),(3000, 21, 100)
# Aucun changement =  False
# d) Compute optimal distances: 984 unique alive particles (10,)
# SHapes: y = (10, 100), z = (21, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2789 (7.03% of the particles killed)
# f) Resampling: Resampling... 970 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.1 max = 2.2 std = 0.32
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (21, 100), w = (10,), L = 10
# Performing linear sum assignment for 677 particles.
# Smart Acceptance: 32.30% (323/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 67.70% (677/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 1.1 max = 2.2 std = 0.32
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# PRIOR MU: min = -93.3, max = -70.5, mean = -78.1
# PRIOR SIGMA: min = -3.45e+03, max = -0.757, mean = -9.0
# PRIOR MU: min = -93.4, max = -70.7, mean = -77.9
# PRIOR SIGMA: min = -4.19, max = -0.757, mean = -1.28
# Sample proposal: loc min = -3.6e+01 max 4.9e+01 mean = 0.13 glob min = 0.0014 max = 6.6 mean = 2.1
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.206
# Prior ratio: min = -3.45e+03, max = 2.36, mean = -7.92
# Kernel ratio: min = -12.0, max = 3.76, mean = -1.13
# 3. Results: Acceptance = 20.60% Rejection ABC = 67.70% Rejection MH = 11.70%
# Prior forward: min = -3.53e+03, max = -71.7, mean = -87.1
# Forward thetas loc: min = -36.5, max = 49.5, mean = 0.126 global: min = 0.00144, max = 6.64, mean = 2.14
# Prior backward: min = -95.1, max = -71.9, mean = -79.1
# Backward thetas loc: min = -34.9, max = 49.5, mean = 0.153 global: min = 0.499, max = 6.63, mean = 1.9
# Iteration 11: M = 21 Espilon = 29.2334, ESS = 1000 Acc. rate = 20.60% Uniqueness rate particules = 100.0% Uniqueness rate components = 78.4% Global parameters uniqueness rate = 75.7%
#
# a) Update M: new M = 19 old M = 21
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  3
# Duplicating the 1000 alive particles in 3 copies...
# (3000, 21) 3
# Now particles of shape (4000, 21, 1) and (4000, 21, 100) with 4000 unique particles
# c) Truncate particles: before (4000, 21, 1),(4000, 21, 100) after (4000, 19, 1),(4000, 19, 100)
# Aucun changement =  False
# d) Compute optimal distances: 983 unique alive particles (10,)
# SHapes: y = (10, 100), z = (19, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 4000 New ESS = 3617 (9.57% of the particles killed)
# f) Resampling: Resampling... 980 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.3 max = 2.3 std = 0.35
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (19, 100), w = (10,), L = 10
# Performing linear sum assignment for 798 particles.
# Smart Acceptance: 20.20% (202/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 79.70% (797/1000 particles).
# Unchanged but rejected after reassignment: 0.10% (1/1000 particles).
# Tau loc: min = 1.3 max = 2.3 std = 0.35
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# PRIOR MU: min = -87.4, max = -64.2, mean = -70.5
# PRIOR SIGMA: min = -6.31e+03, max = -0.757, mean = -11.3
# PRIOR MU: min = -86.7, max = -63.9, mean = -70.3
# PRIOR SIGMA: min = -4.19, max = -0.757, mean = -1.25
# Sample proposal: loc min = -3.4e+01 max 5e+01 mean = 0.22 glob min = 0.00079 max = 7.6 mean = 2.1
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.128
# Prior ratio: min = -6.31e+03, max = 2.58, mean = -10.2
# Kernel ratio: min = -12.3, max = 3.98, mean = -1.19
# 3. Results: Acceptance = 12.70% Rejection ABC = 79.80% Rejection MH = 7.50%
# Prior forward: min = -6.38e+03, max = -65.4, mean = -81.8
# Forward thetas loc: min = -34.5, max = 49.6, mean = 0.218 global: min = 0.000789, max = 7.59, mean = 2.14
# Prior backward: min = -88.0, max = -65.2, mean = -71.6
# Backward thetas loc: min = -34.9, max = 49.5, mean = 0.222 global: min = 0.462, max = 6.63, mean = 1.87
# Iteration 12: M = 19 Espilon = 29.2334, ESS = 1000 Acc. rate = 12.70% Uniqueness rate particules = 100.0% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 70.8%
#
# a) Update M: new M = 18 old M = 19
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  1
# No duplication because n_duplicate = 1
# c) Truncate particles: before (1000, 19, 1),(1000, 19, 100) after (1000, 18, 1),(1000, 18, 100)
# Aucun changement =  False
# d) Compute optimal distances: 986 unique alive particles (10,)
# SHapes: y = (10, 100), z = (18, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 926 (7.40% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.3 max = 2.4 std = 0.35
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (18, 100), w = (10,), L = 10
# Performing linear sum assignment for 754 particles.
# Smart Acceptance: 18.57% (172/926 particles).
# Newly accepted after reassignment: 0.00% (0/926 particles).
# Changed but rejected after reassignment: 81.43% (754/926 particles).
# Unchanged but rejected after reassignment: 0.00% (0/926 particles).
# Tau loc: min = 1.3 max = 2.4 std = 0.35
# Tau glob: min = 1.3 max = 1.3 std = 0.0
# PRIOR MU: min = -82.5, max = -60.4, mean = -66.8
# PRIOR SIGMA: min = -2.87e+02, max = -0.757, mean = -3.64
# PRIOR MU: min = -82.7, max = -60.6, mean = -66.5
# PRIOR SIGMA: min = -4.19, max = -0.757, mean = -1.24
# Sample proposal: loc min = -3.6e+01 max 5e+01 mean = 0.24 glob min = 0.016 max = 6.7 mean = 2.1
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.117
# Prior ratio: min = -2.87e+02, max = 2.91, mean = -2.61
# Kernel ratio: min = -12.8, max = 3.0, mean = -1.17
# 3. Results: Acceptance = 11.88% Rejection ABC = 81.43% Rejection MH = 6.70%
# Prior forward: min = -3.61e+02, max = -62.1, mean = -70.4
# Forward thetas loc: min = -35.9, max = 49.8, mean = 0.245 global: min = 0.0163, max = 6.69, mean = 2.08
# Prior backward: min = -84.0, max = -61.8, mean = -67.8
# Backward thetas loc: min = -34.9, max = 49.5, mean = 0.273 global: min = 0.462, max = 6.63, mean = 1.85
# Iteration 13: M = 18 Espilon = 29.2334, ESS = 926 Acc. rate = 11.88% Uniqueness rate particules = 100.0% Uniqueness rate components = 79.8% Global parameters uniqueness rate = 76.1%
#
# a) Update M: new M = 17 old M = 18
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 926 alive particles in 2 copies...
# (1852, 18) 2
# Now particles of shape (2852, 18, 1) and (2852, 18, 100) with 2852 unique particles
# c) Truncate particles: before (2852, 18, 1),(2852, 18, 100) after (2852, 17, 1),(2852, 17, 100)
# Aucun changement =  False
# d) Compute optimal distances: 923 unique alive particles (10,)
# SHapes: y = (10, 100), z = (17, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 2778 New ESS = 2523 (9.18% of the particles killed)
# f) Resampling: Resampling... 921 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.5 std = 0.37
# Tau glob: min = 1.2 max = 1.2 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (17, 100), w = (10,), L = 10
# Performing linear sum assignment for 817 particles.
# Smart Acceptance: 18.30% (183/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 81.60% (816/1000 particles).
# Unchanged but rejected after reassignment: 0.10% (1/1000 particles).
# Tau loc: min = 1.4 max = 2.5 std = 0.37
# Tau glob: min = 1.2 max = 1.2 std = 0.0
# PRIOR MU: min = -78.6, max = -57.5, mean = -63.0
# PRIOR SIGMA: min = -4.08e+02, max = -0.757, mean = -4.17
# PRIOR MU: min = -79.3, max = -57.4, mean = -62.8
# PRIOR SIGMA: min = -3.59, max = -0.757, mean = -1.21
# Sample proposal: loc min = -3.6e+01 max 5.2e+01 mean = 0.3 glob min = 0.012 max = 7.5 mean = 2.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.112
# Prior ratio: min = -4.06e+02, max = 3.3, mean = -3.17
# Kernel ratio: min = -12.0, max = 6.15, mean = -0.914
# 3. Results: Acceptance = 12.00% Rejection ABC = 81.70% Rejection MH = 6.30%
# Prior forward: min = -4.77e+02, max = -58.8, mean = -67.2
# Forward thetas loc: min = -36.2, max = 52.0, mean = 0.298 global: min = 0.0116, max = 7.49, mean = 2.04
# Prior backward: min = -80.4, max = -58.3, mean = -64.0
# Backward thetas loc: min = -36.2, max = 49.5, mean = 0.291 global: min = 0.462, max = 5.43, mean = 1.82
# Iteration 14: M = 17 Espilon = 29.2334, ESS = 1000 Acc. rate = 12.00% Uniqueness rate particules = 100.0% Uniqueness rate components = 72.0% Global parameters uniqueness rate = 68.9%
#
# a) Update M: new M = 16 old M = 17
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 17) 2
# Now particles of shape (3000, 17, 1) and (3000, 17, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 17, 1),(3000, 17, 100) after (3000, 16, 1),(3000, 16, 100)
# Aucun changement =  False
# d) Compute optimal distances: 936 unique alive particles (10,)
# SHapes: y = (10, 100), z = (16, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2609 (13.03% of the particles killed)
# f) Resampling: Resampling... 928 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.6 std = 0.36
# Tau glob: min = 1.2 max = 1.2 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (16, 100), w = (10,), L = 10
# Performing linear sum assignment for 859 particles.
# Smart Acceptance: 14.10% (141/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 85.90% (859/1000 particles).
# Unchanged but rejected after reassignment: 0.00% (0/1000 particles).
# Tau loc: min = 1.4 max = 2.6 std = 0.36
# Tau glob: min = 1.2 max = 1.2 std = 0.0
# PRIOR MU: min = -74.8, max = -53.8, mean = -59.3
# PRIOR SIGMA: min = -1.02e+03, max = -0.757, mean = -5.98
# PRIOR MU: min = -74.5, max = -54.0, mean = -59.0
# PRIOR SIGMA: min = -3.59, max = -0.757, mean = -1.23
# Sample proposal: loc min = -3.8e+01 max 4.9e+01 mean = 0.26 glob min = 0.0048 max = 6.2 mean = 2.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0818
# Prior ratio: min = -1.02e+03, max = 2.56, mean = -4.96
# Kernel ratio: min = -17.3, max = 3.17, mean = -0.912
# 3. Results: Acceptance = 8.40% Rejection ABC = 85.90% Rejection MH = 5.70%
# Prior forward: min = -1.08e+03, max = -54.7, mean = -65.2
# Forward thetas loc: min = -38.4, max = 49.5, mean = 0.259 global: min = 0.00478, max = 6.18, mean = 2.02
# Prior backward: min = -76.3, max = -54.7, mean = -60.3
# Backward thetas loc: min = -36.2, max = 49.5, mean = 0.268 global: min = 0.419, max = 5.43, mean = 1.79
# Iteration 15: M = 16 Espilon = 29.2334, ESS = 1000 Acc. rate = 8.40% Uniqueness rate particules = 100.0% Uniqueness rate components = 65.6% Global parameters uniqueness rate = 62.3%
#
# a) Update M: new M = 15 old M = 16
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 16) 2
# Now particles of shape (3000, 16, 1) and (3000, 16, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 16, 1),(3000, 16, 100) after (3000, 15, 1),(3000, 15, 100)
# Aucun changement =  False
# d) Compute optimal distances: 942 unique alive particles (10,)
# SHapes: y = (10, 100), z = (15, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2444 (18.53% of the particles killed)
# f) Resampling: Resampling... 927 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.5 max = 2.7 std = 0.37
# Tau glob: min = 1.2 max = 1.2 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (15, 100), w = (10,), L = 10
# Performing linear sum assignment for 879 particles.
# Smart Acceptance: 12.10% (121/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 87.80% (878/1000 particles).
# Unchanged but rejected after reassignment: 0.10% (1/1000 particles).
# Tau loc: min = 1.5 max = 2.7 std = 0.37
# Tau glob: min = 1.2 max = 1.2 std = 0.0
# PRIOR MU: min = -71.0, max = -50.5, mean = -55.4
# PRIOR SIGMA: min = -3.72e+02, max = -0.757, mean = -3.71
# PRIOR MU: min = -70.3, max = -50.7, mean = -55.1
# PRIOR SIGMA: min = -4.31, max = -0.757, mean = -1.21
# Sample proposal: loc min = -3.5e+01 max 5.1e+01 mean = 0.32 glob min = 0.013 max = 7.2 mean = 2.0
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0785
# Prior ratio: min = -3.72e+02, max = 3.55, mean = -2.73
# Kernel ratio: min = -12.0, max = 4.43, mean = -0.869
# 3. Results: Acceptance = 7.70% Rejection ABC = 87.90% Rejection MH = 4.40%
# Prior forward: min = -4.27e+02, max = -51.3, mean = -59.1
# Forward thetas loc: min = -35.3, max = 50.5, mean = 0.315 global: min = 0.0127, max = 7.15, mean = 2.0
# Prior backward: min = -72.2, max = -51.5, mean = -56.3
# Backward thetas loc: min = -36.2, max = 49.2, mean = 0.315 global: min = 0.419, max = 5.43, mean = 1.74
# Iteration 16: M = 15 Espilon = 29.2334, ESS = 1000 Acc. rate = 7.70% Uniqueness rate particules = 100.0% Uniqueness rate components = 62.4% Global parameters uniqueness rate = 58.8%
#
# a) Update M: new M = 14 old M = 15
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  2
# Duplicating the 1000 alive particles in 2 copies...
# (2000, 15) 2
# Now particles of shape (3000, 15, 1) and (3000, 15, 100) with 3000 unique particles
# c) Truncate particles: before (3000, 15, 1),(3000, 15, 100) after (3000, 14, 1),(3000, 14, 100)
# Aucun changement =  False
# d) Compute optimal distances: 941 unique alive particles (10,)
# SHapes: y = (10, 100), z = (14, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 3000 New ESS = 2280 (24.00% of the particles killed)
# f) Resampling: Resampling... 926 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.5 max = 2.7 std = 0.36
# Tau glob: min = 1.1 max = 1.1 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (14, 100), w = (10,), L = 10
# Performing linear sum assignment for 880 particles.
# Smart Acceptance: 12.00% (120/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 87.90% (879/1000 particles).
# Unchanged but rejected after reassignment: 0.10% (1/1000 particles).
# Tau loc: min = 1.5 max = 2.7 std = 0.36
# Tau glob: min = 1.1 max = 1.1 std = 0.0
# PRIOR MU: min = -67.0, max = -47.0, mean = -51.4
# PRIOR SIGMA: min = -1.37e+03, max = -0.757, mean = -7.55
# PRIOR MU: min = -65.6, max = -47.3, mean = -51.1
# PRIOR SIGMA: min = -4.31, max = -0.757, mean = -1.17
# Sample proposal: loc min = -3.8e+01 max 5.1e+01 mean = 0.36 glob min = 0.0036 max = 7.6 mean = 1.9
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0709
# Prior ratio: min = -1.37e+03, max = 3.38, mean = -6.6
# Kernel ratio: min = -15.7, max = 3.38, mean = -0.74
# 3. Results: Acceptance = 7.40% Rejection ABC = 88.00% Rejection MH = 4.60%
# Prior forward: min = -1.42e+03, max = -48.3, mean = -58.9
# Forward thetas loc: min = -38.3, max = 51.1, mean = 0.359 global: min = 0.00359, max = 7.59, mean = 1.91
# Prior backward: min = -67.1, max = -48.0, mean = -52.3
# Backward thetas loc: min = -36.2, max = 48.9, mean = 0.364 global: min = 0.419, max = 5.43, mean = 1.7
# Iteration 17: M = 14 Espilon = 29.2334, ESS = 1000 Acc. rate = 7.40% Uniqueness rate particules = 100.0% Uniqueness rate components = 58.5% Global parameters uniqueness rate = 54.6%
#
# a) Update M: new M = 13 old M = 14
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  3
# Duplicating the 1000 alive particles in 3 copies...
# (3000, 14) 3
# Now particles of shape (4000, 14, 1) and (4000, 14, 100) with 4000 unique particles
# c) Truncate particles: before (4000, 14, 1),(4000, 14, 100) after (4000, 13, 1),(4000, 13, 100)
# Aucun changement =  False
# d) Compute optimal distances: 935 unique alive particles (10,)
# SHapes: y = (10, 100), z = (13, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 4000 New ESS = 2749 (31.27% of the particles killed)
# f) Resampling: Resampling... 926 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.5 max = 2.8 std = 0.39
# Tau glob: min = 1.1 max = 1.1 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (13, 100), w = (10,), L = 10
# Performing linear sum assignment for 909 particles.
# Smart Acceptance: 9.10% (91/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 90.10% (901/1000 particles).
# Unchanged but rejected after reassignment: 0.80% (8/1000 particles).
# Tau loc: min = 1.5 max = 2.8 std = 0.39
# Tau glob: min = 1.1 max = 1.1 std = 0.0
# PRIOR MU: min = -56.6, max = -43.8, mean = -47.4
# PRIOR SIGMA: min = -1.34e+03, max = -0.757, mean = -7.03
# PRIOR MU: min = -56.3, max = -43.8, mean = -47.2
# PRIOR SIGMA: min = -4.31, max = -0.757, mean = -1.17
# Sample proposal: loc min = -3.6e+01 max 4.8e+01 mean = 0.38 glob min = 0.0037 max = 6.6 mean = 1.9
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0607
# Prior ratio: min = -1.34e+03, max = 3.43, mean = -6.1
# Kernel ratio: min = -12.3, max = 3.72, mean = -0.971
# 3. Results: Acceptance = 6.20% Rejection ABC = 90.90% Rejection MH = 2.90%
# Prior forward: min = -1.38e+03, max = -44.6, mean = -54.5
# Forward thetas loc: min = -36.1, max = 48.2, mean = 0.379 global: min = 0.00367, max = 6.64, mean = 1.89
# Prior backward: min = -57.7, max = -44.7, mean = -48.4
# Backward thetas loc: min = -36.2, max = 47.5, mean = 0.411 global: min = 0.419, max = 5.43, mean = 1.67
# Iteration 18: M = 13 Espilon = 29.2334, ESS = 1000 Acc. rate = 6.20% Uniqueness rate particules = 100.0% Uniqueness rate components = 55.5% Global parameters uniqueness rate = 51.5%
#
# a) Update M: new M = 12 old M = 13
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  3
# Duplicating the 1000 alive particles in 3 copies...
# (3000, 13) 3
# Now particles of shape (4000, 13, 1) and (4000, 13, 100) with 4000 unique particles
# c) Truncate particles: before (4000, 13, 1),(4000, 13, 100) after (4000, 12, 1),(4000, 12, 100)
# Aucun changement =  False
# d) Compute optimal distances: 935 unique alive particles (10,)
# SHapes: y = (10, 100), z = (12, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 4000 New ESS = 2256 (43.60% of the particles killed)
# f) Resampling: Resampling... 916 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.5 max = 2.9 std = 0.41
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (12, 100), w = (10,), L = 10
# Performing linear sum assignment for 913 particles.
# Smart Acceptance: 8.70% (87/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 90.00% (900/1000 particles).
# Unchanged but rejected after reassignment: 1.30% (13/1000 particles).
# Tau loc: min = 1.5 max = 2.9 std = 0.41
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# PRIOR MU: min = -52.7, max = -39.9, mean = -43.3
# PRIOR SIGMA: min = -1.05e+03, max = -0.757, mean = -6.36
# PRIOR MU: min = -51.8, max = -40.5, mean = -43.1
# PRIOR SIGMA: min = -4.22, max = -0.757, mean = -1.15
# Sample proposal: loc min = -3.7e+01 max 4.9e+01 mean = 0.55 glob min = 0.0046 max = 6.6 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0617
# Prior ratio: min = -1.05e+03, max = 3.16, mean = -5.42
# Kernel ratio: min = -14.0, max = 3.58, mean = -0.936
# 3. Results: Acceptance = 6.50% Rejection ABC = 91.30% Rejection MH = 2.20%
# Prior forward: min = -1.1e+03, max = -41.1, mean = -49.7
# Forward thetas loc: min = -37.2, max = 48.9, mean = 0.546 global: min = 0.00464, max = 6.55, mean = 1.81
# Prior backward: min = -54.3, max = -41.4, mean = -44.3
# Backward thetas loc: min = -36.2, max = 47.5, mean = 0.536 global: min = 0.425, max = 5.43, mean = 1.61
# Iteration 19: M = 12 Espilon = 29.2334, ESS = 1000 Acc. rate = 6.50% Uniqueness rate particules = 100.0% Uniqueness rate components = 49.7% Global parameters uniqueness rate = 45.2%
#
# a) Update M: new M = 11 old M = 12
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  5
# Duplicating the 1000 alive particles in 5 copies...
# (5000, 12) 5
# Now particles of shape (6000, 12, 1) and (6000, 12, 100) with 6000 unique particles
# c) Truncate particles: before (6000, 12, 1),(6000, 12, 100) after (6000, 11, 1),(6000, 11, 100)
# Aucun changement =  False
# d) Compute optimal distances: 926 unique alive particles (10,)
# SHapes: y = (10, 100), z = (11, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 6000 New ESS = 2718 (54.70% of the particles killed)
# f) Resampling: Resampling... 919 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 3.0 std = 0.41
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (11, 100), w = (10,), L = 10
# Performing linear sum assignment for 911 particles.
# Smart Acceptance: 8.90% (89/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 89.50% (895/1000 particles).
# Unchanged but rejected after reassignment: 1.60% (16/1000 particles).
# Tau loc: min = 1.4 max = 3.0 std = 0.41
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# PRIOR MU: min = -50.7, max = -36.9, mean = -39.3
# PRIOR SIGMA: min = -4.37e+02, max = -0.757, mean = -4.48
# PRIOR MU: min = -48.5, max = -37.2, mean = -39.0
# PRIOR SIGMA: min = -4.22, max = -0.757, mean = -1.14
# Sample proposal: loc min = -3.8e+01 max 5e+01 mean = 0.69 glob min = 0.011 max = 6.2 mean = 1.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0629
# Prior ratio: min = -4.36e+02, max = 2.67, mean = -3.56
# Kernel ratio: min = -14.7, max = 3.27, mean = -0.716
# 3. Results: Acceptance = 6.10% Rejection ABC = 91.10% Rejection MH = 2.80%
# Prior forward: min = -4.76e+02, max = -38.0, mean = -43.8
# Forward thetas loc: min = -38.1, max = 49.5, mean = 0.688 global: min = 0.0109, max = 6.23, mean = 1.7
# Prior backward: min = -51.0, max = -38.1, mean = -40.2
# Backward thetas loc: min = -36.2, max = 47.5, mean = 0.697 global: min = 0.382, max = 4.26, mean = 1.59
# Iteration 20: M = 11 Espilon = 29.2334, ESS = 1000 Acc. rate = 6.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 45.7% Global parameters uniqueness rate = 41.1%
#
# a) Update M: new M = 10 old M = 11
# b) Duplicate particles
# Adaptive duplication: n_duplicate =  9
# Duplicating the 1000 alive particles in 9 copies...
# (9000, 11) 9
# Now particles of shape (10000, 11, 1) and (10000, 11, 100) with 10000 unique particles
# c) Truncate particles: before (10000, 11, 1),(10000, 11, 100) after (10000, 10, 1),(10000, 10, 100)
# Aucun changement =  False
# d) Compute optimal distances: 922 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 10000 New ESS = 2459 (75.41% of the particles killed)
# f) Resampling: Resampling... 875 unique particles left
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 3.0 std = 0.42
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 925 particles.
# Smart Acceptance: 7.50% (75/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 89.10% (891/1000 particles).
# Unchanged but rejected after reassignment: 3.40% (34/1000 particles).
# Tau loc: min = 1.4 max = 3.0 std = 0.42
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# PRIOR MU: min = -37.2, max = -33.3, mean = -35.0
# PRIOR SIGMA: min = -4.92e+02, max = -0.757, mean = -5.0
# PRIOR MU: min = -35.9, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.1, max = -0.757, mean = -1.13
# Sample proposal: loc min = -2e+01 max 1.8e+01 mean = 0.67 glob min = 0.0097 max = 6.1 mean = 1.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0522
# Prior ratio: min = -4.91e+02, max = 3.11, mean = -4.06
# Kernel ratio: min = -8.98, max = 4.34, mean = -0.543
# 3. Results: Acceptance = 5.10% Rejection ABC = 92.50% Rejection MH = 2.40%
# Prior forward: min = -5.26e+02, max = -34.2, mean = -40.0
# Forward thetas loc: min = -19.6, max = 18.4, mean = 0.666 global: min = 0.00972, max = 6.15, mean = 1.72
# Prior backward: min = -40.3, max = -34.9, mean = -36.0
# Backward thetas loc: min = -16.3, max = 15.0, mean = 0.698 global: min = 0.382, max = 4.26, mean = 1.59
# Iteration 21: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 5.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 38.2% Global parameters uniqueness rate = 34.4%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 889 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 3.0 std = 0.41
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 930 particles.
# Smart Acceptance: 7.00% (70/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 90.00% (900/1000 particles).
# Unchanged but rejected after reassignment: 3.00% (30/1000 particles).
# Tau loc: min = 1.4 max = 3.0 std = 0.41
# Tau glob: min = 1.0 max = 1.0 std = 0.0
# PRIOR MU: min = -37.3, max = -33.4, mean = -35.0
# PRIOR SIGMA: min = -3.31e+03, max = -0.757, mean = -8.32
# PRIOR MU: min = -35.9, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.1, max = -0.757, mean = -1.13
# ...
# Prior backward: min = -40.6, max = -34.8, mean = -35.9
# Backward thetas loc: min = -16.3, max = 14.9, mean = 0.72 global: min = 0.352, max = 4.58, mean = 1.59
# Iteration 63: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 4.80% Uniqueness rate particules = 100.0% Uniqueness rate components = 95.9% Global parameters uniqueness rate = 95.1%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.35
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 915 particles.
# Smart Acceptance: 8.50% (85/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 87.80% (878/1000 particles).
# Unchanged but rejected after reassignment: 3.70% (37/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.35
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# PRIOR MU: min = -37.0, max = -33.5, mean = -35.0
# PRIOR SIGMA: min = -1.38e+04, max = -0.757, mean = -18.7
# PRIOR MU: min = -36.1, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.91, max = -0.757, mean = -1.12
# Sample proposal: loc min = -2e+01 max 1.9e+01 mean = 0.73 glob min = 0.00036 max = 6.0 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0611
# Prior ratio: min = -1.38e+04, max = 3.84, mean = -17.8
# Kernel ratio: min = -11.4, max = 4.03, mean = -0.334
# 3. Results: Acceptance = 6.20% Rejection ABC = 91.50% Rejection MH = 2.30%
# Prior forward: min = -1.39e+04, max = -34.4, mean = -53.8
# Forward thetas loc: min = -19.9, max = 19.0, mean = 0.733 global: min = 0.00036, max = 6.05, mean = 1.78
# Prior backward: min = -40.6, max = -34.8, mean = -36.0
# Backward thetas loc: min = -16.3, max = 14.9, mean = 0.723 global: min = 0.352, max = 4.58, mean = 1.6
# Iteration 64: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 6.20% Uniqueness rate particules = 100.0% Uniqueness rate components = 96.2% Global parameters uniqueness rate = 95.5%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.35
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 923 particles.
# Smart Acceptance: 7.70% (77/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 89.20% (892/1000 particles).
# Unchanged but rejected after reassignment: 3.10% (31/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.35
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# PRIOR MU: min = -37.1, max = -33.2, mean = -35.0
# PRIOR SIGMA: min = -3.04e+03, max = -0.757, mean = -6.88
# PRIOR MU: min = -36.1, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.91, max = -0.757, mean = -1.12
# Sample proposal: loc min = -1.9e+01 max 2e+01 mean = 0.69 glob min = 0.0016 max = 5.0 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0536
# Prior ratio: min = -3.04e+03, max = 3.03, mean = -5.97
# Kernel ratio: min = -7.05, max = 4.2, mean = -0.333
# 3. Results: Acceptance = 5.20% Rejection ABC = 92.30% Rejection MH = 2.50%
# Prior forward: min = -3.07e+03, max = -34.4, mean = -41.9
# Forward thetas loc: min = -19.3, max = 19.7, mean = 0.691 global: min = 0.00163, max = 4.97, mean = 1.76
# Prior backward: min = -40.6, max = -34.9, mean = -35.9
# Backward thetas loc: min = -16.3, max = 14.9, mean = 0.721 global: min = 0.352, max = 4.35, mean = 1.6
# Iteration 65: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 5.20% Uniqueness rate particules = 100.0% Uniqueness rate components = 96.4% Global parameters uniqueness rate = 95.7%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.95 max = 0.95 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 928 particles.
# Smart Acceptance: 7.20% (72/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 89.30% (893/1000 particles).
# Unchanged but rejected after reassignment: 3.50% (35/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.95 max = 0.95 std = 0.0
# PRIOR MU: min = -37.5, max = -33.4, mean = -35.0
# PRIOR SIGMA: min = -9.39e+02, max = -0.757, mean = -4.73
# PRIOR MU: min = -36.1, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.91, max = -0.757, mean = -1.12
# Sample proposal: loc min = -2.1e+01 max 1.9e+01 mean = 0.68 glob min = 0.0052 max = 6.9 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0513
# Prior ratio: min = -9.38e+02, max = 3.31, mean = -3.81
# Kernel ratio: min = -8.33, max = 3.65, mean = -0.375
# 3. Results: Acceptance = 5.10% Rejection ABC = 92.80% Rejection MH = 2.10%
# Prior forward: min = -9.74e+02, max = -34.4, mean = -39.8
# Forward thetas loc: min = -21.1, max = 19.5, mean = 0.682 global: min = 0.00519, max = 6.92, mean = 1.76
# Prior backward: min = -40.6, max = -34.9, mean = -35.9
# Backward thetas loc: min = -16.3, max = 14.9, mean = 0.719 global: min = 0.352, max = 4.35, mean = 1.6
# Iteration 66: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 5.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 96.5% Global parameters uniqueness rate = 95.8%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.95 max = 0.95 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 921 particles.
# Smart Acceptance: 7.90% (79/1000 particles).
# Newly accepted after reassignment: 0.10% (1/1000 particles).
# Changed but rejected after reassignment: 89.00% (890/1000 particles).
# Unchanged but rejected after reassignment: 3.00% (30/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.95 max = 0.95 std = 0.0
# PRIOR MU: min = -37.1, max = -33.5, mean = -35.0
# PRIOR SIGMA: min = -1.73e+03, max = -0.757, mean = -7.51
# PRIOR MU: min = -36.1, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.91, max = -0.757, mean = -1.12
# Sample proposal: loc min = -2.1e+01 max 1.9e+01 mean = 0.72 glob min = 0.0028 max = 6.4 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0504
# Prior ratio: min = -1.73e+03, max = 2.33, mean = -6.58
# Kernel ratio: min = -7.78, max = 2.6, mean = -0.389
# 3. Results: Acceptance = 4.80% Rejection ABC = 92.00% Rejection MH = 3.20%
# Prior forward: min = -1.76e+03, max = -34.5, mean = -42.5
# Forward thetas loc: min = -20.9, max = 18.6, mean = 0.725 global: min = 0.00285, max = 6.4, mean = 1.79
# Prior backward: min = -40.6, max = -34.9, mean = -35.9
# Backward thetas loc: min = -16.3, max = 14.9, mean = 0.714 global: min = 0.352, max = 5.07, mean = 1.62
# Iteration 67: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 4.80% Uniqueness rate particules = 100.0% Uniqueness rate components = 96.6% Global parameters uniqueness rate = 95.9%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.97 max = 0.97 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 917 particles.
# Smart Acceptance: 8.30% (83/1000 particles).
# Newly accepted after reassignment: 0.10% (1/1000 particles).
# Changed but rejected after reassignment: 88.30% (883/1000 particles).
# Unchanged but rejected after reassignment: 3.30% (33/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.97 max = 0.97 std = 0.0
# PRIOR MU: min = -37.7, max = -33.4, mean = -35.0
# PRIOR SIGMA: min = -1.44e+03, max = -0.757, mean = -4.95
# PRIOR MU: min = -36.1, max = -33.9, mean = -34.8
# PRIOR SIGMA: min = -5.91, max = -0.757, mean = -1.12
# Sample proposal: loc min = -2e+01 max 1.8e+01 mean = 0.74 glob min = 0.0034 max = 5.6 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.056
# Prior ratio: min = -1.44e+03, max = 4.54, mean = -4.02
# Kernel ratio: min = -6.14, max = 6.4, mean = -0.421
# 3. Results: Acceptance = 6.00% Rejection ABC = 91.60% Rejection MH = 2.40%
# Prior forward: min = -1.48e+03, max = -34.4, mean = -40.0
# Forward thetas loc: min = -19.5, max = 17.9, mean = 0.737 global: min = 0.0034, max = 5.57, mean = 1.75
# Prior backward: min = -40.6, max = -34.9, mean = -36.0
# Backward thetas loc: min = -16.3, max = 14.9, mean = 0.718 global: min = 0.352, max = 4.54, mean = 1.62
# Iteration 68: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 6.00% Uniqueness rate particules = 100.0% Uniqueness rate components = 97.0% Global parameters uniqueness rate = 96.4%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 906 particles.
# Smart Acceptance: 9.40% (94/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 87.30% (873/1000 particles).
# Unchanged but rejected after reassignment: 3.30% (33/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.36
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# PRIOR MU: min = -37.1, max = -33.2, mean = -35.0
# PRIOR SIGMA: min = -1.89e+04, max = -0.757, mean = -24.5
# PRIOR MU: min = -36.1, max = -34.0, mean = -34.8
# PRIOR SIGMA: min = -5.91, max = -0.757, mean = -1.13
# Sample proposal: loc min = -2.1e+01 max 2e+01 mean = 0.72 glob min = 0.00026 max = 6.3 mean = 1.7
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0612
# Prior ratio: min = -1.89e+04, max = 4.51, mean = -23.6
# Kernel ratio: min = -7.34, max = 4.4, mean = -0.362
# 3. Results: Acceptance = 6.30% Rejection ABC = 90.60% Rejection MH = 3.10%
# Prior forward: min = -1.9e+04, max = -34.2, mean = -59.5
# Forward thetas loc: min = -20.7, max = 20.2, mean = 0.716 global: min = 0.000263, max = 6.34, mean = 1.74
# Prior backward: min = -40.6, max = -34.9, mean = -36.0
# Backward thetas loc: min = -16.4, max = 14.9, mean = 0.714 global: min = 0.432, max = 4.54, mean = 1.62
# Iteration 69: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 6.30% Uniqueness rate particules = 100.0% Uniqueness rate components = 97.3% Global parameters uniqueness rate = 96.7%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.37
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 928 particles.
# Smart Acceptance: 7.20% (72/1000 particles).
# Newly accepted after reassignment: 0.00% (0/1000 particles).
# Changed but rejected after reassignment: 89.40% (894/1000 particles).
# Unchanged but rejected after reassignment: 3.40% (34/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.37
# Tau glob: min = 0.96 max = 0.96 std = 0.0
# PRIOR MU: min = -37.4, max = -33.4, mean = -35.0
# PRIOR SIGMA: min = -1.51e+03, max = -0.757, mean = -5.02
# PRIOR MU: min = -36.1, max = -34.0, mean = -34.8
# PRIOR SIGMA: min = -4.08, max = -0.757, mean = -1.12
# Sample proposal: loc min = -2.2e+01 max 1.9e+01 mean = 0.73 glob min = 0.0033 max = 5.9 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.0495
# Prior ratio: min = -1.51e+03, max = 2.69, mean = -4.11
# Kernel ratio: min = -12.0, max = 3.78, mean = -0.438
# 3. Results: Acceptance = 5.10% Rejection ABC = 92.80% Rejection MH = 2.10%
# Prior forward: min = -1.54e+03, max = -34.1, mean = -40.1
# Forward thetas loc: min = -21.7, max = 18.8, mean = 0.735 global: min = 0.00326, max = 5.94, mean = 1.76
# Prior backward: min = -39.4, max = -34.9, mean = -36.0
# Backward thetas loc: min = -16.4, max = 14.9, mean = 0.712 global: min = 0.432, max = 4.54, mean = 1.62
# Iteration 70: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 5.10% Uniqueness rate particules = 100.0% Uniqueness rate components = 97.5% Global parameters uniqueness rate = 96.9%
#
# a) Update M: new M = 10 old M = 10
# d) Compute optimal distances: 998 unique alive particles (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing full optimal assignment (no prior indices).
# e) Weights update/Killing of the particles: Old ESS = 1000 New ESS = 1000 (0.00% of the particles killed)
# f) Resampling: No resampling
# g) Move particles:
# 1. Forward kernel:
# Tau loc: min = 1.4 max = 2.8 std = 0.37
# Tau glob: min = 0.97 max = 0.97 std = 0.0
# (10,)
# SHapes: y = (10, 100), z = (10, 100), w = (10,), L = 10
# Performing linear sum assignment for 920 particles.
# Smart Acceptance: 8.00% (80/1000 particles).
# Newly accepted after reassignment: 12.60% (126/1000 particles).
# Changed but rejected after reassignment: 75.30% (753/1000 particles).
# Unchanged but rejected after reassignment: 4.10% (41/1000 particles).
# Tau loc: min = 1.4 max = 2.8 std = 0.37
# Tau glob: min = 0.97 max = 0.97 std = 0.0
# PRIOR MU: min = -37.6, max = -33.4, mean = -35.0
# PRIOR SIGMA: min = -2.64e+03, max = -0.757, mean = -7.99
# PRIOR MU: min = -36.1, max = -34.0, mean = -34.8
# PRIOR SIGMA: min = -4.08, max = -0.757, mean = -1.13
# Sample proposal: loc min = -2e+01 max 1.9e+01 mean = 0.73 glob min = 0.0019 max = 5.6 mean = 1.8
# 2. MH acceptance: ratio min = 0.0 max = 1.0 mean 0.122
# Prior ratio: min = -2.64e+03, max = 3.66, mean = -7.06
# Kernel ratio: min = -6.46, max = 3.83, mean = -0.344
# 3. Results: Acceptance = 12.40% Rejection ABC = 79.40% Rejection MH = 8.20%
# Prior forward: min = -2.68e+03, max = -34.3, mean = -43.0
# Forward thetas loc: min = -20.0, max = 18.6, mean = 0.727 global: min = 0.00187, max = 5.59, mean = 1.76
# Prior backward: min = -39.4, max = -34.9, mean = -36.0
# Backward thetas loc: min = -16.4, max = 14.9, mean = 0.72 global: min = 0.432, max = 4.73, mean = 1.63
# Iteration 71: M = 10 Espilon = 29.2334, ESS = 1000 Acc. rate = 12.40% Uniqueness rate particules = 99.8% Uniqueness rate components = 97.7% Global parameters uniqueness rate = 97.2%

# %% [markdown]
# ## Under Matching

# %%
L0 = 3
key = random.PRNGKey(0)
key, subkey = random.split(key)
kernel = KernelTruncatedRW
um = perm_abc_smc_um(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 3, L_0 = L0,  alpha_L = .75, alpha_epsilon= .75,Final_iteration= 50)

mus_um = um["Thetas"][-1].loc.squeeze()
betas_um = um["Thetas"][-1].glob.squeeze()
n_sim_um = np.sum(um["N_sim"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 5
#       3 key, subkey = random.split(key)
#       4 kernel = KernelTruncatedRW
# ----> 5 um = perm_abc_smc_um(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 3, L_0 = L0,  alpha_L = .75, alpha_epsilon= .75,Final_iteration= 50)
#       7 mus_um = um["Thetas"][-1].loc.squeeze()
#       8 betas_um = um["Thetas"][-1].glob.squeeze()
#
# File ~/Documents/Recherche/permABC_new/permABC/under_matching.py:56, in perm_abc_smc_um(key, model, n_particles, y_obs, kernel, L_0, epsilon, alpha_epsilon, alpha_L, Final_iteration, alpha_resample, num_blocks_gibbs, update_weights_distance, verbose)
#      54 time_0 = time.time()
#      55 if update_weights_distance:
# ---> 56     model.reset_weights_distance()
#      57 K = model.K
#      58 if y_obs.ndim == 1: y_obs = y_obs.reshape(1,-1)
#
# AttributeError: 'Model' object has no attribute 'reset_weights_distance'

# %% [markdown]
# ### Comparison

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
N_plot = 2

f, ax = plt.subplots(1, N_plot + 1, figsize=(15, 5))
if N_plot < K:
    perm = np.random.permutation(K)
else:
    perm = np.arange(K)

for i in range(N_plot):
    k = perm[i]
    sns.kdeplot(np.unique(mus_perm_van[:, k]), ax=ax[i], label="Perm ABC vanilla")
    # sns.kdeplot(np.unique(mus_van[:, k]), ax=ax[i], label="ABC vanilla")
    # sns.kdeplot(np.unique(mus_smc[:, k]), ax=ax[i], label="ABC SMC")
    # sns.kdeplot(np.unique(mus_perm_smc[:, k]), ax=ax[i], label="Perm ABC SMC")
    sns.kdeplot(np.unique(mus_os[:, k]), ax=ax[i], label="Perm ABC SMC OS")
    sns.kdeplot(np.unique(mus_um[:, k]), ax=ax[i], label="Perm ABC SMC UM")
    ax[i].axvline(true_theta.loc[0, k], color="black", linestyle="--")
    ax[i].set_title("Component {}".format(k))
    # ax[i].legend()
    ax[i].set_xlabel(r"$\mu_{}$".format(k))
    ax[i].set_ylabel("Density")

sns.kdeplot(np.unique(betas_perm_van), ax=ax[-1], label="Perm ABC vanilla")
# sns.kdeplot(np.unique(betas_van), ax=ax[-1], label="ABC vanilla")
# sns.kdeplot(np.unique(betas_smc), ax=ax[-1], label="ABC SMC", fill=True)
# sns.kdeplot(np.unique(betas_perm_smc), ax=ax[-1], label="Perm ABC SMC")
sns.kdeplot(np.unique(betas_os), ax=ax[-1], label="Perm ABC SMC OS")
sns.kdeplot(np.unique(betas_um), ax=ax[-1], label="Perm ABC SMC UM")
ax[-1].axvline(true_theta.glob[0], color="black", linestyle="--")
ax[-1].set_title("Global parameter")
ax[-1].legend()
ax[-1].set_xlabel(r"$\beta$")
ax[-1].set_ylabel("Density")
plt.tight_layout()
plt.show()

# %% [markdown]
# # ABC-Gibbs

# %%
import numpy as np
from tqdm.notebook import tqdm
from jax import vmap, jit, random
import jax.numpy as jnp
from scipy import stats
from scipy.optimize import linear_sum_assignment

@jit
def distance_one_silo(x_k,y_k):
    return jnp.sum((x_k-y_k)**2)

@jit
def distance_all_silo(x,y):
    return vmap(distance_one_silo, in_axes=(0, 0))(x,y)
@jit
def distance_xs(xs, y):
    return vmap(distance_all_silo, in_axes=(0, None))(xs, y)

@jit
def distance_sum_silo(x,y):
    return jnp.mean((distance_all_silo(x,y)))

@jit
def distance_sum(xs, y):
    return (vmap(distance_sum_silo, in_axes=(0, None))(xs, y))
# @jit 
# def dist_full_y(xs, y):
#     return jnp.sum(vmap(dist_full, in_axes=(0, None))(xs, y), axis = 1)

def ABCmus(key, M, y_obs, alpha):
    key, key_mus, key_data = random.split(key, 3)
    mus = random.normal(key_mus, shape=(M,K))*model.sigma_mu
    thetas = Theta(loc = mus[:,:,None], glob = np.repeat([alpha], M)[:,None])
    xs = model.data_generator(key_data, thetas)
    dists = distance_xs(xs, y_obs)
    index_min = jnp.argmin(dists, axis=0)
    Eps_betas = jnp.array([dists[index_min[i],i] for i in range(K)])
    mus_min = np.array([mus[index_min[i],i] for i in range(K)])
    return mus_min, Eps_betas
    

def ABCalpha(key, M, y_obs, mus):
    key, key_alpha, key_data = random.split(key, 3)
    alphas = random.normal(key_alpha, shape=(M,1))*model.sigma_alpha
    thetas = Theta(loc = np.repeat([mus], M, axis=0)[:,:,None], glob = alphas)
    xs = model.data_generator(key_data, thetas)
    dists = distance_sum(xs, y_obs)
    index_min = jnp.argmin(dists)
    Eps_alpha = dists[index_min]
    alpha_min = alphas[index_min]
    return alpha_min[0], Eps_alpha



def gibbs_robin(key, T, M_mu, M_alpha, y_obs):
    mus = np.zeros((T+1,K))
    alphas = np.zeros(T+1)
    
    Eps_mu = np.zeros((T, K))
    Eps_alpha = np.zeros(T)
    
    
    key, key_alpha, key_mu = random.split(key, 3)
    
    # alphas[0] = -10
    mus[0] = random.normal(key_mu, shape=(K,))*model.sigma_mu
    # mus[0] = -10
    alphas[0] = random.normal(key_alpha)*model.sigma_alpha
    for t in tqdm(range(T)):
        key, key_mus = random.split(key)
        mus[t+1], Eps_mu[t] = ABCmus(key_mus, M_mu, y_obs, alphas[t])
        key, key_alpha = random.split(key)
        alphas[t+1], Eps_alpha[t] = ABCalpha(key_alpha, M_alpha, y_obs, mus[t+1])
        
    return mus, alphas, Eps_mu, Eps_alpha

# %%
# M = int(n_sim_perm_smc/((N)*2*K))
# print(model.sigma_alpha, model.sigma_mu, model.K, model.n_obs)
# print(y_obs[0].shape)
N = 1000
M = n_sim_perm_smc//(2*K*N)
print(M)
mus_gibbs, alphas_gibbs, Eps_mus_gibbs, Eps_alphas_gibbs = gibbs_robin(key, N, M, M, y_obs[0])
# Out:
# 51
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
k = 0
sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black", alpha = .5)
sns.kdeplot(x = mus_perm_smc[:,k], y = betas_perm_smc, label = "Perm ABC SMC", level = 3, color = "blue", alpha = .5, fill=True)

# sns.kdeplot(x = mus_gibbs[:,k], y = alphas_gibbs, label = "Gibbs", level = 3, color = "red", alpha = .5, fill=True)
plt.plot(mus_gibbs[:,k], alphas_gibbs, color = "red", alpha = .5)
# Out:
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %%
k = 0
plt.scatter(x = mus_perm_smc[:,k], y = betas_perm_smc, label = "Perm ABC SMC", color = "blue", alpha = .25)

# sns.kdeplot(x = mus_gibbs[:,k], y = alphas_gibbs, label = "Gibbs", level = 3, color = "red", alpha = .5, fill=True)
sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black", alpha =1 )

plt.plot(mus_gibbs[:,k], alphas_gibbs, color = "red", alpha = .75)
# sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black", alpha =1 )
# Out:
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %% [markdown]
# # PyMC

# %%
import pymc as pm

# Define the model
with pm.Model() as mod:
    # Priors for unknown model parameters

    sigma_x = 1.0

    mu = pm.Normal('mu', mu=0, sigma=sigma_mu, shape=(K, 1))
    alpha = pm.Normal('alpha', mu=0, sigma=sigma_alpha, shape=(1, 1))

    # Likelihood (sampling distribution) of observations
    x = pm.Normal('x', mu=mu + alpha, sigma=sigma_x, observed=y_obs[0])

    # Inference
    trace = pm.sample(N_pymc, return_inferencedata=True)
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, alpha]
# /Users/antoineluciano/.pyenv/versions/3.10.13/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Output()
# /Users/antoineluciano/.pyenv/versions/3.10.13/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 10_000 draw iterations (4_000 + 40_000 draws total) took 36 seconds.

# %%
true_post_mu = np.array(trace.posterior.mu[:,:,:,0]).reshape(4*N_pymc, K)
true_post_alpha = np.array(trace.posterior.alpha).reshape(-1)

# %%
for k in range(K):
    sns.kdeplot(true_post_mu[:,k], label="True posterior")
    sns.kdeplot(mus_gibbs[:,k], label="Gibbs")
    sns.kdeplot(mus_perm_smc[:,k], label="Perm ABC SMC")
    plt.axvline(true_theta.loc[0,k], color="black", linestyle="--")
    plt.title("Component {}".format(k))
    plt.xlabel(r"$\mu_{}$".format(k))
    plt.ylabel("Density")
    plt.legend()
    plt.show()
plt.show()
sns.kdeplot(true_post_alpha, label="True posterior")
sns.kdeplot(alphas_gibbs, label="Gibbs")
sns.kdeplot(betas_perm_smc, label="Perm ABC SMC")
plt.axvline(true_theta.glob[0], color="black", linestyle="--")
plt.title("Global parameter")
plt.xlabel(r"$\beta$")
plt.ylabel("Density")
plt.legend()

plt.show()

# %% [markdown]
# Probleme permSMC ? Acc plus faible que OS et UM pour meme epsilon!!!

# %% [markdown]
# # PLOT

# %%
n_sim_perm_smc
# Out:
# 1024910

# %%
k = 0
sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black", alpha = .5)
sns.kdeplot(x = mus_perm_smc[:,k], y = betas_perm_smc, label = "Perm ABC SMC", level = 3, color = "blue", alpha = .5, fill=True)
# sns.kdeplot(x = mus_gibbs[:,k], y = alphas_gibbs, label = "Gibbs", level = 3, color = "red", alpha = .5, fill=True)
plt.plot(mus_gibbs[:,k], alphas_gibbs, color = "red", alpha = .5)

# plt.scatter(mus_perm_smc[:,k], betas_perm_smc, alpha = .1, color = "blue", label = "Perm ABC SMC")
# plt.scatter(mus_gibbs[:,k], alphas_gibbs, alpha = .1, color = "red", label = "Gibbs")
# sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black")
# Out:
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %% [markdown]
# # plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sns.kdeplot(x = mus_van[:, 0], y = betas_van.squeeze(), label='ABC Vanille', color = "pink", alpha = .5, fill = True)
k = 0
sns.kdeplot(x = mus_perm_smc[:, 0], y = betas_perm_smc, label='ABC SMC perm',  color = "darkblue", alpha =.5, fill = True)
# sns.kdeplot(x = mus_perm_van[:, 0], y = betas_perm_van.squeeze(), label='ABC Vanille perm', color = "lightblue", alpha = .5, fill = True)
sns.kdeplot(x = true_post_mu_k, y = true_post_alpha, label = "True", color = "green", alpha = .5, levels=3, fill = True)

# sns.kdeplot(x = mus_smc[:, k], y = alphas_smc, label='ABC SMC')
sns.kdeplot(x = np.array(mus_gibbs[:,0]), y = np.array(alphas_gibbs), label='ABC Gibbs', color ="orange", levels=3, fill = True, alpha = .5)
# plt.scatter(true_theta.loc[0,k], true_theta.glob[0], color='red', label='True value', marker = "x")
plt.ylabel("$\\alpha$")
plt.xlabel('$\mu_{'+str(1)+'}$')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
