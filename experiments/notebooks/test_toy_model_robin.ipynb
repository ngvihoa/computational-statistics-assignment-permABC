# %% [markdown]
# # Initialisation

# %%
# %load_ext autoreload
# %autoreload 2

import os
path = os.getcwd().split(os.sep)
path = os.sep.join(path[:-1])
os.chdir(path)
import sys
sys.path.append(path)
here = "here "
print(here)
from functions.abc_smc import abc_smc
print(here + 'functions/abc_smc.py')
from functions.models import model_robin
print(here + 'functions/models.py')
from functions.kernels import Kernel_no_perm_RW, Kernel_trunc_RW
print(here + 'functions/kernels.py')
from functions.perm_abc_smc import perm_abc_smc, optimal_index_distance
print(here + 'functions/perm_abc_smc.py')
from functions.perm_abc_smc_os import perm_abc_smc_os
print(here + 'functions/perm_abc_smc_os.py')
import numpy as np
from jax import random, vmap, jit, lax
import jax.numpy as jnp
from scipy.optimize import linear_sum_assignment
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from functions.dataclass_Theta import Theta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# here
# here functions/abc_smc.py
# here functions/models.py
# here functions/kernels.py
# here functions/perm_abc_smc.py
# here functions/perm_abc_smc_os.py

# %% [markdown]
# # Toy Model

# %%
K = 10 
n_obs = 20
sigma_alpha, sigma_mu = 10, 10
model = model_robin(K = K, n_obs = n_obs, sigma_alpha= sigma_alpha, sigma_mu= sigma_mu)

key = random.PRNGKey(0)
key, key_theta, key_yobs = random.split(key, 3)
true_theta = model.prior_generator(key_theta, 1)
true_theta.loc[0,0,0] = 0.
true_theta.glob[0,0] = 0.
y_obs = model.data_generator(key_yobs, true_theta)
print("True theta: ", true_theta)
# Out:
# True theta:  Theta(loc=array([[[  0.       ],
#         [ 21.891056 ],
#         [ -1.6292391],
#         [ -0.574461 ],
#         [  4.99312  ],
#         [  1.0972358],
#         [-16.793629 ],
#         [ -6.226515 ],
#         [ -2.968302 ],
#         [  7.779063 ]]], dtype=float32), glob=array([[0.]], dtype=float32))

# %% [markdown]
# # permABC-SMC

# %%
gen = random.PRNGKey(0)
alpha = .95
N = 1000
test_perm = perm_abc_smc(gen, model, N, 100.,  alpha, y_obs, Kernel_trunc_RW, Final_iteration= 10, verbose = 3)

N_perm_smc = np.sum(test_perm["N_sim"])
epsilon_smc_perm = test_perm["Eps_values"][-1]
mus_smc_perm = test_perm["Thetas"][-1].loc.squeeze()
alphas_smc_perm = test_perm["Thetas"][-1].glob.squeeze()
# Out:
# Distance Weights updated! (100.00% loc/ 0.00% glob)
# In optimal index distance: zs min = -64.3 max = 59.0 matrices min = 0.116 max = 1.23e+03
# Not smart version
# Iteration 0: Epsilon = inf, ESS = 1000 Acc. rate = 100% Numb. unique particles = 1000
# Std local: min = 5.29, max = 8.36 mean = 6.56
# Std global: min = 12.6, max = 12.6 mean = 12.6
# Proposed thetas loc min = -45.9 max = 53.6 glob min = -55.8 max = 53.3
# Proposed zs min = -87.2 max = 75.4
# In optimal index distance: zs min = -87.2 max = 75.4 matrices min = 0.102 max = 1.92e+03
# Rate of smart (no change) acceptance = 78.11% (742/950)
# In change, rate of acceptation = 13.46% (28/208) of rejection with change = 86.54% (180/208) and rejection with no change = 0.00% (0/208)
# Index sum total = 950 Number of particles = 950
# Index sum change = 208 Number of particles = 208
# (950, 10, 1) (950,)
# Acceptance rate = 26.53% Reject because ABC condition = 18.95% because ratio = 54.53%
# Iteration 2: Espilon = 876.0485, ESS = 950 Acc. rate = 26.53% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 6.07, max = 9.8 mean = 7.55
# Std global: min = 11.7, max = 11.7 mean = 11.7
# Proposed thetas loc min = -57.5 max = 49.8 glob min = -44.7 max = 52.8
# Proposed zs min = -74.7 max = 76.3
# In optimal index distance: zs min = -74.7 max = 76.3 matrices min = 0.0842 max = 1.85e+03
# Rate of smart (no change) acceptance = 71.18% (642/902)
# In change, rate of acceptation = 15.38% (40/260) of rejection with change = 84.62% (220/260) and rejection with no change = 0.00% (0/260)
# Index sum total = 902 Number of particles = 902
# Index sum change = 260 Number of particles = 260
# (902, 10, 1) (902,)
# Acceptance rate = 18.29% Reject because ABC condition = 24.39% because ratio = 57.32%
# Iteration 3: Espilon = 684.0689, ESS = 902 Acc. rate = 18.29% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 6.84, max = 10.5 mean = 8.25
# Std global: min = 11.1, max = 11.1 mean = 11.1
# Proposed thetas loc min = -52.7 max = 60.0 glob min = -39.4 max = 36.2
# Proposed zs min = -76.2 max = 76.4
# In optimal index distance: zs min = -76.2 max = 76.4 matrices min = 0.112 max = 1.82e+03
# Rate of smart (no change) acceptance = 65.42% (560/856)
# In change, rate of acceptation = 15.88% (47/296) of rejection with change = 84.12% (249/296) and rejection with no change = 0.00% (0/296)
# Index sum total = 856 Number of particles = 856
# Index sum change = 296 Number of particles = 296
# (856, 10, 1) (856,)
# Acceptance rate = 15.77% Reject because ABC condition = 29.09% because ratio = 55.14%
# Iteration 4: Espilon = 571.7820, ESS = 856 Acc. rate = 15.77% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 7.47, max = 11.5 mean = 8.83
# Std global: min = 10.6, max = 10.6 mean = 10.6
# Proposed thetas loc min = -58.7 max = 62.1 glob min = -50.5 max = 35.9
# Proposed zs min = -81.2 max = 74.5
# In optimal index distance: zs min = -81.2 max = 74.5 matrices min = 0.101 max = 1.76e+03
# Rate of smart (no change) acceptance = 57.20% (465/813)
# In change, rate of acceptation = 29.31% (102/348) of rejection with change = 70.40% (245/348) and rejection with no change = 0.29% (1/348)
# Index sum total = 813 Number of particles = 813
# Index sum change = 348 Number of particles = 348
# (813, 10, 1) (813,)
# Acceptance rate = 14.39% Reject because ABC condition = 30.26% because ratio = 55.35%
# Iteration 5: Espilon = 491.0329, ESS = 813 Acc. rate = 14.39% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 7.98, max = 12.2 mean = 9.28
# Std global: min = 9.92, max = 9.92 mean = 9.92
# Proposed thetas loc min = -51.9 max = 51.0 glob min = -38.8 max = 32.4
# Proposed zs min = -63.3 max = 70.4
# In optimal index distance: zs min = -63.3 max = 70.4 matrices min = 0.115 max = 1.6e+03
# Rate of smart (no change) acceptance = 54.02% (417/772)
# In change, rate of acceptation = 41.69% (148/355) of rejection with change = 58.31% (207/355) and rejection with no change = 0.00% (0/355)
# Index sum total = 772 Number of particles = 772
# Index sum change = 355 Number of particles = 355
# (772, 10, 1) (772,)
# Acceptance rate = 12.82% Reject because ABC condition = 26.81% because ratio = 60.36%
# Iteration 6: Espilon = 453.1829, ESS = 772 Acc. rate = 12.82% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.26, max = 12.2 mean = 9.63
# Std global: min = 9.64, max = 9.64 mean = 9.64
# Proposed thetas loc min = -53.8 max = 61.1 glob min = -40.9 max = 36.7
# Proposed zs min = -66.6 max = 78.5
# In optimal index distance: zs min = -66.6 max = 78.5 matrices min = 0.105 max = 1.9e+03
# Rate of smart (no change) acceptance = 48.29% (354/733)
# In change, rate of acceptation = 39.05% (148/379) of rejection with change = 60.95% (231/379) and rejection with no change = 0.00% (0/379)
# Index sum total = 733 Number of particles = 733
# Index sum change = 379 Number of particles = 379
# (733, 10, 1) (733,)
# Acceptance rate = 12.82% Reject because ABC condition = 31.51% because ratio = 55.66%
# Iteration 7: Espilon = 414.9717, ESS = 733 Acc. rate = 12.82% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.44, max = 12.5 mean = 9.88
# Std global: min = 9.26, max = 9.26 mean = 9.26
# Proposed thetas loc min = -49.4 max = 55.5 glob min = -31.6 max = 28.9
# Proposed zs min = -68.0 max = 69.5
# In optimal index distance: zs min = -68.0 max = 69.5 matrices min = 0.0885 max = 1.59e+03
# Rate of smart (no change) acceptance = 41.52% (289/696)
# In change, rate of acceptation = 45.21% (184/407) of rejection with change = 54.79% (223/407) and rejection with no change = 0.00% (0/407)
# Index sum total = 696 Number of particles = 696
# Index sum change = 407 Number of particles = 407
# (696, 10, 1) (696,)
# Acceptance rate = 11.64% Reject because ABC condition = 32.04% because ratio = 56.32%
# Iteration 8: Espilon = 373.6104, ESS = 696 Acc. rate = 11.64% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.46, max = 12.5 mean = 9.98
# Std global: min = 9.02, max = 9.02 mean = 9.02
# Proposed thetas loc min = -47.8 max = 60.9 glob min = -42.4 max = 37.7
# Proposed zs min = -69.7 max = 71.0
# In optimal index distance: zs min = -69.7 max = 71.0 matrices min = 0.0814 max = 1.62e+03
# Rate of smart (no change) acceptance = 34.64% (229/661)
# In change, rate of acceptation = 45.14% (195/432) of rejection with change = 54.86% (237/432) and rejection with no change = 0.00% (0/432)
# Index sum total = 661 Number of particles = 661
# Index sum change = 432 Number of particles = 432
# (661, 10, 1) (661,)
# Acceptance rate = 9.68% Reject because ABC condition = 35.85% because ratio = 54.46%
# Iteration 9: Espilon = 345.6461, ESS = 661 Acc. rate = 9.68% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.36, max = 12.7 mean = 10.0
# Std global: min = 8.66, max = 8.66 mean = 8.66
# Proposed thetas loc min = -48.8 max = 51.2 glob min = -32.5 max = 28.7
# Proposed zs min = -64.8 max = 63.7
# In optimal index distance: zs min = -64.8 max = 63.7 matrices min = 0.103 max = 1.39e+03
# Rate of smart (no change) acceptance = 32.64% (205/628)
# In change, rate of acceptation = 47.75% (202/423) of rejection with change = 52.25% (221/423) and rejection with no change = 0.00% (0/423)
# Index sum total = 628 Number of particles = 628
# Index sum change = 423 Number of particles = 423
# (628, 10, 1) (628,)
# Acceptance rate = 8.44% Reject because ABC condition = 35.19% because ratio = 56.37%
# Iteration 10: Espilon = 324.4113, ESS = 628 Acc. rate = 8.44% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.35, max = 12.6 mean = 9.98
# Std global: min = 8.49, max = 8.49 mean = 8.49
# Proposed thetas loc min = -60.6 max = 63.7 glob min = -32.7 max = 28.6
# Proposed zs min = -68.5 max = 62.6
# In optimal index distance: zs min = -68.5 max = 62.6 matrices min = 0.105 max = 1.34e+03
# Rate of smart (no change) acceptance = 30.03% (179/596)
# In change, rate of acceptation = 44.84% (187/417) of rejection with change = 55.16% (230/417) and rejection with no change = 0.00% (0/417)
# Index sum total = 596 Number of particles = 596
# Index sum change = 417 Number of particles = 417
# (596, 10, 1) (596,)
# Acceptance rate = 11.91% Reject because ABC condition = 38.59% because ratio = 49.50%
# Iteration 11: Espilon = 304.7485, ESS = 596 Acc. rate = 11.91% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.31, max = 12.5 mean = 9.92
# Std global: min = 8.44, max = 8.44 mean = 8.44
# Proposed thetas loc min = -51.4 max = 61.1 glob min = -29.7 max = 33.8
# Proposed zs min = -62.5 max = 64.6
# In optimal index distance: zs min = -62.5 max = 64.6 matrices min = 0.073 max = 1.39e+03
# Rate of smart (no change) acceptance = 27.74% (157/566)
# In change, rate of acceptation = 46.94% (192/409) of rejection with change = 53.06% (217/409) and rejection with no change = 0.00% (0/409)
# Index sum total = 566 Number of particles = 566
# Index sum change = 409 Number of particles = 409
# (566, 10, 1) (566,)
# Acceptance rate = 9.36% Reject because ABC condition = 38.34% because ratio = 52.30%
# Iteration 12: Espilon = 288.5778, ESS = 566 Acc. rate = 9.36% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.43, max = 12.5 mean = 9.92
# Std global: min = 8.37, max = 8.37 mean = 8.37
# Proposed thetas loc min = -49.9 max = 63.6 glob min = -35.4 max = 32.3
# Proposed zs min = -75.3 max = 82.2
# In optimal index distance: zs min = -75.3 max = 82.2 matrices min = 0.112 max = 2.06e+03
# Rate of smart (no change) acceptance = 25.51% (137/537)
# In change, rate of acceptation = 46.25% (185/400) of rejection with change = 53.75% (215/400) and rejection with no change = 0.00% (0/400)
# Index sum total = 537 Number of particles = 537
# Index sum change = 400 Number of particles = 400
# (537, 10, 1) (537,)
# Acceptance rate = 12.29% Reject because ABC condition = 40.04% because ratio = 47.67%
# Iteration 13: Espilon = 278.6028, ESS = 537 Acc. rate = 12.29% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Std local: min = 8.42, max = 12.2 mean = 9.81
# Std global: min = 8.08, max = 8.08 mean = 8.08
# Proposed thetas loc min = -46.1 max = 56.0 glob min = -32.6 max = 24.2
# Proposed zs min = -61.0 max = 71.2
# In optimal index distance: zs min = -61.0 max = 71.2 matrices min = 0.123 max = 1.61e+03
# Rate of smart (no change) acceptance = 25.88% (132/510)
# In change, rate of acceptation = 46.30% (175/378) of rejection with change = 53.70% (203/378) and rejection with no change = 0.00% (0/378)
# Index sum total = 510 Number of particles = 510
# Index sum change = 378 Number of particles = 378
# (510, 10, 1) (510,)
# Acceptance rate = 9.41% Reject because ABC condition = 39.80% because ratio = 50.78%
# Iteration 14: Espilon = 264.2470, ESS = 510 Acc. rate = 9.41% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0%
# Glob unique: 100.00%
#
# Resampling... 484 unique particles left
# Std local: min = 8.27, max = 12.1 mean = 9.76
# Std global: min = 7.97, max = 7.97 mean = 7.97
# Proposed thetas loc min = -53.7 max = 51.3 glob min = -34.3 max = 27.8
# Proposed zs min = -62.2 max = 66.9
# In optimal index distance: zs min = -62.2 max = 66.9 matrices min = 0.108 max = 1.51e+03
# Rate of smart (no change) acceptance = 22.80% (228/1000)
# In change, rate of acceptation = 44.17% (341/772) of rejection with change = 55.83% (431/772) and rejection with no change = 0.00% (0/772)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 772 Number of particles = 772
# (1000, 10, 1) (1000,)
# Acceptance rate = 10.20% Reject because ABC condition = 43.10% because ratio = 46.70%
# Iteration 15: Espilon = 252.4666, ESS = 1000 Acc. rate = 10.20% Uniqueness rate particules = 58.0% Uniqueness rate components = 58.0%
# Glob unique: 58.00%
#
# Std local: min = 7.99, max = 12.0 mean = 9.65
# Std global: min = 7.91, max = 7.91 mean = 7.91
# Proposed thetas loc min = -54.1 max = 59.7 glob min = -28.6 max = 28.5
# Proposed zs min = -76.4 max = 63.5
# In optimal index distance: zs min = -76.4 max = 63.5 matrices min = 0.138 max = 1.44e+03
# Rate of smart (no change) acceptance = 20.32% (193/950)
# In change, rate of acceptation = 45.57% (345/757) of rejection with change = 54.43% (412/757) and rejection with no change = 0.00% (0/757)
# Index sum total = 950 Number of particles = 950
# Index sum change = 757 Number of particles = 757
# (950, 10, 1) (950,)
# Acceptance rate = 12.00% Reject because ABC condition = 43.37% because ratio = 44.63%
# Iteration 16: Espilon = 242.6251, ESS = 950 Acc. rate = 12.00% Uniqueness rate particules = 67.1% Uniqueness rate components = 67.1%
# Glob unique: 67.10%
#
# Std local: min = 7.97, max = 11.7 mean = 9.51
# Std global: min = 7.75, max = 7.75 mean = 7.75
# Proposed thetas loc min = -56.9 max = 58.5 glob min = -32.5 max = 28.1
# Proposed zs min = -64.1 max = 66.5
# In optimal index distance: zs min = -64.1 max = 66.5 matrices min = 0.0879 max = 1.47e+03
# Rate of smart (no change) acceptance = 21.73% (196/902)
# In change, rate of acceptation = 44.19% (312/706) of rejection with change = 55.81% (394/706) and rejection with no change = 0.00% (0/706)
# Index sum total = 902 Number of particles = 902
# Index sum change = 706 Number of particles = 706
# (902, 10, 1) (902,)
# Acceptance rate = 9.42% Reject because ABC condition = 43.68% because ratio = 46.90%
# Iteration 17: Espilon = 235.2870, ESS = 902 Acc. rate = 9.42% Uniqueness rate particules = 72.0% Uniqueness rate components = 72.0%
# Glob unique: 72.00%
#
# Std local: min = 8.09, max = 11.8 mean = 9.44
# Std global: min = 7.48, max = 7.48 mean = 7.48
# Proposed thetas loc min = -58.6 max = 64.3 glob min = -35.8 max = 27.9
# Proposed zs min = -77.9 max = 63.5
# In optimal index distance: zs min = -77.9 max = 63.5 matrices min = 0.116 max = 1.53e+03
# Rate of smart (no change) acceptance = 19.39% (166/856)
# In change, rate of acceptation = 42.90% (296/690) of rejection with change = 57.10% (394/690) and rejection with no change = 0.00% (0/690)
# Index sum total = 856 Number of particles = 856
# Index sum change = 690 Number of particles = 690
# (856, 10, 1) (856,)
# Acceptance rate = 10.98% Reject because ABC condition = 46.03% because ratio = 42.99%
# Iteration 18: Espilon = 225.0951, ESS = 856 Acc. rate = 10.98% Uniqueness rate particules = 76.4% Uniqueness rate components = 76.4%
# Glob unique: 76.40%
#
# Std local: min = 7.91, max = 11.8 mean = 9.34
# Std global: min = 7.36, max = 7.36 mean = 7.36
# Proposed thetas loc min = -51.8 max = 54.8 glob min = -35.2 max = 28.0
# Proposed zs min = -68.0 max = 74.0
# In optimal index distance: zs min = -68.0 max = 74.0 matrices min = 0.0987 max = 1.74e+03
# Rate of smart (no change) acceptance = 17.34% (141/813)
# In change, rate of acceptation = 42.26% (284/672) of rejection with change = 57.74% (388/672) and rejection with no change = 0.00% (0/672)
# Index sum total = 813 Number of particles = 813
# Index sum change = 672 Number of particles = 672
# (813, 10, 1) (813,)
# Acceptance rate = 10.82% Reject because ABC condition = 47.72% because ratio = 41.45%
# Iteration 19: Espilon = 211.7629, ESS = 813 Acc. rate = 10.82% Uniqueness rate particules = 80.5% Uniqueness rate components = 80.5%
# Glob unique: 80.50%
#
# Std local: min = 7.74, max = 11.5 mean = 9.11
# Std global: min = 7.43, max = 7.43 mean = 7.43
# Proposed thetas loc min = -48.0 max = 59.1 glob min = -26.8 max = 30.3
# Proposed zs min = -53.3 max = 60.0
# In optimal index distance: zs min = -53.3 max = 60.0 matrices min = 0.121 max = 1.25e+03
# Rate of smart (no change) acceptance = 19.69% (152/772)
# In change, rate of acceptation = 44.52% (276/620) of rejection with change = 55.48% (344/620) and rejection with no change = 0.00% (0/620)
# Index sum total = 772 Number of particles = 772
# Index sum change = 620 Number of particles = 620
# (772, 10, 1) (772,)
# Acceptance rate = 11.01% Reject because ABC condition = 44.56% because ratio = 44.43%
# Iteration 20: Espilon = 204.7271, ESS = 772 Acc. rate = 11.01% Uniqueness rate particules = 83.1% Uniqueness rate components = 83.1%
# Glob unique: 83.10%
#
# Std local: min = 7.62, max = 11.5 mean = 9.04
# Std global: min = 7.29, max = 7.29 mean = 7.29
# Proposed thetas loc min = -47.5 max = 49.2 glob min = -26.0 max = 25.5
# Proposed zs min = -55.2 max = 58.6
# In optimal index distance: zs min = -55.2 max = 58.6 matrices min = 0.089 max = 1.22e+03
# Rate of smart (no change) acceptance = 17.74% (130/733)
# In change, rate of acceptation = 42.62% (257/603) of rejection with change = 57.38% (346/603) and rejection with no change = 0.00% (0/603)
# Index sum total = 733 Number of particles = 733
# Index sum change = 603 Number of particles = 603
# (733, 10, 1) (733,)
# Acceptance rate = 10.64% Reject because ABC condition = 47.20% because ratio = 42.16%
# Iteration 21: Espilon = 199.7292, ESS = 733 Acc. rate = 10.64% Uniqueness rate particules = 84.9% Uniqueness rate components = 84.9%
# Glob unique: 84.90%
#
# Std local: min = 7.68, max = 11.1 mean = 8.91
# Std global: min = 7.2, max = 7.2 mean = 7.2
# Proposed thetas loc min = -48.4 max = 56.7 glob min = -29.3 max = 24.3
# Proposed zs min = -60.1 max = 60.1
# In optimal index distance: zs min = -60.1 max = 60.1 matrices min = 0.108 max = 1.26e+03
# Rate of smart (no change) acceptance = 16.79% (117/697)
# In change, rate of acceptation = 43.28% (251/580) of rejection with change = 56.72% (329/580) and rejection with no change = 0.00% (0/580)
# Index sum total = 697 Number of particles = 697
# Index sum change = 580 Number of particles = 580
# (697, 10, 1) (697,)
# Acceptance rate = 11.05% Reject because ABC condition = 47.20% because ratio = 41.75%
# Iteration 22: Espilon = 193.1721, ESS = 697 Acc. rate = 11.05% Uniqueness rate particules = 86.7% Uniqueness rate components = 86.7%
# Glob unique: 86.70%
#
# Std local: min = 7.6, max = 10.8 mean = 8.81
# Std global: min = 7.04, max = 7.04 mean = 7.04
# Proposed thetas loc min = -49.2 max = 47.0 glob min = -24.1 max = 23.2
# Proposed zs min = -64.6 max = 61.1
# In optimal index distance: zs min = -64.6 max = 61.1 matrices min = 0.11 max = 1.26e+03
# Rate of smart (no change) acceptance = 16.77% (111/662)
# In change, rate of acceptation = 44.46% (245/551) of rejection with change = 55.54% (306/551) and rejection with no change = 0.00% (0/551)
# Index sum total = 662 Number of particles = 662
# Index sum change = 551 Number of particles = 551
# (662, 10, 1) (662,)
# Acceptance rate = 11.63% Reject because ABC condition = 46.22% because ratio = 42.15%
# Iteration 23: Espilon = 185.5271, ESS = 662 Acc. rate = 11.63% Uniqueness rate particules = 88.1% Uniqueness rate components = 88.1%
# Glob unique: 88.10%
#
# Std local: min = 7.46, max = 10.6 mean = 8.63
# Std global: min = 6.99, max = 6.99 mean = 6.99
# Proposed thetas loc min = -48.0 max = 44.8 glob min = -25.8 max = 25.7
# Proposed zs min = -57.9 max = 55.5
# In optimal index distance: zs min = -57.9 max = 55.5 matrices min = 0.0693 max = 1.15e+03
# Rate of smart (no change) acceptance = 18.31% (115/628)
# In change, rate of acceptation = 44.64% (229/513) of rejection with change = 55.36% (284/513) and rejection with no change = 0.00% (0/513)
# Index sum total = 628 Number of particles = 628
# Index sum change = 513 Number of particles = 513
# (628, 10, 1) (628,)
# Acceptance rate = 12.10% Reject because ABC condition = 45.22% because ratio = 42.68%
# Iteration 24: Espilon = 177.7723, ESS = 628 Acc. rate = 12.10% Uniqueness rate particules = 88.7% Uniqueness rate components = 88.7%
# Glob unique: 88.70%
#
# Std local: min = 7.5, max = 10.6 mean = 8.6
# Std global: min = 6.79, max = 6.79 mean = 6.79
# Proposed thetas loc min = -57.6 max = 63.0 glob min = -24.8 max = 30.0
# Proposed zs min = -65.4 max = 78.3
# In optimal index distance: zs min = -65.4 max = 78.3 matrices min = 0.108 max = 1.93e+03
# Rate of smart (no change) acceptance = 18.29% (109/596)
# In change, rate of acceptation = 43.94% (214/487) of rejection with change = 56.06% (273/487) and rejection with no change = 0.00% (0/487)
# Index sum total = 596 Number of particles = 596
# Index sum change = 487 Number of particles = 487
# (596, 10, 1) (596,)
# Acceptance rate = 15.77% Reject because ABC condition = 45.81% because ratio = 38.42%
# Iteration 25: Espilon = 171.1296, ESS = 596 Acc. rate = 15.77% Uniqueness rate particules = 89.5% Uniqueness rate components = 89.5%
# Glob unique: 89.50%
#
# Std local: min = 7.51, max = 10.5 mean = 8.52
# Std global: min = 6.66, max = 6.66 mean = 6.66
# Proposed thetas loc min = -47.8 max = 53.1 glob min = -19.6 max = 23.9
# Proposed zs min = -56.0 max = 66.1
# In optimal index distance: zs min = -56.0 max = 66.1 matrices min = 0.112 max = 1.47e+03
# Rate of smart (no change) acceptance = 18.02% (102/566)
# In change, rate of acceptation = 42.67% (198/464) of rejection with change = 57.33% (266/464) and rejection with no change = 0.00% (0/464)
# Index sum total = 566 Number of particles = 566
# Index sum change = 464 Number of particles = 464
# (566, 10, 1) (566,)
# Acceptance rate = 16.96% Reject because ABC condition = 47.00% because ratio = 36.04%
# Iteration 26: Espilon = 163.9329, ESS = 566 Acc. rate = 16.96% Uniqueness rate particules = 90.2% Uniqueness rate components = 90.2%
# Glob unique: 90.20%
#
# Std local: min = 7.39, max = 10.5 mean = 8.41
# Std global: min = 6.6, max = 6.6 mean = 6.6
# Proposed thetas loc min = -47.9 max = 55.2 glob min = -24.5 max = 21.4
# Proposed zs min = -59.3 max = 63.6
# In optimal index distance: zs min = -59.3 max = 63.6 matrices min = 0.0804 max = 1.4e+03
# Rate of smart (no change) acceptance = 15.08% (81/537)
# In change, rate of acceptation = 45.39% (207/456) of rejection with change = 54.61% (249/456) and rejection with no change = 0.00% (0/456)
# Index sum total = 537 Number of particles = 537
# Index sum change = 456 Number of particles = 456
# (537, 10, 1) (537,)
# Acceptance rate = 12.85% Reject because ABC condition = 46.37% because ratio = 40.78%
# Iteration 27: Espilon = 159.7608, ESS = 537 Acc. rate = 12.85% Uniqueness rate particules = 90.8% Uniqueness rate components = 90.8%
# Glob unique: 90.80%
#
# Std local: min = 7.22, max = 10.1 mean = 8.28
# Std global: min = 6.37, max = 6.37 mean = 6.37
# Proposed thetas loc min = -45.0 max = 56.4 glob min = -23.3 max = 22.0
# Proposed zs min = -57.2 max = 69.1
# In optimal index distance: zs min = -57.2 max = 69.1 matrices min = 0.126 max = 1.58e+03
# Rate of smart (no change) acceptance = 17.84% (91/510)
# In change, rate of acceptation = 41.29% (173/419) of rejection with change = 58.71% (246/419) and rejection with no change = 0.00% (0/419)
# Index sum total = 510 Number of particles = 510
# Index sum change = 419 Number of particles = 419
# (510, 10, 1) (510,)
# Acceptance rate = 15.88% Reject because ABC condition = 48.24% because ratio = 35.88%
# Iteration 28: Espilon = 154.3317, ESS = 510 Acc. rate = 15.88% Uniqueness rate particules = 91.2% Uniqueness rate components = 91.2%
# Glob unique: 91.20%
#
# Resampling... 475 unique particles left
# Std local: min = 7.19, max = 10.2 mean = 8.24
# Std global: min = 6.25, max = 6.25 mean = 6.25
# Proposed thetas loc min = -49.7 max = 53.1 glob min = -21.4 max = 23.9
# Proposed zs min = -55.9 max = 60.0
# In optimal index distance: zs min = -55.9 max = 60.0 matrices min = 0.0979 max = 1.2e+03
# Rate of smart (no change) acceptance = 16.20% (162/1000)
# In change, rate of acceptation = 40.45% (339/838) of rejection with change = 59.55% (499/838) and rejection with no change = 0.00% (0/838)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 838 Number of particles = 838
# (1000, 10, 1) (1000,)
# Acceptance rate = 13.90% Reject because ABC condition = 49.90% because ratio = 36.20%
# Iteration 29: Espilon = 150.2434, ESS = 1000 Acc. rate = 13.90% Uniqueness rate particules = 60.0% Uniqueness rate components = 60.0%
# Glob unique: 60.00%
#
# Std local: min = 7.06, max = 10.1 mean = 8.14
# Std global: min = 6.17, max = 6.17 mean = 6.17
# Proposed thetas loc min = -47.1 max = 53.7 glob min = -23.3 max = 25.5
# Proposed zs min = -60.2 max = 67.6
# In optimal index distance: zs min = -60.2 max = 67.6 matrices min = 0.11 max = 1.52e+03
# Rate of smart (no change) acceptance = 15.16% (144/950)
# In change, rate of acceptation = 40.32% (325/806) of rejection with change = 59.68% (481/806) and rejection with no change = 0.00% (0/806)
# Index sum total = 950 Number of particles = 950
# Index sum change = 806 Number of particles = 806
# (950, 10, 1) (950,)
# Acceptance rate = 16.00% Reject because ABC condition = 50.63% because ratio = 33.37%
# Iteration 30: Espilon = 145.5070, ESS = 950 Acc. rate = 16.00% Uniqueness rate particules = 70.4% Uniqueness rate components = 70.4%
# Glob unique: 70.40%
#
# Std local: min = 7.01, max = 9.67 mean = 8.02
# Std global: min = 6.17, max = 6.17 mean = 6.17
# Proposed thetas loc min = -47.9 max = 50.0 glob min = -21.8 max = 21.2
# Proposed zs min = -56.3 max = 54.1
# In optimal index distance: zs min = -56.3 max = 54.1 matrices min = 0.104 max = 1.09e+03
# Rate of smart (no change) acceptance = 14.86% (134/902)
# In change, rate of acceptation = 38.15% (293/768) of rejection with change = 61.72% (474/768) and rejection with no change = 0.13% (1/768)
# Index sum total = 902 Number of particles = 902
# Index sum change = 768 Number of particles = 768
# (902, 10, 1) (902,)
# Acceptance rate = 14.08% Reject because ABC condition = 52.66% because ratio = 33.26%
# Iteration 31: Espilon = 141.1092, ESS = 902 Acc. rate = 14.08% Uniqueness rate particules = 76.4% Uniqueness rate components = 76.4%
# Glob unique: 76.40%
#
# Std local: min = 6.97, max = 9.54 mean = 8.01
# Std global: min = 6.06, max = 6.06 mean = 6.06
# Proposed thetas loc min = -46.7 max = 49.1 glob min = -25.0 max = 25.3
# Proposed zs min = -55.1 max = 65.4
# In optimal index distance: zs min = -55.1 max = 65.4 matrices min = 0.0862 max = 1.43e+03
# Rate of smart (no change) acceptance = 13.43% (115/856)
# In change, rate of acceptation = 42.38% (314/741) of rejection with change = 57.62% (427/741) and rejection with no change = 0.00% (0/741)
# Index sum total = 856 Number of particles = 856
# Index sum change = 741 Number of particles = 741
# (856, 10, 1) (856,)
# Acceptance rate = 17.17% Reject because ABC condition = 49.88% because ratio = 32.94%
# Iteration 32: Espilon = 137.0714, ESS = 856 Acc. rate = 17.17% Uniqueness rate particules = 82.7% Uniqueness rate components = 82.7%
# Glob unique: 82.70%
#
# Std local: min = 6.95, max = 9.4 mean = 7.86
# Std global: min = 6.02, max = 6.02 mean = 6.02
# Proposed thetas loc min = -49.6 max = 50.4 glob min = -20.5 max = 24.6
# Proposed zs min = -57.7 max = 59.3
# In optimal index distance: zs min = -57.7 max = 59.3 matrices min = 0.0703 max = 1.23e+03
# Rate of smart (no change) acceptance = 13.90% (113/813)
# In change, rate of acceptation = 39.29% (275/700) of rejection with change = 60.71% (425/700) and rejection with no change = 0.00% (0/700)
# Index sum total = 813 Number of particles = 813
# Index sum change = 700 Number of particles = 700
# (813, 10, 1) (813,)
# Acceptance rate = 13.53% Reject because ABC condition = 52.28% because ratio = 34.19%
# Iteration 33: Espilon = 133.0348, ESS = 813 Acc. rate = 13.53% Uniqueness rate particules = 85.4% Uniqueness rate components = 85.4%
# Glob unique: 85.40%
#
# Std local: min = 6.77, max = 9.08 mean = 7.74
# Std global: min = 6.01, max = 6.01 mean = 6.01
# Proposed thetas loc min = -52.3 max = 54.9 glob min = -19.9 max = 26.1
# Proposed zs min = -55.7 max = 57.8
# In optimal index distance: zs min = -55.7 max = 57.8 matrices min = 0.102 max = 1.19e+03
# Rate of smart (no change) acceptance = 13.34% (103/772)
# In change, rate of acceptation = 38.86% (260/669) of rejection with change = 61.14% (409/669) and rejection with no change = 0.00% (0/669)
# Index sum total = 772 Number of particles = 772
# Index sum change = 669 Number of particles = 669
# (772, 10, 1) (772,)
# Acceptance rate = 16.32% Reject because ABC condition = 52.98% because ratio = 30.70%
# Iteration 34: Espilon = 129.4957, ESS = 772 Acc. rate = 16.32% Uniqueness rate particules = 88.0% Uniqueness rate components = 88.0%
# Glob unique: 88.00%
#
# Std local: min = 6.73, max = 8.92 mean = 7.68
# Std global: min = 5.98, max = 5.98 mean = 5.98
# Proposed thetas loc min = -54.2 max = 51.6 glob min = -19.5 max = 21.6
# Proposed zs min = -70.1 max = 61.3
# In optimal index distance: zs min = -70.1 max = 61.3 matrices min = 0.119 max = 1.3e+03
# Rate of smart (no change) acceptance = 15.28% (112/733)
# In change, rate of acceptation = 38.00% (236/621) of rejection with change = 62.00% (385/621) and rejection with no change = 0.00% (0/621)
# Index sum total = 733 Number of particles = 733
# Index sum change = 621 Number of particles = 621
# (733, 10, 1) (733,)
# Acceptance rate = 14.73% Reject because ABC condition = 52.52% because ratio = 32.74%
# Iteration 35: Espilon = 125.7861, ESS = 733 Acc. rate = 14.73% Uniqueness rate particules = 89.9% Uniqueness rate components = 89.9%
# Glob unique: 89.90%
#
# Std local: min = 6.55, max = 8.9 mean = 7.54
# Std global: min = 5.84, max = 5.84 mean = 5.84
# Proposed thetas loc min = -45.9 max = 45.9 glob min = -19.3 max = 23.6
# Proposed zs min = -55.3 max = 54.7
# In optimal index distance: zs min = -55.3 max = 54.7 matrices min = 0.114 max = 1.1e+03
# Rate of smart (no change) acceptance = 12.36% (86/696)
# In change, rate of acceptation = 37.87% (231/610) of rejection with change = 62.13% (379/610) and rejection with no change = 0.00% (0/610)
# Index sum total = 696 Number of particles = 696
# Index sum change = 610 Number of particles = 610
# (696, 10, 1) (696,)
# Acceptance rate = 14.51% Reject because ABC condition = 54.45% because ratio = 31.03%
# Iteration 36: Espilon = 121.5514, ESS = 696 Acc. rate = 14.51% Uniqueness rate particules = 91.0% Uniqueness rate components = 91.0%
# Glob unique: 91.00%
#
# Std local: min = 6.62, max = 8.79 mean = 7.5
# Std global: min = 5.95, max = 5.95 mean = 5.95
# Proposed thetas loc min = -48.6 max = 46.6 glob min = -22.8 max = 20.9
# Proposed zs min = -55.2 max = 55.7
# In optimal index distance: zs min = -55.2 max = 55.7 matrices min = 0.127 max = 1.13e+03
# Rate of smart (no change) acceptance = 12.71% (84/661)
# In change, rate of acceptation = 42.81% (247/577) of rejection with change = 57.19% (330/577) and rejection with no change = 0.00% (0/577)
# Index sum total = 661 Number of particles = 661
# Index sum change = 577 Number of particles = 577
# (661, 10, 1) (661,)
# Acceptance rate = 18.00% Reject because ABC condition = 49.92% because ratio = 32.07%
# Iteration 37: Espilon = 118.4515, ESS = 661 Acc. rate = 18.00% Uniqueness rate particules = 92.1% Uniqueness rate components = 92.1%
# Glob unique: 92.10%
#
# Std local: min = 6.56, max = 8.71 mean = 7.35
# Std global: min = 5.9, max = 5.9 mean = 5.9
# Proposed thetas loc min = -42.9 max = 44.6 glob min = -27.5 max = 21.7
# Proposed zs min = -54.2 max = 46.4
# In optimal index distance: zs min = -54.2 max = 46.4 matrices min = 0.0981 max = 8.69e+02
# Rate of smart (no change) acceptance = 11.46% (72/628)
# In change, rate of acceptation = 37.23% (207/556) of rejection with change = 62.59% (348/556) and rejection with no change = 0.18% (1/556)
# Index sum total = 628 Number of particles = 628
# Index sum change = 556 Number of particles = 556
# (628, 10, 1) (628,)
# Acceptance rate = 17.68% Reject because ABC condition = 55.57% because ratio = 26.75%
# Iteration 38: Espilon = 115.7254, ESS = 628 Acc. rate = 17.68% Uniqueness rate particules = 92.7% Uniqueness rate components = 92.7%
# Glob unique: 92.70%
#
# Std local: min = 6.36, max = 8.73 mean = 7.23
# Std global: min = 5.82, max = 5.82 mean = 5.82
# Proposed thetas loc min = -44.3 max = 57.5 glob min = -21.2 max = 21.8
# Proposed zs min = -49.4 max = 52.3
# In optimal index distance: zs min = -49.4 max = 52.3 matrices min = 0.106 max = 1.04e+03
# Rate of smart (no change) acceptance = 16.78% (100/596)
# In change, rate of acceptation = 39.92% (198/496) of rejection with change = 59.88% (297/496) and rejection with no change = 0.20% (1/496)
# Index sum total = 596 Number of particles = 596
# Index sum change = 496 Number of particles = 496
# (596, 10, 1) (596,)
# Acceptance rate = 17.95% Reject because ABC condition = 50.00% because ratio = 32.05%
# Iteration 39: Espilon = 112.6758, ESS = 596 Acc. rate = 17.95% Uniqueness rate particules = 92.9% Uniqueness rate components = 92.9%
# Glob unique: 92.90%
#
# Std local: min = 6.23, max = 8.65 mean = 7.15
# Std global: min = 5.81, max = 5.81 mean = 5.81
# Proposed thetas loc min = -40.7 max = 44.6 glob min = -20.8 max = 22.8
# Proposed zs min = -51.9 max = 56.5
# In optimal index distance: zs min = -51.9 max = 56.5 matrices min = 0.104 max = 1.16e+03
# Rate of smart (no change) acceptance = 13.96% (79/566)
# In change, rate of acceptation = 38.60% (188/487) of rejection with change = 61.19% (298/487) and rejection with no change = 0.21% (1/487)
# Index sum total = 566 Number of particles = 566
# Index sum change = 487 Number of particles = 487
# (566, 10, 1) (566,)
# Acceptance rate = 18.37% Reject because ABC condition = 52.83% because ratio = 28.80%
# Iteration 40: Espilon = 110.2555, ESS = 566 Acc. rate = 18.37% Uniqueness rate particules = 93.0% Uniqueness rate components = 93.0%
# Glob unique: 93.00%
#
# Std local: min = 6.18, max = 8.49 mean = 7.03
# Std global: min = 5.97, max = 5.97 mean = 5.97
# Proposed thetas loc min = -49.4 max = 46.3 glob min = -19.0 max = 24.8
# Proposed zs min = -59.0 max = 46.7
# In optimal index distance: zs min = -59.0 max = 46.7 matrices min = 0.0861 max = 9.04e+02
# Rate of smart (no change) acceptance = 13.59% (73/537)
# In change, rate of acceptation = 38.15% (177/464) of rejection with change = 61.85% (287/464) and rejection with no change = 0.00% (0/464)
# Index sum total = 537 Number of particles = 537
# Index sum change = 464 Number of particles = 464
# (537, 10, 1) (537,)
# Acceptance rate = 20.48% Reject because ABC condition = 53.45% because ratio = 26.07%
# Iteration 41: Espilon = 105.9934, ESS = 537 Acc. rate = 20.48% Uniqueness rate particules = 93.0% Uniqueness rate components = 93.0%
# Glob unique: 93.00%
#
# Std local: min = 5.83, max = 8.2 mean = 6.94
# Std global: min = 5.97, max = 5.97 mean = 5.97
# Proposed thetas loc min = -43.1 max = 41.0 glob min = -21.6 max = 18.3
# Proposed zs min = -56.2 max = 53.5
# In optimal index distance: zs min = -56.2 max = 53.5 matrices min = 0.0847 max = 1.06e+03
# Rate of smart (no change) acceptance = 11.96% (61/510)
# In change, rate of acceptation = 39.20% (176/449) of rejection with change = 60.80% (273/449) and rejection with no change = 0.00% (0/449)
# Index sum total = 510 Number of particles = 510
# Index sum change = 449 Number of particles = 449
# (510, 10, 1) (510,)
# Acceptance rate = 16.67% Reject because ABC condition = 53.53% because ratio = 29.80%
# Iteration 42: Espilon = 102.8528, ESS = 510 Acc. rate = 16.67% Uniqueness rate particules = 93.0% Uniqueness rate components = 93.0%
# Glob unique: 93.00%
#
# Resampling... 484 unique particles left
# Std local: min = 5.7, max = 8.36 mean = 6.84
# Std global: min = 5.97, max = 5.97 mean = 5.97
# Proposed thetas loc min = -44.8 max = 42.4 glob min = -22.2 max = 24.0
# Proposed zs min = -60.1 max = 47.7
# In optimal index distance: zs min = -60.1 max = 47.7 matrices min = 0.103 max = 9.49e+02
# Rate of smart (no change) acceptance = 13.60% (136/1000)
# In change, rate of acceptation = 35.42% (306/864) of rejection with change = 64.58% (558/864) and rejection with no change = 0.00% (0/864)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 864 Number of particles = 864
# (1000, 10, 1) (1000,)
# Acceptance rate = 17.00% Reject because ABC condition = 55.80% because ratio = 27.20%
# Iteration 43: Espilon = 100.0000, ESS = 1000 Acc. rate = 17.00% Uniqueness rate particules = 64.3% Uniqueness rate components = 64.3%
# Glob unique: 64.30%
#
# Std local: min = 5.88, max = 8.39 mean = 6.92
# Std global: min = 6.04, max = 6.04 mean = 6.04
# Proposed thetas loc min = -49.0 max = 43.9 glob min = -24.5 max = 26.2
# Proposed zs min = -51.9 max = 50.4
# In optimal index distance: zs min = -51.9 max = 50.4 matrices min = 0.0985 max = 9.74e+02
# Rate of smart (no change) acceptance = 14.00% (140/1000)
# In change, rate of acceptation = 35.81% (308/860) of rejection with change = 64.07% (551/860) and rejection with no change = 0.12% (1/860)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 860 Number of particles = 860
# (1000, 10, 1) (1000,)
# Acceptance rate = 17.20% Reject because ABC condition = 55.20% because ratio = 27.60%
# Iteration 44: Espilon = 100.0000, ESS = 1000 Acc. rate = 17.20% Uniqueness rate particules = 74.9% Uniqueness rate components = 74.9%
# Glob unique: 74.90%
#
# Std local: min = 5.84, max = 8.28 mean = 6.92
# Std global: min = 6.05, max = 6.05 mean = 6.05
# Proposed thetas loc min = -47.8 max = 46.2 glob min = -25.4 max = 23.7
# Proposed zs min = -54.0 max = 46.8
# In optimal index distance: zs min = -54.0 max = 46.8 matrices min = 0.0886 max = 8.68e+02
# Rate of smart (no change) acceptance = 10.50% (105/1000)
# In change, rate of acceptation = 37.09% (332/895) of rejection with change = 62.91% (563/895) and rejection with no change = 0.00% (0/895)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 895 Number of particles = 895
# (1000, 10, 1) (1000,)
# Acceptance rate = 17.70% Reject because ABC condition = 56.30% because ratio = 26.00%
# Iteration 45: Espilon = 100.0000, ESS = 1000 Acc. rate = 17.70% Uniqueness rate particules = 82.6% Uniqueness rate components = 82.6%
# Glob unique: 82.60%
#
# Std local: min = 5.81, max = 8.13 mean = 6.9
# Std global: min = 6.0, max = 6.0 mean = 6.0
# Proposed thetas loc min = -46.4 max = 48.3 glob min = -21.2 max = 21.6
# Proposed zs min = -51.1 max = 51.9
# In optimal index distance: zs min = -51.1 max = 51.9 matrices min = 0.111 max = 1.03e+03
# Rate of smart (no change) acceptance = 12.80% (128/1000)
# In change, rate of acceptation = 34.98% (305/872) of rejection with change = 64.79% (565/872) and rejection with no change = 0.23% (2/872)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 872 Number of particles = 872
# (1000, 10, 1) (1000,)
# Acceptance rate = 16.90% Reject because ABC condition = 56.70% because ratio = 26.40%
# Iteration 46: Espilon = 100.0000, ESS = 1000 Acc. rate = 16.90% Uniqueness rate particules = 86.9% Uniqueness rate components = 86.9%
# Glob unique: 86.90%
#
# Std local: min = 5.81, max = 8.16 mean = 6.88
# Std global: min = 6.03, max = 6.03 mean = 6.03
#
#
# INFINITE VALUE IN PROPOSED THETAS LOC
#
#
# Proposed thetas loc min = -48.3 max = 47.7 glob min = -20.6 max = 26.8
# Proposed zs min = -55.0 max = 62.9
# In optimal index distance: zs min = -55.0 max = 62.9 matrices min = 0.102 max = 1.34e+03
# Rate of smart (no change) acceptance = 13.20% (132/1000)
# In change, rate of acceptation = 33.99% (295/868) of rejection with change = 65.90% (572/868) and rejection with no change = 0.12% (1/868)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 868 Number of particles = 868
# (1000, 10, 1) (1000,)
# Acceptance rate = 16.70% Reject because ABC condition = 57.30% because ratio = 26.00%
# Iteration 47: Espilon = 100.0000, ESS = 1000 Acc. rate = 16.70% Uniqueness rate particules = 91.3% Uniqueness rate components = 91.3%
# Glob unique: 91.30%
#
# Std local: min = 5.78, max = 8.22 mean = 6.89
# Std global: min = 5.99, max = 5.99 mean = 5.99
# Proposed thetas loc min = -46.4 max = 46.0 glob min = -22.3 max = 26.1
# Proposed zs min = -61.8 max = 58.7
# In optimal index distance: zs min = -61.8 max = 58.7 matrices min = 0.109 max = 1.21e+03
# Rate of smart (no change) acceptance = 11.00% (110/1000)
# In change, rate of acceptation = 33.71% (300/890) of rejection with change = 66.29% (590/890) and rejection with no change = 0.00% (0/890)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 890 Number of particles = 890
# (1000, 10, 1) (1000,)
# Acceptance rate = 13.60% Reject because ABC condition = 59.00% because ratio = 27.40%
# Iteration 48: Espilon = 100.0000, ESS = 1000 Acc. rate = 13.60% Uniqueness rate particules = 94.0% Uniqueness rate components = 94.0%
# Glob unique: 94.00%
#
# Std local: min = 5.64, max = 8.21 mean = 6.9
# Std global: min = 5.88, max = 5.88 mean = 5.88
# Proposed thetas loc min = -48.6 max = 42.6 glob min = -22.3 max = 24.6
# Proposed zs min = -59.1 max = 48.9
# In optimal index distance: zs min = -59.1 max = 48.9 matrices min = 0.079 max = 9.33e+02
# Rate of smart (no change) acceptance = 14.80% (148/1000)
# In change, rate of acceptation = 38.26% (326/852) of rejection with change = 61.62% (525/852) and rejection with no change = 0.12% (1/852)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 852 Number of particles = 852
# (1000, 10, 1) (1000,)
# Acceptance rate = 16.40% Reject because ABC condition = 52.60% because ratio = 31.00%
# Iteration 49: Espilon = 100.0000, ESS = 1000 Acc. rate = 16.40% Uniqueness rate particules = 95.8% Uniqueness rate components = 95.8%
# Glob unique: 95.80%
#
# Std local: min = 5.82, max = 8.26 mean = 6.94
# Std global: min = 5.87, max = 5.87 mean = 5.87
# Proposed thetas loc min = -43.3 max = 44.5 glob min = -18.0 max = 24.4
# Proposed zs min = -54.7 max = 51.4
# In optimal index distance: zs min = -54.7 max = 51.4 matrices min = 0.103 max = 1e+03
# Rate of smart (no change) acceptance = 12.50% (125/1000)
# In change, rate of acceptation = 35.31% (309/875) of rejection with change = 64.46% (564/875) and rejection with no change = 0.23% (2/875)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 875 Number of particles = 875
# (1000, 10, 1) (1000,)
# Acceptance rate = 14.10% Reject because ABC condition = 56.60% because ratio = 29.30%
# Iteration 50: Espilon = 100.0000, ESS = 1000 Acc. rate = 14.10% Uniqueness rate particules = 97.0% Uniqueness rate components = 97.0%
# Glob unique: 97.00%
#
# Std local: min = 5.84, max = 8.36 mean = 6.96
# Std global: min = 5.83, max = 5.83 mean = 5.83
# Proposed thetas loc min = -52.6 max = 49.3 glob min = -23.4 max = 21.9
# Proposed zs min = -54.0 max = 48.1
# In optimal index distance: zs min = -54.0 max = 48.1 matrices min = 0.0987 max = 9.05e+02
# Rate of smart (no change) acceptance = 11.40% (114/1000)
# In change, rate of acceptation = 37.02% (328/886) of rejection with change = 62.98% (558/886) and rejection with no change = 0.00% (0/886)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 886 Number of particles = 886
# (1000, 10, 1) (1000,)
# Acceptance rate = 16.10% Reject because ABC condition = 55.80% because ratio = 28.10%
# Iteration 51: Espilon = 100.0000, ESS = 1000 Acc. rate = 16.10% Uniqueness rate particules = 97.6% Uniqueness rate components = 97.6%
# Glob unique: 97.60%
#
# Std local: min = 5.92, max = 8.3 mean = 7.0
# Std global: min = 5.9, max = 5.9 mean = 5.9
# Proposed thetas loc min = -42.6 max = 47.5 glob min = -22.7 max = 24.5
# Proposed zs min = -51.4 max = 50.6
# In optimal index distance: zs min = -51.4 max = 50.6 matrices min = 0.108 max = 9.9e+02
# Rate of smart (no change) acceptance = 11.10% (111/1000)
# In change, rate of acceptation = 34.98% (311/889) of rejection with change = 64.90% (577/889) and rejection with no change = 0.11% (1/889)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 889 Number of particles = 889
# (1000, 10, 1) (1000,)
# Acceptance rate = 15.10% Reject because ABC condition = 57.80% because ratio = 27.10%
# Iteration 52: Espilon = 100.0000, ESS = 1000 Acc. rate = 15.10% Uniqueness rate particules = 97.9% Uniqueness rate components = 97.9%
# Glob unique: 97.90%
#
# Std local: min = 5.93, max = 8.28 mean = 6.93
# Std global: min = 5.95, max = 5.95 mean = 5.95
# Proposed thetas loc min = -49.3 max = 57.8 glob min = -23.2 max = 22.8
# Proposed zs min = -57.3 max = 55.9
# In optimal index distance: zs min = -57.3 max = 55.9 matrices min = 0.0758 max = 1.15e+03
# Rate of smart (no change) acceptance = 12.90% (129/1000)
# In change, rate of acceptation = 34.44% (300/871) of rejection with change = 65.56% (571/871) and rejection with no change = 0.00% (0/871)
# Index sum total = 1000 Number of particles = 1000
# Index sum change = 871 Number of particles = 871
# (1000, 10, 1) (1000,)
# Acceptance rate = 16.80% Reject because ABC condition = 57.10% because ratio = 26.10%
# Iteration 53: Espilon = 100.0000, ESS = 1000 Acc. rate = 16.80% Uniqueness rate particules = 98.3% Uniqueness rate components = 98.3%
# Glob unique: 98.30%
#
#
# SIMULATION OF 1000 ALIVE PARTICLES (983 UNIQUE PARTICLES) DONE IN 416620 SILOS SIMULATIONS and 32406 LINEAR SUM ASSIGNMENT

# %% [markdown]
# # ABC-Vanille

# %%
def ABC_table(key, model, y_obs, n_sim):
    key, key_theta, key_sim = random.split(key, 3)
    thetas = model.prior_generator(key_theta, n_sim)
    zs = model.data_generator(key_sim, thetas)
    distances = model.distance(zs, y_obs)
    print(distances.shape)
    return zs, thetas, distances

def permABC_table(key, model, y_obs, n_sim):
    key, key_theta, key_sim = random.split(key, 3)
    thetas = model.prior_generator(key_theta, n_sim)
    zs = model.data_generator(key_sim, thetas)
    dists, zs_index, _ = optimal_index_distance(zs, y_obs, model)
    zs = zs[np.arange(n_sim)[:,None],zs_index]
    thetas = thetas.apply_permutation(zs_index)
    return zs, thetas, dists

# %%
N_abc = int(N_perm_smc/K)
key = random.PRNGKey(0)
key, key_table = random.split(key)
zs_van, thetas_van, dists_van = ABC_table(key_table, model, y_obs, N_abc)

mus_van = thetas_van.loc.squeeze()
alphas_van = thetas_van.glob.squeeze()
indexes = np.argsort(dists_van)[:N]
epsilon_van = dists_van[indexes].max()
mus_van = thetas_van.loc[indexes].squeeze()
alphas_van = thetas_van.glob[indexes].squeeze()
print("Epsilon vanille =", epsilon_van)
# Out:
# (41662,)
# Epsilon vanille = 159.686

# %% [markdown]
# # permABC-Vanille

# %%
N_permabc = int(N_perm_smc/K)
zs_perm_van, thetas_perm_van, dists_perm_van = permABC_table(key_table, model, y_obs, N_permabc)
mus_perm_van = thetas_perm_van.loc.squeeze()
alphas_perm_van = thetas_perm_van.glob.squeeze()
indexes_perm = np.argsort(dists_perm_van)[:N]
epsilon_perm_van = dists_perm_van[indexes_perm].max()  
mus_perm_van = thetas_perm_van.loc[indexes_perm,:].squeeze()
alphas_perm_van = thetas_perm_van.glob[indexes_perm,:].squeeze()
print("Epsilon perm vanille =", epsilon_perm_van)
# Out:
# In optimal index distance: zs min = -64.1 max = 66.6 matrices min = 0.0687 max = 1.46e+03
# Epsilon perm vanille = 24.140305

# %% [markdown]
# # ABC-Gibbs

# %%
import numpy as np
from tqdm.notebook import tqdm
from jax import vmap, jit, random
import jax.numpy as jnp
from scipy import stats
from scipy.optimize import linear_sum_assignment

@jit
def distance_one_silo(x_k,y_k):
    return jnp.sum((x_k-y_k)**2)

@jit
def distance_all_silo(x,y):
    return vmap(distance_one_silo, in_axes=(0, 0))(x,y)
@jit
def distance_xs(xs, y):
    return vmap(distance_all_silo, in_axes=(0, None))(xs, y)

@jit
def distance_sum_silo(x,y):
    return jnp.mean((distance_all_silo(x,y)))

@jit
def distance_sum(xs, y):
    return (vmap(distance_sum_silo, in_axes=(0, None))(xs, y))
# @jit 
# def dist_full_y(xs, y):
#     return jnp.sum(vmap(dist_full, in_axes=(0, None))(xs, y), axis = 1)

def ABCmus(key, M, y_obs, alpha):
    key, key_mus, key_data = random.split(key, 3)
    mus = random.normal(key_mus, shape=(M,K))*model.sigma_mu
    thetas = Theta(loc = mus[:,:,None], glob = np.repeat([alpha], M)[:,None])
    xs = model.data_generator(key_data, thetas)
    dists = distance_xs(xs, y_obs)
    index_min = jnp.argmin(dists, axis=0)
    Eps_betas = jnp.array([dists[index_min[i],i] for i in range(K)])
    mus_min = np.array([mus[index_min[i],i] for i in range(K)])
    return mus_min, Eps_betas
    

def ABCalpha(key, M, y_obs, mus):
    key, key_alpha, key_data = random.split(key, 3)
    alphas = random.normal(key_alpha, shape=(M,1))*model.sigma_alpha
    thetas = Theta(loc = np.repeat([mus], M, axis=0)[:,:,None], glob = alphas)
    xs = model.data_generator(key_data, thetas)
    dists = distance_sum(xs, y_obs)
    index_min = jnp.argmin(dists)
    Eps_alpha = dists[index_min]
    alpha_min = alphas[index_min]
    return alpha_min[0], Eps_alpha



def gibbs_robin(key, T, M_mu, M_alpha, y_obs):
    mus = np.zeros((T+1,K))
    alphas = np.zeros(T+1)
    
    Eps_mu = np.zeros((T, K))
    Eps_alpha = np.zeros(T)
    
    key, key_alpha, key_mu = random.split(key, 3)
    mus[0] = random.normal(key_mu, shape=(K,))*model.sigma_mu
    alphas[0] = random.normal(key_alpha)*model.sigma_alpha
    for t in tqdm(range(T)):
        key, key_mus = random.split(key)
        mus[t+1], Eps_mu[t] = ABCmus(key_mus, M_mu, y_obs, alphas[t])
        key, key_alpha = random.split(key)
        alphas[t+1], Eps_alpha[t] = ABCalpha(key_alpha, M_alpha, y_obs, mus[t+1])
        
    return mus, alphas, Eps_mu, Eps_alpha

# %%
# M = int(N_perm_smc/((N)*2*K))
print(model.sigma_alpha, model.sigma_mu, model.K, model.n_obs)
print(y_obs[0].shape)
M = 20
N = 1000
print(M)
mus_gibbs, alphas_gibbs, Eps_mus_gibbs, Eps_alphas_gibbs = gibbs_robin(key, N, M, M, y_obs[0])
# Out:
# 10 10 10 20
# (10, 20)
# 20
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# # PyMC

# %%
import pymc as pm

# Define the model
with pm.Model() as mod:
    # Priors for unknown model parameters

    sigma_x = 1.0

    mu = pm.Normal('mu', mu=0, sigma=sigma_mu, shape=(K, 1))
    alpha = pm.Normal('alpha', mu=0, sigma=sigma_alpha, shape=(1, 1))

    # Likelihood (sampling distribution) of observations
    x = pm.Normal('x', mu=mu + alpha, sigma=sigma_x, observed=y_obs[0])

    # Inference
    trace = pm.sample(1000, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, alpha]
# /Users/antoineluciano/.pyenv/versions/3.10.13/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Output()
# /Users/antoineluciano/.pyenv/versions/3.10.13/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 13 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details

# %%
true_post_mu = np.array(trace.posterior.mu[:,:,:,0]).reshape(4*1000, K)
true_post_alpha = np.array(trace.posterior.alpha).reshape(-1)

# %%
k = 2
sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black", alpha = .5)

plt.scatter(mus_gibbs[:,k], alphas_gibbs, alpha = .4, color = "red", label = "Gibbs")
# plt.scatter(mus_perm_smc[:,k], betas_perm_smc, alpha = .1, color = "blue", label = "Perm ABC SMC")
# sns.kdeplot(x=true_post_mu[:, k], y=true_post_alpha, label="True posterior", level = 3, color = "black")
# Out:
# /Users/antoineluciano/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %% [markdown]
# Probleme permSMC ? Acc plus faible que OS et UM pour meme epsilon!!!

# %%
true_post_mu= np.array(trace.posterior.mu[:,:,:,0]).reshape(4*1000,K)
true_post_alpha = np.array(trace.posterior.alpha).reshape(-1)

# %% [markdown]
# # Comparison

# %% [markdown]
# ## Marginals

# %%
N_plot = 2
burnin = 5
f, ax = plt.subplots(1, 3, figsize=(25, 5))

sns.kdeplot(mus_perm_van[:,0], ax=ax[0], label='ABC perm')
sns.kdeplot(mus_van[:,0], ax=ax[0], label='ABC Vanille')
sns.kdeplot(mus_smc_perm[:,0], ax=ax[0], label='ABC perm SMC')
sns.kdeplot(mus_gibbs[burnin:,0], ax=ax[0], label='Gibbs')
ax[0].axvline(true_theta.loc[0,0], color='red', label='True value')
ax[0].set_title('$\mu_{1}$')

sns.kdeplot(alphas_perm_van, ax=ax[1], label='ABC perm')
sns.kdeplot(alphas_van, ax=ax[1], label='ABC Vanille')
sns.kdeplot(alphas_smc_perm, ax=ax[1], label='ABC perm SMC')
sns.kdeplot(alphas_gibbs[burnin:], ax=ax[1], label='Gibbs')
ax[1].axvline(true_theta.glob[0], color='red', label='True value')
ax[1].set_title('$\\alpha$')

sns.kdeplot(alphas_perm_van+mus_perm_van[:,0], ax=ax[2], label='ABC perm')
sns.kdeplot(alphas_van+mus_van[:,0], ax=ax[2], label='ABC Vanille')
sns.kdeplot(alphas_smc_perm+mus_smc_perm[:,0], ax=ax[2], label='ABC perm SMC')
sns.kdeplot(alphas_gibbs[burnin:]+mus_gibbs[burnin:,0], ax=ax[2], label='Gibbs')
ax[2].axvline(true_theta.glob[0]+true_theta.loc[0,0], color='red', label='True value')
ax[2].set_title('$\\alpha + \mu_{1}$')

for a in ax:
    a.legend()

plt.show()

# %% [markdown]
# ## Joint

# %%
sns.kdeplot(x = mus_van[:, 0], y = alphas_van.squeeze(), label='ABC Vanille', color = "pink", alpha = .5, fill = True)
k = 0
sns.kdeplot(x = mus_smc_perm[:, 0], y = alphas_smc_perm, label='ABC SMC perm',  color = "darkblue", alpha =.5, fill = True)
sns.kdeplot(x = mus_perm_van[:, 0], y = alphas_perm_van.squeeze(), label='ABC Vanille perm', color = "lightblue", alpha = .5, fill = True)
sns.kdeplot(x = true_post_mu_k, y = true_post_alpha, label = "True", color = "green", alpha = .5, levels=3, fill = True)

# sns.kdeplot(x = mus_smc[:, k], y = alphas_smc, label='ABC SMC')
sns.kdeplot(x = np.array(mus_gibbs[:,0]), y = np.array(alphas_gibbs), label='ABC Gibbs', color ="orange", levels=3, fill = True, alpha = .5)
# plt.scatter(true_theta.loc[0,k], true_theta.glob[0], color='red', label='True value', marker = "x")
plt.ylabel("$\\alpha$")
plt.xlabel('$\mu_{'+str(1)+'}$')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # True Posterior

# %%
import jax.numpy as jnp
from jax.scipy.stats import multivariate_normal
import jax.random as random

def posterior_parameters(x, sigma_x, sigma_mu, sigma_alpha):
    """Calcule la moyenne et la covariance de la distribution postérieure."""
    K, n = x.shape
    x_bar = jnp.mean(x, axis=1)  # Moyenne empirique de chaque groupe
    
    # Variance et covariance des paramètres
    var_mu = sigma_x**2 / (n + sigma_x**2 / sigma_mu**2)
    var_alpha = sigma_x**2 / (K * n + sigma_x**2 / sigma_alpha**2)
    cov_mu_alpha = (sigma_x**2 / sigma_mu**2) / (n + sigma_x**2 / sigma_mu**2) * var_alpha
    
    # Matrice de covariance
    cov_matrix = jnp.eye(K+1) * var_mu
    cov_matrix = cov_matrix.at[K, K].set(var_alpha)
    cov_matrix = cov_matrix.at[:K, K].set(cov_mu_alpha)
    cov_matrix = cov_matrix.at[K, :K].set(cov_mu_alpha)
    
    # Moyenne postérieure
    mean_mu = (n * x_bar) / (n + sigma_x**2 / sigma_mu**2)
    mean_alpha = (n * jnp.sum(x_bar)) / (K * n + sigma_x**2 / sigma_alpha**2)
    mean_vector = jnp.concatenate([mean_mu, jnp.array([mean_alpha])])

    return mean_vector, cov_matrix

def posterior_pdf(x, mu_alpha, sigma):
    """Calcule la densité de probabilité de la loi normale postérieure."""
    return multivariate_normal.pdf(x, mean=mu_alpha, cov=sigma)

def sample_posterior(key, mean_vector, cov_matrix, num_samples=1):
    """Génère des échantillons depuis la postérieure en utilisant JAX."""
    samples = random.multivariate_normal(key, mean_vector, cov_matrix, shape=(num_samples,))
    return samples

# %% [markdown]
# # ABC-SMC

# %%
N = 1000
alpha = .95
key = random.PRNGKey(0)
test = abc_smc(key, model, N, 0, alpha, y_obs, Kernel_no_perm_RW, verbose = 3, Final_iteration = 30)

mus_smc= test["Thetas"][-1].loc.squeeze()
alphas_smc = test["Thetas"][-1].glob.squeeze()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 alpha = .95
#       3 key = random.PRNGKey(0)
# ----> 4 test = abc_smc(key, model, N, 0, alpha, y_obs, Kernel_no_perm_RW, verbose = 3, Final_iteration = 30)
#       6 mus_smc= test["Thetas"][-1].loc.squeeze()
#       7 alphas_smc = test["Thetas"][-1].glob.squeeze()
#
# File ~/Documents/Recherche/permABC_new/functions/abc_smc.py:166, in abc_smc(key, model, n_particles, epsilon_target, alpha, y_obs, kernel, Final_iteration, H, verbose, alpha_resample, both_loc_glob, T_pop, time_max, Nsim_max)
#     163 def abc_smc(
#     164     key, model, n_particles, epsilon_target, alpha, y_obs, kernel, Final_iteration = 0, H = 0, verbose = 1, alpha_resample = 0.5, both_loc_glob = True, T_pop = np.inf, time_max = np.inf, Nsim_max = np.inf
#     165 ):
# --> 166     if H > model.K:
#     167         raise Warning("H should be smaller than K")
#     168         H = model.K
#
# AttributeError: 'Model' object has no attribute 'K'

# %% [markdown]
# # ABC-PMC

# %%
from functions.abc_pmc import abc_pmc
thetas_pmc, weights_pmc, ess_pmc, epsilon_pmc, n_sim_pmc = abc_pmc(key = random.PRNGKey(0), model = model, n_particles = 20000, epsilon_target= epsilon_perm_van, alpha = .95, y_obs = sum_y, epsilon_1 = np.inf)
mus_pmc = thetas_pmc[-1].loc[:,:,0]
alphas_pmc = thetas_pmc[-1].glob[:,0]
w_pmc = weights_pmc[-1]
# Out:
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
