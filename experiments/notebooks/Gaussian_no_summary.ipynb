# %% [markdown]
# # Initialization

# %%
import os 

# %load_ext autoreload
# %autoreload 2

os.chdir("/Users/antoineluciano/Documents/Recherche/permABC_new/permABC")


from vanilla import abc_vanilla, perm_abc_vanilla
from smc import abc_smc, perm_abc_smc
from over_sampling import perm_abc_smc_os
from under_matching import perm_abc_smc_um  
from kernels import KernelTruncatedRW
from distances import optimal_index_distance
from models.Gaussian_with_no_summary_stats import GaussianWithNoSummaryStats
from jax import random
import numpy as np
import jax.numpy as jnp
from scipy.stats import invgamma
import matplotlib.pyplot as plt
import seaborn as sns

# %%
key = random.PRNGKey(0)
key, subkey = random.split(key)
K = 15
n = 10
sigma0 = 10
alpha, beta = 5,5
model = GaussianWithNoSummaryStats(K = K, n_obs= n, sigma_0 = sigma0, alpha = alpha, beta = beta)
true_theta = model.prior_generator(subkey, 1)
# true_theta.loc = np.linspace(-2*sigma0, 2*sigma0, K)[None,:, None]
true_theta.glob = np.array([1.])[None,:]
key, subkey = random.split(key)
y_obs = model.data_generator(subkey, true_theta)
print(y_obs.shape)
# Out:
# (1, 15, 10)

# %% [markdown]
# # Vanilla

# %% [markdown]
# ## permABC

# %%
key, subkey = random.split(key)
N_points = 1000000
model.reset_weights_distance()
key, key_theta, key_perm = random.split(key, 3)
thetas = model.prior_generator(key_theta, N_points)
zs = model.data_generator(key, thetas)
dists_perm, ys_index, zs_index, _ = optimal_index_distance(model, zs, y_obs)
thetas_perm = thetas.apply_permutation(zs_index)

mus_perm_van = thetas_perm.loc.squeeze()
betas_perm_van = thetas_perm.glob.squeeze()
# Out:
# Minimum distance: 0.0001124188 Maximum distance: 245.82314 Number of NaNs: 0

# %% [markdown]
# ## ABC

# %%
key, subkey = random.split(key)
zs_van, thetas_van, dists_van, n_sim_van = abc_vanilla(key = subkey, model = model, n_points = N_points, epsilon = np.inf, y_obs = y_obs)
mus_van = thetas_van.loc.squeeze()
betas_van = thetas_van.glob.squeeze()

# %% [markdown]
# # SMC

# %% [markdown]
# ## ABC

# %%
kernel = KernelTruncatedRW 
key, subkey = random.split(key)
# epsilon = 0.
# N = 1000
N_smc = 1000
out_smc = abc_smc(key = subkey, model = model, n_particles= N_smc, epsilon_target= 0, y_obs = y_obs, kernel = kernel, verbose =1, Final_iteration = 0, update_weights_distance= False, N_sim_max= N_points*K, stopping_accept_rate= 0.)

mus_smc = out_smc['Thetas'][-1].loc.squeeze()
betas_smc = out_smc['Thetas'][-1].glob.squeeze()
n_sim = np.sum(out_smc["N_sim"])
# Out:
# Iteration 0: Epsilon = inf, ESS = 1000 Acc. rate = 100% Numb. unique particles = 1000
# Iteration 1: Espilon = 234.1950, ESS = 950 Acc. rate = 1.37% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 29250/15000000
#
# Iteration 2: Espilon = 211.6925, ESS = 902 Acc. rate = 1.11% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 42780/15000000
#
# Iteration 3: Espilon = 202.6110, ESS = 856 Acc. rate = 1.05% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 55620/15000000
#
# Iteration 4: Espilon = 189.9334, ESS = 813 Acc. rate = 0.49% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 67815/15000000
#
# Iteration 5: Espilon = 183.0445, ESS = 772 Acc. rate = 1.04% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 79395/15000000
#
# Iteration 6: Espilon = 177.4478, ESS = 733 Acc. rate = 0.82% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 90390/15000000
#
# Iteration 7: Espilon = 171.2305, ESS = 696 Acc. rate = 0.72% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 100830/15000000
#
# Iteration 8: Espilon = 166.8359, ESS = 661 Acc. rate = 0.76% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 110745/15000000
#
# Iteration 9: Espilon = 162.3091, ESS = 628 Acc. rate = 0.48% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 120165/15000000
#
# Iteration 10: Espilon = 159.1035, ESS = 596 Acc. rate = 1.17% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 129105/15000000
#
# Iteration 11: Espilon = 156.2837, ESS = 566 Acc. rate = 0.88% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 137595/15000000
#
# Iteration 12: Espilon = 153.4099, ESS = 537 Acc. rate = 1.12% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 145650/15000000
#
# Iteration 13: Espilon = 151.1301, ESS = 510 Acc. rate = 0.59% Uniqueness rate particules = 100.0% Uniqueness rate components = 99.9% Global parameters uniqueness rate = 99.9%
# NUMBER OF SIMULATIONS 153300/15000000
#
# Resampling... 484 unique particles left
# Iteration 14: Espilon = 147.7327, ESS = 1000 Acc. rate = 1.00% Uniqueness rate particules = 49.4% Uniqueness rate components = 49.4% Global parameters uniqueness rate = 49.3%
# NUMBER OF SIMULATIONS 168300/15000000
#
# Iteration 15: Espilon = 143.6866, ESS = 950 Acc. rate = 0.84% Uniqueness rate particules = 50.2% Uniqueness rate components = 50.2% Global parameters uniqueness rate = 50.1%
# NUMBER OF SIMULATIONS 182550/15000000
#
# Iteration 16: Espilon = 140.0022, ESS = 903 Acc. rate = 0.78% Uniqueness rate particules = 50.8% Uniqueness rate components = 50.8% Global parameters uniqueness rate = 50.7%
# NUMBER OF SIMULATIONS 196095/15000000
#
# Iteration 17: Espilon = 138.0527, ESS = 857 Acc. rate = 1.05% Uniqueness rate particules = 51.7% Uniqueness rate components = 51.7% Global parameters uniqueness rate = 51.6%
# NUMBER OF SIMULATIONS 208950/15000000
#
# Iteration 18: Espilon = 135.6638, ESS = 814 Acc. rate = 0.74% Uniqueness rate particules = 52.1% Uniqueness rate components = 52.1% Global parameters uniqueness rate = 52.0%
# NUMBER OF SIMULATIONS 221160/15000000
#
# Iteration 19: Espilon = 132.5270, ESS = 774 Acc. rate = 0.90% Uniqueness rate particules = 52.5% Uniqueness rate components = 52.5% Global parameters uniqueness rate = 52.4%
# NUMBER OF SIMULATIONS 232770/15000000
#
# Iteration 20: Espilon = 130.2294, ESS = 735 Acc. rate = 1.09% Uniqueness rate particules = 53.0% Uniqueness rate components = 53.0% Global parameters uniqueness rate = 52.9%
# NUMBER OF SIMULATIONS 243795/15000000
#
# Iteration 21: Espilon = 128.7141, ESS = 698 Acc. rate = 0.72% Uniqueness rate particules = 53.3% Uniqueness rate components = 53.3% Global parameters uniqueness rate = 53.2%
# NUMBER OF SIMULATIONS 254265/15000000
#
# Iteration 22: Espilon = 127.1009, ESS = 664 Acc. rate = 0.60% Uniqueness rate particules = 53.7% Uniqueness rate components = 53.7% Global parameters uniqueness rate = 53.6%
# NUMBER OF SIMULATIONS 264225/15000000
#
# Iteration 23: Espilon = 125.3753, ESS = 630 Acc. rate = 1.11% Uniqueness rate particules = 54.3% Uniqueness rate components = 54.3% Global parameters uniqueness rate = 54.2%
# NUMBER OF SIMULATIONS 273675/15000000
#
# Iteration 24: Espilon = 123.5346, ESS = 599 Acc. rate = 0.50% Uniqueness rate particules = 54.6% Uniqueness rate components = 54.6% Global parameters uniqueness rate = 54.5%
# NUMBER OF SIMULATIONS 282660/15000000
#
# Iteration 25: Espilon = 122.2334, ESS = 570 Acc. rate = 0.18% Uniqueness rate particules = 54.7% Uniqueness rate components = 54.7% Global parameters uniqueness rate = 54.6%
# NUMBER OF SIMULATIONS 291210/15000000
#
# Iteration 26: Espilon = 120.7062, ESS = 541 Acc. rate = 0.74% Uniqueness rate particules = 55.1% Uniqueness rate components = 55.1% Global parameters uniqueness rate = 55.0%
# NUMBER OF SIMULATIONS 299325/15000000
#
# Iteration 27: Espilon = 118.6987, ESS = 514 Acc. rate = 0.78% Uniqueness rate particules = 55.4% Uniqueness rate components = 55.4% Global parameters uniqueness rate = 55.3%
# NUMBER OF SIMULATIONS 307035/15000000
#
# Resampling... 283 unique particles left
# Iteration 28: Espilon = 117.1117, ESS = 1000 Acc. rate = 1.20% Uniqueness rate particules = 29.5% Uniqueness rate components = 29.5% Global parameters uniqueness rate = 29.4%
# NUMBER OF SIMULATIONS 322035/15000000
#
# Iteration 29: Espilon = 115.2854, ESS = 952 Acc. rate = 1.05% Uniqueness rate particules = 30.5% Uniqueness rate components = 30.5% Global parameters uniqueness rate = 30.4%
# NUMBER OF SIMULATIONS 336315/15000000
#
# Iteration 30: Espilon = 113.9664, ESS = 905 Acc. rate = 0.44% Uniqueness rate particules = 30.9% Uniqueness rate components = 30.9% Global parameters uniqueness rate = 30.8%
# NUMBER OF SIMULATIONS 349890/15000000
#
# Iteration 31: Espilon = 111.7696, ESS = 859 Acc. rate = 1.05% Uniqueness rate particules = 31.8% Uniqueness rate components = 31.8% Global parameters uniqueness rate = 31.7%
# NUMBER OF SIMULATIONS 362775/15000000
#
# Iteration 32: Espilon = 110.4564, ESS = 816 Acc. rate = 0.74% Uniqueness rate particules = 32.4% Uniqueness rate components = 32.4% Global parameters uniqueness rate = 32.3%
# NUMBER OF SIMULATIONS 375015/15000000
#
# Iteration 33: Espilon = 109.3986, ESS = 776 Acc. rate = 1.03% Uniqueness rate particules = 33.2% Uniqueness rate components = 33.2% Global parameters uniqueness rate = 33.1%
# NUMBER OF SIMULATIONS 386655/15000000
#
# Iteration 34: Espilon = 108.5320, ESS = 740 Acc. rate = 0.81% Uniqueness rate particules = 33.8% Uniqueness rate components = 33.8% Global parameters uniqueness rate = 33.7%
# NUMBER OF SIMULATIONS 397755/15000000
#
# Iteration 35: Espilon = 106.9551, ESS = 705 Acc. rate = 0.43% Uniqueness rate particules = 34.1% Uniqueness rate components = 34.1% Global parameters uniqueness rate = 34.0%
# NUMBER OF SIMULATIONS 408330/15000000
#
# Iteration 36: Espilon = 105.7980, ESS = 670 Acc. rate = 0.45% Uniqueness rate particules = 34.4% Uniqueness rate components = 34.4% Global parameters uniqueness rate = 34.3%
# NUMBER OF SIMULATIONS 418380/15000000
#
# Iteration 37: Espilon = 104.6196, ESS = 639 Acc. rate = 0.47% Uniqueness rate particules = 34.7% Uniqueness rate components = 34.7% Global parameters uniqueness rate = 34.6%
# NUMBER OF SIMULATIONS 427965/15000000
#
# Iteration 38: Espilon = 103.9026, ESS = 608 Acc. rate = 0.00% Uniqueness rate particules = 34.7% Uniqueness rate components = 34.7% Global parameters uniqueness rate = 34.6%
# NUMBER OF SIMULATIONS 437085/15000000
#
# Iteration 39: Espilon = 103.0024, ESS = 577 Acc. rate = 0.69% Uniqueness rate particules = 35.0% Uniqueness rate components = 35.0% Global parameters uniqueness rate = 34.9%
# NUMBER OF SIMULATIONS 445740/15000000
#
# Iteration 40: Espilon = 102.3929, ESS = 550 Acc. rate = 0.55% Uniqueness rate particules = 35.3% Uniqueness rate components = 35.3% Global parameters uniqueness rate = 35.2%
# NUMBER OF SIMULATIONS 453990/15000000
#
# Iteration 41: Espilon = 101.0944, ESS = 522 Acc. rate = 0.19% Uniqueness rate particules = 35.4% Uniqueness rate components = 35.4% Global parameters uniqueness rate = 35.3%
# NUMBER OF SIMULATIONS 461820/15000000
#
# Resampling... 185 unique particles left
# Iteration 42: Espilon = 98.8500, ESS = 1000 Acc. rate = 0.70% Uniqueness rate particules = 19.2% Uniqueness rate components = 19.2% Global parameters uniqueness rate = 19.2%
# NUMBER OF SIMULATIONS 476820/15000000
#
# Iteration 43: Espilon = 97.7202, ESS = 955 Acc. rate = 0.42% Uniqueness rate particules = 19.6% Uniqueness rate components = 19.6% Global parameters uniqueness rate = 19.6%
# NUMBER OF SIMULATIONS 491145/15000000
#
# Iteration 44: Espilon = 97.4043, ESS = 913 Acc. rate = 0.55% Uniqueness rate particules = 20.0% Uniqueness rate components = 20.0% Global parameters uniqueness rate = 20.0%
# NUMBER OF SIMULATIONS 504840/15000000
#
# Iteration 45: Espilon = 96.5673, ESS = 869 Acc. rate = 0.81% Uniqueness rate particules = 20.7% Uniqueness rate components = 20.7% Global parameters uniqueness rate = 20.7%
# NUMBER OF SIMULATIONS 517875/15000000
#
# Iteration 46: Espilon = 95.5226, ESS = 827 Acc. rate = 0.48% Uniqueness rate particules = 21.1% Uniqueness rate components = 21.1% Global parameters uniqueness rate = 21.1%
# NUMBER OF SIMULATIONS 530280/15000000
#
# Iteration 47: Espilon = 95.1252, ESS = 792 Acc. rate = 0.51% Uniqueness rate particules = 21.5% Uniqueness rate components = 21.5% Global parameters uniqueness rate = 21.5%
# NUMBER OF SIMULATIONS 542160/15000000
#
# Iteration 48: Espilon = 94.8809, ESS = 754 Acc. rate = 1.06% Uniqueness rate particules = 22.1% Uniqueness rate components = 22.1% Global parameters uniqueness rate = 22.1%
# NUMBER OF SIMULATIONS 553470/15000000
#
# Iteration 49: Espilon = 94.4128, ESS = 716 Acc. rate = 0.42% Uniqueness rate particules = 22.4% Uniqueness rate components = 22.4% Global parameters uniqueness rate = 22.4%
# NUMBER OF SIMULATIONS 564210/15000000
#
# Iteration 50: Espilon = 93.8073, ESS = 681 Acc. rate = 0.00% Uniqueness rate particules = 22.4% Uniqueness rate components = 22.4% Global parameters uniqueness rate = 22.4%
# NUMBER OF SIMULATIONS 574425/15000000
#
# Iteration 51: Espilon = 91.8465, ESS = 648 Acc. rate = 0.77% Uniqueness rate particules = 22.9% Uniqueness rate components = 22.9% Global parameters uniqueness rate = 22.9%
# NUMBER OF SIMULATIONS 584145/15000000
#
# Iteration 52: Espilon = 90.0887, ESS = 622 Acc. rate = 0.80% Uniqueness rate particules = 23.4% Uniqueness rate components = 23.4% Global parameters uniqueness rate = 23.4%
# NUMBER OF SIMULATIONS 593475/15000000
#
# Iteration 53: Espilon = 89.0240, ESS = 590 Acc. rate = 1.69% Uniqueness rate particules = 24.4% Uniqueness rate components = 24.4% Global parameters uniqueness rate = 24.4%
# NUMBER OF SIMULATIONS 602325/15000000
#
# Iteration 54: Espilon = 88.0431, ESS = 564 Acc. rate = 0.71% Uniqueness rate particules = 24.7% Uniqueness rate components = 24.7% Global parameters uniqueness rate = 24.7%
# NUMBER OF SIMULATIONS 610785/15000000
#
# Iteration 55: Espilon = 87.4783, ESS = 539 Acc. rate = 0.37% Uniqueness rate particules = 24.9% Uniqueness rate components = 24.9% Global parameters uniqueness rate = 24.9%
# NUMBER OF SIMULATIONS 618870/15000000
#
# Iteration 56: Espilon = 86.8693, ESS = 513 Acc. rate = 0.58% Uniqueness rate particules = 25.2% Uniqueness rate components = 25.2% Global parameters uniqueness rate = 25.2%
# NUMBER OF SIMULATIONS 626565/15000000
#
# Resampling... 140 unique particles left
# Iteration 57: Espilon = 86.3891, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 14.4% Uniqueness rate components = 14.4% Global parameters uniqueness rate = 14.4%
# NUMBER OF SIMULATIONS 641565/15000000
#
# Iteration 58: Espilon = 85.7793, ESS = 956 Acc. rate = 0.10% Uniqueness rate particules = 14.5% Uniqueness rate components = 14.5% Global parameters uniqueness rate = 14.5%
# NUMBER OF SIMULATIONS 655905/15000000
#
# Iteration 59: Espilon = 85.5313, ESS = 920 Acc. rate = 0.65% Uniqueness rate particules = 15.1% Uniqueness rate components = 15.1% Global parameters uniqueness rate = 15.1%
# NUMBER OF SIMULATIONS 669705/15000000
#
# Iteration 60: Espilon = 85.3423, ESS = 882 Acc. rate = 0.68% Uniqueness rate particules = 15.7% Uniqueness rate components = 15.7% Global parameters uniqueness rate = 15.7%
# NUMBER OF SIMULATIONS 682935/15000000
#
# Iteration 61: Espilon = 84.8862, ESS = 839 Acc. rate = 1.07% Uniqueness rate particules = 16.6% Uniqueness rate components = 16.6% Global parameters uniqueness rate = 16.6%
# NUMBER OF SIMULATIONS 695520/15000000
#
# Iteration 62: Espilon = 84.7197, ESS = 810 Acc. rate = 0.37% Uniqueness rate particules = 16.9% Uniqueness rate components = 16.9% Global parameters uniqueness rate = 16.9%
# NUMBER OF SIMULATIONS 707670/15000000
#
# Iteration 63: Espilon = 83.9477, ESS = 779 Acc. rate = 0.64% Uniqueness rate particules = 17.4% Uniqueness rate components = 17.4% Global parameters uniqueness rate = 17.4%
# NUMBER OF SIMULATIONS 719355/15000000
#
# Iteration 64: Espilon = 83.8121, ESS = 740 Acc. rate = 0.54% Uniqueness rate particules = 17.7% Uniqueness rate components = 17.7% Global parameters uniqueness rate = 17.7%
# NUMBER OF SIMULATIONS 730455/15000000
#
# Iteration 65: Espilon = 82.6218, ESS = 719 Acc. rate = 1.11% Uniqueness rate particules = 18.3% Uniqueness rate components = 18.3% Global parameters uniqueness rate = 18.3%
# NUMBER OF SIMULATIONS 741240/15000000
#
# Iteration 66: Espilon = 82.1095, ESS = 683 Acc. rate = 0.73% Uniqueness rate particules = 18.7% Uniqueness rate components = 18.7% Global parameters uniqueness rate = 18.7%
# NUMBER OF SIMULATIONS 751485/15000000
#
# Iteration 67: Espilon = 80.6944, ESS = 648 Acc. rate = 1.54% Uniqueness rate particules = 19.7% Uniqueness rate components = 19.7% Global parameters uniqueness rate = 19.7%
# NUMBER OF SIMULATIONS 761205/15000000
#
# Iteration 68: Espilon = 79.8698, ESS = 620 Acc. rate = 0.32% Uniqueness rate particules = 19.9% Uniqueness rate components = 19.9% Global parameters uniqueness rate = 19.9%
# NUMBER OF SIMULATIONS 770505/15000000
#
# Iteration 69: Espilon = 79.5301, ESS = 592 Acc. rate = 0.17% Uniqueness rate particules = 20.0% Uniqueness rate components = 20.0% Global parameters uniqueness rate = 20.0%
# NUMBER OF SIMULATIONS 779385/15000000
#
# Iteration 70: Espilon = 78.7799, ESS = 567 Acc. rate = 0.88% Uniqueness rate particules = 20.4% Uniqueness rate components = 20.4% Global parameters uniqueness rate = 20.4%
# NUMBER OF SIMULATIONS 787890/15000000
#
# Iteration 71: Espilon = 78.6593, ESS = 543 Acc. rate = 0.18% Uniqueness rate particules = 20.5% Uniqueness rate components = 20.5% Global parameters uniqueness rate = 20.5%
# NUMBER OF SIMULATIONS 796035/15000000
#
# Iteration 72: Espilon = 78.3825, ESS = 515 Acc. rate = 0.58% Uniqueness rate particules = 20.8% Uniqueness rate components = 20.8% Global parameters uniqueness rate = 20.8%
# NUMBER OF SIMULATIONS 803760/15000000
#
# Resampling... 137 unique particles left
# Iteration 73: Espilon = 77.5336, ESS = 1000 Acc. rate = 1.00% Uniqueness rate particules = 14.7% Uniqueness rate components = 14.7% Global parameters uniqueness rate = 14.7%
# NUMBER OF SIMULATIONS 818760/15000000
#
# Iteration 74: Espilon = 77.0852, ESS = 959 Acc. rate = 1.04% Uniqueness rate particules = 15.7% Uniqueness rate components = 15.7% Global parameters uniqueness rate = 15.7%
# NUMBER OF SIMULATIONS 833145/15000000
#
# Iteration 75: Espilon = 76.2892, ESS = 914 Acc. rate = 0.77% Uniqueness rate particules = 16.4% Uniqueness rate components = 16.4% Global parameters uniqueness rate = 16.4%
# NUMBER OF SIMULATIONS 846855/15000000
#
# Iteration 76: Espilon = 74.8870, ESS = 869 Acc. rate = 0.92% Uniqueness rate particules = 17.1% Uniqueness rate components = 17.1% Global parameters uniqueness rate = 17.1%
# NUMBER OF SIMULATIONS 859890/15000000
#
# Iteration 77: Espilon = 74.5617, ESS = 831 Acc. rate = 0.72% Uniqueness rate particules = 17.7% Uniqueness rate components = 17.7% Global parameters uniqueness rate = 17.7%
# NUMBER OF SIMULATIONS 872355/15000000
#
# Iteration 78: Espilon = 74.2900, ESS = 792 Acc. rate = 0.63% Uniqueness rate particules = 18.1% Uniqueness rate components = 18.1% Global parameters uniqueness rate = 18.1%
# NUMBER OF SIMULATIONS 884235/15000000
#
# Iteration 79: Espilon = 73.7941, ESS = 765 Acc. rate = 0.65% Uniqueness rate particules = 18.5% Uniqueness rate components = 18.5% Global parameters uniqueness rate = 18.5%
# NUMBER OF SIMULATIONS 895710/15000000
#
# Iteration 80: Espilon = 73.3654, ESS = 744 Acc. rate = 1.48% Uniqueness rate particules = 19.6% Uniqueness rate components = 19.6% Global parameters uniqueness rate = 19.6%
# NUMBER OF SIMULATIONS 906870/15000000
#
# Iteration 81: Espilon = 73.0287, ESS = 707 Acc. rate = 0.85% Uniqueness rate particules = 20.1% Uniqueness rate components = 20.1% Global parameters uniqueness rate = 20.1%
# NUMBER OF SIMULATIONS 917475/15000000
#
# Iteration 82: Espilon = 72.3816, ESS = 682 Acc. rate = 0.73% Uniqueness rate particules = 20.6% Uniqueness rate components = 20.6% Global parameters uniqueness rate = 20.6%
# NUMBER OF SIMULATIONS 927705/15000000
#
# Iteration 83: Espilon = 72.1705, ESS = 649 Acc. rate = 1.08% Uniqueness rate particules = 21.1% Uniqueness rate components = 21.1% Global parameters uniqueness rate = 21.1%
# NUMBER OF SIMULATIONS 937440/15000000
#
# Iteration 84: Espilon = 71.2795, ESS = 616 Acc. rate = 0.65% Uniqueness rate particules = 21.5% Uniqueness rate components = 21.5% Global parameters uniqueness rate = 21.5%
# NUMBER OF SIMULATIONS 946680/15000000
#
# Iteration 85: Espilon = 70.5928, ESS = 586 Acc. rate = 0.68% Uniqueness rate particules = 21.9% Uniqueness rate components = 21.9% Global parameters uniqueness rate = 21.9%
# NUMBER OF SIMULATIONS 955470/15000000
#
# Iteration 86: Espilon = 70.0653, ESS = 566 Acc. rate = 0.53% Uniqueness rate particules = 22.0% Uniqueness rate components = 22.0% Global parameters uniqueness rate = 22.0%
# NUMBER OF SIMULATIONS 963960/15000000
#
# Iteration 87: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 22.3% Uniqueness rate components = 22.3% Global parameters uniqueness rate = 22.3%
# NUMBER OF SIMULATIONS 972255/15000000
#
# Iteration 88: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 22.4% Uniqueness rate components = 22.4% Global parameters uniqueness rate = 22.4%
# NUMBER OF SIMULATIONS 980550/15000000
#
# Iteration 89: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 22.6% Uniqueness rate components = 22.6% Global parameters uniqueness rate = 22.6%
# NUMBER OF SIMULATIONS 988845/15000000
#
# Iteration 90: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 22.7% Uniqueness rate components = 22.7% Global parameters uniqueness rate = 22.7%
# NUMBER OF SIMULATIONS 997140/15000000
#
# Iteration 91: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 23.3% Uniqueness rate components = 23.3% Global parameters uniqueness rate = 23.3%
# NUMBER OF SIMULATIONS 1005435/15000000
#
# Iteration 92: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 23.9% Uniqueness rate components = 23.9% Global parameters uniqueness rate = 23.9%
# NUMBER OF SIMULATIONS 1013730/15000000
#
# Iteration 93: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 24.2% Uniqueness rate components = 24.2% Global parameters uniqueness rate = 24.2%
# NUMBER OF SIMULATIONS 1022025/15000000
#
# Iteration 94: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 24.6% Uniqueness rate components = 24.6% Global parameters uniqueness rate = 24.6%
# NUMBER OF SIMULATIONS 1030320/15000000
#
# Iteration 95: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 24.8% Uniqueness rate components = 24.8% Global parameters uniqueness rate = 24.8%
# NUMBER OF SIMULATIONS 1038615/15000000
#
# Iteration 96: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 25.2% Uniqueness rate components = 25.2% Global parameters uniqueness rate = 25.2%
# NUMBER OF SIMULATIONS 1046910/15000000
#
# Iteration 97: Espilon = 69.9483, ESS = 553 Acc. rate = 0.00% Uniqueness rate particules = 25.2% Uniqueness rate components = 25.2% Global parameters uniqueness rate = 25.2%
# NUMBER OF SIMULATIONS 1055205/15000000
#
# Iteration 98: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 25.4% Uniqueness rate components = 25.4% Global parameters uniqueness rate = 25.4%
# NUMBER OF SIMULATIONS 1063500/15000000
#
# Iteration 99: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 25.5% Uniqueness rate components = 25.5% Global parameters uniqueness rate = 25.5%
# NUMBER OF SIMULATIONS 1071795/15000000
#
# Iteration 100: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 25.6% Uniqueness rate components = 25.6% Global parameters uniqueness rate = 25.6%
# NUMBER OF SIMULATIONS 1080090/15000000
#
# Iteration 101: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 25.8% Uniqueness rate components = 25.8% Global parameters uniqueness rate = 25.8%
# NUMBER OF SIMULATIONS 1088385/15000000
#
# Iteration 102: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 25.9% Uniqueness rate components = 25.9% Global parameters uniqueness rate = 25.9%
# NUMBER OF SIMULATIONS 1096680/15000000
#
# Iteration 103: Espilon = 69.9483, ESS = 553 Acc. rate = 0.00% Uniqueness rate particules = 25.9% Uniqueness rate components = 25.9% Global parameters uniqueness rate = 25.9%
# NUMBER OF SIMULATIONS 1104975/15000000
#
# Iteration 104: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 26.2% Uniqueness rate components = 26.2% Global parameters uniqueness rate = 26.2%
# NUMBER OF SIMULATIONS 1113270/15000000
#
# Iteration 105: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 26.7% Uniqueness rate components = 26.7% Global parameters uniqueness rate = 26.7%
# NUMBER OF SIMULATIONS 1121565/15000000
#
# Iteration 106: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 26.9% Uniqueness rate components = 26.9% Global parameters uniqueness rate = 26.9%
# NUMBER OF SIMULATIONS 1129860/15000000
#
# Iteration 107: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 27.3% Uniqueness rate components = 27.3% Global parameters uniqueness rate = 27.3%
# NUMBER OF SIMULATIONS 1138155/15000000
#
# Iteration 108: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 27.6% Uniqueness rate components = 27.6% Global parameters uniqueness rate = 27.6%
# NUMBER OF SIMULATIONS 1146450/15000000
#
# Iteration 109: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 27.8% Uniqueness rate components = 27.8% Global parameters uniqueness rate = 27.8%
# NUMBER OF SIMULATIONS 1154745/15000000
#
# Iteration 110: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 27.9% Uniqueness rate components = 27.9% Global parameters uniqueness rate = 27.9%
# NUMBER OF SIMULATIONS 1163040/15000000
#
# Iteration 111: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 28.3% Uniqueness rate components = 28.3% Global parameters uniqueness rate = 28.3%
# NUMBER OF SIMULATIONS 1171335/15000000
#
# Iteration 112: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 28.6% Uniqueness rate components = 28.6% Global parameters uniqueness rate = 28.6%
# NUMBER OF SIMULATIONS 1179630/15000000
#
# Iteration 113: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 28.7% Uniqueness rate components = 28.7% Global parameters uniqueness rate = 28.7%
# NUMBER OF SIMULATIONS 1187925/15000000
#
# Iteration 114: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 28.9% Uniqueness rate components = 28.9% Global parameters uniqueness rate = 28.9%
# NUMBER OF SIMULATIONS 1196220/15000000
#
# Iteration 115: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 29.0% Uniqueness rate components = 29.0% Global parameters uniqueness rate = 29.0%
# NUMBER OF SIMULATIONS 1204515/15000000
#
# Iteration 116: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 29.1% Uniqueness rate components = 29.1% Global parameters uniqueness rate = 29.1%
# NUMBER OF SIMULATIONS 1212810/15000000
#
# Iteration 117: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 29.3% Uniqueness rate components = 29.3% Global parameters uniqueness rate = 29.3%
# NUMBER OF SIMULATIONS 1221105/15000000
#
# Iteration 118: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 29.5% Uniqueness rate components = 29.5% Global parameters uniqueness rate = 29.5%
# NUMBER OF SIMULATIONS 1229400/15000000
#
# Iteration 119: Espilon = 69.9483, ESS = 553 Acc. rate = 1.45% Uniqueness rate particules = 29.9% Uniqueness rate components = 29.9% Global parameters uniqueness rate = 29.9%
# NUMBER OF SIMULATIONS 1237695/15000000
#
# Iteration 120: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 30.1% Uniqueness rate components = 30.1% Global parameters uniqueness rate = 30.1%
# NUMBER OF SIMULATIONS 1245990/15000000
#
# Iteration 121: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 30.4% Uniqueness rate components = 30.4% Global parameters uniqueness rate = 30.4%
# NUMBER OF SIMULATIONS 1254285/15000000
#
# Iteration 122: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 30.7% Uniqueness rate components = 30.7% Global parameters uniqueness rate = 30.7%
# NUMBER OF SIMULATIONS 1262580/15000000
#
# Iteration 123: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 30.7% Uniqueness rate components = 30.7% Global parameters uniqueness rate = 30.7%
# NUMBER OF SIMULATIONS 1270875/15000000
#
# Iteration 124: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 31.0% Uniqueness rate components = 31.0% Global parameters uniqueness rate = 31.0%
# NUMBER OF SIMULATIONS 1279170/15000000
#
# Iteration 125: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 31.2% Uniqueness rate components = 31.2% Global parameters uniqueness rate = 31.2%
# NUMBER OF SIMULATIONS 1287465/15000000
#
# Iteration 126: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 31.3% Uniqueness rate components = 31.3% Global parameters uniqueness rate = 31.3%
# NUMBER OF SIMULATIONS 1295760/15000000
#
# Iteration 127: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 31.7% Uniqueness rate components = 31.7% Global parameters uniqueness rate = 31.7%
# NUMBER OF SIMULATIONS 1304055/15000000
#
# Iteration 128: Espilon = 69.9483, ESS = 553 Acc. rate = 0.00% Uniqueness rate particules = 31.7% Uniqueness rate components = 31.7% Global parameters uniqueness rate = 31.7%
# NUMBER OF SIMULATIONS 1312350/15000000
#
# Iteration 129: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 31.8% Uniqueness rate components = 31.8% Global parameters uniqueness rate = 31.8%
# NUMBER OF SIMULATIONS 1320645/15000000
#
# Iteration 130: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 32.0% Uniqueness rate components = 32.0% Global parameters uniqueness rate = 32.0%
# NUMBER OF SIMULATIONS 1328940/15000000
#
# Iteration 131: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 32.1% Uniqueness rate components = 32.1% Global parameters uniqueness rate = 32.1%
# NUMBER OF SIMULATIONS 1337235/15000000
#
# Iteration 132: Espilon = 69.9483, ESS = 553 Acc. rate = 1.99% Uniqueness rate particules = 32.5% Uniqueness rate components = 32.5% Global parameters uniqueness rate = 32.5%
# NUMBER OF SIMULATIONS 1345530/15000000
#
# Iteration 133: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 32.7% Uniqueness rate components = 32.7% Global parameters uniqueness rate = 32.7%
# NUMBER OF SIMULATIONS 1353825/15000000
#
# Iteration 134: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 32.8% Uniqueness rate components = 32.8% Global parameters uniqueness rate = 32.8%
# NUMBER OF SIMULATIONS 1362120/15000000
#
# Iteration 135: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 32.9% Uniqueness rate components = 32.9% Global parameters uniqueness rate = 32.9%
# NUMBER OF SIMULATIONS 1370415/15000000
#
# Iteration 136: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 33.1% Uniqueness rate components = 33.1% Global parameters uniqueness rate = 33.1%
# NUMBER OF SIMULATIONS 1378710/15000000
#
# Iteration 137: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 33.3% Uniqueness rate components = 33.3% Global parameters uniqueness rate = 33.3%
# NUMBER OF SIMULATIONS 1387005/15000000
#
# Iteration 138: Espilon = 69.9483, ESS = 553 Acc. rate = 1.45% Uniqueness rate particules = 33.8% Uniqueness rate components = 33.8% Global parameters uniqueness rate = 33.8%
# NUMBER OF SIMULATIONS 1395300/15000000
#
# Iteration 139: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 34.2% Uniqueness rate components = 34.2% Global parameters uniqueness rate = 34.2%
# NUMBER OF SIMULATIONS 1403595/15000000
#
# Iteration 140: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 34.3% Uniqueness rate components = 34.3% Global parameters uniqueness rate = 34.3%
# NUMBER OF SIMULATIONS 1411890/15000000
#
# Iteration 141: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 34.4% Uniqueness rate components = 34.4% Global parameters uniqueness rate = 34.4%
# NUMBER OF SIMULATIONS 1420185/15000000
#
# Iteration 142: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 34.6% Uniqueness rate components = 34.6% Global parameters uniqueness rate = 34.6%
# NUMBER OF SIMULATIONS 1428480/15000000
#
# Iteration 143: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 34.7% Uniqueness rate components = 34.7% Global parameters uniqueness rate = 34.7%
# NUMBER OF SIMULATIONS 1436775/15000000
#
# Iteration 144: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 34.9% Uniqueness rate components = 34.9% Global parameters uniqueness rate = 34.9%
# NUMBER OF SIMULATIONS 1445070/15000000
#
# Iteration 145: Espilon = 69.9483, ESS = 553 Acc. rate = 1.45% Uniqueness rate particules = 35.4% Uniqueness rate components = 35.4% Global parameters uniqueness rate = 35.4%
# NUMBER OF SIMULATIONS 1453365/15000000
#
# Iteration 146: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 35.5% Uniqueness rate components = 35.5% Global parameters uniqueness rate = 35.5%
# NUMBER OF SIMULATIONS 1461660/15000000
#
# Iteration 147: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 35.9% Uniqueness rate components = 35.9% Global parameters uniqueness rate = 35.9%
# NUMBER OF SIMULATIONS 1469955/15000000
#
# Iteration 148: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 36.4% Uniqueness rate components = 36.4% Global parameters uniqueness rate = 36.4%
# NUMBER OF SIMULATIONS 1478250/15000000
#
# Iteration 149: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 36.4% Uniqueness rate components = 36.4% Global parameters uniqueness rate = 36.4%
# NUMBER OF SIMULATIONS 1486545/15000000
#
# Iteration 150: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 36.4% Uniqueness rate components = 36.4% Global parameters uniqueness rate = 36.4%
# NUMBER OF SIMULATIONS 1494840/15000000
#
# Iteration 151: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 36.8% Uniqueness rate components = 36.8% Global parameters uniqueness rate = 36.8%
# NUMBER OF SIMULATIONS 1503135/15000000
#
# Iteration 152: Espilon = 69.9483, ESS = 553 Acc. rate = 1.99% Uniqueness rate particules = 37.1% Uniqueness rate components = 37.1% Global parameters uniqueness rate = 37.1%
# NUMBER OF SIMULATIONS 1511430/15000000
#
# Iteration 153: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 37.3% Uniqueness rate components = 37.3% Global parameters uniqueness rate = 37.3%
# NUMBER OF SIMULATIONS 1519725/15000000
#
# Iteration 154: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 37.6% Uniqueness rate components = 37.6% Global parameters uniqueness rate = 37.6%
# NUMBER OF SIMULATIONS 1528020/15000000
#
# Iteration 155: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 37.6% Uniqueness rate components = 37.6% Global parameters uniqueness rate = 37.6%
# NUMBER OF SIMULATIONS 1536315/15000000
#
# Iteration 156: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 37.7% Uniqueness rate components = 37.7% Global parameters uniqueness rate = 37.7%
# NUMBER OF SIMULATIONS 1544610/15000000
#
# Iteration 157: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 37.9% Uniqueness rate components = 37.9% Global parameters uniqueness rate = 37.9%
# NUMBER OF SIMULATIONS 1552905/15000000
#
# Iteration 158: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 38.0% Uniqueness rate components = 38.0% Global parameters uniqueness rate = 38.0%
# NUMBER OF SIMULATIONS 1561200/15000000
#
# Iteration 159: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 38.0% Uniqueness rate components = 38.0% Global parameters uniqueness rate = 38.0%
# NUMBER OF SIMULATIONS 1569495/15000000
#
# Iteration 160: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 38.1% Uniqueness rate components = 38.1% Global parameters uniqueness rate = 38.1%
# NUMBER OF SIMULATIONS 1577790/15000000
#
# Iteration 161: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 38.2% Uniqueness rate components = 38.2% Global parameters uniqueness rate = 38.2%
# NUMBER OF SIMULATIONS 1586085/15000000
#
# Iteration 162: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 38.4% Uniqueness rate components = 38.4% Global parameters uniqueness rate = 38.4%
# NUMBER OF SIMULATIONS 1594380/15000000
#
# Iteration 163: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 38.6% Uniqueness rate components = 38.6% Global parameters uniqueness rate = 38.6%
# NUMBER OF SIMULATIONS 1602675/15000000
#
# Iteration 164: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 38.8% Uniqueness rate components = 38.8% Global parameters uniqueness rate = 38.8%
# NUMBER OF SIMULATIONS 1610970/15000000
#
# Iteration 165: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 38.9% Uniqueness rate components = 38.9% Global parameters uniqueness rate = 38.9%
# NUMBER OF SIMULATIONS 1619265/15000000
#
# Iteration 166: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 38.9% Uniqueness rate components = 38.9% Global parameters uniqueness rate = 38.9%
# NUMBER OF SIMULATIONS 1627560/15000000
#
# Iteration 167: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 39.1% Uniqueness rate components = 39.1% Global parameters uniqueness rate = 39.1%
# NUMBER OF SIMULATIONS 1635855/15000000
#
# Iteration 168: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 39.2% Uniqueness rate components = 39.2% Global parameters uniqueness rate = 39.2%
# NUMBER OF SIMULATIONS 1644150/15000000
#
# Iteration 169: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 39.2% Uniqueness rate components = 39.2% Global parameters uniqueness rate = 39.2%
# NUMBER OF SIMULATIONS 1652445/15000000
#
# Iteration 170: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 1660740/15000000
#
# Iteration 171: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 1669035/15000000
#
# Iteration 172: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 39.5% Uniqueness rate components = 39.5% Global parameters uniqueness rate = 39.5%
# NUMBER OF SIMULATIONS 1677330/15000000
#
# Iteration 173: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 39.5% Uniqueness rate components = 39.5% Global parameters uniqueness rate = 39.5%
# NUMBER OF SIMULATIONS 1685625/15000000
#
# Iteration 174: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 39.5% Uniqueness rate components = 39.5% Global parameters uniqueness rate = 39.5%
# NUMBER OF SIMULATIONS 1693920/15000000
#
# Iteration 175: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 39.6% Uniqueness rate components = 39.6% Global parameters uniqueness rate = 39.6%
# NUMBER OF SIMULATIONS 1702215/15000000
#
# Iteration 176: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 39.7% Uniqueness rate components = 39.7% Global parameters uniqueness rate = 39.7%
# NUMBER OF SIMULATIONS 1710510/15000000
#
# Iteration 177: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 39.9% Uniqueness rate components = 39.9% Global parameters uniqueness rate = 39.9%
# NUMBER OF SIMULATIONS 1718805/15000000
#
# Iteration 178: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 39.9% Uniqueness rate components = 39.9% Global parameters uniqueness rate = 39.9%
# NUMBER OF SIMULATIONS 1727100/15000000
#
# Iteration 179: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 40.1% Uniqueness rate components = 40.1% Global parameters uniqueness rate = 40.1%
# NUMBER OF SIMULATIONS 1735395/15000000
#
# Iteration 180: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 40.1% Uniqueness rate components = 40.1% Global parameters uniqueness rate = 40.1%
# NUMBER OF SIMULATIONS 1743690/15000000
#
# Iteration 181: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 40.2% Uniqueness rate components = 40.2% Global parameters uniqueness rate = 40.2%
# NUMBER OF SIMULATIONS 1751985/15000000
#
# Iteration 182: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 40.4% Uniqueness rate components = 40.4% Global parameters uniqueness rate = 40.4%
# NUMBER OF SIMULATIONS 1760280/15000000
#
# Iteration 183: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 40.4% Uniqueness rate components = 40.4% Global parameters uniqueness rate = 40.4%
# NUMBER OF SIMULATIONS 1768575/15000000
#
# Iteration 184: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 40.4% Uniqueness rate components = 40.4% Global parameters uniqueness rate = 40.4%
# NUMBER OF SIMULATIONS 1776870/15000000
#
# Iteration 185: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 40.5% Uniqueness rate components = 40.5% Global parameters uniqueness rate = 40.5%
# NUMBER OF SIMULATIONS 1785165/15000000
#
# Iteration 186: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 40.6% Uniqueness rate components = 40.6% Global parameters uniqueness rate = 40.6%
# NUMBER OF SIMULATIONS 1793460/15000000
#
# Iteration 187: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 40.8% Uniqueness rate components = 40.8% Global parameters uniqueness rate = 40.8%
# NUMBER OF SIMULATIONS 1801755/15000000
#
# Iteration 188: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 41.0% Uniqueness rate components = 41.0% Global parameters uniqueness rate = 41.0%
# NUMBER OF SIMULATIONS 1810050/15000000
#
# Iteration 189: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 41.2% Uniqueness rate components = 41.2% Global parameters uniqueness rate = 41.2%
# NUMBER OF SIMULATIONS 1818345/15000000
#
# Iteration 190: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 41.2% Uniqueness rate components = 41.2% Global parameters uniqueness rate = 41.2%
# NUMBER OF SIMULATIONS 1826640/15000000
#
# Iteration 191: Espilon = 69.9483, ESS = 553 Acc. rate = 0.00% Uniqueness rate particules = 41.2% Uniqueness rate components = 41.2% Global parameters uniqueness rate = 41.2%
# NUMBER OF SIMULATIONS 1834935/15000000
#
# Iteration 192: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 41.4% Uniqueness rate components = 41.4% Global parameters uniqueness rate = 41.4%
# NUMBER OF SIMULATIONS 1843230/15000000
#
# Iteration 193: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 41.4% Uniqueness rate components = 41.4% Global parameters uniqueness rate = 41.4%
# NUMBER OF SIMULATIONS 1851525/15000000
#
# Iteration 194: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 41.6% Uniqueness rate components = 41.6% Global parameters uniqueness rate = 41.6%
# NUMBER OF SIMULATIONS 1859820/15000000
#
# Iteration 195: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 41.8% Uniqueness rate components = 41.8% Global parameters uniqueness rate = 41.8%
# NUMBER OF SIMULATIONS 1868115/15000000
#
# Iteration 196: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 41.8% Uniqueness rate components = 41.8% Global parameters uniqueness rate = 41.8%
# NUMBER OF SIMULATIONS 1876410/15000000
#
# Iteration 197: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 41.9% Uniqueness rate components = 41.9% Global parameters uniqueness rate = 41.9%
# NUMBER OF SIMULATIONS 1884705/15000000
#
# Iteration 198: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 41.9% Uniqueness rate components = 41.9% Global parameters uniqueness rate = 41.9%
# NUMBER OF SIMULATIONS 1893000/15000000
#
# Iteration 199: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 42.2% Uniqueness rate components = 42.2% Global parameters uniqueness rate = 42.2%
# NUMBER OF SIMULATIONS 1901295/15000000
#
# Iteration 200: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 42.2% Uniqueness rate components = 42.2% Global parameters uniqueness rate = 42.2%
# NUMBER OF SIMULATIONS 1909590/15000000
#
# Iteration 201: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 42.2% Uniqueness rate components = 42.2% Global parameters uniqueness rate = 42.2%
# NUMBER OF SIMULATIONS 1917885/15000000
#
# Iteration 202: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 42.4% Uniqueness rate components = 42.4% Global parameters uniqueness rate = 42.4%
# NUMBER OF SIMULATIONS 1926180/15000000
#
# Iteration 203: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 42.6% Uniqueness rate components = 42.6% Global parameters uniqueness rate = 42.6%
# NUMBER OF SIMULATIONS 1934475/15000000
#
# Iteration 204: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 42.7% Uniqueness rate components = 42.7% Global parameters uniqueness rate = 42.7%
# NUMBER OF SIMULATIONS 1942770/15000000
#
# Iteration 205: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 42.8% Uniqueness rate components = 42.8% Global parameters uniqueness rate = 42.8%
# NUMBER OF SIMULATIONS 1951065/15000000
#
# Iteration 206: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 42.8% Uniqueness rate components = 42.8% Global parameters uniqueness rate = 42.8%
# NUMBER OF SIMULATIONS 1959360/15000000
#
# Iteration 207: Espilon = 69.9483, ESS = 553 Acc. rate = 0.36% Uniqueness rate particules = 42.9% Uniqueness rate components = 42.9% Global parameters uniqueness rate = 42.9%
# NUMBER OF SIMULATIONS 1967655/15000000
#
# Iteration 208: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 42.9% Uniqueness rate components = 42.9% Global parameters uniqueness rate = 42.9%
# NUMBER OF SIMULATIONS 1975950/15000000
#
# Iteration 209: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 43.3% Uniqueness rate components = 43.3% Global parameters uniqueness rate = 43.3%
# NUMBER OF SIMULATIONS 1984245/15000000
#
# Iteration 210: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 43.6% Uniqueness rate components = 43.6% Global parameters uniqueness rate = 43.6%
# NUMBER OF SIMULATIONS 1992540/15000000
#
# Iteration 211: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 43.7% Uniqueness rate components = 43.7% Global parameters uniqueness rate = 43.7%
# NUMBER OF SIMULATIONS 2000835/15000000
#
# Iteration 212: Espilon = 69.9483, ESS = 553 Acc. rate = 1.27% Uniqueness rate particules = 43.7% Uniqueness rate components = 43.7% Global parameters uniqueness rate = 43.7%
# NUMBER OF SIMULATIONS 2009130/15000000
#
# Iteration 213: Espilon = 69.9483, ESS = 553 Acc. rate = 1.08% Uniqueness rate particules = 43.8% Uniqueness rate components = 43.8% Global parameters uniqueness rate = 43.8%
# NUMBER OF SIMULATIONS 2017425/15000000
#
# Iteration 214: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 44.1% Uniqueness rate components = 44.1% Global parameters uniqueness rate = 44.1%
# NUMBER OF SIMULATIONS 2025720/15000000
#
# Iteration 215: Espilon = 69.9483, ESS = 553 Acc. rate = 0.90% Uniqueness rate particules = 44.3% Uniqueness rate components = 44.3% Global parameters uniqueness rate = 44.3%
# NUMBER OF SIMULATIONS 2034015/15000000
#
# Iteration 216: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 44.4% Uniqueness rate components = 44.4% Global parameters uniqueness rate = 44.4%
# NUMBER OF SIMULATIONS 2042310/15000000
#
# Iteration 217: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 44.5% Uniqueness rate components = 44.5% Global parameters uniqueness rate = 44.5%
# NUMBER OF SIMULATIONS 2050605/15000000
#
# Iteration 218: Espilon = 69.9483, ESS = 553 Acc. rate = 0.18% Uniqueness rate particules = 44.5% Uniqueness rate components = 44.5% Global parameters uniqueness rate = 44.5%
# NUMBER OF SIMULATIONS 2058900/15000000
#
# Iteration 219: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 44.5% Uniqueness rate components = 44.5% Global parameters uniqueness rate = 44.5%
# NUMBER OF SIMULATIONS 2067195/15000000
#
# Iteration 220: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 44.6% Uniqueness rate components = 44.6% Global parameters uniqueness rate = 44.6%
# NUMBER OF SIMULATIONS 2075490/15000000
#
# Iteration 221: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 44.7% Uniqueness rate components = 44.7% Global parameters uniqueness rate = 44.7%
# NUMBER OF SIMULATIONS 2083785/15000000
#
# Iteration 222: Espilon = 69.9483, ESS = 553 Acc. rate = 0.54% Uniqueness rate particules = 44.7% Uniqueness rate components = 44.7% Global parameters uniqueness rate = 44.7%
# NUMBER OF SIMULATIONS 2092080/15000000
#
# Iteration 223: Espilon = 69.9483, ESS = 553 Acc. rate = 0.72% Uniqueness rate particules = 44.9% Uniqueness rate components = 44.9% Global parameters uniqueness rate = 44.9%
# NUMBER OF SIMULATIONS 2100375/15000000
#
# ...
# NUMBER OF SIMULATIONS 14329620/15000000
#
# Iteration 1345: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 73.7% Uniqueness rate components = 73.7% Global parameters uniqueness rate = 73.7%
# NUMBER OF SIMULATIONS 14339055/15000000
#
# Iteration 1346: Espilon = 25.6933, ESS = 629 Acc. rate = 1.27% Uniqueness rate particules = 73.8% Uniqueness rate components = 73.8% Global parameters uniqueness rate = 73.8%
# NUMBER OF SIMULATIONS 14348490/15000000
#
# Iteration 1347: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 73.8% Uniqueness rate components = 73.8% Global parameters uniqueness rate = 73.8%
# NUMBER OF SIMULATIONS 14357925/15000000
#
# Iteration 1348: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14367360/15000000
#
# Iteration 1349: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14376795/15000000
#
# Iteration 1350: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14386230/15000000
#
# Iteration 1351: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14395665/15000000
#
# Iteration 1352: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14405100/15000000
#
# Iteration 1353: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14414535/15000000
#
# Iteration 1354: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14423970/15000000
#
# Iteration 1355: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14433405/15000000
#
# Iteration 1356: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 73.9% Uniqueness rate components = 73.9% Global parameters uniqueness rate = 73.9%
# NUMBER OF SIMULATIONS 14442840/15000000
#
# Iteration 1357: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14452275/15000000
#
# Iteration 1358: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14461710/15000000
#
# Iteration 1359: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14471145/15000000
#
# Iteration 1360: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14480580/15000000
#
# Iteration 1361: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14490015/15000000
#
# Iteration 1362: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14499450/15000000
#
# Iteration 1363: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14508885/15000000
#
# Iteration 1364: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14518320/15000000
#
# Iteration 1365: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14527755/15000000
#
# Iteration 1366: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14537190/15000000
#
# Iteration 1367: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14546625/15000000
#
# Iteration 1368: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14556060/15000000
#
# Iteration 1369: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14565495/15000000
#
# Iteration 1370: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.1% Uniqueness rate components = 74.1% Global parameters uniqueness rate = 74.1%
# NUMBER OF SIMULATIONS 14574930/15000000
#
# Iteration 1371: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.2% Uniqueness rate components = 74.2% Global parameters uniqueness rate = 74.2%
# NUMBER OF SIMULATIONS 14584365/15000000
#
# Iteration 1372: Espilon = 25.6933, ESS = 629 Acc. rate = 1.11% Uniqueness rate particules = 74.2% Uniqueness rate components = 74.2% Global parameters uniqueness rate = 74.2%
# NUMBER OF SIMULATIONS 14593800/15000000
#
# Iteration 1373: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.2% Uniqueness rate components = 74.2% Global parameters uniqueness rate = 74.2%
# NUMBER OF SIMULATIONS 14603235/15000000
#
# Iteration 1374: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.2% Uniqueness rate components = 74.2% Global parameters uniqueness rate = 74.2%
# NUMBER OF SIMULATIONS 14612670/15000000
#
# Iteration 1375: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.2% Uniqueness rate components = 74.2% Global parameters uniqueness rate = 74.2%
# NUMBER OF SIMULATIONS 14622105/15000000
#
# Iteration 1376: Espilon = 25.6933, ESS = 629 Acc. rate = 0.95% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14631540/15000000
#
# Iteration 1377: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14640975/15000000
#
# Iteration 1378: Espilon = 25.6933, ESS = 629 Acc. rate = 0.95% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14650410/15000000
#
# Iteration 1379: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14659845/15000000
#
# Iteration 1380: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14669280/15000000
#
# Iteration 1381: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14678715/15000000
#
# Iteration 1382: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14688150/15000000
#
# Iteration 1383: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14697585/15000000
#
# Iteration 1384: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14707020/15000000
#
# Iteration 1385: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 14716455/15000000
#
# Iteration 1386: Espilon = 25.6933, ESS = 629 Acc. rate = 1.43% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14725890/15000000
#
# Iteration 1387: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14735325/15000000
#
# Iteration 1388: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14744760/15000000
#
# Iteration 1389: Espilon = 25.6933, ESS = 629 Acc. rate = 0.95% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14754195/15000000
#
# Iteration 1390: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14763630/15000000
#
# Iteration 1391: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14773065/15000000
#
# Iteration 1392: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14782500/15000000
#
# Iteration 1393: Espilon = 25.6933, ESS = 629 Acc. rate = 1.11% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14791935/15000000
#
# Iteration 1394: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14801370/15000000
#
# Iteration 1395: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14810805/15000000
#
# Iteration 1396: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14820240/15000000
#
# Iteration 1397: Espilon = 25.6933, ESS = 629 Acc. rate = 1.11% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14829675/15000000
#
# Iteration 1398: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14839110/15000000
#
# Iteration 1399: Espilon = 25.6933, ESS = 629 Acc. rate = 0.95% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14848545/15000000
#
# Iteration 1400: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14857980/15000000
#
# Iteration 1401: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14867415/15000000
#
# Iteration 1402: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14876850/15000000
#
# Iteration 1403: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14886285/15000000
#
# Iteration 1404: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14895720/15000000
#
# Iteration 1405: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14905155/15000000
#
# Iteration 1406: Espilon = 25.6933, ESS = 629 Acc. rate = 0.16% Uniqueness rate particules = 74.4% Uniqueness rate components = 74.4% Global parameters uniqueness rate = 74.4%
# NUMBER OF SIMULATIONS 14914590/15000000
#
# Iteration 1407: Espilon = 25.6933, ESS = 629 Acc. rate = 1.11% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14924025/15000000
#
# Iteration 1408: Espilon = 25.6933, ESS = 629 Acc. rate = 0.00% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14933460/15000000
#
# Iteration 1409: Espilon = 25.6933, ESS = 629 Acc. rate = 1.11% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14942895/15000000
#
# Iteration 1410: Espilon = 25.6933, ESS = 629 Acc. rate = 0.64% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14952330/15000000
#
# Iteration 1411: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14961765/15000000
#
# Iteration 1412: Espilon = 25.6933, ESS = 629 Acc. rate = 1.11% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14971200/15000000
#
# Iteration 1413: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14980635/15000000
#
# Iteration 1414: Espilon = 25.6933, ESS = 629 Acc. rate = 0.32% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14990070/15000000
#
# Iteration 1415: Espilon = 25.6933, ESS = 629 Acc. rate = 0.79% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 14999505/15000000
#
# Iteration 1416: Espilon = 25.6933, ESS = 629 Acc. rate = 0.48% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 15008940/15000000
#
# Resampling... 576 unique particles left
# Iteration 1417: Espilon = 25.6933, ESS = 1000 Acc. rate = 0.80% Uniqueness rate particules = 58.3% Uniqueness rate components = 58.3% Global parameters uniqueness rate = 58.3%
# NUMBER OF SIMULATIONS 15023940/15000000

# %% [markdown]
# ## permABC

# %%
key, subkey = random.split(key)
kernel = KernelTruncatedRW
model.reset_weights_distance()
N_smc = 1000
out_perm_smc = perm_abc_smc(key = subkey, model = model, n_particles= N_smc, epsilon_target= 0, y_obs = y_obs, kernel = kernel, verbose = 1, Final_iteration= 0, update_weights_distance= False, N_sim_max= N_points*K, stopping_accept_rate= 0.)

mus_perm_smc = out_perm_smc["Thetas"][-1].loc.squeeze()
betas_perm_smc = out_perm_smc["Thetas"][-1].glob.squeeze()
n_sim_perm_smc = np.sum(out_perm_smc["N_sim"])
# Out:
# Minimum distance: 0.00057838025 Maximum distance: 148.275 Number of NaNs: 0
# Iteration 0: Epsilon = inf, ESS = 1000 Acc. rate = 100% Numb. unique particles = 1000
# Minimum distance: 0.00038595108 Maximum distance: 231.09857 Number of NaNs: 0
# Iteration 2: Espilon = 36.0558, ESS = 950 Acc. rate = 18.84% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 29250/15000000
#
# Minimum distance: 0.00040824874 Maximum distance: 222.08594 Number of NaNs: 0
# Iteration 3: Espilon = 29.3164, ESS = 902 Acc. rate = 20.18% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 42780/15000000
#
# Minimum distance: 0.0005910766 Maximum distance: 295.15866 Number of NaNs: 0
# Iteration 4: Espilon = 26.4557, ESS = 856 Acc. rate = 21.26% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 55620/15000000
#
# Minimum distance: 0.00046135316 Maximum distance: 220.80235 Number of NaNs: 0
# Iteration 5: Espilon = 23.6867, ESS = 813 Acc. rate = 21.77% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 67815/15000000
#
# Minimum distance: 0.00043056914 Maximum distance: 238.0704 Number of NaNs: 0
# Iteration 6: Espilon = 21.9901, ESS = 772 Acc. rate = 19.04% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 79395/15000000
#
# Minimum distance: 0.00051704433 Maximum distance: 214.65245 Number of NaNs: 0
# Iteration 7: Espilon = 20.2788, ESS = 733 Acc. rate = 20.33% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 90390/15000000
#
# Minimum distance: 0.00070639123 Maximum distance: 231.75034 Number of NaNs: 0
# Iteration 8: Espilon = 18.8626, ESS = 696 Acc. rate = 22.41% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 100830/15000000
#
# Minimum distance: 0.00023117 Maximum distance: 195.91022 Number of NaNs: 0
# Iteration 9: Espilon = 17.6018, ESS = 661 Acc. rate = 18.76% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 110745/15000000
#
# Minimum distance: 0.0008995909 Maximum distance: 193.40878 Number of NaNs: 0
# Iteration 10: Espilon = 16.7217, ESS = 628 Acc. rate = 19.27% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 120165/15000000
#
# Minimum distance: 0.00056389265 Maximum distance: 196.89084 Number of NaNs: 0
# Iteration 11: Espilon = 15.8954, ESS = 596 Acc. rate = 17.11% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 129105/15000000
#
# Minimum distance: 0.00044141145 Maximum distance: 226.41524 Number of NaNs: 0
# Iteration 12: Espilon = 15.0755, ESS = 566 Acc. rate = 13.96% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 137595/15000000
#
# Minimum distance: 0.0005598014 Maximum distance: 230.83139 Number of NaNs: 0
# Iteration 13: Espilon = 14.1608, ESS = 537 Acc. rate = 16.95% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 145650/15000000
#
# Minimum distance: 0.00043150168 Maximum distance: 206.29794 Number of NaNs: 0
# Iteration 14: Espilon = 13.6618, ESS = 510 Acc. rate = 16.86% Uniqueness rate particules = 100.0% Uniqueness rate components = 100.0% Global parameters uniqueness rate = 100.0%
# NUMBER OF SIMULATIONS 153300/15000000
#
# Resampling... 484 unique particles left
# Minimum distance: 0.00029039307 Maximum distance: 209.20949 Number of NaNs: 0
# Iteration 15: Espilon = 12.9844, ESS = 1000 Acc. rate = 16.60% Uniqueness rate particules = 63.5% Uniqueness rate components = 63.5% Global parameters uniqueness rate = 63.4%
# NUMBER OF SIMULATIONS 168300/15000000
#
# Minimum distance: 0.000607612 Maximum distance: 309.2024 Number of NaNs: 0
# Iteration 16: Espilon = 12.5475, ESS = 950 Acc. rate = 15.47% Uniqueness rate particules = 73.1% Uniqueness rate components = 73.1% Global parameters uniqueness rate = 73.0%
# NUMBER OF SIMULATIONS 182550/15000000
#
# Minimum distance: 9.1972775e-05 Maximum distance: 235.90956 Number of NaNs: 0
# Iteration 17: Espilon = 12.0759, ESS = 903 Acc. rate = 12.40% Uniqueness rate particules = 77.9% Uniqueness rate components = 77.9% Global parameters uniqueness rate = 77.9%
# NUMBER OF SIMULATIONS 196095/15000000
#
# Minimum distance: 0.0004913053 Maximum distance: 199.87651 Number of NaNs: 0
# Iteration 18: Espilon = 11.6804, ESS = 857 Acc. rate = 16.22% Uniqueness rate particules = 82.3% Uniqueness rate components = 82.3% Global parameters uniqueness rate = 82.3%
# NUMBER OF SIMULATIONS 208950/15000000
#
# Minimum distance: 0.00059861457 Maximum distance: 200.66925 Number of NaNs: 0
# Iteration 19: Espilon = 11.3679, ESS = 815 Acc. rate = 15.58% Uniqueness rate particules = 85.3% Uniqueness rate components = 85.3% Global parameters uniqueness rate = 85.3%
# NUMBER OF SIMULATIONS 221175/15000000
#
# Minimum distance: 0.00060155825 Maximum distance: 175.58792 Number of NaNs: 0
# Iteration 20: Espilon = 11.0852, ESS = 774 Acc. rate = 14.73% Uniqueness rate particules = 87.5% Uniqueness rate components = 87.5% Global parameters uniqueness rate = 87.5%
# NUMBER OF SIMULATIONS 232785/15000000
#
# Minimum distance: 0.00071220694 Maximum distance: 189.39798 Number of NaNs: 0
# Iteration 21: Espilon = 10.7512, ESS = 735 Acc. rate = 14.97% Uniqueness rate particules = 89.0% Uniqueness rate components = 89.0% Global parameters uniqueness rate = 89.0%
# NUMBER OF SIMULATIONS 243810/15000000
#
# Minimum distance: 0.0005552998 Maximum distance: 187.87979 Number of NaNs: 0
# Iteration 22: Espilon = 10.4456, ESS = 698 Acc. rate = 15.90% Uniqueness rate particules = 89.9% Uniqueness rate components = 89.9% Global parameters uniqueness rate = 89.9%
# NUMBER OF SIMULATIONS 254280/15000000
#
# Minimum distance: 0.000621073 Maximum distance: 203.07965 Number of NaNs: 0
# Iteration 23: Espilon = 10.1207, ESS = 664 Acc. rate = 13.55% Uniqueness rate particules = 90.4% Uniqueness rate components = 90.4% Global parameters uniqueness rate = 90.4%
# NUMBER OF SIMULATIONS 264240/15000000
#
# Minimum distance: 0.00010594928 Maximum distance: 203.88055 Number of NaNs: 0
# Iteration 24: Espilon = 9.8621, ESS = 630 Acc. rate = 12.06% Uniqueness rate particules = 90.8% Uniqueness rate components = 90.8% Global parameters uniqueness rate = 90.8%
# NUMBER OF SIMULATIONS 273690/15000000
#
# Minimum distance: 0.00042915132 Maximum distance: 199.96727 Number of NaNs: 0
# Iteration 25: Espilon = 9.6075, ESS = 598 Acc. rate = 12.54% Uniqueness rate particules = 91.0% Uniqueness rate components = 91.0% Global parameters uniqueness rate = 91.0%
# NUMBER OF SIMULATIONS 282660/15000000
#
# Minimum distance: 0.00036316697 Maximum distance: 184.87837 Number of NaNs: 0
# Iteration 26: Espilon = 9.3490, ESS = 568 Acc. rate = 15.14% Uniqueness rate particules = 91.2% Uniqueness rate components = 91.2% Global parameters uniqueness rate = 91.2%
# NUMBER OF SIMULATIONS 291180/15000000
#
# Minimum distance: 0.0004934364 Maximum distance: 177.03897 Number of NaNs: 0
# Iteration 27: Espilon = 9.1575, ESS = 539 Acc. rate = 13.36% Uniqueness rate particules = 91.5% Uniqueness rate components = 91.5% Global parameters uniqueness rate = 91.5%
# NUMBER OF SIMULATIONS 299265/15000000
#
# Minimum distance: 0.00037072675 Maximum distance: 160.2876 Number of NaNs: 0
# Iteration 28: Espilon = 8.9754, ESS = 512 Acc. rate = 13.48% Uniqueness rate particules = 91.5% Uniqueness rate components = 91.5% Global parameters uniqueness rate = 91.5%
# NUMBER OF SIMULATIONS 306945/15000000
#
# Resampling... 480 unique particles left
# Minimum distance: 0.0006058181 Maximum distance: 188.27136 Number of NaNs: 0
# Iteration 29: Espilon = 8.8297, ESS = 1000 Acc. rate = 15.10% Uniqueness rate particules = 62.1% Uniqueness rate components = 62.1% Global parameters uniqueness rate = 62.1%
# NUMBER OF SIMULATIONS 321945/15000000
#
# Minimum distance: 0.00035786422 Maximum distance: 194.40126 Number of NaNs: 0
# Iteration 30: Espilon = 8.6555, ESS = 950 Acc. rate = 13.89% Uniqueness rate particules = 70.8% Uniqueness rate components = 70.8% Global parameters uniqueness rate = 70.8%
# NUMBER OF SIMULATIONS 336195/15000000
#
# Minimum distance: 0.00026642316 Maximum distance: 165.12485 Number of NaNs: 0
# Iteration 31: Espilon = 8.4741, ESS = 902 Acc. rate = 13.41% Uniqueness rate particules = 76.2% Uniqueness rate components = 76.2% Global parameters uniqueness rate = 76.2%
# NUMBER OF SIMULATIONS 349725/15000000
#
# Minimum distance: 0.00054134737 Maximum distance: 168.65964 Number of NaNs: 0
# Iteration 32: Espilon = 8.3345, ESS = 857 Acc. rate = 15.40% Uniqueness rate particules = 80.4% Uniqueness rate components = 80.4% Global parameters uniqueness rate = 80.4%
# NUMBER OF SIMULATIONS 362580/15000000
#
# Minimum distance: 0.00040695345 Maximum distance: 148.19397 Number of NaNs: 0
# Iteration 33: Espilon = 8.2105, ESS = 814 Acc. rate = 12.65% Uniqueness rate particules = 83.0% Uniqueness rate components = 83.0% Global parameters uniqueness rate = 83.0%
# NUMBER OF SIMULATIONS 374790/15000000
#
# Minimum distance: 0.00044351962 Maximum distance: 187.64536 Number of NaNs: 0
# Iteration 34: Espilon = 8.0351, ESS = 773 Acc. rate = 12.94% Uniqueness rate particules = 84.5% Uniqueness rate components = 84.5% Global parameters uniqueness rate = 84.5%
# NUMBER OF SIMULATIONS 386385/15000000
#
# Minimum distance: 0.000688279 Maximum distance: 171.68063 Number of NaNs: 0
# Iteration 35: Espilon = 7.9501, ESS = 734 Acc. rate = 13.76% Uniqueness rate particules = 86.2% Uniqueness rate components = 86.2% Global parameters uniqueness rate = 86.2%
# NUMBER OF SIMULATIONS 397395/15000000
#
# Minimum distance: 0.00059593876 Maximum distance: 158.4913 Number of NaNs: 0
# Iteration 36: Espilon = 7.7760, ESS = 697 Acc. rate = 15.21% Uniqueness rate particules = 87.3% Uniqueness rate components = 87.3% Global parameters uniqueness rate = 87.3%
# NUMBER OF SIMULATIONS 407850/15000000
#
# Minimum distance: 0.00037101944 Maximum distance: 219.17201 Number of NaNs: 0
# Iteration 37: Espilon = 7.6432, ESS = 662 Acc. rate = 16.31% Uniqueness rate particules = 88.5% Uniqueness rate components = 88.5% Global parameters uniqueness rate = 88.5%
# NUMBER OF SIMULATIONS 417780/15000000
#
# Minimum distance: 0.0005627295 Maximum distance: 146.1024 Number of NaNs: 0
# Iteration 38: Espilon = 7.4686, ESS = 628 Acc. rate = 14.17% Uniqueness rate particules = 89.1% Uniqueness rate components = 89.1% Global parameters uniqueness rate = 89.1%
# NUMBER OF SIMULATIONS 427200/15000000
#
# Minimum distance: 0.00054758834 Maximum distance: 203.43192 Number of NaNs: 0
# Iteration 39: Espilon = 7.3356, ESS = 596 Acc. rate = 11.74% Uniqueness rate particules = 89.3% Uniqueness rate components = 89.3% Global parameters uniqueness rate = 89.3%
# NUMBER OF SIMULATIONS 436140/15000000
#
# Minimum distance: 0.00036985203 Maximum distance: 157.75665 Number of NaNs: 0
# Iteration 40: Espilon = 7.1399, ESS = 566 Acc. rate = 16.43% Uniqueness rate particules = 89.5% Uniqueness rate components = 89.5% Global parameters uniqueness rate = 89.5%
# NUMBER OF SIMULATIONS 444630/15000000
#
# Minimum distance: 0.00050960336 Maximum distance: 168.72972 Number of NaNs: 0
# Iteration 41: Espilon = 6.9904, ESS = 537 Acc. rate = 15.83% Uniqueness rate particules = 89.6% Uniqueness rate components = 89.6% Global parameters uniqueness rate = 89.6%
# NUMBER OF SIMULATIONS 452685/15000000
#
# Minimum distance: 0.00017160685 Maximum distance: 136.98978 Number of NaNs: 0
# Iteration 42: Espilon = 6.8764, ESS = 510 Acc. rate = 13.92% Uniqueness rate particules = 89.7% Uniqueness rate components = 89.7% Global parameters uniqueness rate = 89.7%
# NUMBER OF SIMULATIONS 460335/15000000
#
# Resampling... 482 unique particles left
# Minimum distance: 0.00051195774 Maximum distance: 174.05524 Number of NaNs: 0
# Iteration 43: Espilon = 6.7861, ESS = 1000 Acc. rate = 14.90% Uniqueness rate particules = 61.3% Uniqueness rate components = 61.3% Global parameters uniqueness rate = 61.3%
# NUMBER OF SIMULATIONS 475335/15000000
#
# Minimum distance: 0.00036033124 Maximum distance: 156.27011 Number of NaNs: 0
# Iteration 44: Espilon = 6.6597, ESS = 950 Acc. rate = 11.16% Uniqueness rate particules = 68.4% Uniqueness rate components = 68.4% Global parameters uniqueness rate = 68.4%
# NUMBER OF SIMULATIONS 489585/15000000
#
# Minimum distance: 0.00042569137 Maximum distance: 152.11403 Number of NaNs: 0
# Iteration 45: Espilon = 6.5913, ESS = 902 Acc. rate = 14.75% Uniqueness rate particules = 75.5% Uniqueness rate components = 75.5% Global parameters uniqueness rate = 75.5%
# NUMBER OF SIMULATIONS 503115/15000000
#
# Minimum distance: 0.0004835273 Maximum distance: 151.71529 Number of NaNs: 0
# Iteration 46: Espilon = 6.4608, ESS = 856 Acc. rate = 12.73% Uniqueness rate particules = 79.6% Uniqueness rate components = 79.6% Global parameters uniqueness rate = 79.6%
# NUMBER OF SIMULATIONS 515955/15000000
#
# Minimum distance: 0.00024947224 Maximum distance: 161.91055 Number of NaNs: 0
# Iteration 47: Espilon = 6.3543, ESS = 813 Acc. rate = 14.15% Uniqueness rate particules = 83.2% Uniqueness rate components = 83.2% Global parameters uniqueness rate = 83.2%
# NUMBER OF SIMULATIONS 528150/15000000
#
# Minimum distance: 0.00031909937 Maximum distance: 141.67061 Number of NaNs: 0
# Iteration 48: Espilon = 6.2394, ESS = 773 Acc. rate = 13.07% Uniqueness rate particules = 85.2% Uniqueness rate components = 85.2% Global parameters uniqueness rate = 85.2%
# NUMBER OF SIMULATIONS 539745/15000000
#
# Minimum distance: 0.0005316811 Maximum distance: 174.99956 Number of NaNs: 0
# Iteration 49: Espilon = 6.1034, ESS = 734 Acc. rate = 12.40% Uniqueness rate particules = 86.3% Uniqueness rate components = 86.3% Global parameters uniqueness rate = 86.3%
# NUMBER OF SIMULATIONS 550755/15000000
#
# Minimum distance: 0.0005367222 Maximum distance: 152.59021 Number of NaNs: 0
# Iteration 50: Espilon = 6.0006, ESS = 697 Acc. rate = 13.20% Uniqueness rate particules = 87.0% Uniqueness rate components = 87.0% Global parameters uniqueness rate = 87.0%
# NUMBER OF SIMULATIONS 561210/15000000
#
# Minimum distance: 0.00059045816 Maximum distance: 187.13347 Number of NaNs: 0
# Iteration 51: Espilon = 5.8892, ESS = 662 Acc. rate = 11.63% Uniqueness rate particules = 87.9% Uniqueness rate components = 87.9% Global parameters uniqueness rate = 87.9%
# NUMBER OF SIMULATIONS 571140/15000000
#
# Minimum distance: 0.0003803274 Maximum distance: 151.77592 Number of NaNs: 0
# Iteration 52: Espilon = 5.8101, ESS = 628 Acc. rate = 11.15% Uniqueness rate particules = 87.9% Uniqueness rate components = 87.9% Global parameters uniqueness rate = 87.9%
# NUMBER OF SIMULATIONS 580560/15000000
#
# Minimum distance: 0.00033033802 Maximum distance: 165.0333 Number of NaNs: 0
# Iteration 53: Espilon = 5.7408, ESS = 596 Acc. rate = 12.58% Uniqueness rate particules = 88.6% Uniqueness rate components = 88.6% Global parameters uniqueness rate = 88.6%
# NUMBER OF SIMULATIONS 589500/15000000
#
# Minimum distance: 0.00025448616 Maximum distance: 163.825 Number of NaNs: 0
# Iteration 54: Espilon = 5.6305, ESS = 566 Acc. rate = 11.48% Uniqueness rate particules = 88.9% Uniqueness rate components = 88.9% Global parameters uniqueness rate = 88.9%
# NUMBER OF SIMULATIONS 597990/15000000
#
# Minimum distance: 0.00044021156 Maximum distance: 146.32387 Number of NaNs: 0
# Iteration 55: Espilon = 5.5385, ESS = 537 Acc. rate = 11.55% Uniqueness rate particules = 89.2% Uniqueness rate components = 89.2% Global parameters uniqueness rate = 89.2%
# NUMBER OF SIMULATIONS 606045/15000000
#
# Minimum distance: 0.00039558113 Maximum distance: 147.72084 Number of NaNs: 0
# Iteration 56: Espilon = 5.4509, ESS = 510 Acc. rate = 11.96% Uniqueness rate particules = 89.6% Uniqueness rate components = 89.6% Global parameters uniqueness rate = 89.6%
# NUMBER OF SIMULATIONS 613695/15000000
#
# Resampling... 477 unique particles left
# Minimum distance: 0.00047759828 Maximum distance: 175.31293 Number of NaNs: 0
# Iteration 57: Espilon = 5.3359, ESS = 1000 Acc. rate = 13.40% Uniqueness rate particules = 60.1% Uniqueness rate components = 60.1% Global parameters uniqueness rate = 60.1%
# NUMBER OF SIMULATIONS 628695/15000000
#
# Minimum distance: 0.00051055086 Maximum distance: 159.63402 Number of NaNs: 0
# Iteration 58: Espilon = 5.2587, ESS = 951 Acc. rate = 12.83% Uniqueness rate particules = 68.3% Uniqueness rate components = 68.3% Global parameters uniqueness rate = 68.3%
# NUMBER OF SIMULATIONS 642960/15000000
#
# Minimum distance: 0.0007018095 Maximum distance: 151.39531 Number of NaNs: 0
# Iteration 59: Espilon = 5.1394, ESS = 903 Acc. rate = 11.96% Uniqueness rate particules = 73.4% Uniqueness rate components = 73.4% Global parameters uniqueness rate = 73.4%
# NUMBER OF SIMULATIONS 656505/15000000
#
# Minimum distance: 0.00043535075 Maximum distance: 179.0453 Number of NaNs: 0
# Iteration 60: Espilon = 5.0696, ESS = 857 Acc. rate = 12.14% Uniqueness rate particules = 77.1% Uniqueness rate components = 77.1% Global parameters uniqueness rate = 77.1%
# NUMBER OF SIMULATIONS 669360/15000000
#
# Minimum distance: 0.00027872715 Maximum distance: 168.86775 Number of NaNs: 0
# Iteration 61: Espilon = 5.0091, ESS = 815 Acc. rate = 10.06% Uniqueness rate particules = 79.5% Uniqueness rate components = 79.5% Global parameters uniqueness rate = 79.5%
# NUMBER OF SIMULATIONS 681585/15000000
#
# Minimum distance: 0.0004768498 Maximum distance: 146.06155 Number of NaNs: 0
# Iteration 62: Espilon = 4.9486, ESS = 775 Acc. rate = 12.13% Uniqueness rate particules = 81.9% Uniqueness rate components = 81.9% Global parameters uniqueness rate = 81.9%
# NUMBER OF SIMULATIONS 693210/15000000
#
# Minimum distance: 0.000650533 Maximum distance: 148.08696 Number of NaNs: 0
# Iteration 63: Espilon = 4.8713, ESS = 736 Acc. rate = 9.38% Uniqueness rate particules = 82.8% Uniqueness rate components = 82.8% Global parameters uniqueness rate = 82.8%
# NUMBER OF SIMULATIONS 704250/15000000
#
# Minimum distance: 0.00038064522 Maximum distance: 150.37529 Number of NaNs: 0
# Iteration 64: Espilon = 4.7991, ESS = 699 Acc. rate = 13.30% Uniqueness rate particules = 84.4% Uniqueness rate components = 84.4% Global parameters uniqueness rate = 84.4%
# NUMBER OF SIMULATIONS 714735/15000000
#
# Minimum distance: 0.0004972501 Maximum distance: 138.14796 Number of NaNs: 0
# Iteration 65: Espilon = 4.7445, ESS = 664 Acc. rate = 12.20% Uniqueness rate particules = 85.6% Uniqueness rate components = 85.6% Global parameters uniqueness rate = 85.6%
# NUMBER OF SIMULATIONS 724695/15000000
#
# Minimum distance: 0.0009026484 Maximum distance: 138.51201 Number of NaNs: 0
# Iteration 66: Espilon = 4.6786, ESS = 630 Acc. rate = 12.06% Uniqueness rate particules = 86.5% Uniqueness rate components = 86.5% Global parameters uniqueness rate = 86.5%
# NUMBER OF SIMULATIONS 734145/15000000
#
# Minimum distance: 0.00033682754 Maximum distance: 168.65578 Number of NaNs: 0
# Iteration 67: Espilon = 4.6178, ESS = 598 Acc. rate = 8.86% Uniqueness rate particules = 87.0% Uniqueness rate components = 87.0% Global parameters uniqueness rate = 87.0%
# NUMBER OF SIMULATIONS 743115/15000000
#
# Minimum distance: 0.0007181516 Maximum distance: 140.95912 Number of NaNs: 0
# Iteration 68: Espilon = 4.5556, ESS = 569 Acc. rate = 12.13% Uniqueness rate particules = 87.2% Uniqueness rate components = 87.2% Global parameters uniqueness rate = 87.2%
# NUMBER OF SIMULATIONS 751650/15000000
#
# Minimum distance: 0.0005572805 Maximum distance: 167.10358 Number of NaNs: 0
# Iteration 69: Espilon = 4.5078, ESS = 540 Acc. rate = 10.93% Uniqueness rate particules = 87.4% Uniqueness rate components = 87.4% Global parameters uniqueness rate = 87.4%
# NUMBER OF SIMULATIONS 759750/15000000
#
# Minimum distance: 0.0006572542 Maximum distance: 154.36604 Number of NaNs: 0
# Iteration 70: Espilon = 4.4458, ESS = 513 Acc. rate = 10.33% Uniqueness rate particules = 87.5% Uniqueness rate components = 87.5% Global parameters uniqueness rate = 87.5%
# NUMBER OF SIMULATIONS 767445/15000000
#
# Resampling... 471 unique particles left
# Minimum distance: 0.0005933632 Maximum distance: 144.53906 Number of NaNs: 0
# Iteration 71: Espilon = 4.4021, ESS = 1000 Acc. rate = 10.80% Uniqueness rate particules = 57.5% Uniqueness rate components = 57.5% Global parameters uniqueness rate = 57.5%
# NUMBER OF SIMULATIONS 782445/15000000
#
# Minimum distance: 0.00018421654 Maximum distance: 147.5619 Number of NaNs: 0
# Iteration 72: Espilon = 4.3641, ESS = 950 Acc. rate = 10.42% Uniqueness rate particules = 64.9% Uniqueness rate components = 64.9% Global parameters uniqueness rate = 64.9%
# NUMBER OF SIMULATIONS 796695/15000000
#
# Minimum distance: 0.00052645145 Maximum distance: 147.81924 Number of NaNs: 0
# Iteration 73: Espilon = 4.3168, ESS = 903 Acc. rate = 10.52% Uniqueness rate particules = 70.3% Uniqueness rate components = 70.3% Global parameters uniqueness rate = 70.3%
# NUMBER OF SIMULATIONS 810240/15000000
#
# Minimum distance: 0.00048578662 Maximum distance: 142.39388 Number of NaNs: 0
# Iteration 74: Espilon = 4.2634, ESS = 857 Acc. rate = 10.04% Uniqueness rate particules = 73.5% Uniqueness rate components = 73.5% Global parameters uniqueness rate = 73.5%
# NUMBER OF SIMULATIONS 823095/15000000
#
# Minimum distance: 0.0006034749 Maximum distance: 148.70958 Number of NaNs: 0
# Iteration 75: Espilon = 4.2087, ESS = 814 Acc. rate = 8.11% Uniqueness rate particules = 75.9% Uniqueness rate components = 75.9% Global parameters uniqueness rate = 75.9%
# NUMBER OF SIMULATIONS 835305/15000000
#
# Minimum distance: 0.0005406404 Maximum distance: 154.7704 Number of NaNs: 0
# Iteration 76: Espilon = 4.1601, ESS = 773 Acc. rate = 12.68% Uniqueness rate particules = 78.4% Uniqueness rate components = 78.4% Global parameters uniqueness rate = 78.4%
# NUMBER OF SIMULATIONS 846900/15000000
#
# Minimum distance: 0.00042653742 Maximum distance: 159.03595 Number of NaNs: 0
# Iteration 77: Espilon = 4.0961, ESS = 736 Acc. rate = 11.28% Uniqueness rate particules = 79.9% Uniqueness rate components = 79.9% Global parameters uniqueness rate = 79.9%
# NUMBER OF SIMULATIONS 857940/15000000
#
# Minimum distance: 0.0009839366 Maximum distance: 145.58978 Number of NaNs: 0
# Iteration 78: Espilon = 4.0434, ESS = 699 Acc. rate = 10.16% Uniqueness rate particules = 81.1% Uniqueness rate components = 81.1% Global parameters uniqueness rate = 81.1%
# NUMBER OF SIMULATIONS 868425/15000000
#
# Minimum distance: 0.0008807769 Maximum distance: 146.73587 Number of NaNs: 0
# Iteration 79: Espilon = 3.9929, ESS = 665 Acc. rate = 11.13% Uniqueness rate particules = 82.1% Uniqueness rate components = 82.1% Global parameters uniqueness rate = 82.1%
# NUMBER OF SIMULATIONS 878400/15000000
#
# Minimum distance: 0.00038170014 Maximum distance: 162.65866 Number of NaNs: 0
# Iteration 80: Espilon = 3.9584, ESS = 631 Acc. rate = 8.87% Uniqueness rate particules = 82.9% Uniqueness rate components = 82.9% Global parameters uniqueness rate = 82.9%
# NUMBER OF SIMULATIONS 887865/15000000
#
# Minimum distance: 0.00085033564 Maximum distance: 140.6438 Number of NaNs: 0
# Iteration 81: Espilon = 3.9170, ESS = 605 Acc. rate = 9.59% Uniqueness rate particules = 83.3% Uniqueness rate components = 83.3% Global parameters uniqueness rate = 83.3%
# NUMBER OF SIMULATIONS 896940/15000000
#
# Minimum distance: 0.0004038706 Maximum distance: 132.81657 Number of NaNs: 0
# Iteration 82: Espilon = 3.8787, ESS = 574 Acc. rate = 8.71% Uniqueness rate particules = 83.8% Uniqueness rate components = 83.8% Global parameters uniqueness rate = 83.8%
# NUMBER OF SIMULATIONS 905550/15000000
#
# Minimum distance: 0.0006066101 Maximum distance: 134.65582 Number of NaNs: 0
# Iteration 83: Espilon = 3.8307, ESS = 545 Acc. rate = 6.79% Uniqueness rate particules = 84.2% Uniqueness rate components = 84.2% Global parameters uniqueness rate = 84.2%
# NUMBER OF SIMULATIONS 913725/15000000
#
# Minimum distance: 0.0008382158 Maximum distance: 129.18166 Number of NaNs: 0
# Iteration 84: Espilon = 3.7970, ESS = 517 Acc. rate = 9.09% Uniqueness rate particules = 84.4% Uniqueness rate components = 84.4% Global parameters uniqueness rate = 84.4%
# NUMBER OF SIMULATIONS 921480/15000000
#
# Resampling... 470 unique particles left
# Minimum distance: 0.00026517376 Maximum distance: 154.741 Number of NaNs: 0
# Iteration 85: Espilon = 3.7449, ESS = 1000 Acc. rate = 8.80% Uniqueness rate particules = 55.1% Uniqueness rate components = 55.1% Global parameters uniqueness rate = 55.1%
# NUMBER OF SIMULATIONS 936480/15000000
#
# Minimum distance: 0.0002531044 Maximum distance: 162.9609 Number of NaNs: 0
# Iteration 86: Espilon = 3.6982, ESS = 950 Acc. rate = 7.47% Uniqueness rate particules = 60.6% Uniqueness rate components = 60.6% Global parameters uniqueness rate = 60.6%
# NUMBER OF SIMULATIONS 950730/15000000
#
# Minimum distance: 0.00014145879 Maximum distance: 141.89362 Number of NaNs: 0
# Iteration 87: Espilon = 3.6616, ESS = 902 Acc. rate = 7.32% Uniqueness rate particules = 64.8% Uniqueness rate components = 64.8% Global parameters uniqueness rate = 64.8%
# NUMBER OF SIMULATIONS 964260/15000000
#
# Minimum distance: 0.00048906525 Maximum distance: 150.77173 Number of NaNs: 0
# Iteration 88: Espilon = 3.6093, ESS = 856 Acc. rate = 8.88% Uniqueness rate particules = 68.9% Uniqueness rate components = 68.9% Global parameters uniqueness rate = 68.9%
# NUMBER OF SIMULATIONS 977100/15000000
#
# Minimum distance: 0.00033608644 Maximum distance: 152.4178 Number of NaNs: 0
# Iteration 89: Espilon = 3.5799, ESS = 814 Acc. rate = 8.60% Uniqueness rate particules = 72.5% Uniqueness rate components = 72.5% Global parameters uniqueness rate = 72.5%
# NUMBER OF SIMULATIONS 989310/15000000
#
# Minimum distance: 0.00064478256 Maximum distance: 134.30086 Number of NaNs: 0
# Iteration 90: Espilon = 3.5413, ESS = 773 Acc. rate = 8.28% Uniqueness rate particules = 74.6% Uniqueness rate components = 74.6% Global parameters uniqueness rate = 74.6%
# NUMBER OF SIMULATIONS 1000905/15000000
#
# Minimum distance: 0.00037346076 Maximum distance: 140.7517 Number of NaNs: 0
# Iteration 91: Espilon = 3.4996, ESS = 734 Acc. rate = 8.99% Uniqueness rate particules = 76.7% Uniqueness rate components = 76.7% Global parameters uniqueness rate = 76.7%
# NUMBER OF SIMULATIONS 1011915/15000000
#
# Minimum distance: 0.00038281793 Maximum distance: 153.16777 Number of NaNs: 0
# Iteration 92: Espilon = 3.4672, ESS = 697 Acc. rate = 7.75% Uniqueness rate particules = 77.9% Uniqueness rate components = 77.9% Global parameters uniqueness rate = 77.9%
# NUMBER OF SIMULATIONS 1022370/15000000
#
# Minimum distance: 0.0005939588 Maximum distance: 143.89668 Number of NaNs: 0
# Iteration 93: Espilon = 3.4278, ESS = 662 Acc. rate = 8.91% Uniqueness rate particules = 79.2% Uniqueness rate components = 79.2% Global parameters uniqueness rate = 79.2%
# NUMBER OF SIMULATIONS 1032300/15000000
#
# Minimum distance: 0.0006639903 Maximum distance: 127.255005 Number of NaNs: 0
# Iteration 94: Espilon = 3.3932, ESS = 628 Acc. rate = 8.12% Uniqueness rate particules = 79.9% Uniqueness rate components = 79.9% Global parameters uniqueness rate = 79.9%
# NUMBER OF SIMULATIONS 1041720/15000000
#
# Minimum distance: 0.00055082917 Maximum distance: 168.94109 Number of NaNs: 0
# Iteration 95: Espilon = 3.3620, ESS = 596 Acc. rate = 9.40% Uniqueness rate particules = 80.9% Uniqueness rate components = 80.9% Global parameters uniqueness rate = 80.9%
# NUMBER OF SIMULATIONS 1050660/15000000
#
# Minimum distance: 0.00041543666 Maximum distance: 135.02676 Number of NaNs: 0
# Iteration 96: Espilon = 3.3231, ESS = 566 Acc. rate = 8.48% Uniqueness rate particules = 81.3% Uniqueness rate components = 81.3% Global parameters uniqueness rate = 81.3%
# NUMBER OF SIMULATIONS 1059150/15000000
#
# Minimum distance: 0.0003430829 Maximum distance: 139.23672 Number of NaNs: 0
# Iteration 97: Espilon = 3.2895, ESS = 537 Acc. rate = 7.82% Uniqueness rate particules = 81.7% Uniqueness rate components = 81.7% Global parameters uniqueness rate = 81.7%
# NUMBER OF SIMULATIONS 1067205/15000000
#
# Minimum distance: 0.00034986247 Maximum distance: 166.8501 Number of NaNs: 0
# Iteration 98: Espilon = 3.2433, ESS = 510 Acc. rate = 10.59% Uniqueness rate particules = 82.3% Uniqueness rate components = 82.3% Global parameters uniqueness rate = 82.3%
# NUMBER OF SIMULATIONS 1074855/15000000
#
# Resampling... 455 unique particles left
# Minimum distance: 0.0005750705 Maximum distance: 148.798 Number of NaNs: 0
# Iteration 99: Espilon = 3.2087, ESS = 1000 Acc. rate = 6.70% Uniqueness rate particules = 52.0% Uniqueness rate components = 52.0% Global parameters uniqueness rate = 52.0%
# NUMBER OF SIMULATIONS 1089855/15000000
#
# Minimum distance: 0.00044114797 Maximum distance: 139.28477 Number of NaNs: 0
# Iteration 100: Espilon = 3.1815, ESS = 950 Acc. rate = 7.47% Uniqueness rate particules = 57.3% Uniqueness rate components = 57.3% Global parameters uniqueness rate = 57.3%
# NUMBER OF SIMULATIONS 1104105/15000000
#
# Minimum distance: 0.00084361725 Maximum distance: 155.94029 Number of NaNs: 0
# Iteration 101: Espilon = 3.1573, ESS = 903 Acc. rate = 6.87% Uniqueness rate particules = 61.8% Uniqueness rate components = 61.8% Global parameters uniqueness rate = 61.8%
# NUMBER OF SIMULATIONS 1117650/15000000
#
# Minimum distance: 0.00043047764 Maximum distance: 147.2492 Number of NaNs: 0
# Iteration 102: Espilon = 3.1299, ESS = 857 Acc. rate = 5.83% Uniqueness rate particules = 64.8% Uniqueness rate components = 64.8% Global parameters uniqueness rate = 64.8%
# NUMBER OF SIMULATIONS 1130505/15000000
#
# Minimum distance: 0.0007153362 Maximum distance: 133.17554 Number of NaNs: 0
# Iteration 103: Espilon = 3.0937, ESS = 815 Acc. rate = 8.47% Uniqueness rate particules = 69.4% Uniqueness rate components = 69.4% Global parameters uniqueness rate = 69.4%
# NUMBER OF SIMULATIONS 1142730/15000000
#
# Minimum distance: 0.00043145445 Maximum distance: 153.72821 Number of NaNs: 0
# Iteration 104: Espilon = 3.0632, ESS = 775 Acc. rate = 6.97% Uniqueness rate particules = 71.3% Uniqueness rate components = 71.3% Global parameters uniqueness rate = 71.3%
# NUMBER OF SIMULATIONS 1154355/15000000
#
# Minimum distance: 0.00029134308 Maximum distance: 133.27205 Number of NaNs: 0
# Iteration 105: Espilon = 3.0264, ESS = 737 Acc. rate = 7.33% Uniqueness rate particules = 73.4% Uniqueness rate components = 73.4% Global parameters uniqueness rate = 73.4%
# NUMBER OF SIMULATIONS 1165410/15000000
#
# Minimum distance: 0.00037362732 Maximum distance: 128.23697 Number of NaNs: 0
# Iteration 106: Espilon = 3.0011, ESS = 700 Acc. rate = 5.43% Uniqueness rate particules = 75.1% Uniqueness rate components = 75.1% Global parameters uniqueness rate = 75.1%
# NUMBER OF SIMULATIONS 1175910/15000000
#
# Minimum distance: 0.00036159906 Maximum distance: 131.07227 Number of NaNs: 0
# Iteration 107: Espilon = 2.9789, ESS = 665 Acc. rate = 7.97% Uniqueness rate particules = 76.3% Uniqueness rate components = 76.3% Global parameters uniqueness rate = 76.3%
# NUMBER OF SIMULATIONS 1185885/15000000
#
# Minimum distance: 0.00042104663 Maximum distance: 160.14828 Number of NaNs: 0
# Iteration 108: Espilon = 2.9428, ESS = 633 Acc. rate = 8.37% Uniqueness rate particules = 77.0% Uniqueness rate components = 77.0% Global parameters uniqueness rate = 77.0%
# NUMBER OF SIMULATIONS 1195380/15000000
#
# Minimum distance: 0.00044523797 Maximum distance: 145.30685 Number of NaNs: 0
# Iteration 109: Espilon = 2.9160, ESS = 601 Acc. rate = 7.15% Uniqueness rate particules = 77.9% Uniqueness rate components = 77.9% Global parameters uniqueness rate = 77.9%
# NUMBER OF SIMULATIONS 1204395/15000000
#
# Minimum distance: 0.000599813 Maximum distance: 139.87585 Number of NaNs: 0
# Iteration 110: Espilon = 2.8866, ESS = 571 Acc. rate = 7.36% Uniqueness rate particules = 78.6% Uniqueness rate components = 78.6% Global parameters uniqueness rate = 78.6%
# NUMBER OF SIMULATIONS 1212960/15000000
#
# Minimum distance: 0.00059443654 Maximum distance: 133.53777 Number of NaNs: 0
# Iteration 111: Espilon = 2.8646, ESS = 543 Acc. rate = 8.47% Uniqueness rate particules = 79.2% Uniqueness rate components = 79.2% Global parameters uniqueness rate = 79.2%
# NUMBER OF SIMULATIONS 1221105/15000000
#
# Minimum distance: 0.00022618404 Maximum distance: 125.91266 Number of NaNs: 0
# Iteration 112: Espilon = 2.8332, ESS = 515 Acc. rate = 5.83% Uniqueness rate particules = 80.0% Uniqueness rate components = 80.0% Global parameters uniqueness rate = 80.0%
# NUMBER OF SIMULATIONS 1228830/15000000
#
# Resampling... 447 unique particles left
# Minimum distance: 0.0007815442 Maximum distance: 142.81787 Number of NaNs: 0
# Iteration 113: Espilon = 2.8017, ESS = 1000 Acc. rate = 7.50% Uniqueness rate particules = 51.8% Uniqueness rate components = 51.8% Global parameters uniqueness rate = 51.8%
# NUMBER OF SIMULATIONS 1243830/15000000
#
# Minimum distance: 0.0005185036 Maximum distance: 132.41965 Number of NaNs: 0
# Iteration 114: Espilon = 2.7709, ESS = 950 Acc. rate = 8.11% Uniqueness rate particules = 57.5% Uniqueness rate components = 57.5% Global parameters uniqueness rate = 57.5%
# NUMBER OF SIMULATIONS 1258080/15000000
#
# Minimum distance: 0.0004926664 Maximum distance: 127.040344 Number of NaNs: 0
# Iteration 115: Espilon = 2.7441, ESS = 902 Acc. rate = 6.65% Uniqueness rate particules = 62.1% Uniqueness rate components = 62.1% Global parameters uniqueness rate = 62.1%
# NUMBER OF SIMULATIONS 1271610/15000000
#
# Minimum distance: 0.00036188812 Maximum distance: 137.02634 Number of NaNs: 0
# Iteration 116: Espilon = 2.7260, ESS = 860 Acc. rate = 6.40% Uniqueness rate particules = 65.4% Uniqueness rate components = 65.4% Global parameters uniqueness rate = 65.4%
# NUMBER OF SIMULATIONS 1284510/15000000
#
# Minimum distance: 0.00067640666 Maximum distance: 145.53258 Number of NaNs: 0
# Iteration 117: Espilon = 2.6963, ESS = 817 Acc. rate = 7.10% Uniqueness rate particules = 68.2% Uniqueness rate components = 68.2% Global parameters uniqueness rate = 68.2%
# NUMBER OF SIMULATIONS 1296765/15000000
#
# Minimum distance: 0.0004882766 Maximum distance: 154.94798 Number of NaNs: 0
# Iteration 118: Espilon = 2.6724, ESS = 776 Acc. rate = 6.70% Uniqueness rate particules = 70.4% Uniqueness rate components = 70.4% Global parameters uniqueness rate = 70.4%
# NUMBER OF SIMULATIONS 1308405/15000000
#
# Minimum distance: 0.00056014006 Maximum distance: 133.879 Number of NaNs: 0
# Iteration 119: Espilon = 2.6441, ESS = 737 Acc. rate = 7.06% Uniqueness rate particules = 72.2% Uniqueness rate components = 72.2% Global parameters uniqueness rate = 72.2%
# NUMBER OF SIMULATIONS 1319460/15000000
#
# Minimum distance: 0.0006758272 Maximum distance: 126.0569 Number of NaNs: 0
# Iteration 120: Espilon = 2.6185, ESS = 700 Acc. rate = 6.43% Uniqueness rate particules = 73.2% Uniqueness rate components = 73.2% Global parameters uniqueness rate = 73.2%
# NUMBER OF SIMULATIONS 1329960/15000000
#
# Minimum distance: 0.00034259318 Maximum distance: 151.73952 Number of NaNs: 0
# Iteration 121: Espilon = 2.5858, ESS = 665 Acc. rate = 5.86% Uniqueness rate particules = 74.3% Uniqueness rate components = 74.3% Global parameters uniqueness rate = 74.3%
# NUMBER OF SIMULATIONS 1339935/15000000
#
# Minimum distance: 0.00033656455 Maximum distance: 119.826645 Number of NaNs: 0
# Iteration 122: Espilon = 2.5560, ESS = 631 Acc. rate = 4.91% Uniqueness rate particules = 74.9% Uniqueness rate components = 74.9% Global parameters uniqueness rate = 74.9%
# NUMBER OF SIMULATIONS 1349400/15000000
#
# Minimum distance: 0.0004821355 Maximum distance: 125.65085 Number of NaNs: 0
# Iteration 123: Espilon = 2.5292, ESS = 599 Acc. rate = 8.35% Uniqueness rate particules = 76.0% Uniqueness rate components = 76.0% Global parameters uniqueness rate = 76.0%
# NUMBER OF SIMULATIONS 1358385/15000000
#
# Minimum distance: 0.00052696903 Maximum distance: 157.23508 Number of NaNs: 0
# Iteration 124: Espilon = 2.5043, ESS = 569 Acc. rate = 9.49% Uniqueness rate particules = 77.4% Uniqueness rate components = 77.4% Global parameters uniqueness rate = 77.4%
# NUMBER OF SIMULATIONS 1366920/15000000
#
# Minimum distance: 0.00042098932 Maximum distance: 131.95384 Number of NaNs: 0
# Iteration 125: Espilon = 2.4746, ESS = 540 Acc. rate = 5.56% Uniqueness rate particules = 77.6% Uniqueness rate components = 77.6% Global parameters uniqueness rate = 77.6%
# NUMBER OF SIMULATIONS 1375020/15000000
#
# Minimum distance: 0.00058945484 Maximum distance: 134.6988 Number of NaNs: 0
# Iteration 126: Espilon = 2.4509, ESS = 513 Acc. rate = 5.46% Uniqueness rate particules = 78.2% Uniqueness rate components = 78.2% Global parameters uniqueness rate = 78.2%
# NUMBER OF SIMULATIONS 1382715/15000000
#
# Resampling... 432 unique particles left
# Minimum distance: 0.00025388293 Maximum distance: 163.217 Number of NaNs: 0
# Iteration 127: Espilon = 2.4271, ESS = 1000 Acc. rate = 6.20% Uniqueness rate particules = 49.0% Uniqueness rate components = 49.0% Global parameters uniqueness rate = 49.0%
# NUMBER OF SIMULATIONS 1397715/15000000
#
# Minimum distance: 0.0004248906 Maximum distance: 131.33305 Number of NaNs: 0
# Iteration 128: Espilon = 2.4131, ESS = 950 Acc. rate = 5.26% Uniqueness rate particules = 53.5% Uniqueness rate components = 53.5% Global parameters uniqueness rate = 53.5%
# NUMBER OF SIMULATIONS 1411965/15000000
#
# Minimum distance: 0.00041910395 Maximum distance: 131.50574 Number of NaNs: 0
# Iteration 129: Espilon = 2.3886, ESS = 902 Acc. rate = 4.66% Uniqueness rate particules = 56.6% Uniqueness rate components = 56.6% Global parameters uniqueness rate = 56.6%
# NUMBER OF SIMULATIONS 1425495/15000000
#
# Minimum distance: 0.0003075834 Maximum distance: 124.82458 Number of NaNs: 0
# Iteration 130: Espilon = 2.3717, ESS = 856 Acc. rate = 4.44% Uniqueness rate particules = 59.3% Uniqueness rate components = 59.3% Global parameters uniqueness rate = 59.3%
# NUMBER OF SIMULATIONS 1438335/15000000
#
# Minimum distance: 0.00031832175 Maximum distance: 137.32256 Number of NaNs: 0
# Iteration 131: Espilon = 2.3552, ESS = 813 Acc. rate = 6.89% Uniqueness rate particules = 62.5% Uniqueness rate components = 62.5% Global parameters uniqueness rate = 62.5%
# NUMBER OF SIMULATIONS 1450530/15000000
#
# Minimum distance: 0.00021482774 Maximum distance: 135.86371 Number of NaNs: 0
# Iteration 132: Espilon = 2.3307, ESS = 772 Acc. rate = 7.38% Uniqueness rate particules = 65.2% Uniqueness rate components = 65.2% Global parameters uniqueness rate = 65.2%
# NUMBER OF SIMULATIONS 1462110/15000000
#
# Minimum distance: 0.0004295503 Maximum distance: 128.30615 Number of NaNs: 0
# Iteration 133: Espilon = 2.3178, ESS = 733 Acc. rate = 6.28% Uniqueness rate particules = 66.5% Uniqueness rate components = 66.5% Global parameters uniqueness rate = 66.5%
# NUMBER OF SIMULATIONS 1473105/15000000
#
# Minimum distance: 0.0003426785 Maximum distance: 121.30446 Number of NaNs: 0
# Iteration 134: Espilon = 2.2915, ESS = 696 Acc. rate = 5.32% Uniqueness rate particules = 67.8% Uniqueness rate components = 67.8% Global parameters uniqueness rate = 67.8%
# NUMBER OF SIMULATIONS 1483545/15000000
#
# Minimum distance: 0.00052660157 Maximum distance: 120.15706 Number of NaNs: 0
# Iteration 135: Espilon = 2.2656, ESS = 661 Acc. rate = 6.66% Uniqueness rate particules = 69.0% Uniqueness rate components = 69.0% Global parameters uniqueness rate = 69.0%
# NUMBER OF SIMULATIONS 1493460/15000000
#
# Minimum distance: 0.0004823093 Maximum distance: 123.92498 Number of NaNs: 0
# Iteration 136: Espilon = 2.2421, ESS = 628 Acc. rate = 5.57% Uniqueness rate particules = 70.3% Uniqueness rate components = 70.3% Global parameters uniqueness rate = 70.3%
# NUMBER OF SIMULATIONS 1502880/15000000
#
# Minimum distance: 0.000684486 Maximum distance: 113.00758 Number of NaNs: 0
# Iteration 137: Espilon = 2.2236, ESS = 597 Acc. rate = 7.37% Uniqueness rate particules = 71.2% Uniqueness rate components = 71.2% Global parameters uniqueness rate = 71.2%
# NUMBER OF SIMULATIONS 1511835/15000000
#
# Minimum distance: 0.00039794963 Maximum distance: 113.32123 Number of NaNs: 0
# Iteration 138: Espilon = 2.2092, ESS = 569 Acc. rate = 6.68% Uniqueness rate particules = 71.8% Uniqueness rate components = 71.8% Global parameters uniqueness rate = 71.8%
# NUMBER OF SIMULATIONS 1520370/15000000
#
# Minimum distance: 0.00048138338 Maximum distance: 128.62564 Number of NaNs: 0
# Iteration 139: Espilon = 2.1835, ESS = 540 Acc. rate = 4.81% Uniqueness rate particules = 72.2% Uniqueness rate components = 72.2% Global parameters uniqueness rate = 72.2%
# NUMBER OF SIMULATIONS 1528470/15000000
#
# Minimum distance: 0.0005942009 Maximum distance: 131.1611 Number of NaNs: 0
# Iteration 140: Espilon = 2.1581, ESS = 513 Acc. rate = 5.85% Uniqueness rate particules = 72.5% Uniqueness rate components = 72.5% Global parameters uniqueness rate = 72.5%
# NUMBER OF SIMULATIONS 1536165/15000000
#
# Resampling... 420 unique particles left
# Minimum distance: 0.00038452892 Maximum distance: 118.853516 Number of NaNs: 0
# Iteration 141: Espilon = 2.1377, ESS = 1000 Acc. rate = 4.90% Uniqueness rate particules = 46.6% Uniqueness rate components = 46.6% Global parameters uniqueness rate = 46.6%
# NUMBER OF SIMULATIONS 1551165/15000000
#
# Minimum distance: 0.00033351348 Maximum distance: 152.63269 Number of NaNs: 0
# Iteration 142: Espilon = 2.1249, ESS = 952 Acc. rate = 5.15% Uniqueness rate particules = 50.9% Uniqueness rate components = 50.9% Global parameters uniqueness rate = 50.9%
# NUMBER OF SIMULATIONS 1565445/15000000
#
# Minimum distance: 0.0005659221 Maximum distance: 107.17623 Number of NaNs: 0
# Iteration 143: Espilon = 2.1048, ESS = 908 Acc. rate = 5.29% Uniqueness rate particules = 54.8% Uniqueness rate components = 54.8% Global parameters uniqueness rate = 54.8%
# NUMBER OF SIMULATIONS 1579065/15000000
#
# Minimum distance: 0.00065173145 Maximum distance: 112.17756 Number of NaNs: 0
# Iteration 144: Espilon = 2.0921, ESS = 862 Acc. rate = 5.57% Uniqueness rate particules = 57.8% Uniqueness rate components = 57.8% Global parameters uniqueness rate = 57.8%
# NUMBER OF SIMULATIONS 1591995/15000000
#
# Minimum distance: 0.00038805074 Maximum distance: 148.12405 Number of NaNs: 0
# Iteration 145: Espilon = 2.0729, ESS = 818 Acc. rate = 5.50% Uniqueness rate particules = 60.6% Uniqueness rate components = 60.6% Global parameters uniqueness rate = 60.6%
# NUMBER OF SIMULATIONS 1604265/15000000
#
# Minimum distance: 0.00046452717 Maximum distance: 132.30486 Number of NaNs: 0
# Iteration 146: Espilon = 2.0516, ESS = 778 Acc. rate = 6.04% Uniqueness rate particules = 63.0% Uniqueness rate components = 63.0% Global parameters uniqueness rate = 63.0%
# NUMBER OF SIMULATIONS 1615935/15000000
#
# Minimum distance: 0.00044116937 Maximum distance: 111.828896 Number of NaNs: 0
# Iteration 147: Espilon = 2.0342, ESS = 739 Acc. rate = 4.87% Uniqueness rate particules = 64.8% Uniqueness rate components = 64.8% Global parameters uniqueness rate = 64.8%
# NUMBER OF SIMULATIONS 1627020/15000000
#
# Minimum distance: 0.0005156651 Maximum distance: 110.65711 Number of NaNs: 0
# Iteration 148: Espilon = 2.0093, ESS = 703 Acc. rate = 5.26% Uniqueness rate particules = 66.3% Uniqueness rate components = 66.3% Global parameters uniqueness rate = 66.3%
# NUMBER OF SIMULATIONS 1637565/15000000
#
# Minimum distance: 0.0003383066 Maximum distance: 118.28212 Number of NaNs: 0
# Iteration 149: Espilon = 1.9962, ESS = 667 Acc. rate = 4.80% Uniqueness rate particules = 67.1% Uniqueness rate components = 67.1% Global parameters uniqueness rate = 67.1%
# NUMBER OF SIMULATIONS 1647570/15000000
#
# Minimum distance: 0.00032231613 Maximum distance: 114.72144 Number of NaNs: 0
# Iteration 150: Espilon = 1.9761, ESS = 633 Acc. rate = 4.11% Uniqueness rate particules = 67.7% Uniqueness rate components = 67.7% Global parameters uniqueness rate = 67.7%
# NUMBER OF SIMULATIONS 1657065/15000000
#
# Minimum distance: 0.0006695861 Maximum distance: 139.2698 Number of NaNs: 0
# Iteration 151: Espilon = 1.9603, ESS = 602 Acc. rate = 4.15% Uniqueness rate particules = 68.6% Uniqueness rate components = 68.6% Global parameters uniqueness rate = 68.6%
# NUMBER OF SIMULATIONS 1666095/15000000
#
# Minimum distance: 0.00020231724 Maximum distance: 123.78957 Number of NaNs: 0
# Iteration 152: Espilon = 1.9435, ESS = 571 Acc. rate = 5.43% Uniqueness rate particules = 69.3% Uniqueness rate components = 69.3% Global parameters uniqueness rate = 69.3%
# NUMBER OF SIMULATIONS 1674660/15000000
#
# Minimum distance: 0.00040634448 Maximum distance: 117.604706 Number of NaNs: 0
# Iteration 153: Espilon = 1.9332, ESS = 542 Acc. rate = 4.61% Uniqueness rate particules = 69.8% Uniqueness rate components = 69.8% Global parameters uniqueness rate = 69.8%
# NUMBER OF SIMULATIONS 1682790/15000000
#
# Minimum distance: 0.0006464821 Maximum distance: 103.96245 Number of NaNs: 0
# Iteration 154: Espilon = 1.9210, ESS = 514 Acc. rate = 4.28% Uniqueness rate particules = 70.3% Uniqueness rate components = 70.3% Global parameters uniqueness rate = 70.3%
# NUMBER OF SIMULATIONS 1690500/15000000
#
# Resampling... 402 unique particles left
# Minimum distance: 0.0007699233 Maximum distance: 131.8086 Number of NaNs: 0
# Iteration 155: Espilon = 1.9058, ESS = 1000 Acc. rate = 4.50% Uniqueness rate particules = 44.5% Uniqueness rate components = 44.5% Global parameters uniqueness rate = 44.5%
# NUMBER OF SIMULATIONS 1705500/15000000
#
# Minimum distance: 0.00027319964 Maximum distance: 104.96117 Number of NaNs: 0
# Iteration 156: Espilon = 1.8848, ESS = 953 Acc. rate = 3.67% Uniqueness rate particules = 47.7% Uniqueness rate components = 47.7% Global parameters uniqueness rate = 47.7%
# NUMBER OF SIMULATIONS 1719795/15000000
#
# Minimum distance: 0.00083723204 Maximum distance: 119.72357 Number of NaNs: 0
# Iteration 157: Espilon = 1.8701, ESS = 905 Acc. rate = 4.64% Uniqueness rate particules = 51.0% Uniqueness rate components = 51.0% Global parameters uniqueness rate = 51.0%
# NUMBER OF SIMULATIONS 1733370/15000000
#
# Minimum distance: 0.00052176544 Maximum distance: 122.851036 Number of NaNs: 0
# Iteration 158: Espilon = 1.8579, ESS = 859 Acc. rate = 5.36% Uniqueness rate particules = 54.3% Uniqueness rate components = 54.3% Global parameters uniqueness rate = 54.3%
# NUMBER OF SIMULATIONS 1746255/15000000
#
# Minimum distance: 0.00036984612 Maximum distance: 138.9832 Number of NaNs: 0
# Iteration 159: Espilon = 1.8371, ESS = 817 Acc. rate = 3.79% Uniqueness rate particules = 56.3% Uniqueness rate components = 56.3% Global parameters uniqueness rate = 56.3%
# NUMBER OF SIMULATIONS 1758510/15000000
#
# Minimum distance: 0.00058059156 Maximum distance: 119.11797 Number of NaNs: 0
# Iteration 160: Espilon = 1.8219, ESS = 776 Acc. rate = 5.54% Uniqueness rate particules = 58.6% Uniqueness rate components = 58.6% Global parameters uniqueness rate = 58.6%
# NUMBER OF SIMULATIONS 1770150/15000000
#
# Minimum distance: 0.0003367273 Maximum distance: 111.245094 Number of NaNs: 0
# Iteration 161: Espilon = 1.8032, ESS = 738 Acc. rate = 5.56% Uniqueness rate particules = 61.0% Uniqueness rate components = 61.0% Global parameters uniqueness rate = 61.0%
# NUMBER OF SIMULATIONS 1781220/15000000
#
# Minimum distance: 0.0006536597 Maximum distance: 113.0566 Number of NaNs: 0
# Iteration 162: Espilon = 1.7893, ESS = 702 Acc. rate = 4.99% Uniqueness rate particules = 62.5% Uniqueness rate components = 62.5% Global parameters uniqueness rate = 62.5%
# NUMBER OF SIMULATIONS 1791750/15000000
#
# Minimum distance: 0.00064644415 Maximum distance: 106.73064 Number of NaNs: 0
# Iteration 163: Espilon = 1.7809, ESS = 671 Acc. rate = 4.32% Uniqueness rate particules = 63.9% Uniqueness rate components = 63.9% Global parameters uniqueness rate = 63.9%
# NUMBER OF SIMULATIONS 1801815/15000000
#
# Minimum distance: 0.0006573099 Maximum distance: 104.528946 Number of NaNs: 0
# Iteration 164: Espilon = 1.7696, ESS = 638 Acc. rate = 4.08% Uniqueness rate particules = 65.1% Uniqueness rate components = 65.1% Global parameters uniqueness rate = 65.1%
# NUMBER OF SIMULATIONS 1811385/15000000
#
# Minimum distance: 0.0005066093 Maximum distance: 113.22812 Number of NaNs: 0
# ...
# NUMBER OF SIMULATIONS 14210325/15000000
#
# Minimum distance: 0.00021327485 Maximum distance: 84.36982 Number of NaNs: 0
# Iteration 1213: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 38.5% Uniqueness rate components = 38.5% Global parameters uniqueness rate = 38.5%
# NUMBER OF SIMULATIONS 14225325/15000000
#
# Minimum distance: 0.00036978727 Maximum distance: 80.64763 Number of NaNs: 0
# Iteration 1214: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.60% Uniqueness rate particules = 38.7% Uniqueness rate components = 38.7% Global parameters uniqueness rate = 38.7%
# NUMBER OF SIMULATIONS 14240325/15000000
#
# Minimum distance: 0.00032422907 Maximum distance: 83.915054 Number of NaNs: 0
# Iteration 1215: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 38.8% Uniqueness rate components = 38.8% Global parameters uniqueness rate = 38.8%
# NUMBER OF SIMULATIONS 14255325/15000000
#
# Minimum distance: 0.00039335576 Maximum distance: 82.21312 Number of NaNs: 0
# Iteration 1216: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 38.8% Uniqueness rate components = 38.8% Global parameters uniqueness rate = 38.8%
# NUMBER OF SIMULATIONS 14270325/15000000
#
# Minimum distance: 0.00023029611 Maximum distance: 85.94484 Number of NaNs: 0
# Iteration 1217: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.00% Uniqueness rate particules = 38.8% Uniqueness rate components = 38.8% Global parameters uniqueness rate = 38.8%
# NUMBER OF SIMULATIONS 14285325/15000000
#
# Minimum distance: 0.00050857745 Maximum distance: 82.84555 Number of NaNs: 0
# Iteration 1218: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 38.8% Uniqueness rate components = 38.8% Global parameters uniqueness rate = 38.8%
# NUMBER OF SIMULATIONS 14300325/15000000
#
# Minimum distance: 0.00041983472 Maximum distance: 84.60393 Number of NaNs: 0
# Iteration 1219: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.50% Uniqueness rate particules = 39.1% Uniqueness rate components = 39.1% Global parameters uniqueness rate = 39.1%
# NUMBER OF SIMULATIONS 14315325/15000000
#
# Minimum distance: 0.00031509265 Maximum distance: 79.87315 Number of NaNs: 0
# Iteration 1220: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 39.1% Uniqueness rate components = 39.1% Global parameters uniqueness rate = 39.1%
# NUMBER OF SIMULATIONS 14330325/15000000
#
# Minimum distance: 0.00033783473 Maximum distance: 82.577324 Number of NaNs: 0
# Iteration 1221: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.00% Uniqueness rate particules = 39.1% Uniqueness rate components = 39.1% Global parameters uniqueness rate = 39.1%
# NUMBER OF SIMULATIONS 14345325/15000000
#
# Minimum distance: 0.00022178153 Maximum distance: 81.93022 Number of NaNs: 0
# Iteration 1222: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 39.3% Uniqueness rate components = 39.3% Global parameters uniqueness rate = 39.3%
# NUMBER OF SIMULATIONS 14360325/15000000
#
# Minimum distance: 0.00044694042 Maximum distance: 83.32078 Number of NaNs: 0
# Iteration 1223: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 14375325/15000000
#
# Minimum distance: 0.00028429893 Maximum distance: 78.569374 Number of NaNs: 0
# Iteration 1224: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.00% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 14390325/15000000
#
# Minimum distance: 0.00037550245 Maximum distance: 78.58742 Number of NaNs: 0
# Iteration 1225: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 14405325/15000000
#
# Minimum distance: 0.0002692039 Maximum distance: 79.55599 Number of NaNs: 0
# Iteration 1226: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 14420325/15000000
#
# Minimum distance: 0.00043095232 Maximum distance: 83.11265 Number of NaNs: 0
# Iteration 1227: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 39.4% Uniqueness rate components = 39.4% Global parameters uniqueness rate = 39.4%
# NUMBER OF SIMULATIONS 14435325/15000000
#
# Minimum distance: 0.00024410435 Maximum distance: 82.88132 Number of NaNs: 0
# Iteration 1228: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 39.6% Uniqueness rate components = 39.6% Global parameters uniqueness rate = 39.6%
# NUMBER OF SIMULATIONS 14450325/15000000
#
# Minimum distance: 0.00058196275 Maximum distance: 82.26715 Number of NaNs: 0
# Iteration 1229: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 39.7% Uniqueness rate components = 39.7% Global parameters uniqueness rate = 39.7%
# NUMBER OF SIMULATIONS 14465325/15000000
#
# Minimum distance: 0.0004610784 Maximum distance: 80.098724 Number of NaNs: 0
# Iteration 1230: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 39.8% Uniqueness rate components = 39.8% Global parameters uniqueness rate = 39.8%
# NUMBER OF SIMULATIONS 14480325/15000000
#
# Minimum distance: 0.00037381152 Maximum distance: 85.166115 Number of NaNs: 0
# Iteration 1231: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 40.0% Uniqueness rate components = 40.0% Global parameters uniqueness rate = 40.0%
# NUMBER OF SIMULATIONS 14495325/15000000
#
# Minimum distance: 0.00038637535 Maximum distance: 83.88518 Number of NaNs: 0
# Iteration 1232: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 40.0% Uniqueness rate components = 40.0% Global parameters uniqueness rate = 40.0%
# NUMBER OF SIMULATIONS 14510325/15000000
#
# Minimum distance: 0.0003817123 Maximum distance: 80.08574 Number of NaNs: 0
# Iteration 1233: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 40.2% Uniqueness rate components = 40.2% Global parameters uniqueness rate = 40.2%
# NUMBER OF SIMULATIONS 14525325/15000000
#
# Minimum distance: 0.0005088033 Maximum distance: 79.91609 Number of NaNs: 0
# Iteration 1234: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 40.2% Uniqueness rate components = 40.2% Global parameters uniqueness rate = 40.2%
# NUMBER OF SIMULATIONS 14540325/15000000
#
# Minimum distance: 0.00035470614 Maximum distance: 88.57579 Number of NaNs: 0
# Iteration 1235: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 40.4% Uniqueness rate components = 40.4% Global parameters uniqueness rate = 40.4%
# NUMBER OF SIMULATIONS 14555325/15000000
#
# Minimum distance: 0.00017159003 Maximum distance: 80.44447 Number of NaNs: 0
# Iteration 1236: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 40.6% Uniqueness rate components = 40.6% Global parameters uniqueness rate = 40.6%
# NUMBER OF SIMULATIONS 14570325/15000000
#
# Minimum distance: 0.00042925385 Maximum distance: 80.68304 Number of NaNs: 0
# Iteration 1237: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.50% Uniqueness rate particules = 40.9% Uniqueness rate components = 40.9% Global parameters uniqueness rate = 40.9%
# NUMBER OF SIMULATIONS 14585325/15000000
#
# Minimum distance: 0.000119993514 Maximum distance: 82.09954 Number of NaNs: 0
# Iteration 1238: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 40.9% Uniqueness rate components = 40.9% Global parameters uniqueness rate = 40.9%
# NUMBER OF SIMULATIONS 14600325/15000000
#
# Minimum distance: 0.00026659376 Maximum distance: 84.13815 Number of NaNs: 0
# Iteration 1239: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.00% Uniqueness rate particules = 40.9% Uniqueness rate components = 40.9% Global parameters uniqueness rate = 40.9%
# NUMBER OF SIMULATIONS 14615325/15000000
#
# Minimum distance: 0.00045758663 Maximum distance: 81.83084 Number of NaNs: 0
# Iteration 1240: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 41.1% Uniqueness rate components = 41.1% Global parameters uniqueness rate = 41.1%
# NUMBER OF SIMULATIONS 14630325/15000000
#
# Minimum distance: 0.0003019055 Maximum distance: 83.56706 Number of NaNs: 0
# Iteration 1241: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 41.3% Uniqueness rate components = 41.3% Global parameters uniqueness rate = 41.3%
# NUMBER OF SIMULATIONS 14645325/15000000
#
# Minimum distance: 0.0004136006 Maximum distance: 82.02011 Number of NaNs: 0
# Iteration 1242: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 41.4% Uniqueness rate components = 41.4% Global parameters uniqueness rate = 41.4%
# NUMBER OF SIMULATIONS 14660325/15000000
#
# Minimum distance: 0.0003192863 Maximum distance: 87.36529 Number of NaNs: 0
# Iteration 1243: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 41.5% Uniqueness rate components = 41.5% Global parameters uniqueness rate = 41.5%
# NUMBER OF SIMULATIONS 14675325/15000000
#
# Minimum distance: 0.00023028607 Maximum distance: 83.6541 Number of NaNs: 0
# Iteration 1244: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 41.7% Uniqueness rate components = 41.7% Global parameters uniqueness rate = 41.7%
# NUMBER OF SIMULATIONS 14690325/15000000
#
# Minimum distance: 0.000246417 Maximum distance: 79.97892 Number of NaNs: 0
# Iteration 1245: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 41.8% Uniqueness rate components = 41.8% Global parameters uniqueness rate = 41.8%
# NUMBER OF SIMULATIONS 14705325/15000000
#
# Minimum distance: 0.00040542101 Maximum distance: 84.98987 Number of NaNs: 0
# Iteration 1246: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 41.9% Uniqueness rate components = 41.9% Global parameters uniqueness rate = 41.9%
# NUMBER OF SIMULATIONS 14720325/15000000
#
# Minimum distance: 0.00032639824 Maximum distance: 77.68729 Number of NaNs: 0
# Iteration 1247: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 42.0% Uniqueness rate components = 42.0% Global parameters uniqueness rate = 42.0%
# NUMBER OF SIMULATIONS 14735325/15000000
#
# Minimum distance: 0.00045514913 Maximum distance: 81.45081 Number of NaNs: 0
# Iteration 1248: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 42.1% Uniqueness rate components = 42.1% Global parameters uniqueness rate = 42.1%
# NUMBER OF SIMULATIONS 14750325/15000000
#
# Minimum distance: 0.00020560455 Maximum distance: 84.12579 Number of NaNs: 0
# Iteration 1249: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 42.2% Uniqueness rate components = 42.2% Global parameters uniqueness rate = 42.2%
# NUMBER OF SIMULATIONS 14765325/15000000
#
# Minimum distance: 0.00042324577 Maximum distance: 82.25834 Number of NaNs: 0
# Iteration 1250: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 42.2% Uniqueness rate components = 42.2% Global parameters uniqueness rate = 42.2%
# NUMBER OF SIMULATIONS 14780325/15000000
#
# Minimum distance: 0.00030298042 Maximum distance: 78.201324 Number of NaNs: 0
# Iteration 1251: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.50% Uniqueness rate particules = 42.5% Uniqueness rate components = 42.5% Global parameters uniqueness rate = 42.5%
# NUMBER OF SIMULATIONS 14795325/15000000
#
# Minimum distance: 0.0002574321 Maximum distance: 79.937454 Number of NaNs: 0
# Iteration 1252: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.60% Uniqueness rate particules = 42.6% Uniqueness rate components = 42.6% Global parameters uniqueness rate = 42.6%
# NUMBER OF SIMULATIONS 14810325/15000000
#
# Minimum distance: 0.00023695518 Maximum distance: 82.93611 Number of NaNs: 0
# Iteration 1253: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 42.8% Uniqueness rate components = 42.8% Global parameters uniqueness rate = 42.8%
# NUMBER OF SIMULATIONS 14825325/15000000
#
# Minimum distance: 0.0003230782 Maximum distance: 81.4657 Number of NaNs: 0
# Iteration 1254: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 42.9% Uniqueness rate components = 42.9% Global parameters uniqueness rate = 42.9%
# NUMBER OF SIMULATIONS 14840325/15000000
#
# Minimum distance: 0.00024607155 Maximum distance: 80.50471 Number of NaNs: 0
# Iteration 1255: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 42.9% Uniqueness rate components = 42.9% Global parameters uniqueness rate = 42.9%
# NUMBER OF SIMULATIONS 14855325/15000000
#
# Minimum distance: 0.00040486665 Maximum distance: 81.73001 Number of NaNs: 0
# Iteration 1256: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 42.9% Uniqueness rate components = 42.9% Global parameters uniqueness rate = 42.9%
# NUMBER OF SIMULATIONS 14870325/15000000
#
# Minimum distance: 0.0002022717 Maximum distance: 92.46831 Number of NaNs: 0
# Iteration 1257: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 42.9% Uniqueness rate components = 42.9% Global parameters uniqueness rate = 42.9%
# NUMBER OF SIMULATIONS 14885325/15000000
#
# Minimum distance: 0.00027379778 Maximum distance: 79.24787 Number of NaNs: 0
# Iteration 1258: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.50% Uniqueness rate particules = 43.1% Uniqueness rate components = 43.1% Global parameters uniqueness rate = 43.1%
# NUMBER OF SIMULATIONS 14900325/15000000
#
# Minimum distance: 0.000285517 Maximum distance: 78.57062 Number of NaNs: 0
# Iteration 1259: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 43.2% Uniqueness rate components = 43.2% Global parameters uniqueness rate = 43.2%
# NUMBER OF SIMULATIONS 14915325/15000000
#
# Minimum distance: 0.00014112784 Maximum distance: 81.89528 Number of NaNs: 0
# Iteration 1260: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 43.4% Uniqueness rate components = 43.4% Global parameters uniqueness rate = 43.4%
# NUMBER OF SIMULATIONS 14930325/15000000
#
# Minimum distance: 0.00012948873 Maximum distance: 80.124306 Number of NaNs: 0
# Iteration 1261: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.20% Uniqueness rate particules = 43.4% Uniqueness rate components = 43.4% Global parameters uniqueness rate = 43.4%
# NUMBER OF SIMULATIONS 14945325/15000000
#
# Minimum distance: 0.00040386815 Maximum distance: 79.560196 Number of NaNs: 0
# Iteration 1262: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 43.4% Uniqueness rate components = 43.4% Global parameters uniqueness rate = 43.4%
# NUMBER OF SIMULATIONS 14960325/15000000
#
# Minimum distance: 0.0003699659 Maximum distance: 83.26823 Number of NaNs: 0
# Iteration 1263: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.30% Uniqueness rate particules = 43.6% Uniqueness rate components = 43.6% Global parameters uniqueness rate = 43.6%
# NUMBER OF SIMULATIONS 14975325/15000000
#
# Minimum distance: 0.00022746524 Maximum distance: 84.367714 Number of NaNs: 0
# Iteration 1264: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.40% Uniqueness rate particules = 43.7% Uniqueness rate components = 43.7% Global parameters uniqueness rate = 43.7%
# NUMBER OF SIMULATIONS 14990325/15000000
#
# Minimum distance: 0.00026765128 Maximum distance: 80.95381 Number of NaNs: 0
# Iteration 1265: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 43.8% Uniqueness rate components = 43.8% Global parameters uniqueness rate = 43.8%
# NUMBER OF SIMULATIONS 15005325/15000000
#
# Minimum distance: 0.00053573935 Maximum distance: 80.47211 Number of NaNs: 0
# Iteration 1266: Espilon = 0.2765, ESS = 1000 Acc. rate = 0.10% Uniqueness rate particules = 43.9% Uniqueness rate components = 43.9% Global parameters uniqueness rate = 43.9%
# NUMBER OF SIMULATIONS 15020325/15000000

# %%
# N_plot = 3

# f, ax = plt.subplots(1, N_plot + 1, figsize=(15, 5))
# if N_plot < K:
#     perm = np.random.permutation(K)
# else:
#     perm = np.arange(K)

# for i in range(N_plot):
#     k = perm[i]
#     sns.kdeplot(np.unique(mus_perm_van[dists_perm<epsilon, k][:N]), ax=ax[i], label="Perm ABC vanilla")
#     # sns.kdeplot(np.unique(mus_van[:, k]), ax=ax[i], label="ABC vanilla")
#     # sns.kdeplot(np.unique(mus_smc[:, k]), ax=ax[i], label="ABC SMC")
#     sns.kdeplot(np.unique(mus_perm_smc[:, k][:N]), ax=ax[i], label="Perm ABC SMC")
#     # sns.kdeplot(np.unique(mus_os[:, k]), ax=ax[i], label="Perm ABC SMC OS")
#     # sns.kdeplot(np.unique(mus_um[:, k]), ax=ax[i], label="Perm ABC SMC UM")
#     ax[i].axvline(true_theta.loc[0, k], color="black", linestyle="--")
#     ax[i].set_title("Component {}".format(k))
#     # ax[i].legend()
#     ax[i].set_xlabel(r"$\mu_{}$".format(k))
#     ax[i].set_ylabel("Density")

# sns.kdeplot(np.unique(betas_perm_van[dists_perm<epsilon][:N]), ax=ax[-1], label="Perm ABC vanilla")
# # sns.kdeplot(np.unique(betas_van), ax=ax[-1], label="ABC vanilla")
# # sns.kdeplot(np.unique(betas_smc), ax=ax[-1], label="ABC SMC", fill=True)
# sns.kdeplot(np.unique(betas_perm_smc)[:N], ax=ax[-1], label="Perm ABC SMC")
# # sns.kdeplot(np.unique(betas_os), ax=ax[-1], label="Perm ABC SMC OS")
# # sns.kdeplot(np.unique(betas_um), ax=ax[-1], label="Perm ABC SMC UM")
# ax[-1].axvline(true_theta.glob[0], color="black", linestyle="--")
# ax[-1].set_title("Global parameter")
# ax[-1].legend()
# ax[-1].set_xlabel(r"$\beta$")
# ax[-1].set_ylabel("Density")
# ax[-1].set_xlim(0, 5)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Over Sampling

# %%
# M0 = 50
# key = random.PRNGKey(0)
# key, subkey = random.split(key)
# kernel = KernelTruncatedRW
# model.reset_weights_distance()
# os = perm_abc_smc_os(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 3, M_0 = M0, duplicate= True, n_duplicate = 0, alpha_M = .9, Final_iteration= 50, update_weights_distance= False)
# mus_os = os["Thetas"][-1].loc.squeeze()
# betas_os = os["Thetas"][-1].glob.squeeze()
# n_sim_os = np.sum(os["N_sim"])

# %% [markdown]
# ## Under Matching

# %%
# L0 = 3
# key = random.PRNGKey(0)
# key, subkey = random.split(key)
# kernel = KernelTruncatedRW
# model.reset_weights_distance()
# um = perm_abc_smc_um(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 3, L_0 = L0,  alpha_L = .75, alpha_epsilon= .75,Final_iteration= 50, update_weights_distance= False)

# mus_um = um["Thetas"][-1].loc.squeeze()
# betas_um = um["Thetas"][-1].glob.squeeze()
# n_sim_um = np.sum(um["N_sim"])

# %% [markdown]
# ## ABC-PMC

# %%
from pmc import abc_pmc

# %%
key, subkey = random.split(key)
model.reset_weights_distance()
N_smc = 1000
out_pmc = abc_pmc(key = subkey, model = model, n_particles= N_smc, epsilon_target= 0, y_obs = y_obs, verbose =1, update_weights_distance= False, N_sim_max= N_points*K, stopping_accept_rate= 0., alpha = .95)
# Out:
# DISTANCE VALUES: MIN = 43.1, MAX = 3.57e+02 MEAN = 1.54e+02
# Iteration 0: Epsilon = inf ESS = 1000 (100.000%)
# Iteration 1: Epsilon = 2.35e+02
# Std loc: min = 13.5, max = 14.9
# Std glob = 0.888
# Simulating...
# NUMBER OF SIMULATIONS: 62310/15000000
# Number of simulations: 3.15E+03 (Accept rate 31.70577%)
# Weight update...
# DISTANCE VALUES: MIN = 43.3, MAX = 2.35e+02 MEAN = 1.86e+02
# Log Denominateur: min = -70.2 (index = 315), max = -58.4 (index = 600)
# Log prior: min -1.674e+03 (index = 140), max = -51.16 (index = 600)
# Weights: min = 0.0 (index = 54), max = 0.314 (index = 600)
# ESS = 9 (0.856%)
# Resampling...
# Number of unique index:  4 1
# Number of unique particles: 124
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 2: Epsilon = 2.14e+02
# Std loc: min = 10.2, max = 15.0
# Std glob = 0.624
# Simulating...
# NUMBER OF SIMULATIONS: 108525/15000000
# Number of simulations: 3.08E+03 (Accept rate 32.45699%)
# Weight update...
# DISTANCE VALUES: MIN = 51.5, MAX = 2.14e+02 MEAN = 1.64e+02
# Log Denominateur: min = -69.4 (index = 19), max = -53.8 (index = 440)
# Log prior: min -624.0 (index = 732), max = -50.69 (index = 440)
# Weights: min = 0.0 (index = 172), max = 0.0564 (index = 816)
# ESS = 74 (7.407%)
# Resampling...
# Number of unique index:  4 16
# Number of unique particles: 235
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 3: Epsilon = 2.04e+02
# Std loc: min = 11.7, max = 15.4
# Std glob = 0.721
# Simulating...
# NUMBER OF SIMULATIONS: 171285/15000000
# Number of simulations: 4.18E+03 (Accept rate 23.90057%)
# Weight update...
# DISTANCE VALUES: MIN = 59.1, MAX = 2.04e+02 MEAN = 1.63e+02
# Log Denominateur: min = -69.4 (index = 521), max = -58.0 (index = 514)
# Log prior: min -1.032e+03 (index = 585), max = -53.01 (index = 743)
# Weights: min = 0.0 (index = 397), max = 0.091 (index = 122)
# ESS = 40 (4.047%)
# Resampling...
# Number of unique index:  2 1
# Number of unique particles: 208
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 4: Epsilon = 1.92e+02
# Std loc: min = 12.7, max = 15.1
# Std glob = 0.838
# Simulating...
# NUMBER OF SIMULATIONS: 250455/15000000
# Number of simulations: 5.28E+03 (Accept rate 18.94657%)
# Weight update...
# DISTANCE VALUES: MIN = 45.0, MAX = 1.92e+02 MEAN = 1.55e+02
# Log Denominateur: min = -69.6 (index = 369), max = -57.8 (index = 153)
# Log prior: min -987.6 (index = 251), max = -51.47 (index = 968)
# Weights: min = 0.0 (index = 1), max = 0.14 (index = 968)
# ESS = 29 (2.908%)
# Resampling...
# Number of unique index:  6 3
# Number of unique particles: 200
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 5: Epsilon = 1.79e+02
# Std loc: min = 11.4, max = 15.1
# Std glob = 0.964
# Simulating...
# NUMBER OF SIMULATIONS: 334920/15000000
# Number of simulations: 5.63E+03 (Accept rate 17.75884%)
# Weight update...
# DISTANCE VALUES: MIN = 43.5, MAX = 1.79e+02 MEAN = 1.45e+02
# Log Denominateur: min = -69.3 (index = 651), max = -57.1 (index = 685)
# Log prior: min -5.696e+03 (index = 307), max = -51.79 (index = 34)
# Weights: min = 0.0 (index = 28), max = 0.107 (index = 34)
# ESS = 47 (4.681%)
# Resampling...
# Number of unique index:  0 2
# Number of unique particles: 234
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 6: Epsilon = 1.71e+02
# Std loc: min = 12.0, max = 14.1
# Std glob = 1.02
# Simulating...
# NUMBER OF SIMULATIONS: 416085/15000000
# Number of simulations: 5.41E+03 (Accept rate 18.48087%)
# Weight update...
# DISTANCE VALUES: MIN = 34.1, MAX = 1.71e+02 MEAN = 1.37e+02
# Log Denominateur: min = -69.8 (index = 80), max = -57.6 (index = 613)
# Log prior: min -1.873e+03 (index = 8), max = -52.61 (index = 52)
# Weights: min = 0.0 (index = 8), max = 0.126 (index = 52)
# ESS = 37 (3.659%)
# Resampling...
# Number of unique index:  2 3
# Number of unique particles: 217
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 7: Epsilon = 1.68e+02
# Std loc: min = 12.0, max = 15.8
# Std glob = 1.1
# Simulating...
# NUMBER OF SIMULATIONS: 506085/15000000
# Number of simulations: 6.00E+03 (Accept rate 16.66667%)
# Weight update...
# DISTANCE VALUES: MIN = 31.4, MAX = 1.68e+02 MEAN = 1.35e+02
# Log Denominateur: min = -70.0 (index = 674), max = -57.6 (index = 323)
# Log prior: min -926.4 (index = 241), max = -52.84 (index = 495)
# Weights: min = 0.0 (index = 28), max = 0.0646 (index = 17)
# ESS = 58 (5.750%)
# Resampling...
# Number of unique index:  7 8
# Number of unique particles: 205
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 8: Epsilon = 1.62e+02
# Std loc: min = 11.1, max = 14.6
# Std glob = 1.46
# Simulating...
# NUMBER OF SIMULATIONS: 635025/15000000
# Number of simulations: 8.60E+03 (Accept rate 11.63332%)
# Weight update...
# DISTANCE VALUES: MIN = 34.1, MAX = 1.62e+02 MEAN = 1.33e+02
# Log Denominateur: min = -68.4 (index = 418), max = -57.5 (index = 484)
# Log prior: min -619.8 (index = 850), max = -52.43 (index = 309)
# Weights: min = 0.0 (index = 5), max = 0.085 (index = 403)
# ESS = 30 (3.043%)
# Resampling...
# Number of unique index:  4 3
# Number of unique particles: 161
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 9: Epsilon = 1.58e+02
# Std loc: min = 9.51, max = 15.3
# Std glob = 0.986
# Simulating...
# NUMBER OF SIMULATIONS: 744105/15000000
# Number of simulations: 7.27E+03 (Accept rate 13.75138%)
# Weight update...
# DISTANCE VALUES: MIN = 43.7, MAX = 1.58e+02 MEAN = 1.3e+02
# Log Denominateur: min = -68.4 (index = 652), max = -56.6 (index = 783)
# Log prior: min -1.437e+03 (index = 431), max = -51.34 (index = 185)
# Weights: min = 0.0 (index = 41), max = 0.0821 (index = 196)
# ESS = 39 (3.918%)
# Resampling...
# Number of unique index:  7 3
# Number of unique particles: 214
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 10: Epsilon = 1.53e+02
# Std loc: min = 11.1, max = 14.2
# Std glob = 1.22
# Simulating...
# NUMBER OF SIMULATIONS: 853350/15000000
# Number of simulations: 7.28E+03 (Accept rate 13.73061%)
# Weight update...
# DISTANCE VALUES: MIN = 47.5, MAX = 1.53e+02 MEAN = 1.26e+02
# Log Denominateur: min = -68.1 (index = 220), max = -57.3 (index = 317)
# Log prior: min -5.56e+03 (index = 173), max = -50.85 (index = 317)
# Weights: min = 0.0 (index = 5), max = 0.125 (index = 317)
# ESS = 33 (3.305%)
# Resampling...
# Number of unique index:  0 2
# Number of unique particles: 198
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 11: Epsilon = 1.49e+02
# Std loc: min = 10.3, max = 13.7
# Std glob = 0.811
# Simulating...
# NUMBER OF SIMULATIONS: 1003350/15000000
# Number of simulations: 1.00E+04 (Accept rate 10.00000%)
# Weight update...
# DISTANCE VALUES: MIN = 34.6, MAX = 1.49e+02 MEAN = 1.2e+02
# Log Denominateur: min = -66.9 (index = 282), max = -55.0 (index = 780)
# Log prior: min -1.805e+03 (index = 656), max = -52.51 (index = 780)
# Weights: min = 0.0 (index = 0), max = 0.0339 (index = 607)
# ESS = 110 (11.004%)
# Resampling...
# Number of unique index:  2 3
# Number of unique particles: 261
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 12: Epsilon = 1.45e+02
# Std loc: min = 11.2, max = 13.9
# Std glob = 0.897
# Simulating...
# NUMBER OF SIMULATIONS: 1126665/15000000
# Number of simulations: 8.22E+03 (Accept rate 12.16397%)
# Weight update...
# DISTANCE VALUES: MIN = 46.3, MAX = 1.45e+02 MEAN = 1.19e+02
# Log Denominateur: min = -67.8 (index = 406), max = -57.1 (index = 250)
# Log prior: min -1.505e+03 (index = 539), max = -51.77 (index = 328)
# Weights: min = 0.0 (index = 116), max = 0.126 (index = 695)
# ESS = 32 (3.195%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 219
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 13: Epsilon = 1.43e+02
# Std loc: min = 10.8, max = 14.4
# Std glob = 1.09
# Simulating...
# NUMBER OF SIMULATIONS: 1233450/15000000
# Number of simulations: 7.12E+03 (Accept rate 14.04692%)
# Weight update...
# DISTANCE VALUES: MIN = 38.1, MAX = 1.43e+02 MEAN = 1.18e+02
# Log Denominateur: min = -69.5 (index = 705), max = -55.8 (index = 660)
# Log prior: min -1.883e+03 (index = 978), max = -51.87 (index = 577)
# Weights: min = 0.0 (index = 13), max = 0.0391 (index = 136)
# ESS = 85 (8.451%)
# Resampling...
# Number of unique index:  2 1
# Number of unique particles: 241
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 14: Epsilon = 1.41e+02
# Std loc: min = 11.2, max = 13.3
# Std glob = 1.01
# Simulating...
# NUMBER OF SIMULATIONS: 1371900/15000000
# Number of simulations: 9.23E+03 (Accept rate 10.83424%)
# Weight update...
# DISTANCE VALUES: MIN = 45.0, MAX = 1.41e+02 MEAN = 1.16e+02
# Log Denominateur: min = -69.2 (index = 291), max = -56.9 (index = 420)
# Log prior: min -751.0 (index = 90), max = -50.74 (index = 420)
# Weights: min = 0.0 (index = 90), max = 0.132 (index = 420)
# ESS = 38 (3.831%)
# Resampling...
# Number of unique index:  2 2
# Number of unique particles: 231
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 15: Epsilon = 1.39e+02
# Std loc: min = 10.2, max = 13.5
# Std glob = 0.931
# Simulating...
# NUMBER OF SIMULATIONS: 1453950/15000000
# Number of simulations: 5.47E+03 (Accept rate 18.28154%)
# Weight update...
# DISTANCE VALUES: MIN = 39.7, MAX = 1.39e+02 MEAN = 1.12e+02
# Log Denominateur: min = -67.7 (index = 115), max = -55.4 (index = 20)
# Log prior: min -7.99e+03 (index = 527), max = -52.18 (index = 282)
# Weights: min = 0.0 (index = 8), max = 0.0592 (index = 720)
# ESS = 67 (6.672%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 226
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 16: Epsilon = 1.37e+02
# Std loc: min = 11.5, max = 13.8
# Std glob = 0.962
# Simulating...
# NUMBER OF SIMULATIONS: 1578870/15000000
# Number of simulations: 8.33E+03 (Accept rate 12.00768%)
# Weight update...
# DISTANCE VALUES: MIN = 26.3, MAX = 1.37e+02 MEAN = 1.13e+02
# Log Denominateur: min = -67.9 (index = 821), max = -56.9 (index = 622)
# Log prior: min -1.939e+03 (index = 544), max = -52.33 (index = 622)
# Weights: min = 0.0 (index = 157), max = 0.0653 (index = 865)
# ESS = 69 (6.919%)
# Resampling...
# Number of unique index:  1 2
# Number of unique particles: 252
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 17: Epsilon = 1.33e+02
# Std loc: min = 11.6, max = 13.9
# Std glob = 0.922
# Simulating...
# NUMBER OF SIMULATIONS: 1710870/15000000
# Number of simulations: 8.80E+03 (Accept rate 11.36364%)
# Weight update...
# DISTANCE VALUES: MIN = 37.6, MAX = 1.33e+02 MEAN = 1.09e+02
# Log Denominateur: min = -67.5 (index = 990), max = -56.6 (index = 179)
# Log prior: min -1.097e+03 (index = 257), max = -52.07 (index = 179)
# Weights: min = 0.0 (index = 257), max = 0.0532 (index = 320)
# ESS = 68 (6.776%)
# Resampling...
# Number of unique index:  5 3
# Number of unique particles: 240
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 18: Epsilon = 1.32e+02
# Std loc: min = 11.1, max = 15.1
# Std glob = 0.915
# Simulating...
# NUMBER OF SIMULATIONS: 1833615/15000000
# Number of simulations: 8.18E+03 (Accept rate 12.22046%)
# Weight update...
# DISTANCE VALUES: MIN = 34.2, MAX = 1.32e+02 MEAN = 1.08e+02
# Log Denominateur: min = -67.7 (index = 830), max = -56.3 (index = 709)
# Log prior: min -1.233e+04 (index = 859), max = -53.12 (index = 490)
# Weights: min = 0.0 (index = 143), max = 0.0477 (index = 490)
# ESS = 81 (8.051%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 227
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 19: Epsilon = 1.31e+02
# Std loc: min = 10.3, max = 14.0
# Std glob = 1.08
# Simulating...
# NUMBER OF SIMULATIONS: 1986960/15000000
# Number of simulations: 1.02E+04 (Accept rate 9.78186%)
# Weight update...
# DISTANCE VALUES: MIN = 41.6, MAX = 1.31e+02 MEAN = 1.08e+02
# Log Denominateur: min = -67.0 (index = 557), max = -56.9 (index = 775)
# Log prior: min -1.729e+03 (index = 687), max = -50.95 (index = 24)
# Weights: min = 0.0 (index = 1), max = 0.147 (index = 24)
# ESS = 30 (3.020%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 216
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 20: Epsilon = 1.29e+02
# Std loc: min = 10.6, max = 14.2
# Std glob = 0.774
# Simulating...
# NUMBER OF SIMULATIONS: 2127300/15000000
# Number of simulations: 9.36E+03 (Accept rate 10.68833%)
# Weight update...
# DISTANCE VALUES: MIN = 36.9, MAX = 1.29e+02 MEAN = 1.07e+02
# Log Denominateur: min = -67.5 (index = 777), max = -54.7 (index = 989)
# Log prior: min -747.1 (index = 321), max = -51.02 (index = 332)
# Weights: min = 0.0 (index = 237), max = 0.0495 (index = 184)
# ESS = 86 (8.553%)
# Resampling...
# Number of unique index:  0 2
# Number of unique particles: 277
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 21: Epsilon = 1.27e+02
# Std loc: min = 11.3, max = 12.9
# Std glob = 0.981
# Simulating...
# NUMBER OF SIMULATIONS: 2251935/15000000
# Number of simulations: 8.31E+03 (Accept rate 12.03514%)
# Weight update...
# DISTANCE VALUES: MIN = 27.9, MAX = 1.27e+02 MEAN = 1.05e+02
# Log Denominateur: min = -67.6 (index = 731), max = -56.2 (index = 993)
# Log prior: min -2.431e+03 (index = 354), max = -52.1 (index = 356)
# Weights: min = 0.0 (index = 32), max = 0.0584 (index = 356)
# ESS = 94 (9.364%)
# Resampling...
# Number of unique index:  1 2
# Number of unique particles: 283
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 22: Epsilon = 1.24e+02
# Std loc: min = 10.7, max = 13.4
# Std glob = 1.1
# Simulating...
# NUMBER OF SIMULATIONS: 2406960/15000000
# Number of simulations: 1.03E+04 (Accept rate 9.67586%)
# Weight update...
# DISTANCE VALUES: MIN = 30.1, MAX = 1.24e+02 MEAN = 1.03e+02
# Log Denominateur: min = -68.8 (index = 229), max = -56.9 (index = 752)
# Log prior: min -862.3 (index = 482), max = -53.41 (index = 306)
# Weights: min = 0.0 (index = 65), max = 0.0418 (index = 830)
# ESS = 99 (9.870%)
# Resampling...
# Number of unique index:  1 1
# Number of unique particles: 265
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 23: Epsilon = 1.23e+02
# Std loc: min = 11.6, max = 14.2
# Std glob = 1.05
# Simulating...
# NUMBER OF SIMULATIONS: 2587170/15000000
# Number of simulations: 1.20E+04 (Accept rate 8.32362%)
# Weight update...
# DISTANCE VALUES: MIN = 39.7, MAX = 1.23e+02 MEAN = 1.02e+02
# Log Denominateur: min = -67.0 (index = 108), max = -57.1 (index = 347)
# Log prior: min -330.5 (index = 717), max = -51.98 (index = 995)
# Weights: min = 0.0 (index = 89), max = 0.0967 (index = 995)
# ESS = 44 (4.371%)
# Resampling...
# Number of unique index:  1 2
# Number of unique particles: 182
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 24: Epsilon = 1.21e+02
# Std loc: min = 10.7, max = 14.2
# Std glob = 0.811
# Simulating...
# NUMBER OF SIMULATIONS: 2752170/15000000
# Number of simulations: 1.10E+04 (Accept rate 9.09091%)
# Weight update...
# DISTANCE VALUES: MIN = 27.2, MAX = 1.21e+02 MEAN = 99.5
# Log Denominateur: min = -66.3 (index = 639), max = -55.7 (index = 607)
# Log prior: min -2.331e+03 (index = 875), max = -50.49 (index = 607)
# Weights: min = 0.0 (index = 40), max = 0.0658 (index = 607)
# ESS = 75 (7.509%)
# Resampling...
# Number of unique index:  8 15
# Number of unique particles: 239
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 25: Epsilon = 1.18e+02
# Std loc: min = 10.4, max = 13.0
# Std glob = 0.983
# Simulating...
# NUMBER OF SIMULATIONS: 2900235/15000000
# Number of simulations: 9.87E+03 (Accept rate 10.13069%)
# Weight update...
# DISTANCE VALUES: MIN = 42.0, MAX = 1.18e+02 MEAN = 98.4
# Log Denominateur: min = -68.1 (index = 37), max = -55.7 (index = 4)
# Log prior: min -358.6 (index = 669), max = -51.35 (index = 588)
# Weights: min = 0.0 (index = 192), max = 0.0506 (index = 588)
# ESS = 102 (10.161%)
# Resampling...
# Number of unique index:  0 2
# Number of unique particles: 271
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 26: Epsilon = 1.15e+02
# Std loc: min = 10.4, max = 13.6
# Std glob = 0.936
# Simulating...
# NUMBER OF SIMULATIONS: 3069555/15000000
# Number of simulations: 1.13E+04 (Accept rate 8.85897%)
# Weight update...
# DISTANCE VALUES: MIN = 34.8, MAX = 1.15e+02 MEAN = 96.9
# Log Denominateur: min = -67.8 (index = 270), max = -56.0 (index = 277)
# Log prior: min -376.6 (index = 749), max = -51.21 (index = 519)
# Weights: min = 0.0 (index = 22), max = 0.0573 (index = 519)
# ESS = 69 (6.931%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 255
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 27: Epsilon = 1.13e+02
# Std loc: min = 10.4, max = 13.2
# Std glob = 0.887
# Simulating...
# NUMBER OF SIMULATIONS: 3225945/15000000
# Number of simulations: 1.04E+04 (Accept rate 9.59141%)
# Weight update...
# DISTANCE VALUES: MIN = 41.7, MAX = 1.13e+02 MEAN = 94.1
# Log Denominateur: min = -66.5 (index = 690), max = -55.6 (index = 723)
# Log prior: min -707.5 (index = 563), max = -51.23 (index = 531)
# Weights: min = 0.0 (index = 75), max = 0.0592 (index = 531)
# ESS = 63 (6.281%)
# Resampling...
# Number of unique index:  1 9
# Number of unique particles: 246
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 28: Epsilon = 1.13e+02
# Std loc: min = 10.1, max = 13.0
# Std glob = 0.844
# Simulating...
# NUMBER OF SIMULATIONS: 3375885/15000000
# Number of simulations: 1.00E+04 (Accept rate 10.00400%)
# Weight update...
# DISTANCE VALUES: MIN = 27.9, MAX = 1.13e+02 MEAN = 93.8
# Log Denominateur: min = -65.2 (index = 119), max = -55.6 (index = 401)
# Log prior: min -1.068e+04 (index = 779), max = -52.17 (index = 623)
# Weights: min = 0.0 (index = 68), max = 0.0376 (index = 654)
# ESS = 113 (11.327%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 285
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 29: Epsilon = 1.11e+02
# Std loc: min = 11.3, max = 13.7
# Std glob = 0.94
# Simulating...
# NUMBER OF SIMULATIONS: 3550830/15000000
# Number of simulations: 1.17E+04 (Accept rate 8.57412%)
# Weight update...
# DISTANCE VALUES: MIN = 33.9, MAX = 1.11e+02 MEAN = 91.6
# Log Denominateur: min = -69.2 (index = 929), max = -56.5 (index = 327)
# Log prior: min -3.179e+03 (index = 332), max = -50.78 (index = 73)
# Weights: min = 0.0 (index = 180), max = 0.135 (index = 73)
# ESS = 30 (3.000%)
# Resampling...
# Number of unique index:  2 8
# Number of unique particles: 225
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 30: Epsilon = 1.1e+02
# Std loc: min = 9.49, max = 13.5
# Std glob = 1.0
# Simulating...
# NUMBER OF SIMULATIONS: 3715245/15000000
# Number of simulations: 1.10E+04 (Accept rate 9.12326%)
# Weight update...
# DISTANCE VALUES: MIN = 20.6, MAX = 1.1e+02 MEAN = 91.0
# Log Denominateur: min = -66.9 (index = 833), max = -54.0 (index = 217)
# Log prior: min -3.905e+03 (index = 456), max = -49.95 (index = 338)
# Weights: min = 0.0 (index = 20), max = 0.081 (index = 333)
# ESS = 55 (5.519%)
# Resampling...
# Number of unique index:  2 16
# Number of unique particles: 282
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 31: Epsilon = 1.09e+02
# Std loc: min = 9.93, max = 12.5
# Std glob = 0.873
# Simulating...
# NUMBER OF SIMULATIONS: 3858360/15000000
# Number of simulations: 9.54E+03 (Accept rate 10.48108%)
# Weight update...
# DISTANCE VALUES: MIN = 24.2, MAX = 1.09e+02 MEAN = 89.4
# Log Denominateur: min = -66.8 (index = 823), max = -54.3 (index = 268)
# Log prior: min -867.8 (index = 271), max = -51.7 (index = 600)
# Weights: min = 0.0 (index = 15), max = 0.0337 (index = 928)
# ESS = 129 (12.861%)
# Resampling...
# Number of unique index:  4 5
# Number of unique particles: 292
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 32: Epsilon = 1.08e+02
# Std loc: min = 10.6, max = 12.5
# Std glob = 1.03
# Simulating...
# NUMBER OF SIMULATIONS: 4028175/15000000
# Number of simulations: 1.13E+04 (Accept rate 8.83314%)
# Weight update...
# DISTANCE VALUES: MIN = 41.6, MAX = 1.08e+02 MEAN = 89.6
# Log Denominateur: min = -67.2 (index = 420), max = -56.1 (index = 297)
# Log prior: min -1.738e+03 (index = 305), max = -51.48 (index = 453)
# Weights: min = 0.0 (index = 126), max = 0.0647 (index = 453)
# ESS = 77 (7.726%)
# Resampling...
# Number of unique index:  1 22
# Number of unique particles: 239
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 33: Epsilon = 1.06e+02
# Std loc: min = 10.4, max = 12.4
# Std glob = 0.943
# Simulating...
# NUMBER OF SIMULATIONS: 4181310/15000000
# Number of simulations: 1.02E+04 (Accept rate 9.79528%)
# Weight update...
# DISTANCE VALUES: MIN = 26.5, MAX = 1.06e+02 MEAN = 87.5
# Log Denominateur: min = -65.8 (index = 834), max = -55.2 (index = 541)
# Log prior: min -556.5 (index = 465), max = -51.16 (index = 406)
# Weights: min = 0.0 (index = 188), max = 0.0891 (index = 406)
# ESS = 59 (5.915%)
# Resampling...
# Number of unique index:  6 2
# Number of unique particles: 258
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 34: Epsilon = 1.04e+02
# Std loc: min = 10.2, max = 12.3
# Std glob = 0.995
# Simulating...
# NUMBER OF SIMULATIONS: 4339065/15000000
# Number of simulations: 1.05E+04 (Accept rate 9.50841%)
# Weight update...
# DISTANCE VALUES: MIN = 24.3, MAX = 1.04e+02 MEAN = 86.6
# Log Denominateur: min = -67.8 (index = 394), max = -54.5 (index = 292)
# Log prior: min -2.177e+03 (index = 151), max = -50.77 (index = 938)
# Weights: min = 0.0 (index = 5), max = 0.0552 (index = 891)
# ESS = 73 (7.264%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 253
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 35: Epsilon = 1.02e+02
# Std loc: min = 9.61, max = 12.2
# Std glob = 0.894
# Simulating...
# NUMBER OF SIMULATIONS: 4506690/15000000
# Number of simulations: 1.12E+04 (Accept rate 8.94855%)
# Weight update...
# DISTANCE VALUES: MIN = 29.6, MAX = 1.02e+02 MEAN = 84.8
# Log Denominateur: min = -65.8 (index = 922), max = -54.2 (index = 314)
# Log prior: min -1.035e+03 (index = 339), max = -50.2 (index = 314)
# Weights: min = 0.0 (index = 157), max = 0.0428 (index = 670)
# ESS = 80 (8.035%)
# Resampling...
# Number of unique index:  4 1
# Number of unique particles: 295
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 36: Epsilon = 1.01e+02
# Std loc: min = 10.2, max = 12.2
# Std glob = 0.932
# Simulating...
# NUMBER OF SIMULATIONS: 4712925/15000000
# Number of simulations: 1.37E+04 (Accept rate 7.27326%)
# Weight update...
# DISTANCE VALUES: MIN = 30.1, MAX = 1.01e+02 MEAN = 84.2
# Log Denominateur: min = -64.9 (index = 639), max = -55.5 (index = 29)
# Log prior: min -558.8 (index = 360), max = -51.66 (index = 42)
# Weights: min = 0.0 (index = 9), max = 0.0427 (index = 243)
# ESS = 100 (10.003%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 288
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 37: Epsilon = 98.5
# Std loc: min = 10.5, max = 12.9
# Std glob = 0.838
# Simulating...
# NUMBER OF SIMULATIONS: 4898715/15000000
# Number of simulations: 1.24E+04 (Accept rate 8.07363%)
# Weight update...
# DISTANCE VALUES: MIN = 20.8, MAX = 98.5 MEAN = 81.8
# Log Denominateur: min = -66.1 (index = 622), max = -55.2 (index = 426)
# Log prior: min -542.1 (index = 725), max = -51.11 (index = 205)
# Weights: min = 0.0 (index = 45), max = 0.0761 (index = 205)
# ESS = 68 (6.758%)
# Resampling...
# Number of unique index:  2 1
# Number of unique particles: 257
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 38: Epsilon = 97.4
# Std loc: min = 10.1, max = 13.8
# Std glob = 1.08
# Simulating...
# NUMBER OF SIMULATIONS: 5104815/15000000
# Number of simulations: 1.37E+04 (Accept rate 7.27802%)
# Weight update...
# DISTANCE VALUES: MIN = 28.4, MAX = 97.4 MEAN = 80.8
# Log Denominateur: min = -66.1 (index = 996), max = -54.7 (index = 21)
# Log prior: min -1.503e+03 (index = 673), max = -50.96 (index = 491)
# Weights: min = 0.0 (index = 184), max = 0.095 (index = 491)
# ESS = 55 (5.473%)
# Resampling...
# Number of unique index:  1 1
# Number of unique particles: 249
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 39: Epsilon = 96.5
# Std loc: min = 9.84, max = 12.4
# Std glob = 0.854
# Simulating...
# NUMBER OF SIMULATIONS: 5293905/15000000
# Number of simulations: 1.26E+04 (Accept rate 7.93273%)
# Weight update...
# DISTANCE VALUES: MIN = 25.7, MAX = 96.5 MEAN = 80.7
# Log Denominateur: min = -66.0 (index = 417), max = -54.5 (index = 741)
# Log prior: min -1.263e+05 (index = 158), max = -51.66 (index = 171)
# Weights: min = 0.0 (index = 60), max = 0.0383 (index = 62)
# ESS = 92 (9.192%)
# Resampling...
# Number of unique index:  4 5
# Number of unique particles: 276
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 40: Epsilon = 96.0
# Std loc: min = 9.67, max = 12.6
# Std glob = 0.946
# Simulating...
# NUMBER OF SIMULATIONS: 5480430/15000000
# Number of simulations: 1.24E+04 (Accept rate 8.04182%)
# Weight update...
# DISTANCE VALUES: MIN = 30.6, MAX = 96.0 MEAN = 79.1
# Log Denominateur: min = -65.4 (index = 480), max = -54.7 (index = 24)
# Log prior: min -806.3 (index = 579), max = -50.56 (index = 401)
# Weights: min = 0.0 (index = 110), max = 0.0794 (index = 401)
# ESS = 59 (5.924%)
# Resampling...
# Number of unique index:  2 2
# Number of unique particles: 270
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 41: Epsilon = 94.1
# Std loc: min = 9.71, max = 13.0
# Std glob = 1.1
# Simulating...
# NUMBER OF SIMULATIONS: 5662575/15000000
# Number of simulations: 1.21E+04 (Accept rate 8.23520%)
# Weight update...
# DISTANCE VALUES: MIN = 26.0, MAX = 94.1 MEAN = 78.4
# Log Denominateur: min = -66.6 (index = 907), max = -54.0 (index = 177)
# Log prior: min -1.315e+03 (index = 343), max = -50.79 (index = 411)
# Weights: min = 0.0 (index = 143), max = 0.0465 (index = 45)
# ESS = 102 (10.243%)
# Resampling...
# Number of unique index:  0 3
# Number of unique particles: 285
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 42: Epsilon = 92.6
# Std loc: min = 10.2, max = 11.9
# Std glob = 0.896
# Simulating...
# NUMBER OF SIMULATIONS: 5877600/15000000
# Number of simulations: 1.43E+04 (Accept rate 6.97593%)
# Weight update...
# DISTANCE VALUES: MIN = 22.7, MAX = 92.5 MEAN = 77.8
# Log Denominateur: min = -64.8 (index = 214), max = -54.9 (index = 853)
# Log prior: min -5.018e+03 (index = 969), max = -50.72 (index = 139)
# Weights: min = 0.0 (index = 25), max = 0.085 (index = 139)
# ESS = 48 (4.805%)
# Resampling...
# Number of unique index:  5 3
# Number of unique particles: 232
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 43: Epsilon = 91.6
# Std loc: min = 9.92, max = 11.8
# Std glob = 0.931
# Simulating...
# NUMBER OF SIMULATIONS: 6080475/15000000
# Number of simulations: 1.35E+04 (Accept rate 7.39372%)
# Weight update...
# DISTANCE VALUES: MIN = 25.5, MAX = 91.6 MEAN = 76.7
# Log Denominateur: min = -64.3 (index = 662), max = -53.4 (index = 759)
# Log prior: min -1.748e+03 (index = 177), max = -49.93 (index = 510)
# Weights: min = 0.0 (index = 99), max = 0.073 (index = 510)
# ESS = 88 (8.777%)
# Resampling...
# Number of unique index:  1 2
# Number of unique particles: 296
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 44: Epsilon = 90.7
# Std loc: min = 9.81, max = 12.1
# Std glob = 0.785
# Simulating...
# NUMBER OF SIMULATIONS: 6280500/15000000
# Number of simulations: 1.33E+04 (Accept rate 7.49906%)
# Weight update...
# DISTANCE VALUES: MIN = 21.2, MAX = 90.7 MEAN = 76.2
# Log Denominateur: min = -65.2 (index = 652), max = -54.4 (index = 919)
# Log prior: min -3.228e+03 (index = 397), max = -51.0 (index = 376)
# Weights: min = 0.0 (index = 17), max = 0.0442 (index = 376)
# ESS = 113 (11.337%)
# Resampling...
# Number of unique index:  3 3
# Number of unique particles: 297
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 45: Epsilon = 90.0
# Std loc: min = 10.1, max = 12.1
# Std glob = 0.858
# Simulating...
# NUMBER OF SIMULATIONS: 6480495/15000000
# Number of simulations: 1.33E+04 (Accept rate 7.50019%)
# Weight update...
# DISTANCE VALUES: MIN = 27.7, MAX = 90.0 MEAN = 75.3
# Log Denominateur: min = -64.0 (index = 133), max = -54.9 (index = 793)
# Log prior: min -6.337e+03 (index = 581), max = -51.58 (index = 39)
# Weights: min = 0.0 (index = 22), max = 0.0543 (index = 39)
# ESS = 91 (9.069%)
# Resampling...
# Number of unique index:  7 1
# Number of unique particles: 289
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 46: Epsilon = 89.9
# Std loc: min = 10.1, max = 12.4
# Std glob = 0.786
# Simulating...
# NUMBER OF SIMULATIONS: 6683580/15000000
# Number of simulations: 1.35E+04 (Accept rate 7.38607%)
# Weight update...
# DISTANCE VALUES: MIN = 20.1, MAX = 89.8 MEAN = 74.6
# Log Denominateur: min = -64.2 (index = 57), max = -54.8 (index = 640)
# Log prior: min -638.3 (index = 115), max = -50.9 (index = 186)
# Weights: min = 0.0 (index = 13), max = 0.0602 (index = 186)
# ESS = 73 (7.292%)
# Resampling...
# Number of unique index:  1 4
# Number of unique particles: 265
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 47: Epsilon = 89.4
# Std loc: min = 9.41, max = 12.0
# Std glob = 0.723
# Simulating...
# NUMBER OF SIMULATIONS: 6896085/15000000
# Number of simulations: 1.42E+04 (Accept rate 7.05866%)
# Weight update...
# DISTANCE VALUES: MIN = 26.3, MAX = 89.4 MEAN = 74.9
# Log Denominateur: min = -65.0 (index = 455), max = -54.4 (index = 973)
# Log prior: min -1.484e+03 (index = 238), max = -51.14 (index = 973)
# Weights: min = 0.0 (index = 23), max = 0.0447 (index = 415)
# ESS = 93 (9.270%)
# Resampling...
# Number of unique index:  0 4
# Number of unique particles: 284
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 48: Epsilon = 87.9
# Std loc: min = 9.39, max = 12.3
# Std glob = 1.44
# Simulating...
# NUMBER OF SIMULATIONS: 7139355/15000000
# Number of simulations: 1.62E+04 (Accept rate 6.16599%)
# Weight update...
# DISTANCE VALUES: MIN = 18.3, MAX = 87.9 MEAN = 74.3
# Log Denominateur: min = -66.7 (index = 81), max = -55.1 (index = 388)
# Log prior: min -426.2 (index = 65), max = -51.54 (index = 779)
# Weights: min = 0.0 (index = 65), max = 0.0605 (index = 887)
# ESS = 53 (5.284%)
# Resampling...
# Number of unique index:  2 1
# Number of unique particles: 219
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 49: Epsilon = 86.9
# Std loc: min = 9.37, max = 12.8
# Std glob = 0.869
# Simulating...
# NUMBER OF SIMULATIONS: 7373460/15000000
# Number of simulations: 1.56E+04 (Accept rate 6.40738%)
# Weight update...
# DISTANCE VALUES: MIN = 30.6, MAX = 86.9 MEAN = 72.9
# Log Denominateur: min = -64.6 (index = 809), max = -54.3 (index = 48)
# Log prior: min -1.247e+03 (index = 648), max = -50.87 (index = 283)
# Weights: min = 0.0 (index = 290), max = 0.0434 (index = 283)
# ESS = 107 (10.668%)
# Resampling...
# Number of unique index:  12 2
# Number of unique particles: 286
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 50: Epsilon = 86.0
# Std loc: min = 9.48, max = 12.4
# Std glob = 0.771
# Simulating...
# NUMBER OF SIMULATIONS: 7588530/15000000
# Number of simulations: 1.43E+04 (Accept rate 6.97447%)
# Weight update...
# DISTANCE VALUES: MIN = 27.9, MAX = 86.0 MEAN = 71.8
# Log Denominateur: min = -64.9 (index = 333), max = -54.5 (index = 486)
# Log prior: min -3.274e+03 (index = 518), max = -51.51 (index = 520)
# Weights: min = 0.0 (index = 85), max = 0.0447 (index = 520)
# ESS = 127 (12.655%)
# Resampling...
# Number of unique index:  1 3
# Number of unique particles: 305
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 51: Epsilon = 84.4
# Std loc: min = 9.97, max = 11.8
# Std glob = 0.858
# Simulating...
# NUMBER OF SIMULATIONS: 7827540/15000000
# Number of simulations: 1.59E+04 (Accept rate 6.27589%)
# Weight update...
# DISTANCE VALUES: MIN = 36.9, MAX = 84.4 MEAN = 70.9
# Log Denominateur: min = -64.8 (index = 80), max = -54.2 (index = 459)
# Log prior: min -1.552e+03 (index = 313), max = -50.91 (index = 146)
# Weights: min = 0.0 (index = 31), max = 0.108 (index = 146)
# ESS = 54 (5.435%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 278
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 52: Epsilon = 82.9
# Std loc: min = 9.3, max = 12.6
# Std glob = 1.09
# Simulating...
# NUMBER OF SIMULATIONS: 8099430/15000000
# Number of simulations: 1.81E+04 (Accept rate 5.51694%)
# Weight update...
# DISTANCE VALUES: MIN = 29.4, MAX = 82.8 MEAN = 69.8
# Log Denominateur: min = -64.8 (index = 264), max = -54.6 (index = 495)
# Log prior: min -1.437e+03 (index = 737), max = -51.22 (index = 967)
# Weights: min = 0.0 (index = 62), max = 0.0435 (index = 384)
# ESS = 76 (7.575%)
# Resampling...
# Number of unique index:  1 4
# Number of unique particles: 245
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 53: Epsilon = 82.5
# Std loc: min = 9.4, max = 12.7
# Std glob = 0.83
# Simulating...
# NUMBER OF SIMULATIONS: 8341365/15000000
# Number of simulations: 1.61E+04 (Accept rate 6.20001%)
# Weight update...
# DISTANCE VALUES: MIN = 29.7, MAX = 82.4 MEAN = 68.4
# Log Denominateur: min = -66.6 (index = 893), max = -54.2 (index = 77)
# Log prior: min -7.085e+03 (index = 631), max = -50.92 (index = 475)
# Weights: min = 0.0 (index = 122), max = 0.105 (index = 475)
# ESS = 47 (4.675%)
# Resampling...
# Number of unique index:  0 2
# Number of unique particles: 291
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 54: Epsilon = 81.3
# Std loc: min = 9.51, max = 11.6
# Std glob = 0.85
# Simulating...
# NUMBER OF SIMULATIONS: 8559375/15000000
# Number of simulations: 1.45E+04 (Accept rate 6.88042%)
# Weight update...
# DISTANCE VALUES: MIN = 18.1, MAX = 81.3 MEAN = 68.4
# Log Denominateur: min = -65.5 (index = 516), max = -53.8 (index = 613)
# Log prior: min -2.932e+03 (index = 110), max = -51.73 (index = 811)
# Weights: min = 0.0 (index = 18), max = 0.0322 (index = 811)
# ESS = 120 (12.019%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 265
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 55: Epsilon = 80.9
# Std loc: min = 9.4, max = 11.7
# Std glob = 0.893
# Simulating...
# NUMBER OF SIMULATIONS: 8757555/15000000
# Number of simulations: 1.32E+04 (Accept rate 7.56888%)
# Weight update...
# DISTANCE VALUES: MIN = 24.2, MAX = 80.9 MEAN = 68.1
# Log Denominateur: min = -68.0 (index = 399), max = -54.5 (index = 653)
# Log prior: min -7.472e+03 (index = 618), max = -52.69 (index = 303)
# Weights: min = 0.0 (index = 129), max = 0.0301 (index = 303)
# ESS = 145 (14.453%)
# Resampling...
# Number of unique index:  4 1
# Number of unique particles: 301
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 56: Epsilon = 80.2
# Std loc: min = 10.2, max = 11.8
# Std glob = 1.24
# Simulating...
# NUMBER OF SIMULATIONS: 9028020/15000000
# Number of simulations: 1.80E+04 (Accept rate 5.54600%)
# Weight update...
# DISTANCE VALUES: MIN = 16.7, MAX = 80.1 MEAN = 67.1
# Log Denominateur: min = -66.5 (index = 210), max = -55.0 (index = 36)
# Log prior: min -7.647e+03 (index = 18), max = -52.39 (index = 95)
# Weights: min = 0.0 (index = 18), max = 0.0338 (index = 780)
# ESS = 88 (8.844%)
# Resampling...
# Number of unique index:  3 7
# Number of unique particles: 250
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 57: Epsilon = 78.9
# Std loc: min = 9.33, max = 12.5
# Std glob = 0.981
# Simulating...
# NUMBER OF SIMULATIONS: 9267375/15000000
# Number of simulations: 1.60E+04 (Accept rate 6.26684%)
# Weight update...
# DISTANCE VALUES: MIN = 16.2, MAX = 78.9 MEAN = 66.2
# Log Denominateur: min = -65.0 (index = 330), max = -54.0 (index = 409)
# Log prior: min -2.784e+03 (index = 670), max = -51.51 (index = 409)
# Weights: min = 0.0 (index = 24), max = 0.0381 (index = 455)
# ESS = 96 (9.621%)
# Resampling...
# Number of unique index:  4 2
# Number of unique particles: 274
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 58: Epsilon = 78.5
# Std loc: min = 9.01, max = 12.1
# Std glob = 0.902
# Simulating...
# NUMBER OF SIMULATIONS: 9494385/15000000
# Number of simulations: 1.51E+04 (Accept rate 6.60764%)
# Weight update...
# DISTANCE VALUES: MIN = 26.0, MAX = 78.5 MEAN = 65.3
# Log Denominateur: min = -65.6 (index = 940), max = -54.2 (index = 679)
# Log prior: min -599.2 (index = 869), max = -51.6 (index = 569)
# Weights: min = 0.0 (index = 90), max = 0.0428 (index = 569)
# ESS = 99 (9.903%)
# Resampling...
# Number of unique index:  5 3
# Number of unique particles: 276
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 59: Epsilon = 77.8
# Std loc: min = 9.87, max = 12.4
# Std glob = 1.34
# Simulating...
# NUMBER OF SIMULATIONS: 9774600/15000000
# Number of simulations: 1.87E+04 (Accept rate 5.35303%)
# Weight update...
# DISTANCE VALUES: MIN = 27.8, MAX = 77.7 MEAN = 65.7
# Log Denominateur: min = -63.6 (index = 330), max = -54.9 (index = 522)
# Log prior: min -1.799e+03 (index = 371), max = -52.36 (index = 967)
# Weights: min = 0.0 (index = 55), max = 0.0515 (index = 248)
# ESS = 73 (7.298%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 242
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 60: Epsilon = 76.9
# Std loc: min = 8.86, max = 12.3
# Std glob = 0.81
# Simulating...
# NUMBER OF SIMULATIONS: 10063035/15000000
# Number of simulations: 1.92E+04 (Accept rate 5.20048%)
# Weight update...
# DISTANCE VALUES: MIN = 16.3, MAX = 76.9 MEAN = 64.4
# Log Denominateur: min = -67.3 (index = 869), max = -54.1 (index = 20)
# Log prior: min -511.4 (index = 758), max = -52.05 (index = 49)
# Weights: min = 0.0 (index = 87), max = 0.0462 (index = 983)
# ESS = 96 (9.583%)
# Resampling...
# Number of unique index:  7 12
# Number of unique particles: 301
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 61: Epsilon = 75.8
# Std loc: min = 9.32, max = 12.1
# Std glob = 0.751
# Simulating...
# NUMBER OF SIMULATIONS: 10340985/15000000
# Number of simulations: 1.85E+04 (Accept rate 5.39665%)
# Weight update...
# DISTANCE VALUES: MIN = 26.6, MAX = 75.8 MEAN = 63.6
# Log Denominateur: min = -63.9 (index = 453), max = -53.9 (index = 688)
# Log prior: min -739.2 (index = 353), max = -51.84 (index = 970)
# Weights: min = 0.0 (index = 71), max = 0.0391 (index = 970)
# ESS = 111 (11.113%)
# Resampling...
# Number of unique index:  0 2
# Number of unique particles: 281
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 62: Epsilon = 75.2
# Std loc: min = 9.56, max = 11.5
# Std glob = 0.749
# Simulating...
# NUMBER OF SIMULATIONS: 10591605/15000000
# Number of simulations: 1.67E+04 (Accept rate 5.98516%)
# Weight update...
# DISTANCE VALUES: MIN = 23.5, MAX = 75.2 MEAN = 63.4
# Log Denominateur: min = -64.9 (index = 570), max = -54.0 (index = 709)
# Log prior: min -1.708e+03 (index = 476), max = -51.77 (index = 724)
# Weights: min = 0.0 (index = 5), max = 0.0455 (index = 724)
# ESS = 114 (11.439%)
# Resampling...
# Number of unique index:  7 1
# Number of unique particles: 307
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 63: Epsilon = 74.1
# Std loc: min = 9.59, max = 11.5
# Std glob = 0.97
# Simulating...
# NUMBER OF SIMULATIONS: 10851885/15000000
# Number of simulations: 1.74E+04 (Accept rate 5.76302%)
# Weight update...
# DISTANCE VALUES: MIN = 26.1, MAX = 74.1 MEAN = 62.1
# Log Denominateur: min = -63.4 (index = 865), max = -54.3 (index = 811)
# Log prior: min -2.114e+03 (index = 476), max = -51.18 (index = 60)
# Weights: min = 0.0 (index = 128), max = 0.0559 (index = 60)
# ESS = 77 (7.650%)
# Resampling...
# Number of unique index:  1 1
# Number of unique particles: 276
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 64: Epsilon = 73.5
# Std loc: min = 9.05, max = 11.4
# Std glob = 0.906
# Simulating...
# NUMBER OF SIMULATIONS: 11113965/15000000
# Number of simulations: 1.75E+04 (Accept rate 5.72344%)
# Weight update...
# DISTANCE VALUES: MIN = 26.4, MAX = 73.5 MEAN = 62.3
# Log Denominateur: min = -63.9 (index = 139), max = -53.1 (index = 780)
# Log prior: min -1.041e+03 (index = 525), max = -51.86 (index = 121)
# Weights: min = 0.0 (index = 32), max = 0.0302 (index = 671)
# ESS = 135 (13.548%)
# Resampling...
# Number of unique index:  1 10
# Number of unique particles: 294
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 65: Epsilon = 73.0
# Std loc: min = 9.65, max = 11.4
# Std glob = 0.905
# Simulating...
# NUMBER OF SIMULATIONS: 11390220/15000000
# Number of simulations: 1.84E+04 (Accept rate 5.42977%)
# Weight update...
# DISTANCE VALUES: MIN = 22.9, MAX = 72.9 MEAN = 61.1
# Log Denominateur: min = -65.1 (index = 581), max = -54.3 (index = 356)
# Log prior: min -1.96e+03 (index = 106), max = -52.49 (index = 356)
# Weights: min = 0.0 (index = 18), max = 0.0313 (index = 194)
# ESS = 130 (13.019%)
# Resampling...
# Number of unique index:  7 2
# Number of unique particles: 296
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 66: Epsilon = 71.8
# Std loc: min = 9.7, max = 11.6
# Std glob = 0.874
# Simulating...
# NUMBER OF SIMULATIONS: 11660325/15000000
# Number of simulations: 1.80E+04 (Accept rate 5.55340%)
# Weight update...
# DISTANCE VALUES: MIN = 22.6, MAX = 71.8 MEAN = 60.3
# Log Denominateur: min = -64.0 (index = 510), max = -54.1 (index = 275)
# Log prior: min -868.5 (index = 102), max = -52.1 (index = 46)
# Weights: min = 0.0 (index = 17), max = 0.0284 (index = 898)
# ESS = 110 (11.047%)
# Resampling...
# Number of unique index:  1 6
# Number of unique particles: 281
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 67: Epsilon = 71.2
# Std loc: min = 8.91, max = 12.2
# Std glob = 0.935
# Simulating...
# NUMBER OF SIMULATIONS: 11928120/15000000
# Number of simulations: 1.79E+04 (Accept rate 5.60130%)
# Weight update...
# DISTANCE VALUES: MIN = 18.8, MAX = 71.2 MEAN = 59.7
# Log Denominateur: min = -63.4 (index = 583), max = -54.4 (index = 115)
# Log prior: min -1.248e+03 (index = 433), max = -52.64 (index = 941)
# Weights: min = 0.0 (index = 21), max = 0.0327 (index = 941)
# ESS = 132 (13.193%)
# Resampling...
# Number of unique index:  2 1
# Number of unique particles: 303
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 68: Epsilon = 69.7
# Std loc: min = 9.54, max = 11.6
# Std glob = 1.06
# Simulating...
# NUMBER OF SIMULATIONS: 12299370/15000000
# Number of simulations: 2.48E+04 (Accept rate 4.04040%)
# Weight update...
# DISTANCE VALUES: MIN = 22.1, MAX = 69.7 MEAN = 58.4
# Log Denominateur: min = -64.7 (index = 973), max = -54.3 (index = 945)
# Log prior: min -475.1 (index = 517), max = -51.48 (index = 945)
# Weights: min = 0.0 (index = 120), max = 0.0442 (index = 945)
# ESS = 77 (7.676%)
# Resampling...
# Number of unique index:  8 1
# Number of unique particles: 255
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 69: Epsilon = 69.0
# Std loc: min = 8.4, max = 10.8
# Std glob = 0.921
# Simulating...
# NUMBER OF SIMULATIONS: 12700455/15000000
# Number of simulations: 2.67E+04 (Accept rate 3.73986%)
# Weight update...
# DISTANCE VALUES: MIN = 25.5, MAX = 69.0 MEAN = 57.9
# Log Denominateur: min = -67.1 (index = 182), max = -52.6 (index = 421)
# Log prior: min -1.296e+03 (index = 579), max = -51.72 (index = 812)
# Weights: min = 0.0 (index = 86), max = 0.0371 (index = 812)
# ESS = 113 (11.350%)
# Resampling...
# Number of unique index:  3 2
# Number of unique particles: 311
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 70: Epsilon = 68.4
# Std loc: min = 9.42, max = 10.9
# Std glob = 0.866
# Simulating...
# NUMBER OF SIMULATIONS: 12962760/15000000
# Number of simulations: 1.75E+04 (Accept rate 5.71853%)
# Weight update...
# DISTANCE VALUES: MIN = 23.4, MAX = 68.4 MEAN = 57.3
# Log Denominateur: min = -62.7 (index = 632), max = -53.5 (index = 247)
# Log prior: min -6.677e+03 (index = 128), max = -51.52 (index = 585)
# Weights: min = 0.0 (index = 57), max = 0.0385 (index = 39)
# ESS = 111 (11.143%)
# Resampling...
# Number of unique index:  4 2
# Number of unique particles: 287
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 71: Epsilon = 67.8
# Std loc: min = 8.85, max = 11.4
# Std glob = 0.893
# Simulating...
# NUMBER OF SIMULATIONS: 13208280/15000000
# Number of simulations: 1.64E+04 (Accept rate 6.10948%)
# Weight update...
# DISTANCE VALUES: MIN = 11.6, MAX = 67.8 MEAN = 57.1
# Log Denominateur: min = -63.6 (index = 251), max = -53.4 (index = 174)
# Log prior: min -506.1 (index = 495), max = -51.46 (index = 181)
# Weights: min = 0.0 (index = 2), max = 0.0349 (index = 970)
# ESS = 112 (11.226%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 300
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 72: Epsilon = 67.2
# Std loc: min = 9.29, max = 10.7
# Std glob = 1.0
# Simulating...
# NUMBER OF SIMULATIONS: 13523280/15000000
# Number of simulations: 2.10E+04 (Accept rate 4.76190%)
# Weight update...
# DISTANCE VALUES: MIN = 16.3, MAX = 67.2 MEAN = 56.2
# Log Denominateur: min = -62.3 (index = 75), max = -53.4 (index = 953)
# Log prior: min -4.999e+03 (index = 372), max = -51.87 (index = 850)
# Weights: min = 0.0 (index = 79), max = 0.0269 (index = 572)
# ESS = 116 (11.619%)
# Resampling...
# Number of unique index:  6 1
# Number of unique particles: 282
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 73: Epsilon = 66.9
# Std loc: min = 8.97, max = 11.2
# Std glob = 0.847
# Simulating...
# NUMBER OF SIMULATIONS: 13782525/15000000
# Number of simulations: 1.73E+04 (Accept rate 5.78603%)
# Weight update...
# DISTANCE VALUES: MIN = 21.1, MAX = 66.9 MEAN = 56.4
# Log Denominateur: min = -65.5 (index = 301), max = -53.2 (index = 20)
# Log prior: min -396.5 (index = 888), max = -50.92 (index = 23)
# Weights: min = 0.0 (index = 146), max = 0.0526 (index = 23)
# ESS = 70 (6.962%)
# Resampling...
# Number of unique index:  0 1
# Number of unique particles: 279
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 74: Epsilon = 66.1
# Std loc: min = 9.13, max = 10.9
# Std glob = 0.976
# Simulating...
# NUMBER OF SIMULATIONS: 14088585/15000000
# Number of simulations: 2.04E+04 (Accept rate 4.90100%)
# Weight update...
# DISTANCE VALUES: MIN = 24.6, MAX = 66.1 MEAN = 55.6
# Log Denominateur: min = -63.8 (index = 790), max = -53.1 (index = 592)
# Log prior: min -1.786e+03 (index = 484), max = -51.65 (index = 592)
# Weights: min = 0.0 (index = 12), max = 0.0262 (index = 604)
# ESS = 152 (15.223%)
# Resampling...
# Number of unique index:  2 2
# Number of unique particles: 313
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 75: Epsilon = 65.2
# Std loc: min = 9.21, max = 10.8
# Std glob = 0.991
# Simulating...
# NUMBER OF SIMULATIONS: 14393895/15000000
# Number of simulations: 2.04E+04 (Accept rate 4.91304%)
# Weight update...
# DISTANCE VALUES: MIN = 16.8, MAX = 65.2 MEAN = 55.1
# Log Denominateur: min = -62.7 (index = 711), max = -53.5 (index = 704)
# Log prior: min -1.34e+03 (index = 42), max = -51.7 (index = 251)
# Weights: min = 0.0 (index = 42), max = 0.0514 (index = 251)
# ESS = 90 (9.028%)
# Resampling...
# Number of unique index:  0 4
# Number of unique particles: 311
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 76: Epsilon = 64.9
# Std loc: min = 8.79, max = 11.0
# Std glob = 0.86
# Simulating...
# NUMBER OF SIMULATIONS: 14697645/15000000
# Number of simulations: 2.02E+04 (Accept rate 4.93827%)
# Weight update...
# DISTANCE VALUES: MIN = 19.6, MAX = 64.9 MEAN = 54.9
# Log Denominateur: min = -63.3 (index = 223), max = -53.1 (index = 574)
# Log prior: min -1.729e+03 (index = 41), max = -51.96 (index = 540)
# Weights: min = 0.0 (index = 8), max = 0.0456 (index = 160)
# ESS = 97 (9.651%)
# Resampling...
# Number of unique index:  18 3
# Number of unique particles: 293
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 77: Epsilon = 64.2
# Std loc: min = 9.1, max = 10.6
# Std glob = 0.884
# Simulating...
# NUMBER OF SIMULATIONS: 14987100/15000000
# Number of simulations: 1.93E+04 (Accept rate 5.18215%)
# Weight update...
# DISTANCE VALUES: MIN = 21.3, MAX = 64.2 MEAN = 53.9
# Log Denominateur: min = -63.1 (index = 214), max = -52.8 (index = 146)
# Log prior: min -1.274e+03 (index = 667), max = -51.51 (index = 146)
# Weights: min = 0.0 (index = 29), max = 0.0866 (index = 225)
# ESS = 61 (6.139%)
# Resampling...
# Number of unique index:  1 4
# Number of unique particles: 283
# After resampling, new thetas shape: (1000, 15, 1)
#
# Iteration 78: Epsilon = 63.3
# Std loc: min = 8.57, max = 11.1
# Std glob = 1.69
# Simulating...
# NUMBER OF SIMULATIONS: 15302100/15000000
# Accept rate too low, we stop the algorithm
# Number of simulations: 2.10E+04 (Accept rate 4.76190%)
# Weight update...
# DISTANCE VALUES: MIN = 21.2, MAX = 63.3 MEAN = 53.4
# Log Denominateur: min = -63.6 (index = 307), max = -53.6 (index = 787)
# Log prior: min -1.519e+03 (index = 867), max = -52.26 (index = 864)
# Weights: min = 0.0 (index = 105), max = 0.0376 (index = 864)
# ESS = 103 (10.295%)
# Resampling...
# Number of unique index:  4 3
# Number of unique particles: 286
# After resampling, new thetas shape: (1000, 15, 1)

# %% [markdown]
# # Comparison

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# N_plot = 2

# f, ax = plt.subplots(1, N_plot + 1, figsize=(15, 5))
# if N_plot < K:
#     perm = np.random.permutation(K)
# else:
#     perm = np.arange(K)

# for i in range(N_plot):
#     k = perm[i]
#     sns.kdeplot(np.unique(mus_perm_van[dists_perm<epsilon, k]), ax=ax[i], label="Perm ABC vanilla")
#     # sns.kdeplot(np.unique(mus_van[:, k]), ax=ax[i], label="ABC vanilla")
#     # sns.kdeplot(np.unique(mus_smc[:, k]), ax=ax[i], label="ABC SMC")
#     sns.kdeplot(np.unique(mus_perm_smc[:, k]), ax=ax[i], label="Perm ABC SMC")
#     sns.kdeplot(np.unique(mus_os[:, k]), ax=ax[i], label="Perm ABC SMC OS")
#     sns.kdeplot(np.unique(mus_um[:, k]), ax=ax[i], label="Perm ABC SMC UM")
#     ax[i].axvline(true_theta.loc[0, k], color="black", linestyle="--")
#     ax[i].set_title("Component {}".format(k))
#     # ax[i].legend()
#     ax[i].set_xlabel(r"$\mu_{}$".format(k))
#     ax[i].set_ylabel("Density")

# sns.kdeplot(np.unique(betas_perm_van[dists_perm<epsilon]), ax=ax[-1], label="Perm ABC vanilla")
# # sns.kdeplot(np.unique(betas_van), ax=ax[-1], label="ABC vanilla")
# # sns.kdeplot(np.unique(betas_smc), ax=ax[-1], label="ABC SMC", fill=True)
# sns.kdeplot(np.unique(betas_perm_smc), ax=ax[-1], label="Perm ABC SMC")
# sns.kdeplot(np.unique(betas_os), ax=ax[-1], label="Perm ABC SMC OS")
# sns.kdeplot(np.unique(betas_um), ax=ax[-1], label="Perm ABC SMC UM")
# ax[-1].axvline(true_theta.glob[0], color="black", linestyle="--")
# ax[-1].set_title("Global parameter")
# ax[-1].legend()
# ax[-1].set_xlabel(r"$\beta$")
# ax[-1].set_ylabel("Density")
# ax[-1].set_xlim(0, 5)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Plot

# %%
n_sim_smc = np.array(out_smc["N_sim"])
n_sim_perm_smc = np.array(out_perm_smc["N_sim"])
epsilon_smc = np.array(out_smc["Eps_values"])
epsilon_perm_smc = np.array(out_perm_smc["Eps_values"])
unique_smc = np.array(out_smc["unique_part"])
unique_perm_smc = np.array(out_perm_smc["unique_part"])
epsilon_pmc = np.array(out_pmc["Eps_values"])
n_sim_pmc = np.array(out_pmc["N_sim"])
ess_pmc = np.array(out_pmc["Ess"])
unique_pmc = np.array(out_pmc["unique_part"])

# %%
epsilon_smc[0] = epsilon_smc[1]
epsilon_perm_smc[0] = epsilon_perm_smc[1]
epsilon_pmc[0] = epsilon_pmc[1]

# %%
len(n_sim_smc), len(unique_smc), len(epsilon_smc), len(n_sim_perm_smc), len(unique_perm_smc), len(epsilon_perm_smc), len(n_sim_pmc), len(epsilon_pmc), len(ess_pmc)
# Out:
# (1418, 1418, 1418, 1266, 1266, 1266, 79, 79, 79)

# %%
plt.plot(epsilon_pmc, n_sim_pmc, label="PMC")

# %%
plt.plot(epsilon_smc[1:], out_smc["Acc_rate"][1:], label="ABC SMC")
plt.plot(epsilon_perm_smc[1:], out_perm_smc["Acc_rate"][1:], label="permABC SMC")
plt.xscale("log")
plt.gca().invert_xaxis()
plt.xlabel("Epsilon")
plt.ylabel("Acceptance rate")
plt.axhline(0.015, color="black", linestyle="--")
plt.legend()

# %%
plt.plot(epsilon_perm_smc[1:], unique_perm_smc[1:], label="permABC SMC")
plt.plot(epsilon_smc[1:], unique_smc[1:], label="ABC SMC")
plt.xscale("log")
plt.gca().invert_xaxis()
plt.xlabel("Epsilon")
plt.ylabel("Unique particles")
plt.legend()

# %%
plt.plot(epsilon_smc, np.cumsum(n_sim_smc)/K/1000/unique_smc, label="ABC SMC")
plt.plot(epsilon_perm_smc, np.cumsum(n_sim_perm_smc)/K/1000/unique_perm_smc, label="permABC SMC")
plt.plot(np.sort(dists_perm)[::-1][100:], np.arange(1, N_points+1-100), label="permABC vanilla")
plt.plot(np.sort(dists_van[:,0])[::-1][100:], np.arange(1, N_points+1-100), label="ABC vanilla")
plt.yscale("log")
plt.xscale("log")

plt.ylabel("Number of simulations per unique particle")
plt.xlabel(r"$\epsilon$")

plt.legend()
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

# %%
N_sim_pmc = np.cumsum(n_sim_pmc)/K/unique_pmc/1000*N_sample
plt.plot(N_sim_pmc, epsilon_pmc, label="ABC-PMC")
plt.plot(N_sim_smc, epsilon_smc, label="ABC-SMC")
plt.legend()
plt.xscale("log")
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 N_sim_pmc = np.cumsum(n_sim_pmc)/K/unique_pmc/1000*N_sample
#       2 plt.plot(N_sim_pmc, epsilon_pmc, label="ABC-PMC")
#       3 plt.plot(N_sim_smc, epsilon_smc, label="ABC-SMC")
#
# NameError: name 'N_sample' is not defined

# %%
N_sample = 1000

alphas = np.logspace(0, -3, 10)
epsilons_van_perm = np.quantile(dists_perm, alphas)
epsilons_van = np.quantile(dists_van[:,0], alphas)

N_sims = N_sample/alphas

N_sim_pmc = np.cumsum(n_sim_pmc)/K/unique_pmc/1000*N_sample
N_sim_smc = np.cumsum(n_sim_smc)/K/unique_smc/1000*N_sample
N_sim_perm_smc = np.cumsum(n_sim_perm_smc)/K/unique_perm_smc/1000*N_sample


closest_index_smc = np.argmin(np.abs(N_sim_smc - N_sims[:, None]), axis=1)
closest_index_perm_smc = np.argmin(np.abs(N_sim_perm_smc - N_sims[:, None]), axis=1)
closest_index_pmc = np.argmin(np.abs(N_sim_pmc - N_sims[:, None]), axis=1)
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plt.plot(N_sims, np.quantile(dists_perm, alphas), label="permABC Vanilla", linestyle="-", marker="x")
plt.plot(N_sims, np.quantile(dists_van[:,0], alphas), label="ABC Vanilla", linestyle="--", marker="x")
plt.plot(N_sim_perm_smc[closest_index_perm_smc], epsilon_perm_smc[closest_index_perm_smc], label="permABC-SMC", linestyle="-", marker="o")
plt.plot(N_sim_smc[closest_index_smc], epsilon_smc[closest_index_smc], label="ABC-SMC", linestyle="--", marker="o")
plt.plot(N_sim_pmc[closest_index_pmc], epsilon_pmc[closest_index_pmc], label="ABC-PMC", linestyle="--", marker="o")

plt.yscale("log")
plt.xscale("log")
plt.xlabel("Number of simulations per {} unique particles".format(N_sample)) 
plt.ylabel(r"$\epsilon$")
plt.legend()
# plt.gca().invert_xaxis()

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 6))
plt.plot(N_sims, alphas, label="permABC Vanilla", linestyle="-", marker="x")
# plt.plot(N_sims, alphas, label="ABC Vanilla", linestyle="--", marker="x")
plt.plot(N_sim_perm_smc[closest_index_perm_smc], alphas, label="permABC-SMC", linestyle="-", marker="o")
# plt.plot(N_sim_smc[closest_index_smc], alphas, label="ABC-SMC", linestyle="--", marker="o")
# plt.plot(N_sim_pmc[closest_index_pmc], alphas, label="ABC-PMC", linestyle="--", marker="o")

# plt.yscale("log")
plt.xscale("log")
plt.xlabel("Number of simulations per {} unique particles".format(N_sample)) 
plt.ylabel(r"$\alpha$")
plt.legend()
# plt.gca().invert_xaxis()

# %%
import pickle

data_to_save = {
    "N_sample": N_sample,
    "alphas": alphas,
    "dists_perm": dists_perm,
    "dists_van": dists_van,
    "n_sim_pmc": n_sim_pmc,
    "n_sim_smc": n_sim_smc,
    "n_sim_perm_smc": n_sim_perm_smc,
    "epsilon_pmc": epsilon_pmc,
    "epsilon_smc": epsilon_smc,
    "epsilon_perm_smc": epsilon_perm_smc,
    "unique_pmc": unique_pmc,
    "unique_smc": unique_smc,
    "unique_perm_smc": unique_perm_smc,
}

with open("plot_comparison_vanilla_smc.pkl", "wb") as f:
    pickle.dump(data_to_save, f)

# %% [markdown]
# # Save outs

# %%
import lzma
import pickle

# Save out_smc
with lzma.open("out_smc.xz", "wb") as f:
    pickle.dump(out_smc, f)

# Save out_perm_smc
with lzma.open("out_perm_smc.xz", "wb") as f:
    pickle.dump(out_perm_smc, f)

# %%
# from tqdm.notebook import tqdm 
# N = 1000

# kernel = KernelTruncatedRW
# alphas = [.99,.95,.9,.95,.75,.5,.25,.1,.05,.01]
# nsim_perm_van = N/np.array(alphas)
# epsilons= np.quantile(dists_perm, alphas)
# alpha_L = .95
# alphas_M = [.9, .75, .5]
# M0s = [100, 50, 25]
# L0s = [1, 2, 3, 4]
# N_sims = {"OS": {}, "UM": {}, "SMC": []}

# for M0 in M0s:
#     N_sims["OS"][M0] = {}
#     for alpha_M in alphas_M:
#         N_sims["OS"][M0][alpha_M] = []
# for L0 in L0s:
#     N_sims["UM"][L0] = []
    
# Unique = {"OS": {}, "UM": {} , "SMC": []}
# for M0 in M0s:
#     Unique["OS"][M0] = {}
#     for alpha_M in alphas_M:
#         Unique["OS"][M0][alpha_M] = []
# for L0 in L0s:
#     Unique["UM"][L0] = []
    

# for epsilon in tqdm(epsilons):
#     print(epsilon)
#     key, subkey = random.split(key)
#     print("Perm ABC SMC")
#     out_perm_smc = perm_abc_smc(key = subkey, model = model, n_particles= N, epsilon_target= epsilon, y_obs = y_obs, kernel = kernel, verbose = 0)
#     N_sims["SMC"].append(np.sum(out_perm_smc["N_sim"]))
#     Unique["SMC"].append(len(np.unique(out_perm_smc["Thetas"][-1].loc, axis = 0)))
#     print("Perm ABC SMC OS")
#     for M0 in M0s:
#         for alpha_M in alphas_M:
#             key, subkey = random.split(key)
#             os = perm_abc_smc_os(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 0, M_0 = M0, duplicate= True, n_duplicate = 0, alpha_M = alpha_M)
#             N_sims["OS"][M0][alpha_M].append(np.sum(os["N_sim"]))
#             Unique["OS"][M0][alpha_M].append(len(np.unique(os["Thetas"][-1].loc, axis = 0)))
#     print("Perm ABC SMC UM")
#     for L0 in L0s:
#         key, subkey = random.split(key)
#         um = perm_abc_smc_um(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 0, L_0 = L0)
#         N_sims["UM"][L0].append(np.sum(um["N_sim"]))
#         Unique["UM"][L0].append(len(np.unique(um["Thetas"][-1].loc, axis = 0)))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 102.76838851928709
# Perm ABC SMC
# Perm ABC SMC OS
# (2000, 100) 2
# (2000, 91) 2
# (2000, 82) 2
# (2000, 74) 2
# (2000, 67) 2
# (2000, 61) 2
# (2000, 55) 2
# (2000, 50) 2
# (2000, 46) 2
# (2000, 42) 2
# (2000, 38) 2
# (2000, 35) 2
# (2000, 32) 2
# (2000, 29) 2
# (2000, 27) 2
# (2000, 25) 2
# (2000, 23) 2
# (3000, 21) 3
# (2000, 18) 2
# (2000, 17) 2
# (2000, 16) 2
# (2000, 15) 2
# (3000, 14) 3
# (3000, 13) 3
# (5000, 12) 5
# (9000, 11) 9
# (11000, 100) 11
# (10000, 77) 10
# (10000, 60) 10
# (11000, 47) 11
# (8000, 37) 8
# (6000, 30) 6
# (6000, 25) 6
# (6000, 21) 6
# (4000, 18) 4
# (5000, 16) 5
# (2000, 14) 2
# (3000, 13) 3
# (4000, 12) 4
# (8000, 11) 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 41
#      39 for alpha_M in alphas_M:
#      40     key, subkey = random.split(key)
# ---> 41     os = perm_abc_smc_os(key = subkey, model = model, n_particles= N, epsilon = epsilon, y_obs = y_obs, kernel = kernel, verbose = 0, M_0 = M0, duplicate= True, n_duplicate = 0, alpha_M = alpha_M)
#      42     N_sims["OS"][M0][alpha_M].append(np.sum(os["N_sim"]))
#      43     Unique["OS"][M0][alpha_M].append(len(np.unique(os["Thetas"][-1].loc, axis = 0)))
#
# File ~/Documents/Recherche/permABC_new/permABC/over_sampling.py:115, in perm_abc_smc_os(key, model, n_particles, y_obs, kernel, M_0, epsilon, alpha_epsilon, alpha_M, Final_iteration, alpha_resample, num_blocks_gibbs, update_weights_distance, verbose, duplicate, n_duplicate)
#     113 if duplicate:
#     114     if verbose>1: print("b) Duplicate particles")
# --> 115     thetas, zs, distance_values, ys_index, zs_index, weights = duplicate_particles(key = key, model = model, weights = weights, thetas = thetas, zs = zs, ys_index = ys_index, zs_index = zs_index, distance_values = distance_values, old_M = old_M, new_M = M, alpha_M = alpha_M, verbose = verbose, n_duplicate = n_duplicate)
#     117 alive = np.where(weights > 0.0)[0]
#     119 if old_M >K:
#
# File ~/Documents/Recherche/permABC_new/permABC/over_sampling.py:52, in duplicate_particles(key, model, weights, thetas, zs, ys_index, zs_index, distance_values, old_M, new_M, alpha_M, verbose, n_duplicate)
#      48     return thetas, zs, distance_values, ys_index, zs_index, weights
#      50 if verbose >1:print(f"Duplicating the {n_particles} alive particles in {n_duplicate} copies...")
# ---> 52 permutation_duplicates = random.permutation(key, np.repeat([np.arange(old_M)], n_duplicate*n_particles, axis=0), axis = 1, independent = True)
#      54 new_thetas = thetas[alive].copy()
#      55 new_thetas = new_thetas.duplicate(n_duplicate, permutation_duplicates)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/random.py:545, in permutation(key, x, axis, independent)
#     543   return _shuffle(key, jnp.arange(r), axis)
#     544 if independent or np.ndim(x) == 1:
# --> 545   return _shuffle(key, x, axis)
#     546 ind = _shuffle(key, jnp.arange(x.shape[axis]), 0)  # type: ignore[union-attr]
#     547 return jnp.take(x, ind, axis, unique_indices=True)
#
#     [... skipping hidden 1 frame]
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:332, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     330 @api_boundary
#     331 def cache_miss(*args, **kwargs):
# --> 332   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     333       fun, jit_info, *args, **kwargs)
#     334   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     335   pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:190, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     187   args_flat = [*init_states, *args_flat]
#     189 try:
# --> 190   out_flat = pjit_p.bind(*args_flat, **p.params)
#     191 except pxla.DeviceAssignmentMismatchError as e:
#     192   fails, = e.args
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/core.py:939, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     937   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     938 else:
# --> 939   return primitive.impl(*tracers, **params)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:1730, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1727 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1728 has_explicit_sharding = _pjit_explicit_sharding(
#    1729     in_shardings, out_shardings, None, None)
# -> 1730 return xc._xla.pjit(
#    1731     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1732     tree_util.dispatch_registry,
#    1733     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1734     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:1712, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1711 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1712   out_flat, compiled = _pjit_call_impl_python(
#    1713       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1714       out_shardings=out_shardings, in_layouts=in_layouts,
#    1715       out_layouts=out_layouts, resource_env=resource_env,
#    1716       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1717       inline=inline)
#    1718   pgle_profiler = _read_pgle_profiler(jaxpr)
#    1719   fastpath_data = _get_fastpath_data(
#    1720       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1721       jaxpr.consts, None, pgle_profiler)
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/pjit.py:1666, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1658   distributed_debug_log(("Running pjit'd function", name),
#    1659                         ("in_shardings", in_shardings),
#    1660                         ("out_shardings", out_shardings),
#    (...)
#    1663                         ("abstract args", map(xla.abstractify, args)),
#    1664                         ("fingerprint", fingerprint))
#    1665 try:
# -> 1666   return compiled.unsafe_call(*args), compiled
#    1667 except FloatingPointError as e:
#    1668   assert config.debug_nans.value or config.debug_infs.value  # compiled_fun can only raise in this case
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.pyenv/versions/3.10.13/envs/jax_env/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1248, in ExecuteReplicated.__call__(self, *args)
#    1246   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1247 else:
# -> 1248   results = self.xla_executable.execute_sharded(input_bufs)
#    1250 if dispatch.needs_check_special():
#    1251   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:

# %% [markdown]
# Probleme permSMC ? Acc plus faible que OS et UM pour meme epsilon!!!
